# %% [markdown]
# #Architecture comparison for a LSTM recurrent neural network based integrator

# %%
import sys
sys.path.append('..')
import random
import numpy as np
from matplotlib import pyplot as plt
from Code.dynamical_system import *
from Code.time_integrator import *
from Code.neuralnet import *


np.random.seed(2512517)
random.seed(2512517)
tf.random.set_seed(2512517)

# %% [markdown]
# ##Recurrent neural network integrator
# This notebook helps determine the optimal architecture (number and configuration of dense / LSTM layers, number of units per layer) for a LSTM recurrent neural network based integrator with a $4$-step method.

# %% [markdown]
# Set system parameters, construct dynamical system and integrator.
#
# The model system we are using here is the harmonic oscillator, defined by the equations of motion
#
# $$
# \frac{dx}{dt} = v,\qquad\qquad
# \frac{dv}{dt} = -\frac{k}{m}x
# $$
#
# The timestep size of the Neural network integrator is set to $\Delta t=40\Delta t_{\text{Verlet}}$ where $\Delta t_{\text{Verlet}}$ is the step size of the Verlet integrator that is used for training.

# %%
# mass of particle
mass = 1.2
# spring constant of harmonic oscillator
k_spring = 0.9
# timestep for Verlet integrator
dt_verlet = 0.005
# timestep for neural network integrator
dt = 0.2
# number of steps for neural network integrator
nsteps = 4

harmonic_oscillator = HarmonicOscillator(mass,k_spring)
verlet_integrator = VerletIntegrator(harmonic_oscillator,dt_verlet)
lstm_integrator_1 = LSTMIntegrator(harmonic_oscillator,nsteps,dt)
lstm_integrator_2 = LSTM2Integrator(harmonic_oscillator,nsteps,dt)
lstm_integrator_3 = LSTM3Integrator(harmonic_oscillator,nsteps,dt)
lstm_integrator_4 = LSTM4Integrator(harmonic_oscillator,nsteps,dt)
lstm_integrator_5 = LSTM5Integrator(harmonic_oscillator,nsteps,dt)
lstm_integrator_6 = LSTM6Integrator(harmonic_oscillator,nsteps,dt)
lstm_integrator_7 = LSTM7Integrator(harmonic_oscillator,nsteps,dt)
lstm_integrator_8 = LSTM8Integrator(harmonic_oscillator,nsteps,dt)

# visualise the neural network model
lstm_integrator_1.model.summary()
keras.utils.plot_model(lstm_integrator_1.model, show_shapes=True)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 4, 2)]       0           []
#
#  lstm (LSTM)                    (None, 4, 32)        4480        ['input_1[0][0]']
#
#  lstm_1 (LSTM)                  (None, 32)           8320        ['lstm[0][0]']
#
#  dense (Dense)                  (None, 2)            66          ['lstm_1[0][0]']
#
#  tf.unstack (TFOpLambda)        [(None, 2),          0           ['input_1[0][0]']
#                                  (None, 2),
#                                  (None, 2),
#                                  (None, 2)]
#
#  rescaling (Rescaling)          (None, 2)            0           ['dense[0][0]']
#
#  add (Add)                      (None, 2)            0           ['tf.unstack[0][3]',
#                                                                   'rescaling[0][0]']
#
# ==================================================================================================
# Total params: 12,866
# Trainable params: 12,866
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
BATCH_SIZE=32
data_generator = DataGenerator(lstm_integrator_1,verlet_integrator)


train_batches = data_generator.dataset.batch(BATCH_SIZE)

# %% [markdown]
# ## Train neural network based integrator

# %%
EPOCHS=100
STEPS_PER_EPOCH=100
log_dir = './tb_logs/'
tensorboard_cb = tf.keras.callbacks.TensorBoard(log_dir=log_dir)

result_1 = lstm_integrator_1.model.fit(train_batches,epochs=EPOCHS,steps_per_epoch=STEPS_PER_EPOCH,
                                 callbacks=tensorboard_cb)
result_2 = lstm_integrator_2.model.fit(train_batches,epochs=EPOCHS,steps_per_epoch=STEPS_PER_EPOCH,
                                 callbacks=tensorboard_cb)
result_3 = lstm_integrator_3.model.fit(train_batches,epochs=EPOCHS,steps_per_epoch=STEPS_PER_EPOCH,
                                callbacks=tensorboard_cb)
result_4 = lstm_integrator_4.model.fit(train_batches,epochs=EPOCHS,steps_per_epoch=STEPS_PER_EPOCH,
                                 callbacks=tensorboard_cb)
result_5 = lstm_integrator_5.model.fit(train_batches,epochs=EPOCHS,steps_per_epoch=STEPS_PER_EPOCH,
                                 callbacks=tensorboard_cb)
result_6 = lstm_integrator_6.model.fit(train_batches,epochs=EPOCHS,steps_per_epoch=STEPS_PER_EPOCH,
                                 callbacks=tensorboard_cb)
result_7 = lstm_integrator_7.model.fit(train_batches,epochs=EPOCHS,steps_per_epoch=STEPS_PER_EPOCH,
                                 callbacks=tensorboard_cb)
result_8 = lstm_integrator_8.model.fit(train_batches,epochs=EPOCHS,steps_per_epoch=STEPS_PER_EPOCH,
                                 callbacks=tensorboard_cb)
# Out:
# Epoch 1/100
# 100/100 [==============================] - 11s 79ms/step - loss: 0.0472
# Epoch 2/100
# 100/100 [==============================] - 8s 78ms/step - loss: 0.0028
# Epoch 3/100
# 100/100 [==============================] - 8s 78ms/step - loss: 0.0011
# Epoch 4/100
# 100/100 [==============================] - 8s 78ms/step - loss: 5.2299e-04
# Epoch 5/100
# 100/100 [==============================] - 8s 81ms/step - loss: 3.1515e-04
# Epoch 6/100
# 100/100 [==============================] - 8s 78ms/step - loss: 2.4830e-04
# Epoch 7/100
# 100/100 [==============================] - 8s 78ms/step - loss: 1.3463e-04
# Epoch 8/100
# 100/100 [==============================] - 8s 78ms/step - loss: 1.4338e-04
# Epoch 9/100
# 100/100 [==============================] - 8s 82ms/step - loss: 4.7329e-05
# Epoch 10/100
# 100/100 [==============================] - 8s 78ms/step - loss: 4.2435e-05
# Epoch 11/100
# 100/100 [==============================] - 8s 84ms/step - loss: 6.7620e-05
# Epoch 12/100
# 100/100 [==============================] - 8s 84ms/step - loss: 5.9074e-05
# Epoch 13/100
# 100/100 [==============================] - 8s 78ms/step - loss: 2.7761e-05
# Epoch 14/100
# 100/100 [==============================] - 8s 79ms/step - loss: 3.1677e-05
# Epoch 15/100
# 100/100 [==============================] - 8s 78ms/step - loss: 3.7199e-05
# Epoch 16/100
# 100/100 [==============================] - 8s 78ms/step - loss: 3.7060e-05
# Epoch 17/100
# 100/100 [==============================] - 8s 78ms/step - loss: 1.8388e-05
# Epoch 18/100
# 100/100 [==============================] - 8s 78ms/step - loss: 1.8519e-05
# Epoch 19/100
# 100/100 [==============================] - 8s 78ms/step - loss: 2.3323e-05
# Epoch 20/100
# 100/100 [==============================] - 8s 78ms/step - loss: 1.7222e-05
# Epoch 21/100
# 100/100 [==============================] - 8s 79ms/step - loss: 3.4812e-05
# Epoch 22/100
# 100/100 [==============================] - 8s 78ms/step - loss: 1.1698e-05
# Epoch 23/100
# 100/100 [==============================] - 8s 78ms/step - loss: 2.4216e-05
# Epoch 24/100
# 100/100 [==============================] - 8s 79ms/step - loss: 6.5415e-06
# Epoch 25/100
# 100/100 [==============================] - 8s 79ms/step - loss: 1.3567e-05
# Epoch 26/100
# 100/100 [==============================] - 8s 80ms/step - loss: 2.0307e-05
# Epoch 27/100
# 100/100 [==============================] - 8s 79ms/step - loss: 2.2062e-05
# Epoch 28/100
# 100/100 [==============================] - 8s 78ms/step - loss: 5.4618e-06
# Epoch 29/100
# 100/100 [==============================] - 8s 79ms/step - loss: 4.2298e-06
# Epoch 30/100
# 100/100 [==============================] - 8s 79ms/step - loss: 7.2489e-06
# Epoch 31/100
# 100/100 [==============================] - 8s 79ms/step - loss: 3.8510e-05
# Epoch 32/100
# 100/100 [==============================] - 8s 80ms/step - loss: 6.5512e-06
# Epoch 33/100
# 100/100 [==============================] - 8s 79ms/step - loss: 7.0573e-06
# Epoch 34/100
# 100/100 [==============================] - 8s 80ms/step - loss: 3.3591e-06
# Epoch 35/100
# 100/100 [==============================] - 8s 79ms/step - loss: 4.1692e-06
# Epoch 36/100
# 100/100 [==============================] - 8s 79ms/step - loss: 8.8464e-06
# Epoch 37/100
# 100/100 [==============================] - 8s 79ms/step - loss: 6.2890e-06
# Epoch 38/100
# 100/100 [==============================] - 8s 79ms/step - loss: 6.3323e-06
# Epoch 39/100
# 100/100 [==============================] - 8s 79ms/step - loss: 2.0824e-06
# Epoch 40/100
# 100/100 [==============================] - 8s 79ms/step - loss: 1.2478e-05
# Epoch 41/100
# 100/100 [==============================] - 8s 81ms/step - loss: 3.6046e-05
# Epoch 42/100
# 100/100 [==============================] - 8s 82ms/step - loss: 1.6324e-05
# Epoch 43/100
# 100/100 [==============================] - 8s 80ms/step - loss: 1.0042e-05
# Epoch 44/100
# 100/100 [==============================] - 8s 80ms/step - loss: 3.0087e-06
# Epoch 45/100
# 100/100 [==============================] - 8s 79ms/step - loss: 6.1249e-06
# Epoch 46/100
# 100/100 [==============================] - 8s 80ms/step - loss: 3.1933e-06
# Epoch 47/100
# 100/100 [==============================] - 8s 80ms/step - loss: 1.9045e-06
# Epoch 48/100
# 100/100 [==============================] - 8s 80ms/step - loss: 2.8449e-06
# Epoch 49/100
# 100/100 [==============================] - 8s 80ms/step - loss: 2.7800e-06
# Epoch 50/100
# 100/100 [==============================] - 8s 80ms/step - loss: 4.0897e-06
# Epoch 51/100
# 100/100 [==============================] - 8s 79ms/step - loss: 5.8733e-06
# Epoch 52/100
# 100/100 [==============================] - 8s 80ms/step - loss: 5.9690e-06
# Epoch 53/100
# 100/100 [==============================] - 8s 79ms/step - loss: 1.6506e-05
# Epoch 54/100
# 100/100 [==============================] - 8s 80ms/step - loss: 2.2367e-05
# Epoch 55/100
# 100/100 [==============================] - 8s 80ms/step - loss: 9.0571e-06
# Epoch 56/100
# 100/100 [==============================] - 8s 79ms/step - loss: 2.7238e-06
# Epoch 57/100
# 100/100 [==============================] - 8s 79ms/step - loss: 2.6570e-06
# Epoch 58/100
# 100/100 [==============================] - 8s 80ms/step - loss: 1.1771e-05
# Epoch 59/100
# 100/100 [==============================] - 8s 80ms/step - loss: 6.4536e-06
# Epoch 60/100
# 100/100 [==============================] - 8s 79ms/step - loss: 2.0701e-06
# Epoch 61/100
# 100/100 [==============================] - 8s 79ms/step - loss: 4.8222e-06
# Epoch 62/100
# 100/100 [==============================] - 8s 80ms/step - loss: 2.2836e-06
# Epoch 63/100
# 100/100 [==============================] - 8s 80ms/step - loss: 2.7665e-05
# Epoch 64/100
# 100/100 [==============================] - 8s 81ms/step - loss: 2.2887e-05
# Epoch 65/100
# 100/100 [==============================] - 8s 80ms/step - loss: 1.5691e-05
# Epoch 66/100
# 100/100 [==============================] - 8s 79ms/step - loss: 2.8678e-06
# Epoch 67/100
# 100/100 [==============================] - 8s 79ms/step - loss: 8.3092e-07
# Epoch 68/100
# 100/100 [==============================] - 8s 79ms/step - loss: 2.9186e-06
# Epoch 69/100
# 100/100 [==============================] - 8s 80ms/step - loss: 3.5761e-06
# Epoch 70/100
# 100/100 [==============================] - 8s 80ms/step - loss: 1.3194e-06
# Epoch 71/100
# 100/100 [==============================] - 8s 80ms/step - loss: 1.4765e-06
# Epoch 72/100
# 100/100 [==============================] - 8s 80ms/step - loss: 1.0427e-05
# Epoch 73/100
# 100/100 [==============================] - 8s 80ms/step - loss: 4.2167e-06
# Epoch 74/100
# 100/100 [==============================] - 8s 80ms/step - loss: 2.1691e-06
# Epoch 75/100
# 100/100 [==============================] - 8s 80ms/step - loss: 8.5859e-07
# Epoch 76/100
# 100/100 [==============================] - 8s 81ms/step - loss: 1.3831e-06
# Epoch 77/100
# 100/100 [==============================] - 8s 80ms/step - loss: 3.1413e-06
# Epoch 78/100
# 100/100 [==============================] - 8s 80ms/step - loss: 2.0618e-05
# Epoch 79/100
# 100/100 [==============================] - 8s 80ms/step - loss: 1.2423e-05
# Epoch 80/100
# 100/100 [==============================] - 8s 80ms/step - loss: 2.7427e-06
# Epoch 81/100
# 100/100 [==============================] - 8s 80ms/step - loss: 1.1328e-05
# Epoch 82/100
# 100/100 [==============================] - 8s 80ms/step - loss: 3.0168e-05
# Epoch 83/100
# 100/100 [==============================] - 8s 80ms/step - loss: 1.2672e-05
# Epoch 84/100
# 100/100 [==============================] - 8s 80ms/step - loss: 6.8708e-06
# Epoch 85/100
# 100/100 [==============================] - 8s 80ms/step - loss: 1.8299e-06
# Epoch 86/100
# 100/100 [==============================] - 8s 80ms/step - loss: 3.6397e-06
# Epoch 87/100
# 100/100 [==============================] - 8s 79ms/step - loss: 8.9457e-06
# Epoch 88/100
# 100/100 [==============================] - 8s 80ms/step - loss: 2.2531e-06
# Epoch 89/100
# 100/100 [==============================] - 8s 80ms/step - loss: 1.1630e-06
# Epoch 90/100
# 100/100 [==============================] - 8s 80ms/step - loss: 3.5269e-06
# Epoch 91/100
# 100/100 [==============================] - 8s 80ms/step - loss: 1.6535e-06
# Epoch 92/100
# 100/100 [==============================] - 8s 80ms/step - loss: 4.2076e-06
# Epoch 93/100
# 100/100 [==============================] - 8s 80ms/step - loss: 2.3816e-06
# Epoch 94/100
# 100/100 [==============================] - 8s 80ms/step - loss: 1.7658e-06
# Epoch 95/100
# 100/100 [==============================] - 8s 80ms/step - loss: 5.4588e-06
# Epoch 96/100
# 100/100 [==============================] - 8s 80ms/step - loss: 2.0191e-05
# Epoch 97/100
# 100/100 [==============================] - 8s 80ms/step - loss: 1.4440e-05
# Epoch 98/100
# 100/100 [==============================] - 8s 79ms/step - loss: 5.3216e-07
# Epoch 99/100
# 100/100 [==============================] - 8s 80ms/step - loss: 1.0284e-06
# Epoch 100/100
# 100/100 [==============================] - 8s 79ms/step - loss: 3.3484e-06
# Epoch 1/100
# 100/100 [==============================] - 12s 81ms/step - loss: 0.0229
# Epoch 2/100
# 100/100 [==============================] - 8s 81ms/step - loss: 5.7334e-04
# Epoch 3/100
# 100/100 [==============================] - 8s 82ms/step - loss: 2.5740e-04
# Epoch 4/100
# 100/100 [==============================] - 8s 81ms/step - loss: 1.6604e-04
# Epoch 5/100
# 100/100 [==============================] - 8s 81ms/step - loss: 9.4307e-05
# Epoch 6/100
# 100/100 [==============================] - 8s 81ms/step - loss: 4.6771e-05
# Epoch 7/100
# 100/100 [==============================] - 8s 81ms/step - loss: 2.9657e-05
# Epoch 8/100
# 100/100 [==============================] - 8s 81ms/step - loss: 2.1847e-05
# Epoch 9/100
# 100/100 [==============================] - 8s 81ms/step - loss: 2.0130e-05
# Epoch 10/100
# 100/100 [==============================] - 8s 81ms/step - loss: 2.2378e-05
# Epoch 11/100
# 100/100 [==============================] - 8s 82ms/step - loss: 3.9148e-05
# Epoch 12/100
# 100/100 [==============================] - 8s 82ms/step - loss: 1.9062e-05
# Epoch 13/100
# 100/100 [==============================] - 8s 82ms/step - loss: 2.4564e-05
# Epoch 14/100
# 100/100 [==============================] - 8s 81ms/step - loss: 1.5009e-05
# Epoch 15/100
# 100/100 [==============================] - 8s 81ms/step - loss: 9.1350e-06
# Epoch 16/100
# 100/100 [==============================] - 8s 81ms/step - loss: 1.5426e-05
# Epoch 17/100
# 100/100 [==============================] - 8s 81ms/step - loss: 3.7646e-05
# Epoch 18/100
# 100/100 [==============================] - 8s 80ms/step - loss: 2.2517e-05
# Epoch 19/100
# 100/100 [==============================] - 8s 80ms/step - loss: 1.9664e-05
# Epoch 20/100
# 100/100 [==============================] - 8s 82ms/step - loss: 8.0455e-06
# Epoch 21/100
# 100/100 [==============================] - 8s 81ms/step - loss: 6.3332e-06
# Epoch 22/100
# 100/100 [==============================] - 8s 81ms/step - loss: 5.2765e-06
# Epoch 23/100
# 100/100 [==============================] - 8s 81ms/step - loss: 1.0791e-05
# Epoch 24/100
# 100/100 [==============================] - 8s 82ms/step - loss: 1.0577e-05
# Epoch 25/100
# 100/100 [==============================] - 8s 82ms/step - loss: 1.2506e-05
# Epoch 26/100
# 100/100 [==============================] - 8s 81ms/step - loss: 1.1068e-05
# Epoch 27/100
# 100/100 [==============================] - 8s 82ms/step - loss: 3.9617e-06
# Epoch 28/100
# 100/100 [==============================] - 8s 82ms/step - loss: 3.5168e-06
# Epoch 29/100
# 100/100 [==============================] - 8s 82ms/step - loss: 3.0301e-06
# Epoch 30/100
# 100/100 [==============================] - 8s 81ms/step - loss: 1.3860e-05
# Epoch 31/100
# 100/100 [==============================] - 8s 82ms/step - loss: 7.9657e-06
# Epoch 32/100
# 100/100 [==============================] - 8s 82ms/step - loss: 1.2112e-05
# Epoch 33/100
# 100/100 [==============================] - 8s 82ms/step - loss: 1.4673e-05
# Epoch 34/100
# 100/100 [==============================] - 8s 82ms/step - loss: 1.1655e-05
# Epoch 35/100
# 100/100 [==============================] - 8s 82ms/step - loss: 1.3764e-05
# Epoch 36/100
# 100/100 [==============================] - 8s 82ms/step - loss: 9.6397e-06
# Epoch 37/100
# 100/100 [==============================] - 8s 82ms/step - loss: 5.1708e-06
# Epoch 38/100
# 100/100 [==============================] - 8s 81ms/step - loss: 4.8687e-06
# Epoch 39/100
# 100/100 [==============================] - 8s 81ms/step - loss: 7.3171e-06
# Epoch 40/100
# 100/100 [==============================] - 8s 82ms/step - loss: 1.0546e-05
# Epoch 41/100
# 100/100 [==============================] - 8s 82ms/step - loss: 3.2822e-05
# Epoch 42/100
# 100/100 [==============================] - 8s 82ms/step - loss: 1.4597e-05
# Epoch 43/100
# 100/100 [==============================] - 8s 82ms/step - loss: 2.4472e-06
# Epoch 44/100
# 100/100 [==============================] - 8s 82ms/step - loss: 3.7402e-06
# Epoch 45/100
# 100/100 [==============================] - 8s 81ms/step - loss: 2.9641e-06
# Epoch 46/100
# 100/100 [==============================] - 8s 81ms/step - loss: 1.3581e-05
# Epoch 47/100
# 100/100 [==============================] - 8s 82ms/step - loss: 3.7383e-05
# Epoch 48/100
# 100/100 [==============================] - 8s 82ms/step - loss: 1.1292e-05
# Epoch 49/100
# 100/100 [==============================] - 8s 81ms/step - loss: 4.1290e-06
# Epoch 50/100
# 100/100 [==============================] - 8s 82ms/step - loss: 6.6091e-06
# Epoch 51/100
# 100/100 [==============================] - 8s 82ms/step - loss: 4.1280e-06
# Epoch 52/100
# 100/100 [==============================] - 8s 81ms/step - loss: 8.0812e-06
# Epoch 53/100
# 100/100 [==============================] - 8s 82ms/step - loss: 7.8303e-05
# Epoch 54/100
# 100/100 [==============================] - 8s 82ms/step - loss: 2.8677e-05
# Epoch 55/100
# 100/100 [==============================] - 8s 82ms/step - loss: 3.4589e-06
# Epoch 56/100
# 100/100 [==============================] - 8s 82ms/step - loss: 1.2054e-06
# Epoch 57/100
# 100/100 [==============================] - 8s 82ms/step - loss: 2.4781e-06
# Epoch 58/100
# 100/100 [==============================] - 8s 82ms/step - loss: 4.5539e-06
# Epoch 59/100
# 100/100 [==============================] - 8s 82ms/step - loss: 1.8414e-05
# Epoch 60/100
# 100/100 [==============================] - 8s 82ms/step - loss: 5.0096e-06
# Epoch 61/100
# 100/100 [==============================] - 8s 82ms/step - loss: 3.4478e-06
# Epoch 62/100
# 100/100 [==============================] - 8s 82ms/step - loss: 3.3018e-06
# Epoch 63/100
# 100/100 [==============================] - 8s 82ms/step - loss: 4.9834e-06
# Epoch 64/100
# 100/100 [==============================] - 8s 81ms/step - loss: 4.6057e-06
# Epoch 65/100
# 100/100 [==============================] - 8s 82ms/step - loss: 9.4307e-06
# Epoch 66/100
# 100/100 [==============================] - 8s 81ms/step - loss: 7.8194e-06
# Epoch 67/100
# 100/100 [==============================] - 8s 82ms/step - loss: 3.6068e-05
# Epoch 68/100
# 100/100 [==============================] - 8s 81ms/step - loss: 9.7964e-05
# Epoch 69/100
# 100/100 [==============================] - 8s 81ms/step - loss: 1.4684e-05
# Epoch 70/100
# 100/100 [==============================] - 8s 82ms/step - loss: 1.2958e-05
# Epoch 71/100
# 100/100 [==============================] - 8s 82ms/step - loss: 8.9412e-06
# Epoch 72/100
# 100/100 [==============================] - 8s 81ms/step - loss: 4.7447e-07
# Epoch 73/100
# 100/100 [==============================] - 8s 82ms/step - loss: 1.1360e-06
# Epoch 74/100
# 100/100 [==============================] - 8s 82ms/step - loss: 4.8655e-06
# Epoch 75/100
# 100/100 [==============================] - 8s 82ms/step - loss: 3.1460e-06
# Epoch 76/100
# 100/100 [==============================] - 8s 81ms/step - loss: 1.9270e-06
# Epoch 77/100
# 100/100 [==============================] - 8s 81ms/step - loss: 1.8812e-06
# Epoch 78/100
# 100/100 [==============================] - 8s 83ms/step - loss: 7.8056e-06
# Epoch 79/100
# 100/100 [==============================] - 8s 83ms/step - loss: 2.5291e-06
# Epoch 80/100
# 100/100 [==============================] - 8s 82ms/step - loss: 1.8050e-05
# Epoch 81/100
# 100/100 [==============================] - 8s 82ms/step - loss: 6.3218e-05
# Epoch 82/100
# 100/100 [==============================] - 8s 82ms/step - loss: 2.6346e-05
# Epoch 83/100
# 100/100 [==============================] - 8s 82ms/step - loss: 9.3059e-06
# Epoch 84/100
# 100/100 [==============================] - 8s 83ms/step - loss: 1.4564e-05
# Epoch 85/100
# 100/100 [==============================] - 8s 81ms/step - loss: 8.8948e-07
# Epoch 86/100
# 100/100 [==============================] - 8s 82ms/step - loss: 2.1496e-06
# Epoch 87/100
# 100/100 [==============================] - 8s 82ms/step - loss: 1.6548e-05
# Epoch 88/100
# 100/100 [==============================] - 8s 82ms/step - loss: 1.7210e-06
# Epoch 89/100
# 100/100 [==============================] - 8s 83ms/step - loss: 1.4503e-06
# Epoch 90/100
# 100/100 [==============================] - 8s 83ms/step - loss: 6.4433e-07
# Epoch 91/100
# 100/100 [==============================] - 8s 83ms/step - loss: 1.7171e-06
# Epoch 92/100
# 100/100 [==============================] - 8s 84ms/step - loss: 3.0123e-06
# Epoch 93/100
# 100/100 [==============================] - 8s 84ms/step - loss: 1.0232e-05
# Epoch 94/100
# 100/100 [==============================] - 8s 83ms/step - loss: 1.6479e-05
# Epoch 95/100
# 100/100 [==============================] - 8s 82ms/step - loss: 2.4357e-06
# Epoch 96/100
# 100/100 [==============================] - 8s 83ms/step - loss: 9.9380e-07
# Epoch 97/100
# 100/100 [==============================] - 8s 83ms/step - loss: 5.7452e-05
# Epoch 98/100
# 100/100 [==============================] - 8s 83ms/step - loss: 5.2823e-05
# Epoch 99/100
# 100/100 [==============================] - 8s 83ms/step - loss: 3.8941e-06
# Epoch 100/100
# 100/100 [==============================] - 8s 83ms/step - loss: 1.4040e-06
# Epoch 1/100
# 100/100 [==============================] - 12s 82ms/step - loss: 0.0743
# Epoch 2/100
# 100/100 [==============================] - 8s 82ms/step - loss: 0.0113
# Epoch 3/100
# 100/100 [==============================] - 8s 82ms/step - loss: 0.0029
# Epoch 4/100
# 100/100 [==============================] - 8s 82ms/step - loss: 0.0016
# Epoch 5/100
# 100/100 [==============================] - 8s 82ms/step - loss: 0.0011
# Epoch 6/100
# 100/100 [==============================] - 8s 82ms/step - loss: 7.8304e-04
# Epoch 7/100
# 100/100 [==============================] - 8s 81ms/step - loss: 5.3913e-04
# Epoch 8/100
# 100/100 [==============================] - 8s 82ms/step - loss: 2.9332e-04
# Epoch 9/100
# 100/100 [==============================] - 8s 81ms/step - loss: 2.8060e-04
# Epoch 10/100
# 100/100 [==============================] - 8s 83ms/step - loss: 1.7514e-04
# Epoch 11/100
# 100/100 [==============================] - 8s 83ms/step - loss: 1.3437e-04
# Epoch 12/100
# 100/100 [==============================] - 8s 81ms/step - loss: 1.6583e-04
# Epoch 13/100
# 100/100 [==============================] - 8s 82ms/step - loss: 1.4521e-04
# Epoch 14/100
# 100/100 [==============================] - 8s 82ms/step - loss: 1.2206e-04
# Epoch 15/100
# 100/100 [==============================] - 8s 82ms/step - loss: 7.1535e-05
# Epoch 16/100
# 100/100 [==============================] - 8s 82ms/step - loss: 1.4488e-04
# Epoch 17/100
# 100/100 [==============================] - 8s 83ms/step - loss: 9.2278e-05
# Epoch 18/100
# 100/100 [==============================] - 8s 82ms/step - loss: 8.0557e-05
# Epoch 19/100
# 100/100 [==============================] - 8s 81ms/step - loss: 6.2048e-05
# Epoch 20/100
# 100/100 [==============================] - 8s 82ms/step - loss: 2.9486e-05
# Epoch 21/100
# 100/100 [==============================] - 8s 81ms/step - loss: 6.0039e-05
# Epoch 22/100
# 100/100 [==============================] - 8s 81ms/step - loss: 3.3470e-05
# Epoch 23/100
# 100/100 [==============================] - 8s 82ms/step - loss: 4.2563e-05
# Epoch 24/100
# 100/100 [==============================] - 8s 82ms/step - loss: 4.9809e-05
# Epoch 25/100
# 100/100 [==============================] - 8s 82ms/step - loss: 1.9429e-05
# Epoch 26/100
# 100/100 [==============================] - 8s 82ms/step - loss: 2.3731e-05
# Epoch 27/100
# 100/100 [==============================] - 8s 82ms/step - loss: 6.1692e-05
# Epoch 28/100
# 100/100 [==============================] - 8s 81ms/step - loss: 1.3898e-05
# Epoch 29/100
# 100/100 [==============================] - 8s 81ms/step - loss: 1.6090e-05
# Epoch 30/100
# 100/100 [==============================] - 8s 81ms/step - loss: 1.7453e-05
# Epoch 31/100
# 100/100 [==============================] - 8s 82ms/step - loss: 1.9089e-05
# Epoch 32/100
# 100/100 [==============================] - 8s 81ms/step - loss: 2.3523e-05
# Epoch 33/100
# 100/100 [==============================] - 8s 82ms/step - loss: 2.2665e-05
# Epoch 34/100
# 100/100 [==============================] - 8s 82ms/step - loss: 3.1055e-05
# Epoch 35/100
# 100/100 [==============================] - 8s 81ms/step - loss: 1.4268e-05
# Epoch 36/100
# 100/100 [==============================] - 8s 81ms/step - loss: 2.0934e-05
# Epoch 37/100
# 100/100 [==============================] - 8s 82ms/step - loss: 1.6005e-05
# Epoch 38/100
# 100/100 [==============================] - 8s 82ms/step - loss: 7.4604e-06
# Epoch 39/100
# 100/100 [==============================] - 8s 82ms/step - loss: 4.6576e-05
# Epoch 40/100
# 100/100 [==============================] - 8s 82ms/step - loss: 8.1310e-06
# Epoch 41/100
# 100/100 [==============================] - 8s 82ms/step - loss: 2.2094e-05
# Epoch 42/100
# 100/100 [==============================] - 8s 82ms/step - loss: 1.6218e-05
# Epoch 43/100
# 100/100 [==============================] - 8s 81ms/step - loss: 1.2523e-05
# Epoch 44/100
# 100/100 [==============================] - 8s 82ms/step - loss: 4.1091e-06
# Epoch 45/100
# 100/100 [==============================] - 8s 82ms/step - loss: 1.4245e-05
# Epoch 46/100
# 100/100 [==============================] - 8s 82ms/step - loss: 1.1796e-05
# Epoch 47/100
# 100/100 [==============================] - 8s 82ms/step - loss: 1.0696e-05
# Epoch 48/100
# 100/100 [==============================] - 8s 83ms/step - loss: 2.0498e-05
# Epoch 49/100
# 100/100 [==============================] - 8s 84ms/step - loss: 2.1159e-05
# Epoch 50/100
# 100/100 [==============================] - 8s 82ms/step - loss: 9.7795e-06
# Epoch 51/100
# 100/100 [==============================] - 8s 82ms/step - loss: 3.0701e-06
# Epoch 52/100
# 100/100 [==============================] - 8s 82ms/step - loss: 5.3028e-06
# Epoch 53/100
# 100/100 [==============================] - 8s 82ms/step - loss: 3.3384e-05
# Epoch 54/100
# 100/100 [==============================] - 8s 81ms/step - loss: 1.9710e-05
# Epoch 55/100
# 100/100 [==============================] - 8s 81ms/step - loss: 2.1730e-05
# Epoch 56/100
# 100/100 [==============================] - 8s 81ms/step - loss: 1.9602e-05
# Epoch 57/100
# 100/100 [==============================] - 8s 81ms/step - loss: 6.2913e-06
# Epoch 58/100
# 100/100 [==============================] - 8s 81ms/step - loss: 7.3306e-06
# Epoch 59/100
# 100/100 [==============================] - 8s 81ms/step - loss: 7.9711e-06
# Epoch 60/100
# 100/100 [==============================] - 8s 81ms/step - loss: 1.7769e-05
# Epoch 61/100
# 100/100 [==============================] - 8s 82ms/step - loss: 7.5246e-06
# Epoch 62/100
# 100/100 [==============================] - 8s 81ms/step - loss: 1.1013e-05
# Epoch 63/100
# 100/100 [==============================] - 8s 82ms/step - loss: 9.2831e-06
# Epoch 64/100
# 100/100 [==============================] - 8s 83ms/step - loss: 2.9176e-06
# Epoch 65/100
# 100/100 [==============================] - 8s 83ms/step - loss: 3.6957e-05
# Epoch 66/100
# 100/100 [==============================] - 8s 83ms/step - loss: 1.5154e-05
# Epoch 67/100
# 100/100 [==============================] - 8s 83ms/step - loss: 5.3675e-06
# Epoch 68/100
# 100/100 [==============================] - 8s 83ms/step - loss: 1.8782e-05
# Epoch 69/100
# 100/100 [==============================] - 8s 82ms/step - loss: 5.4464e-06
# Epoch 70/100
# 100/100 [==============================] - 8s 83ms/step - loss: 1.4993e-05
# Epoch 71/100
# 100/100 [==============================] - 8s 82ms/step - loss: 1.1315e-05
# Epoch 72/100
# 100/100 [==============================] - 8s 81ms/step - loss: 2.5619e-06
# Epoch 73/100
# 100/100 [==============================] - 8s 82ms/step - loss: 7.0503e-06
# Epoch 74/100
# 100/100 [==============================] - 8s 82ms/step - loss: 1.0331e-05
# Epoch 75/100
# 100/100 [==============================] - 8s 81ms/step - loss: 2.2444e-05
# Epoch 76/100
# 100/100 [==============================] - 8s 82ms/step - loss: 1.9640e-05
# Epoch 77/100
# 100/100 [==============================] - 8s 82ms/step - loss: 2.1256e-06
# Epoch 78/100
# 100/100 [==============================] - 8s 82ms/step - loss: 3.6595e-06
# Epoch 79/100
# 100/100 [==============================] - 8s 82ms/step - loss: 6.5599e-06
# Epoch 80/100
# 100/100 [==============================] - 8s 82ms/step - loss: 3.1945e-06
# Epoch 81/100
# 100/100 [==============================] - 8s 82ms/step - loss: 4.7550e-06
# Epoch 82/100
# 100/100 [==============================] - 8s 82ms/step - loss: 7.8231e-06
# Epoch 83/100
# 100/100 [==============================] - 8s 83ms/step - loss: 1.8152e-05
# Epoch 84/100
# 100/100 [==============================] - 8s 82ms/step - loss: 1.0227e-05
# Epoch 85/100
# 100/100 [==============================] - 8s 82ms/step - loss: 1.5016e-05
# Epoch 86/100
# 100/100 [==============================] - 8s 83ms/step - loss: 1.1469e-05
# Epoch 87/100
# 100/100 [==============================] - 8s 83ms/step - loss: 3.9920e-05
# Epoch 88/100
# 100/100 [==============================] - 8s 81ms/step - loss: 7.5843e-06
# Epoch 89/100
# 100/100 [==============================] - 8s 82ms/step - loss: 1.0164e-05
# Epoch 90/100
# 100/100 [==============================] - 8s 82ms/step - loss: 1.5950e-05
# Epoch 91/100
# 100/100 [==============================] - 8s 82ms/step - loss: 1.0084e-06
# Epoch 92/100
# 100/100 [==============================] - 8s 82ms/step - loss: 2.1079e-06
# Epoch 93/100
# 100/100 [==============================] - 8s 83ms/step - loss: 1.1814e-05
# Epoch 94/100
# 100/100 [==============================] - 8s 82ms/step - loss: 1.7471e-05
# Epoch 95/100
# 100/100 [==============================] - 8s 82ms/step - loss: 4.5727e-06
# Epoch 96/100
# 100/100 [==============================] - 8s 82ms/step - loss: 1.2265e-05
# Epoch 97/100
# 100/100 [==============================] - 8s 82ms/step - loss: 9.6073e-06
# Epoch 98/100
# 100/100 [==============================] - 8s 82ms/step - loss: 6.1989e-06
# Epoch 99/100
# 100/100 [==============================] - 8s 82ms/step - loss: 3.3254e-05
# Epoch 100/100
# 100/100 [==============================] - 8s 82ms/step - loss: 2.1634e-05
# Epoch 1/100
# 100/100 [==============================] - 12s 84ms/step - loss: 0.0447
# Epoch 2/100
# 100/100 [==============================] - 8s 84ms/step - loss: 0.0050
# Epoch 3/100
# 100/100 [==============================] - 8s 83ms/step - loss: 0.0024
# Epoch 4/100
# 100/100 [==============================] - 8s 84ms/step - loss: 0.0019
# Epoch 5/100
# 100/100 [==============================] - 8s 84ms/step - loss: 0.0011
# Epoch 6/100
# 100/100 [==============================] - 8s 85ms/step - loss: 9.3775e-04
# Epoch 7/100
# 100/100 [==============================] - 8s 84ms/step - loss: 8.3601e-04
# Epoch 8/100
# 100/100 [==============================] - 8s 84ms/step - loss: 4.0594e-04
# Epoch 9/100
# 100/100 [==============================] - 8s 83ms/step - loss: 3.9350e-04
# Epoch 10/100
# 100/100 [==============================] - 8s 84ms/step - loss: 3.3110e-04
# Epoch 11/100
# 100/100 [==============================] - 8s 83ms/step - loss: 3.2783e-04
# Epoch 12/100
# 100/100 [==============================] - 8s 84ms/step - loss: 2.3713e-04
# Epoch 13/100
# 100/100 [==============================] - 8s 84ms/step - loss: 1.5344e-04
# Epoch 14/100
# 100/100 [==============================] - 8s 84ms/step - loss: 1.8414e-04
# Epoch 15/100
# 100/100 [==============================] - 8s 84ms/step - loss: 1.8256e-04
# Epoch 16/100
# 100/100 [==============================] - 8s 84ms/step - loss: 8.8577e-05
# Epoch 17/100
# 100/100 [==============================] - 8s 84ms/step - loss: 1.3960e-04
# Epoch 18/100
# 100/100 [==============================] - 8s 85ms/step - loss: 9.2057e-05
# Epoch 19/100
# 100/100 [==============================] - 8s 84ms/step - loss: 8.2672e-05
# Epoch 20/100
# 100/100 [==============================] - 8s 83ms/step - loss: 7.3087e-05
# Epoch 21/100
# 100/100 [==============================] - 8s 83ms/step - loss: 9.8619e-05
# Epoch 22/100
# 100/100 [==============================] - 8s 83ms/step - loss: 5.2309e-05
# Epoch 23/100
# 100/100 [==============================] - 8s 83ms/step - loss: 5.4661e-05
# Epoch 24/100
# 100/100 [==============================] - 8s 83ms/step - loss: 2.7395e-05
# Epoch 25/100
# 100/100 [==============================] - 8s 83ms/step - loss: 1.9641e-05
# Epoch 26/100
# 100/100 [==============================] - 8s 83ms/step - loss: 4.0474e-05
# Epoch 27/100
# 100/100 [==============================] - 8s 83ms/step - loss: 5.5538e-05
# Epoch 28/100
# 100/100 [==============================] - 8s 84ms/step - loss: 7.8821e-05
# Epoch 29/100
# 100/100 [==============================] - 8s 83ms/step - loss: 4.6653e-05
# Epoch 30/100
# 100/100 [==============================] - 8s 85ms/step - loss: 5.1259e-05
# Epoch 31/100
# 100/100 [==============================] - 8s 83ms/step - loss: 4.6904e-05
# Epoch 32/100
# 100/100 [==============================] - 8s 83ms/step - loss: 2.3454e-05
# Epoch 33/100
# 100/100 [==============================] - 8s 83ms/step - loss: 3.1504e-05
# Epoch 34/100
# 100/100 [==============================] - 8s 83ms/step - loss: 5.7297e-05
# Epoch 35/100
# 100/100 [==============================] - 8s 84ms/step - loss: 2.5987e-05
# Epoch 36/100
# 100/100 [==============================] - 8s 83ms/step - loss: 2.7470e-05
# Epoch 37/100
# 100/100 [==============================] - 8s 84ms/step - loss: 3.6784e-05
# Epoch 38/100
# 100/100 [==============================] - 8s 84ms/step - loss: 1.3516e-05
# Epoch 39/100
# 100/100 [==============================] - 8s 84ms/step - loss: 9.6980e-06
# Epoch 40/100
# 100/100 [==============================] - 8s 84ms/step - loss: 2.3995e-05
# Epoch 41/100
# 100/100 [==============================] - 8s 84ms/step - loss: 1.5342e-05
# Epoch 42/100
# 100/100 [==============================] - 8s 84ms/step - loss: 2.8395e-05
# Epoch 43/100
# 100/100 [==============================] - 8s 84ms/step - loss: 1.7429e-05
# Epoch 44/100
# 100/100 [==============================] - 8s 84ms/step - loss: 2.2577e-05
# Epoch 45/100
# 100/100 [==============================] - 8s 84ms/step - loss: 9.8215e-06
# Epoch 46/100
# 100/100 [==============================] - 8s 84ms/step - loss: 1.0779e-05
# Epoch 47/100
# 100/100 [==============================] - 8s 84ms/step - loss: 1.0966e-05
# Epoch 48/100
# 100/100 [==============================] - 8s 84ms/step - loss: 1.2266e-04
# Epoch 49/100
# 100/100 [==============================] - 8s 85ms/step - loss: 4.0397e-05
# Epoch 50/100
# 100/100 [==============================] - 8s 84ms/step - loss: 8.2807e-06
# Epoch 51/100
# 100/100 [==============================] - 8s 83ms/step - loss: 1.1059e-05
# Epoch 52/100
# 100/100 [==============================] - 8s 84ms/step - loss: 5.7372e-06
# Epoch 53/100
# 100/100 [==============================] - 8s 84ms/step - loss: 6.1443e-06
# Epoch 54/100
# 100/100 [==============================] - 8s 84ms/step - loss: 2.7134e-06
# Epoch 55/100
# 100/100 [==============================] - 8s 85ms/step - loss: 5.6183e-06
# Epoch 56/100
# 100/100 [==============================] - 8s 85ms/step - loss: 9.7685e-06
# Epoch 57/100
# 100/100 [==============================] - 8s 84ms/step - loss: 3.0500e-05
# Epoch 58/100
# 100/100 [==============================] - 8s 85ms/step - loss: 9.2078e-06
# Epoch 59/100
# 100/100 [==============================] - 8s 85ms/step - loss: 1.9264e-05
# Epoch 60/100
# 100/100 [==============================] - 8s 84ms/step - loss: 2.5323e-05
# Epoch 61/100
# 100/100 [==============================] - 8s 85ms/step - loss: 4.6235e-05
# Epoch 62/100
# 100/100 [==============================] - 8s 85ms/step - loss: 3.8350e-05
# Epoch 63/100
# 100/100 [==============================] - 8s 84ms/step - loss: 9.1136e-06
# Epoch 64/100
# 100/100 [==============================] - 9s 86ms/step - loss: 2.3922e-06
# Epoch 65/100
# 100/100 [==============================] - 8s 84ms/step - loss: 2.8592e-06
# Epoch 66/100
# 100/100 [==============================] - 8s 84ms/step - loss: 1.7686e-05
# Epoch 67/100
# 100/100 [==============================] - 8s 84ms/step - loss: 1.7064e-05
# Epoch 68/100
# 100/100 [==============================] - 8s 85ms/step - loss: 5.9155e-05
# Epoch 69/100
# 100/100 [==============================] - 8s 85ms/step - loss: 3.0938e-05
# Epoch 70/100
# 100/100 [==============================] - 8s 84ms/step - loss: 3.6388e-05
# Epoch 71/100
# 100/100 [==============================] - 8s 85ms/step - loss: 2.6457e-05
# Epoch 72/100
# 100/100 [==============================] - 8s 84ms/step - loss: 1.7665e-05
# Epoch 73/100
# 100/100 [==============================] - 8s 84ms/step - loss: 2.4201e-05
# Epoch 74/100
# 100/100 [==============================] - 8s 84ms/step - loss: 1.3409e-05
# Epoch 75/100
# 100/100 [==============================] - 8s 84ms/step - loss: 7.9089e-06
# Epoch 76/100
# 100/100 [==============================] - 8s 84ms/step - loss: 9.2927e-06
# Epoch 77/100
# 100/100 [==============================] - 8s 84ms/step - loss: 1.6232e-05
# Epoch 78/100
# 100/100 [==============================] - 8s 84ms/step - loss: 4.9329e-06
# Epoch 79/100
# 100/100 [==============================] - 8s 84ms/step - loss: 2.4369e-06
# Epoch 80/100
# 100/100 [==============================] - 8s 84ms/step - loss: 1.9569e-05
# Epoch 81/100
# 100/100 [==============================] - 8s 84ms/step - loss: 2.6663e-05
# Epoch 82/100
# 100/100 [==============================] - 8s 84ms/step - loss: 1.4699e-05
# Epoch 83/100
# 100/100 [==============================] - 8s 85ms/step - loss: 1.0007e-05
# Epoch 84/100
# 100/100 [==============================] - 8s 84ms/step - loss: 1.4537e-05
# Epoch 85/100
# 100/100 [==============================] - 8s 85ms/step - loss: 9.5125e-06
# Epoch 86/100
# 100/100 [==============================] - 8s 84ms/step - loss: 1.6909e-05
# Epoch 87/100
# 100/100 [==============================] - 8s 84ms/step - loss: 2.5067e-05
# Epoch 88/100
# 100/100 [==============================] - 8s 84ms/step - loss: 2.2305e-05
# Epoch 89/100
# 100/100 [==============================] - 8s 84ms/step - loss: 1.5080e-05
# Epoch 90/100
# 100/100 [==============================] - 8s 84ms/step - loss: 1.9010e-05
# Epoch 91/100
# 100/100 [==============================] - 8s 85ms/step - loss: 7.3510e-06
# Epoch 92/100
# 100/100 [==============================] - 9s 86ms/step - loss: 2.9945e-05
# Epoch 93/100
# 100/100 [==============================] - 8s 85ms/step - loss: 2.3168e-05
# Epoch 94/100
# 100/100 [==============================] - 8s 84ms/step - loss: 3.2320e-06
# Epoch 95/100
# 100/100 [==============================] - 8s 85ms/step - loss: 5.1757e-06
# Epoch 96/100
# 100/100 [==============================] - 8s 84ms/step - loss: 6.2055e-06
# Epoch 97/100
# 100/100 [==============================] - 8s 84ms/step - loss: 8.6744e-06
# Epoch 98/100
# 100/100 [==============================] - 8s 84ms/step - loss: 5.3819e-05
# Epoch 99/100
# 100/100 [==============================] - 8s 85ms/step - loss: 3.8061e-05
# Epoch 100/100
# 100/100 [==============================] - 9s 85ms/step - loss: 3.5855e-06
# Epoch 1/100
# 100/100 [==============================] - 12s 84ms/step - loss: 0.0411
# Epoch 2/100
# 100/100 [==============================] - 8s 84ms/step - loss: 0.0029
# Epoch 3/100
# 100/100 [==============================] - 8s 84ms/step - loss: 0.0010
# Epoch 4/100
# 100/100 [==============================] - 8s 83ms/step - loss: 6.3960e-04
# Epoch 5/100
# 100/100 [==============================] - 8s 84ms/step - loss: 3.7951e-04
# Epoch 6/100
# 100/100 [==============================] - 8s 85ms/step - loss: 3.4198e-04
# Epoch 7/100
# 100/100 [==============================] - 8s 84ms/step - loss: 2.6487e-04
# Epoch 8/100
# 100/100 [==============================] - 8s 84ms/step - loss: 1.0334e-04
# Epoch 9/100
# 100/100 [==============================] - 8s 84ms/step - loss: 2.6645e-04
# Epoch 10/100
# 100/100 [==============================] - 8s 84ms/step - loss: 1.2513e-04
# Epoch 11/100
# 100/100 [==============================] - 8s 84ms/step - loss: 1.0237e-04
# Epoch 12/100
# 100/100 [==============================] - 8s 84ms/step - loss: 1.3877e-04
# Epoch 13/100
# 100/100 [==============================] - 8s 84ms/step - loss: 3.8668e-05
# Epoch 14/100
# 100/100 [==============================] - 8s 84ms/step - loss: 3.4480e-05
# Epoch 15/100
# 100/100 [==============================] - 8s 84ms/step - loss: 9.8475e-05
# Epoch 16/100
# 100/100 [==============================] - 8s 84ms/step - loss: 3.5221e-05
# Epoch 17/100
# 100/100 [==============================] - 8s 84ms/step - loss: 2.0915e-05
# Epoch 18/100
# 100/100 [==============================] - 8s 84ms/step - loss: 7.1814e-05
# Epoch 19/100
# 100/100 [==============================] - 8s 84ms/step - loss: 4.0733e-05
# Epoch 20/100
# 100/100 [==============================] - 8s 84ms/step - loss: 3.2481e-05
# Epoch 21/100
# 100/100 [==============================] - 8s 84ms/step - loss: 4.4823e-05
# Epoch 22/100
# 100/100 [==============================] - 8s 84ms/step - loss: 4.2147e-05
# Epoch 23/100
# 100/100 [==============================] - 8s 84ms/step - loss: 3.6836e-05
# Epoch 24/100
# 100/100 [==============================] - 8s 84ms/step - loss: 4.6619e-05
# Epoch 25/100
# 100/100 [==============================] - 8s 85ms/step - loss: 3.0707e-05
# Epoch 26/100
# 100/100 [==============================] - 9s 85ms/step - loss: 4.5351e-05
# Epoch 27/100
# 100/100 [==============================] - 9s 86ms/step - loss: 5.8384e-05
# Epoch 28/100
# 100/100 [==============================] - 9s 87ms/step - loss: 1.5455e-05
# Epoch 29/100
# 100/100 [==============================] - 9s 86ms/step - loss: 3.3618e-06
# Epoch 30/100
# 100/100 [==============================] - 9s 86ms/step - loss: 3.0682e-05
# Epoch 31/100
# 100/100 [==============================] - 9s 85ms/step - loss: 3.2211e-05
# Epoch 32/100
# 100/100 [==============================] - 9s 85ms/step - loss: 2.3880e-05
# Epoch 33/100
# 100/100 [==============================] - 9s 85ms/step - loss: 4.2388e-06
# Epoch 34/100
# 100/100 [==============================] - 9s 86ms/step - loss: 3.5097e-06
# Epoch 35/100
# 100/100 [==============================] - 9s 86ms/step - loss: 3.5620e-05
# Epoch 36/100
# 100/100 [==============================] - 9s 85ms/step - loss: 2.4989e-05
# Epoch 37/100
# 100/100 [==============================] - 9s 86ms/step - loss: 1.2163e-05
# Epoch 38/100
# 100/100 [==============================] - 9s 85ms/step - loss: 4.0757e-05
# Epoch 39/100
# 100/100 [==============================] - 9s 85ms/step - loss: 3.2718e-05
# Epoch 40/100
# 100/100 [==============================] - 9s 86ms/step - loss: 1.9964e-05
# Epoch 41/100
# 100/100 [==============================] - 9s 86ms/step - loss: 5.1015e-06
# Epoch 42/100
# 100/100 [==============================] - 9s 85ms/step - loss: 3.4396e-05
# Epoch 43/100
# 100/100 [==============================] - 9s 85ms/step - loss: 4.6185e-05
# Epoch 44/100
# 100/100 [==============================] - 9s 86ms/step - loss: 6.7200e-06
# Epoch 45/100
# 100/100 [==============================] - 9s 86ms/step - loss: 8.9250e-06
# Epoch 46/100
# 100/100 [==============================] - 9s 86ms/step - loss: 1.5486e-05
# Epoch 47/100
# 100/100 [==============================] - 9s 85ms/step - loss: 8.9101e-06
# Epoch 48/100
# 100/100 [==============================] - 8s 85ms/step - loss: 5.2422e-06
# Epoch 49/100
# 100/100 [==============================] - 8s 84ms/step - loss: 6.5550e-06
# Epoch 50/100
# 100/100 [==============================] - 8s 85ms/step - loss: 3.4950e-06
# Epoch 51/100
# 100/100 [==============================] - 8s 84ms/step - loss: 4.1959e-05
# Epoch 52/100
# 100/100 [==============================] - 8s 84ms/step - loss: 6.3024e-05
# Epoch 53/100
# 100/100 [==============================] - 8s 84ms/step - loss: 3.9027e-05
# Epoch 54/100
# 100/100 [==============================] - 8s 85ms/step - loss: 1.6164e-05
# Epoch 55/100
# 100/100 [==============================] - 8s 84ms/step - loss: 1.3784e-05
# Epoch 56/100
# 100/100 [==============================] - 8s 84ms/step - loss: 2.5979e-06
# Epoch 57/100
# 100/100 [==============================] - 8s 84ms/step - loss: 4.2910e-06
# Epoch 58/100
# 100/100 [==============================] - 8s 85ms/step - loss: 4.9167e-06
# Epoch 59/100
# 100/100 [==============================] - 8s 85ms/step - loss: 3.7763e-06
# Epoch 60/100
# 100/100 [==============================] - 8s 85ms/step - loss: 2.8332e-06
# Epoch 61/100
# 100/100 [==============================] - 8s 85ms/step - loss: 1.7617e-05
# Epoch 62/100
# 100/100 [==============================] - 8s 84ms/step - loss: 1.9826e-05
# Epoch 63/100
# 100/100 [==============================] - 8s 84ms/step - loss: 1.6179e-05
# Epoch 64/100
# 100/100 [==============================] - 9s 85ms/step - loss: 4.1616e-06
# Epoch 65/100
# 100/100 [==============================] - 9s 86ms/step - loss: 1.4112e-05
# Epoch 66/100
# 100/100 [==============================] - 8s 85ms/step - loss: 1.5764e-05
# Epoch 67/100
# 100/100 [==============================] - 8s 85ms/step - loss: 2.1899e-05
# Epoch 68/100
# 100/100 [==============================] - 8s 84ms/step - loss: 7.3872e-05
# Epoch 69/100
# 100/100 [==============================] - 8s 85ms/step - loss: 7.2204e-06
# Epoch 70/100
# 100/100 [==============================] - 9s 85ms/step - loss: 8.5987e-06
# Epoch 71/100
# 100/100 [==============================] - 8s 85ms/step - loss: 2.0052e-05
# Epoch 72/100
# 100/100 [==============================] - 8s 84ms/step - loss: 5.8068e-06
# Epoch 73/100
# 100/100 [==============================] - 8s 84ms/step - loss: 2.6411e-06
# Epoch 74/100
# 100/100 [==============================] - 8s 85ms/step - loss: 6.6578e-06
# Epoch 75/100
# 100/100 [==============================] - 9s 85ms/step - loss: 9.3172e-06
# Epoch 76/100
# 100/100 [==============================] - 9s 85ms/step - loss: 1.1823e-05
# Epoch 77/100
# 100/100 [==============================] - 9s 85ms/step - loss: 4.5332e-05
# Epoch 78/100
# 100/100 [==============================] - 9s 85ms/step - loss: 1.7682e-05
# Epoch 79/100
# 100/100 [==============================] - 9s 86ms/step - loss: 1.6282e-06
# Epoch 80/100
# 100/100 [==============================] - 9s 85ms/step - loss: 2.0667e-06
# Epoch 81/100
# 100/100 [==============================] - 9s 86ms/step - loss: 3.1799e-06
# Epoch 82/100
# 100/100 [==============================] - 9s 87ms/step - loss: 1.1846e-05
# Epoch 83/100
# 100/100 [==============================] - 9s 86ms/step - loss: 7.1871e-05
# Epoch 84/100
# 100/100 [==============================] - 9s 86ms/step - loss: 1.2579e-05
# Epoch 85/100
# 100/100 [==============================] - 9s 86ms/step - loss: 2.6606e-06
# Epoch 86/100
# 100/100 [==============================] - 9s 86ms/step - loss: 4.5896e-06
# Epoch 87/100
# 100/100 [==============================] - 9s 86ms/step - loss: 1.0429e-05
# Epoch 88/100
# 100/100 [==============================] - 9s 86ms/step - loss: 2.6951e-05
# Epoch 89/100
# 100/100 [==============================] - 9s 86ms/step - loss: 2.0691e-05
# Epoch 90/100
# 100/100 [==============================] - 9s 87ms/step - loss: 3.9235e-06
# Epoch 91/100
# 100/100 [==============================] - 9s 87ms/step - loss: 2.2442e-05
# Epoch 92/100
# 100/100 [==============================] - 9s 86ms/step - loss: 6.3198e-06
# Epoch 93/100
# 100/100 [==============================] - 9s 86ms/step - loss: 3.0903e-06
# Epoch 94/100
# 100/100 [==============================] - 9s 87ms/step - loss: 4.8244e-06
# Epoch 95/100
# 100/100 [==============================] - 9s 87ms/step - loss: 1.8563e-05
# Epoch 96/100
# 100/100 [==============================] - 9s 87ms/step - loss: 4.8655e-06
# Epoch 97/100
# 100/100 [==============================] - 9s 87ms/step - loss: 5.5045e-06
# Epoch 98/100
# 100/100 [==============================] - 9s 86ms/step - loss: 3.6692e-05
# Epoch 99/100
# 100/100 [==============================] - 9s 86ms/step - loss: 2.2061e-05
# Epoch 100/100
# 100/100 [==============================] - 9s 87ms/step - loss: 3.7493e-05
# Epoch 1/100
# 100/100 [==============================] - 14s 89ms/step - loss: 0.0308
# Epoch 2/100
# 100/100 [==============================] - 9s 90ms/step - loss: 8.2508e-04
# Epoch 3/100
# 100/100 [==============================] - 9s 91ms/step - loss: 2.7849e-04
# Epoch 4/100
# 100/100 [==============================] - 9s 90ms/step - loss: 1.3664e-04
# Epoch 5/100
# 100/100 [==============================] - 9s 90ms/step - loss: 6.3306e-05
# Epoch 6/100
# 100/100 [==============================] - 9s 90ms/step - loss: 6.4605e-05
# Epoch 7/100
# 100/100 [==============================] - 9s 90ms/step - loss: 5.1943e-05
# Epoch 8/100
# 100/100 [==============================] - 9s 91ms/step - loss: 3.7919e-05
# Epoch 9/100
# 100/100 [==============================] - 9s 91ms/step - loss: 2.5700e-05
# Epoch 10/100
# 100/100 [==============================] - 9s 90ms/step - loss: 1.1597e-05
# Epoch 11/100
# 100/100 [==============================] - 9s 90ms/step - loss: 2.2481e-05
# Epoch 12/100
# 100/100 [==============================] - 9s 90ms/step - loss: 1.1532e-05
# Epoch 13/100
# 100/100 [==============================] - 9s 90ms/step - loss: 9.6322e-06
# Epoch 14/100
# 100/100 [==============================] - 9s 89ms/step - loss: 2.9214e-05
# Epoch 15/100
# 100/100 [==============================] - 9s 90ms/step - loss: 3.0488e-05
# Epoch 16/100
# 100/100 [==============================] - 9s 90ms/step - loss: 2.7380e-05
# Epoch 17/100
# 100/100 [==============================] - 9s 90ms/step - loss: 1.7615e-05
# Epoch 18/100
# 100/100 [==============================] - 9s 90ms/step - loss: 1.0672e-05
# Epoch 19/100
# 100/100 [==============================] - 9s 90ms/step - loss: 1.1034e-05
# Epoch 20/100
# 100/100 [==============================] - 9s 89ms/step - loss: 2.1424e-05
# Epoch 21/100
# 100/100 [==============================] - 9s 90ms/step - loss: 1.5388e-05
# Epoch 22/100
# 100/100 [==============================] - 9s 90ms/step - loss: 1.1442e-05
# Epoch 23/100
# 100/100 [==============================] - 9s 90ms/step - loss: 8.9141e-06
# Epoch 24/100
# 100/100 [==============================] - 9s 90ms/step - loss: 3.9616e-05
# Epoch 25/100
# 100/100 [==============================] - 9s 90ms/step - loss: 1.0553e-05
# Epoch 26/100
# 100/100 [==============================] - 9s 90ms/step - loss: 2.0387e-05
# Epoch 27/100
# 100/100 [==============================] - 9s 90ms/step - loss: 5.3334e-05
# Epoch 28/100
# 100/100 [==============================] - 9s 90ms/step - loss: 4.6859e-05
# Epoch 29/100
# 100/100 [==============================] - 9s 91ms/step - loss: 1.0426e-05
# Epoch 30/100
# 100/100 [==============================] - 9s 90ms/step - loss: 1.1424e-05
# Epoch 31/100
# 100/100 [==============================] - 9s 90ms/step - loss: 3.5835e-06
# Epoch 32/100
# 100/100 [==============================] - 9s 90ms/step - loss: 1.4238e-05
# Epoch 33/100
# 100/100 [==============================] - 9s 91ms/step - loss: 7.0816e-06
# Epoch 34/100
# 100/100 [==============================] - 9s 92ms/step - loss: 3.6214e-05
# Epoch 35/100
# 100/100 [==============================] - 9s 91ms/step - loss: 1.3051e-04
# Epoch 36/100
# 100/100 [==============================] - 9s 91ms/step - loss: 1.1130e-05
# Epoch 37/100
# 100/100 [==============================] - 9s 90ms/step - loss: 6.5844e-06
# Epoch 38/100
# 100/100 [==============================] - 9s 91ms/step - loss: 9.1830e-06
# Epoch 39/100
# 100/100 [==============================] - 9s 90ms/step - loss: 3.3155e-06
# Epoch 40/100
# 100/100 [==============================] - 9s 90ms/step - loss: 5.2410e-06
# Epoch 41/100
# 100/100 [==============================] - 9s 90ms/step - loss: 6.3182e-06
# Epoch 42/100
# 100/100 [==============================] - 9s 90ms/step - loss: 3.6729e-06
# Epoch 43/100
# 100/100 [==============================] - 9s 91ms/step - loss: 7.2711e-05
# Epoch 44/100
# 100/100 [==============================] - 9s 90ms/step - loss: 2.6578e-05
# Epoch 45/100
# 100/100 [==============================] - 9s 90ms/step - loss: 3.2272e-05
# Epoch 46/100
# 100/100 [==============================] - 9s 90ms/step - loss: 4.9741e-05
# Epoch 47/100
# ...
# 100/100 [==============================] - 9s 88ms/step - loss: 8.2621e-06
# Epoch 20/100
# 100/100 [==============================] - 9s 88ms/step - loss: 3.2960e-05
# Epoch 21/100
# 100/100 [==============================] - 9s 88ms/step - loss: 1.0040e-05
# Epoch 22/100
# 100/100 [==============================] - 9s 88ms/step - loss: 1.8618e-05
# Epoch 23/100
# 100/100 [==============================] - 9s 88ms/step - loss: 1.8810e-05
# Epoch 24/100
# 100/100 [==============================] - 9s 87ms/step - loss: 7.7001e-06
# Epoch 25/100
# 100/100 [==============================] - 9s 87ms/step - loss: 1.4076e-05
# Epoch 26/100
# 100/100 [==============================] - 9s 88ms/step - loss: 1.8151e-05
# Epoch 27/100
# 100/100 [==============================] - 9s 88ms/step - loss: 7.2140e-06
# Epoch 28/100
# 100/100 [==============================] - 9s 89ms/step - loss: 2.0393e-06
# Epoch 29/100
# 100/100 [==============================] - 9s 89ms/step - loss: 2.0292e-06
# Epoch 30/100
# 100/100 [==============================] - 9s 89ms/step - loss: 6.4948e-05
# Epoch 31/100
# 100/100 [==============================] - 9s 89ms/step - loss: 7.7222e-05
# Epoch 32/100
# 100/100 [==============================] - 9s 89ms/step - loss: 2.2831e-05
# Epoch 33/100
# 100/100 [==============================] - 9s 89ms/step - loss: 1.4701e-06
# Epoch 34/100
# 100/100 [==============================] - 9s 88ms/step - loss: 3.6157e-06
# Epoch 35/100
# 100/100 [==============================] - 9s 89ms/step - loss: 1.5821e-05
# Epoch 36/100
# 100/100 [==============================] - 9s 90ms/step - loss: 8.0974e-06
# Epoch 37/100
# 100/100 [==============================] - 9s 90ms/step - loss: 8.5406e-06
# Epoch 38/100
# 100/100 [==============================] - 9s 89ms/step - loss: 6.9925e-06
# Epoch 39/100
# 100/100 [==============================] - 9s 88ms/step - loss: 1.1908e-05
# Epoch 40/100
# 100/100 [==============================] - 9s 89ms/step - loss: 3.3861e-05
# Epoch 41/100
# 100/100 [==============================] - 9s 88ms/step - loss: 3.2944e-05
# Epoch 42/100
# 100/100 [==============================] - 9s 89ms/step - loss: 3.1242e-05
# Epoch 43/100
# 100/100 [==============================] - 9s 88ms/step - loss: 6.8637e-06
# Epoch 44/100
# 100/100 [==============================] - 9s 88ms/step - loss: 1.0825e-05
# Epoch 45/100
# 100/100 [==============================] - 9s 88ms/step - loss: 5.2576e-06
# Epoch 46/100
# 100/100 [==============================] - 9s 88ms/step - loss: 2.0756e-05
# Epoch 47/100
# 100/100 [==============================] - 9s 88ms/step - loss: 2.0889e-05
# Epoch 48/100
# 100/100 [==============================] - 9s 89ms/step - loss: 4.9775e-06
# Epoch 49/100
# 100/100 [==============================] - 9s 89ms/step - loss: 3.4686e-06
# Epoch 50/100
# 100/100 [==============================] - 9s 89ms/step - loss: 2.7073e-05
# Epoch 51/100
# 100/100 [==============================] - 9s 89ms/step - loss: 1.1917e-04
# Epoch 52/100
# 100/100 [==============================] - 9s 89ms/step - loss: 6.2529e-05
# Epoch 53/100
# 100/100 [==============================] - 9s 89ms/step - loss: 2.6135e-05
# Epoch 54/100
# 100/100 [==============================] - 9s 89ms/step - loss: 6.4103e-06
# Epoch 55/100
# 100/100 [==============================] - 9s 89ms/step - loss: 8.3453e-07
# Epoch 56/100
# 100/100 [==============================] - 9s 89ms/step - loss: 6.7390e-07
# Epoch 57/100
# 100/100 [==============================] - 9s 89ms/step - loss: 3.0431e-06
# Epoch 58/100
# 100/100 [==============================] - 9s 89ms/step - loss: 2.3507e-05
# Epoch 59/100
# 100/100 [==============================] - 9s 89ms/step - loss: 1.1698e-05
# Epoch 60/100
# 100/100 [==============================] - 9s 89ms/step - loss: 5.0161e-06
# Epoch 61/100
# 100/100 [==============================] - 9s 89ms/step - loss: 3.6329e-05
# Epoch 62/100
# 100/100 [==============================] - 9s 89ms/step - loss: 1.4713e-05
# Epoch 63/100
# 100/100 [==============================] - 9s 90ms/step - loss: 7.1374e-06
# Epoch 64/100
# 100/100 [==============================] - 9s 90ms/step - loss: 6.6605e-06
# Epoch 65/100
# 100/100 [==============================] - 9s 90ms/step - loss: 1.4096e-05
# Epoch 66/100
# 100/100 [==============================] - 9s 89ms/step - loss: 3.6354e-06
# Epoch 67/100
# 100/100 [==============================] - 9s 89ms/step - loss: 2.9130e-05
# Epoch 68/100
# 100/100 [==============================] - 9s 88ms/step - loss: 6.4819e-06
# Epoch 69/100
# 100/100 [==============================] - 9s 90ms/step - loss: 7.1852e-06
# Epoch 70/100
# 100/100 [==============================] - 9s 89ms/step - loss: 1.1289e-05
# Epoch 71/100
# 100/100 [==============================] - 9s 90ms/step - loss: 1.0291e-05
# Epoch 72/100
# 100/100 [==============================] - 9s 90ms/step - loss: 1.8390e-05
# Epoch 73/100
# 100/100 [==============================] - 9s 91ms/step - loss: 1.8736e-05
# Epoch 74/100
# 100/100 [==============================] - 9s 89ms/step - loss: 8.5436e-05
# Epoch 75/100
# 100/100 [==============================] - 9s 90ms/step - loss: 2.1216e-05
# Epoch 76/100
# 100/100 [==============================] - 9s 89ms/step - loss: 1.3970e-05
# Epoch 77/100
# 100/100 [==============================] - 9s 88ms/step - loss: 5.7602e-06
# Epoch 78/100
# 100/100 [==============================] - 9s 89ms/step - loss: 9.9622e-06
# Epoch 79/100
# 100/100 [==============================] - 9s 89ms/step - loss: 2.3013e-06
# Epoch 80/100
# 100/100 [==============================] - 9s 89ms/step - loss: 2.5271e-06
# Epoch 81/100
# 100/100 [==============================] - 9s 89ms/step - loss: 7.8595e-06
# Epoch 82/100
# 100/100 [==============================] - 9s 89ms/step - loss: 4.4513e-05
# Epoch 83/100
# 100/100 [==============================] - 9s 88ms/step - loss: 1.4014e-05
# Epoch 84/100
# 100/100 [==============================] - 9s 89ms/step - loss: 4.1250e-06
# Epoch 85/100
# 100/100 [==============================] - 9s 89ms/step - loss: 1.4462e-06
# Epoch 86/100
# 100/100 [==============================] - 9s 88ms/step - loss: 8.2316e-07
# Epoch 87/100
# 100/100 [==============================] - 9s 88ms/step - loss: 2.4888e-06
# Epoch 88/100
# 100/100 [==============================] - 9s 89ms/step - loss: 7.4143e-06
# Epoch 89/100
# 100/100 [==============================] - 9s 88ms/step - loss: 4.1478e-06
# Epoch 90/100
# 100/100 [==============================] - 9s 89ms/step - loss: 6.4874e-05
# Epoch 91/100
# 100/100 [==============================] - 9s 88ms/step - loss: 3.3485e-05
# Epoch 92/100
# 100/100 [==============================] - 9s 89ms/step - loss: 1.5647e-05
# Epoch 93/100
# 100/100 [==============================] - 9s 89ms/step - loss: 8.9459e-06
# Epoch 94/100
# 100/100 [==============================] - 9s 88ms/step - loss: 2.5107e-06
# Epoch 95/100
# 100/100 [==============================] - 9s 88ms/step - loss: 4.6589e-06
# Epoch 96/100
# 100/100 [==============================] - 9s 89ms/step - loss: 7.7364e-06
# Epoch 97/100
# 100/100 [==============================] - 9s 88ms/step - loss: 1.0752e-05
# Epoch 98/100
# 100/100 [==============================] - 9s 88ms/step - loss: 6.1693e-06
# Epoch 99/100
# 100/100 [==============================] - 9s 89ms/step - loss: 6.9894e-06
# Epoch 100/100
# 100/100 [==============================] - 9s 89ms/step - loss: 1.8534e-06
# Epoch 1/100
# 100/100 [==============================] - 14s 87ms/step - loss: 0.0538
# Epoch 2/100
# 100/100 [==============================] - 9s 88ms/step - loss: 0.0026
# Epoch 3/100
# 100/100 [==============================] - 9s 87ms/step - loss: 9.6472e-04
# Epoch 4/100
# 100/100 [==============================] - 9s 88ms/step - loss: 2.8651e-04
# Epoch 5/100
# 100/100 [==============================] - 9s 88ms/step - loss: 1.7214e-04
# Epoch 6/100
# 100/100 [==============================] - 9s 87ms/step - loss: 1.2518e-04
# Epoch 7/100
# 100/100 [==============================] - 9s 87ms/step - loss: 6.6866e-05
# Epoch 8/100
# 100/100 [==============================] - 9s 87ms/step - loss: 7.3192e-05
# Epoch 9/100
# 100/100 [==============================] - 9s 87ms/step - loss: 8.9940e-05
# Epoch 10/100
# 100/100 [==============================] - 9s 87ms/step - loss: 4.6541e-05
# Epoch 11/100
# 100/100 [==============================] - 9s 88ms/step - loss: 3.9448e-05
# Epoch 12/100
# 100/100 [==============================] - 9s 88ms/step - loss: 5.4212e-05
# Epoch 13/100
# 100/100 [==============================] - 9s 87ms/step - loss: 5.3221e-05
# Epoch 14/100
# 100/100 [==============================] - 9s 87ms/step - loss: 1.8088e-05
# Epoch 15/100
# 100/100 [==============================] - 9s 88ms/step - loss: 1.6679e-05
# Epoch 16/100
# 100/100 [==============================] - 9s 88ms/step - loss: 3.8374e-05
# Epoch 17/100
# 100/100 [==============================] - 9s 88ms/step - loss: 1.0526e-05
# Epoch 18/100
# 100/100 [==============================] - 9s 88ms/step - loss: 1.5209e-05
# Epoch 19/100
# 100/100 [==============================] - 9s 89ms/step - loss: 8.6457e-06
# Epoch 20/100
# 100/100 [==============================] - 9s 88ms/step - loss: 6.7313e-06
# Epoch 21/100
# 100/100 [==============================] - 9s 88ms/step - loss: 8.3575e-06
# Epoch 22/100
# 100/100 [==============================] - 9s 88ms/step - loss: 1.2266e-05
# Epoch 23/100
# 100/100 [==============================] - 9s 88ms/step - loss: 4.7239e-06
# Epoch 24/100
# 100/100 [==============================] - 9s 88ms/step - loss: 9.3016e-06
# Epoch 25/100
# 100/100 [==============================] - 9s 88ms/step - loss: 6.8543e-06
# Epoch 26/100
# 100/100 [==============================] - 9s 88ms/step - loss: 4.5880e-05
# Epoch 27/100
# 100/100 [==============================] - 9s 88ms/step - loss: 2.2120e-05
# Epoch 28/100
# 100/100 [==============================] - 9s 88ms/step - loss: 3.2007e-06
# Epoch 29/100
# 100/100 [==============================] - 9s 88ms/step - loss: 7.5077e-06
# Epoch 30/100
# 100/100 [==============================] - 9s 87ms/step - loss: 5.8745e-06
# Epoch 31/100
# 100/100 [==============================] - 9s 88ms/step - loss: 3.2249e-06
# Epoch 32/100
# 100/100 [==============================] - 9s 88ms/step - loss: 2.9108e-06
# Epoch 33/100
# 100/100 [==============================] - 9s 88ms/step - loss: 6.1058e-06
# Epoch 34/100
# 100/100 [==============================] - 9s 87ms/step - loss: 3.3470e-05
# Epoch 35/100
# 100/100 [==============================] - 9s 88ms/step - loss: 3.4392e-06
# Epoch 36/100
# 100/100 [==============================] - 9s 88ms/step - loss: 1.3915e-05
# Epoch 37/100
# 100/100 [==============================] - 9s 88ms/step - loss: 4.0358e-06
# Epoch 38/100
# 100/100 [==============================] - 9s 89ms/step - loss: 5.3096e-06
# Epoch 39/100
# 100/100 [==============================] - 9s 90ms/step - loss: 5.7329e-06
# Epoch 40/100
# 100/100 [==============================] - 9s 89ms/step - loss: 1.5877e-06
# Epoch 41/100
# 100/100 [==============================] - 9s 88ms/step - loss: 3.3484e-06
# Epoch 42/100
# 100/100 [==============================] - 9s 88ms/step - loss: 8.4953e-06
# Epoch 43/100
# 100/100 [==============================] - 9s 88ms/step - loss: 3.7286e-05
# Epoch 44/100
# 100/100 [==============================] - 9s 88ms/step - loss: 5.0504e-06
# Epoch 45/100
# 100/100 [==============================] - 9s 88ms/step - loss: 2.8890e-06
# Epoch 46/100
# 100/100 [==============================] - 9s 89ms/step - loss: 8.7383e-06
# Epoch 47/100
# 100/100 [==============================] - 9s 88ms/step - loss: 1.8028e-05
# Epoch 48/100
# 100/100 [==============================] - 9s 89ms/step - loss: 3.6486e-05
# Epoch 49/100
# 100/100 [==============================] - 9s 89ms/step - loss: 1.0135e-05
# Epoch 50/100
# 100/100 [==============================] - 9s 89ms/step - loss: 4.4314e-06
# Epoch 51/100
# 100/100 [==============================] - 9s 88ms/step - loss: 3.3763e-06
# Epoch 52/100
# 100/100 [==============================] - 9s 88ms/step - loss: 3.6046e-05
# Epoch 53/100
# 100/100 [==============================] - 9s 89ms/step - loss: 1.0345e-05
# Epoch 54/100
# 100/100 [==============================] - 9s 88ms/step - loss: 2.3548e-06
# Epoch 55/100
# 100/100 [==============================] - 9s 88ms/step - loss: 1.0619e-05
# Epoch 56/100
# 100/100 [==============================] - 9s 89ms/step - loss: 1.1884e-05
# Epoch 57/100
# 100/100 [==============================] - 9s 88ms/step - loss: 8.3489e-05
# Epoch 58/100
# 100/100 [==============================] - 9s 88ms/step - loss: 1.7487e-05
# Epoch 59/100
# 100/100 [==============================] - 9s 88ms/step - loss: 1.2914e-06
# Epoch 60/100
# 100/100 [==============================] - 9s 89ms/step - loss: 2.2837e-06
# Epoch 61/100
# 100/100 [==============================] - 9s 88ms/step - loss: 4.6559e-06
# Epoch 62/100
# 100/100 [==============================] - 9s 88ms/step - loss: 9.9086e-07
# Epoch 63/100
# 100/100 [==============================] - 9s 88ms/step - loss: 5.3378e-06
# Epoch 64/100
# 100/100 [==============================] - 9s 88ms/step - loss: 4.4333e-06
# Epoch 65/100
# 100/100 [==============================] - 9s 88ms/step - loss: 2.2366e-06
# Epoch 66/100
# 100/100 [==============================] - 9s 88ms/step - loss: 1.8020e-06
# Epoch 67/100
# 100/100 [==============================] - 9s 89ms/step - loss: 1.1026e-05
# Epoch 68/100
# 100/100 [==============================] - 9s 89ms/step - loss: 9.9974e-06
# Epoch 69/100
# 100/100 [==============================] - 9s 88ms/step - loss: 3.0873e-05
# Epoch 70/100
# 100/100 [==============================] - 9s 89ms/step - loss: 9.2439e-06
# Epoch 71/100
# 100/100 [==============================] - 9s 90ms/step - loss: 1.3992e-06
# Epoch 72/100
# 100/100 [==============================] - 9s 89ms/step - loss: 8.1648e-05
# Epoch 73/100
# 100/100 [==============================] - 9s 89ms/step - loss: 3.0336e-05
# Epoch 74/100
# 100/100 [==============================] - 9s 90ms/step - loss: 2.1443e-05
# Epoch 75/100
# 100/100 [==============================] - 9s 90ms/step - loss: 4.4528e-05
# Epoch 76/100
# 100/100 [==============================] - 9s 89ms/step - loss: 1.3637e-06
# Epoch 77/100
# 100/100 [==============================] - 9s 89ms/step - loss: 2.1743e-06
# Epoch 78/100
# 100/100 [==============================] - 9s 89ms/step - loss: 4.3133e-06
# Epoch 79/100
# 100/100 [==============================] - 9s 88ms/step - loss: 5.6712e-07
# Epoch 80/100
# 100/100 [==============================] - 9s 89ms/step - loss: 1.7072e-06
# Epoch 81/100
# 100/100 [==============================] - 9s 89ms/step - loss: 1.4368e-06
# Epoch 82/100
# 100/100 [==============================] - 9s 89ms/step - loss: 9.2522e-07
# Epoch 83/100
# 100/100 [==============================] - 9s 89ms/step - loss: 1.4848e-06
# Epoch 84/100
# 100/100 [==============================] - 9s 89ms/step - loss: 1.1962e-05
# Epoch 85/100
# 100/100 [==============================] - 9s 89ms/step - loss: 2.0422e-05
# Epoch 86/100
# 100/100 [==============================] - 9s 89ms/step - loss: 9.5215e-06
# Epoch 87/100
# 100/100 [==============================] - 9s 89ms/step - loss: 2.9197e-06
# Epoch 88/100
# 100/100 [==============================] - 9s 89ms/step - loss: 2.2322e-05
# Epoch 89/100
# 100/100 [==============================] - 9s 89ms/step - loss: 3.5760e-06
# Epoch 90/100
# 100/100 [==============================] - 9s 89ms/step - loss: 1.4563e-06
# Epoch 91/100
# 100/100 [==============================] - 9s 88ms/step - loss: 1.1233e-06
# Epoch 92/100
# 100/100 [==============================] - 9s 88ms/step - loss: 4.6781e-06
# Epoch 93/100
# 100/100 [==============================] - 9s 89ms/step - loss: 1.7104e-06
# Epoch 94/100
# 100/100 [==============================] - 9s 89ms/step - loss: 6.5523e-06
# Epoch 95/100
# 100/100 [==============================] - 9s 88ms/step - loss: 2.4606e-05
# Epoch 96/100
# 100/100 [==============================] - 9s 88ms/step - loss: 1.5867e-05
# Epoch 97/100
# 100/100 [==============================] - 9s 89ms/step - loss: 1.3242e-05
# Epoch 98/100
# 100/100 [==============================] - 9s 88ms/step - loss: 6.2445e-06
# Epoch 99/100
# 100/100 [==============================] - 9s 88ms/step - loss: 2.1695e-05
# Epoch 100/100
# 100/100 [==============================] - 9s 88ms/step - loss: 2.5164e-05

# %% [markdown]
# ## Visualise Loss function

# %%
#print(result.history.keys())

plt.rcParams['figure.figsize'] = [10, 10]

# summarize history for loss
plt.plot(result_1.history['loss'])
plt.plot(result_2.history['loss'])
plt.plot(result_3.history['loss'])
plt.plot(result_4.history['loss'])
plt.plot(result_5.history['loss'])
plt.plot(result_6.history['loss'])
plt.plot(result_7.history['loss'])
plt.plot(result_8.history['loss'])

plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.rc('font', size=12)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=20)    # legend fontsize
plt.rc('figure', titlesize=20)  # fontsize of the figure title
plt.legend(['32-32 Loss','64-64 Loss','32-32-64D Loss','64-64-32D Loss','64-64-64D Loss','64-64-64 Loss','64-64-32 Loss','32-32-32 Loss','32-32-32D Loss'], loc='upper left')
plt.yscale("log")
plt.show()

# %% [markdown]
# ## Plot trajectories to $t=64$ generated by Verlet integrator and neural network based integrator

# %%
# Final time
T_final = 64

# Initial conditions
x = np.zeros(1)
v = np.zeros(1)
x[0] = 1.0
v[0] = 0.0
verlet_integrator.set_state(x,v)

# ==== Verlet integrator ====
t = 0.0
t_verlet = []
x_verlet = []
E_verlet = []
while t<T_final:
    t_verlet.append(t)
    E_verlet.append(verlet_integrator.energy())
    x_verlet.append(verlet_integrator.x[0])
    verlet_integrator.integrate(1)
    t += dt_verlet
        

# ==== Neural network integrator ====

# Initialise with Verlet integrator
x_initial_1 = np.zeros((lstm_integrator_1.nsteps,lstm_integrator_1.dynamical_system.dim))
v_initial_1 = np.zeros((lstm_integrator_1.nsteps,lstm_integrator_1.dynamical_system.dim))
x_initial_2 = np.zeros((lstm_integrator_2.nsteps,lstm_integrator_2.dynamical_system.dim))
v_initial_2 = np.zeros((lstm_integrator_2.nsteps,lstm_integrator_2.dynamical_system.dim))
x_initial_3 = np.zeros((lstm_integrator_3.nsteps,lstm_integrator_3.dynamical_system.dim))
v_initial_3 = np.zeros((lstm_integrator_3.nsteps,lstm_integrator_3.dynamical_system.dim))
x_initial_4 = np.zeros((lstm_integrator_4.nsteps,lstm_integrator_4.dynamical_system.dim))
v_initial_4 = np.zeros((lstm_integrator_4.nsteps,lstm_integrator_4.dynamical_system.dim))
x_initial_5 = np.zeros((lstm_integrator_5.nsteps,lstm_integrator_5.dynamical_system.dim))
v_initial_5 = np.zeros((lstm_integrator_5.nsteps,lstm_integrator_5.dynamical_system.dim))
x_initial_6 = np.zeros((lstm_integrator_6.nsteps,lstm_integrator_6.dynamical_system.dim))
v_initial_6 = np.zeros((lstm_integrator_6.nsteps,lstm_integrator_6.dynamical_system.dim))
x_initial_7 = np.zeros((lstm_integrator_7.nsteps,lstm_integrator_7.dynamical_system.dim))
v_initial_7 = np.zeros((lstm_integrator_7.nsteps,lstm_integrator_7.dynamical_system.dim))
x_initial_8 = np.zeros((lstm_integrator_8.nsteps,lstm_integrator_8.dynamical_system.dim))
v_initial_8 = np.zeros((lstm_integrator_8.nsteps,lstm_integrator_8.dynamical_system.dim))


verlet_integrator.set_state(x,v)
for k in range(lstm_integrator_1.nsteps):    
    x_initial_1[k,:] = verlet_integrator.x[:]
    v_initial_1[k,:] = verlet_integrator.v[:]
    verlet_integrator.integrate(int(dt/dt_verlet))
verlet_integrator.set_state(x,v)
for k in range(lstm_integrator_2.nsteps):    
    x_initial_2[k,:] = verlet_integrator.x[:]
    v_initial_2[k,:] = verlet_integrator.v[:]
    verlet_integrator.integrate(int(dt/dt_verlet))
verlet_integrator.set_state(x,v)
for k in range(lstm_integrator_3.nsteps):    
    x_initial_3[k,:] = verlet_integrator.x[:]
    v_initial_3[k,:] = verlet_integrator.v[:]
    verlet_integrator.integrate(int(dt/dt_verlet))
verlet_integrator.set_state(x,v)
for k in range(lstm_integrator_4.nsteps):    
    x_initial_4[k,:] = verlet_integrator.x[:]
    v_initial_4[k,:] = verlet_integrator.v[:]
    verlet_integrator.integrate(int(dt/dt_verlet))
verlet_integrator.set_state(x,v)
for k in range(lstm_integrator_5.nsteps):    
    x_initial_5[k,:] = verlet_integrator.x[:]
    v_initial_5[k,:] = verlet_integrator.v[:]
    verlet_integrator.integrate(int(dt/dt_verlet))
verlet_integrator.set_state(x,v)
for k in range(lstm_integrator_6.nsteps):    
    x_initial_6[k,:] = verlet_integrator.x[:]
    v_initial_6[k,:] = verlet_integrator.v[:]
    verlet_integrator.integrate(int(dt/dt_verlet))
verlet_integrator.set_state(x,v)
for k in range(lstm_integrator_7.nsteps):    
    x_initial_7[k,:] = verlet_integrator.x[:]
    v_initial_7[k,:] = verlet_integrator.v[:]
    verlet_integrator.integrate(int(dt/dt_verlet))
verlet_integrator.set_state(x,v)
for k in range(lstm_integrator_8.nsteps):    
    x_initial_8[k,:] = verlet_integrator.x[:]
    v_initial_8[k,:] = verlet_integrator.v[:]
    verlet_integrator.integrate(int(dt/dt_verlet))  
verlet_integrator.set_state(x,v)    

lstm_integrator_1.set_state(x_initial_1,v_initial_1)
t_1 = (lstm_integrator_1.nsteps-1)*lstm_integrator_1.dt
lstm_integrator_2.set_state(x_initial_2,v_initial_2)
t_2 = (lstm_integrator_2.nsteps-1)*lstm_integrator_2.dt
lstm_integrator_3.set_state(x_initial_3,v_initial_3)
t_3 = (lstm_integrator_3.nsteps-1)*lstm_integrator_3.dt
lstm_integrator_4.set_state(x_initial_4,v_initial_4)
t_4 = (lstm_integrator_4.nsteps-1)*lstm_integrator_4.dt
lstm_integrator_5.set_state(x_initial_5,v_initial_5)
t_5 = (lstm_integrator_5.nsteps-1)*lstm_integrator_5.dt
lstm_integrator_6.set_state(x_initial_6,v_initial_6)
t_6 = (lstm_integrator_6.nsteps-1)*lstm_integrator_6.dt
lstm_integrator_7.set_state(x_initial_7,v_initial_7)
t_7 = (lstm_integrator_7.nsteps-1)*lstm_integrator_7.dt
lstm_integrator_8.set_state(x_initial_8,v_initial_8)
t_8 = (lstm_integrator_8.nsteps-1)*lstm_integrator_8.dt

# Timestepping loop
t_lstm_1 = []
x_lstm_1 = []
E_lstm_1 = []
t_lstm_2 = []
x_lstm_2 = []
E_lstm_2 = []
t_lstm_3 = []
x_lstm_3 = []
E_lstm_3 = []
t_lstm_4 = []
x_lstm_4 = []
E_lstm_4 = []
t_lstm_5 = []
x_lstm_5 = []
E_lstm_5 = []
t_lstm_6 = []
x_lstm_6 = []
E_lstm_6 = []
t_lstm_7 = []
x_lstm_7 = []
E_lstm_7 = []
t_lstm_8 = []
x_lstm_8 = []
E_lstm_8 = []


while t_1<T_final:
    t_lstm_1.append(t_1)
    x_lstm_1.append(lstm_integrator_1.x[0])
    E_lstm_1.append(lstm_integrator_1.energy())
    lstm_integrator_1.integrate(1)
    t_1 += dt
while t_2<T_final:
    t_lstm_2.append(t_2)
    x_lstm_2.append(lstm_integrator_2.x[0])
    E_lstm_2.append(lstm_integrator_2.energy())
    lstm_integrator_2.integrate(1)
    t_2 += dt
while t_3<T_final:
    t_lstm_3.append(t_3)
    x_lstm_3.append(lstm_integrator_3.x[0])
    E_lstm_3.append(lstm_integrator_3.energy())
    lstm_integrator_3.integrate(1)
    t_3 += dt
while t_4<T_final:
    t_lstm_4.append(t_4)
    x_lstm_4.append(lstm_integrator_4.x[0])
    E_lstm_4.append(lstm_integrator_4.energy())
    lstm_integrator_4.integrate(1)
    t_4 += dt
while t_5<T_final:
    t_lstm_5.append(t_5)
    x_lstm_5.append(lstm_integrator_5.x[0])
    E_lstm_5.append(lstm_integrator_5.energy())
    lstm_integrator_5.integrate(1)
    t_5 += dt  
while t_6<T_final:
    t_lstm_6.append(t_6)
    x_lstm_6.append(lstm_integrator_6.x[0])
    E_lstm_6.append(lstm_integrator_6.energy())
    lstm_integrator_6.integrate(1)
    t_6 += dt  
while t_7<T_final:
    t_lstm_7.append(t_7)
    x_lstm_7.append(lstm_integrator_7.x[0])
    E_lstm_7.append(lstm_integrator_7.energy())
    lstm_integrator_7.integrate(1)
    t_7 += dt 
while t_8<T_final:
    t_lstm_8.append(t_8)
    x_lstm_8.append(lstm_integrator_8.x[0])
    E_lstm_8.append(lstm_integrator_8.energy())
    lstm_integrator_8.integrate(1)
    t_8 += dt 


# Plot position as a function of time
plt.plot(t_verlet,x_verlet,label='Verlet',color='black')
plt.plot(t_lstm_1,x_lstm_1,label='32-32',color='blue')
plt.plot(t_lstm_2,x_lstm_2,label='64-64',color='orange')
plt.plot(t_lstm_3,x_lstm_3,label='32-32-64D',color='green')
plt.plot(t_lstm_4,x_lstm_4,label='64-64-32D',color='red')
plt.plot(t_lstm_5,x_lstm_5,label='64-64-64D',color='brown')
plt.plot(t_lstm_6,x_lstm_6,label='64-64-64',color='purple')
plt.plot(t_lstm_7,x_lstm_7,label='64-64-32',color='cyan')
plt.plot(t_lstm_8,x_lstm_8,label='32-32-32',color='darkorange')
plt.legend(loc='lower right')
ax = plt.gca()
ax.set_xlabel('time $t$')
ax.set_ylabel('position $x(t)$')
ax.set_title('Position')
plt.show()

plt.rcParams['figure.figsize'] = [10, 20]

plt.clf()
# Plot energy as a function of time
# (subtract energy at time t=0 to show energy drift)
fig, axs = plt.subplots(2,1)
axs[0].plot(t_verlet,E_verlet-E_verlet[0],label='Verlet',color='black')
axs[1].plot(t_lstm_1,E_lstm_1-E_lstm_1[0],label='32-32',color='blue')
axs[1].plot(t_lstm_2,E_lstm_2-E_lstm_2[0],label='64-64',color='orange')
axs[1].plot(t_lstm_3,E_lstm_3-E_lstm_3[0],label='32-32-64D',color='green')
axs[1].plot(t_lstm_4,E_lstm_4-E_lstm_4[0],label='64-64-32D',color='red')
axs[1].plot(t_lstm_5,E_lstm_5-E_lstm_5[0],label='64-64-64D',color='brown')
axs[1].plot(t_lstm_6,E_lstm_6-E_lstm_6[0],label='64-64-64',color='purple')
axs[1].plot(t_lstm_7,E_lstm_7-E_lstm_7[0],label='64-64-32',color='cyan')
axs[1].plot(t_lstm_8,E_lstm_8-E_lstm_8[0],label='32-32-32',color='darkorange')

plt.legend(loc='top left')
for ax in axs:
    ax.set_xlabel('time $t$')
    ax.set_ylabel('energy shift $E(t)-E(t_0)$')
plt.rc('font', size=12)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=20)    # legend fontsize
plt.rc('figure', titlesize=20)  # fontsize of the figure title
plt.grid()
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:233: MatplotlibDeprecationWarning: Unrecognized location 'top left'. Falling back on 'best'; valid locations are
# 	best
# 	upper right
# 	upper left
# 	lower left
# 	lower right
# 	right
# 	center left
# 	center right
# 	lower center
# 	upper center
# 	center
# This will raise an exception in 3.3.

# %% [markdown]
# ##Focus on best performing architectures

# %%
# Plot position as a function of time
plt.plot(t_verlet,x_verlet,label='Verlet',color='black')
plt.plot(t_lstm_1,x_lstm_1,label='32-32',color='blue')
plt.plot(t_lstm_2,x_lstm_2,label='64-64',color='orange')
plt.plot(t_lstm_3,x_lstm_3,label='32-32-64D',color='green')
plt.plot(t_lstm_4,x_lstm_4,label='64-64-32D',color='red')
plt.plot(t_lstm_5,x_lstm_5,label='64-64-64D',color='brown')
plt.plot(t_lstm_6,x_lstm_6,label='64-64-64',color='purple')
plt.plot(t_lstm_7,x_lstm_7,label='64-64-32',color='cyan')
plt.plot(t_lstm_8,x_lstm_8,label='32-32-32',color='darkorange')
plt.legend(loc='lower right')
ax = plt.gca()
ax.set_xlabel('time $t$')
ax.set_ylabel('position $x(t)$')
ax.set_title('Position')
plt.show()

plt.rcParams['figure.figsize'] = [10, 20]

plt.clf()
# Plot energy as a function of time
# (subtract energy at time t=0 to show energy drift)
fig, axs = plt.subplots(2,1)
#axs[0].plot(t_verlet,E_verlet-E_verlet[0],label='Verlet',color='black')
#axs[1].plot(t_lstm_1,E_lstm_1-E_lstm_1[0],label='32-32',color='blue')
#axs[1].plot(t_lstm_2,E_lstm_2-E_lstm_2[0],label='64-64',color='orange')
#axs[1].plot(t_lstm_3,E_lstm_3-E_lstm_3[0],label='32-32-64D',color='green')
#axs[1].plot(t_lstm_4,E_lstm_4-E_lstm_4[0],label='64-64-32D',color='red')
axs[1].plot(t_lstm_5,E_lstm_5-E_lstm_5[0],label='64-64-64D',color='brown')
axs[1].plot(t_lstm_6,E_lstm_6-E_lstm_6[0],label='64-64-64',color='purple')
axs[1].plot(t_lstm_7,E_lstm_7-E_lstm_7[0],label='64-64-32',color='cyan')
#axs[1].plot(t_lstm_8,E_lstm_8-E_lstm_8[0],label='32-32-32',color='darkorange')

plt.legend(loc='top left')
for ax in axs:
    ax.set_xlabel('time $t$')
    ax.set_ylabel('energy shift $E(t)-E(t_0)$')
plt.rc('font', size=12)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=20)    # legend fontsize
plt.rc('figure', titlesize=20)  # fontsize of the figure title
plt.grid()
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:36: MatplotlibDeprecationWarning: Unrecognized location 'top left'. Falling back on 'best'; valid locations are
# 	best
# 	upper right
# 	upper left
# 	lower left
# 	lower right
# 	right
# 	center left
# 	center right
# 	lower center
# 	upper center
# 	center
# This will raise an exception in 3.3.
