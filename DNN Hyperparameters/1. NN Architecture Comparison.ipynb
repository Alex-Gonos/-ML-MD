# %% [markdown]
# #Architecture comparison for dense neural network based integrator

# %%
import sys
sys.path.append('..')

import random
import numpy as np
from matplotlib import pyplot as plt
from Code.dynamical_system import *
from Code.time_integrator import *
from Code.neuralnet import *

np.random.seed(2512517)
random.seed(2512517)
tf.random.set_seed(2512517)

# %% [markdown]
# ## Neural network integrator
#
# This notebook helps determine the optimal architecture (number of dense layers, number of units in each dense layer) for a  neural network based integrator with a $4$-step method.

# %% [markdown]
# The model system we are using here is the harmonic oscillator, defined by the equations of motion
#
# $$
# \frac{dx}{dt} = v,\qquad\qquad
# \frac{dv}{dt} = -\frac{k}{m}x
# $$
#
# The timestep size of the Neural network integrator is set to $\Delta t=40\Delta t_{\text{Verlet}}$ where $\Delta t_{\text{Verlet}}$ is the step size of the Verlet integrator that is used for training.

# %%
# mass of particle
mass = 1.2
# spring constant of harmonic oscillator
k_spring = 0.9
# timestep for Verlet integrator
dt_verlet = 0.005
# timestep for neural network integrator
dt = 0.2
# number of steps for neural network integrator
nsteps = 4

harmonic_oscillator = HarmonicOscillator(mass,k_spring)
verlet_integrator = VerletIntegrator(harmonic_oscillator,dt_verlet)
nn_integrator_1 = NNIntegrator(harmonic_oscillator,nsteps,dt)
nn_integrator_2 = NN2Integrator(harmonic_oscillator,nsteps,dt)
nn_integrator_3 = NN3Integrator(harmonic_oscillator,nsteps,dt)
nn_integrator_4 = NN4Integrator(harmonic_oscillator,nsteps,dt)
nn_integrator_5 = NN5Integrator(harmonic_oscillator,nsteps,dt)
nn_integrator_6 = NN6Integrator(harmonic_oscillator,nsteps,dt)

# visualise the neural network model
nn_integrator_1.model.summary()
keras.utils.plot_model(nn_integrator_1.model, show_shapes=True)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 4, 2)]       0           []
#
#  flatten (Flatten)              (None, 8)            0           ['input_1[0][0]']
#
#  dense (Dense)                  (None, 32)           288         ['flatten[0][0]']
#
#  dense_1 (Dense)                (None, 64)           2112        ['dense[0][0]']
#
#  dense_2 (Dense)                (None, 32)           2080        ['dense_1[0][0]']
#
#  dense_3 (Dense)                (None, 2)            66          ['dense_2[0][0]']
#
#  tf.unstack (TFOpLambda)        [(None, 2),          0           ['input_1[0][0]']
#                                  (None, 2),
#                                  (None, 2),
#                                  (None, 2)]
#
#  rescaling (Rescaling)          (None, 2)            0           ['dense_3[0][0]']
#
#  add (Add)                      (None, 2)            0           ['tf.unstack[0][3]',
#                                                                   'rescaling[0][0]']
#
# ==================================================================================================
# Total params: 4,546
# Trainable params: 4,546
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
BATCH_SIZE=32
data_generator = DataGenerator(nn_integrator_1,verlet_integrator)


train_batches = data_generator.dataset.batch(BATCH_SIZE)

# %% [markdown]
# ## Train neural network based integrators

# %%
EPOCHS=100
STEPS_PER_EPOCH=100
log_dir = './tb_logs/'
tensorboard_cb = tf.keras.callbacks.TensorBoard(log_dir=log_dir)

result_1 = nn_integrator_1.model.fit(train_batches,epochs=EPOCHS,steps_per_epoch=STEPS_PER_EPOCH,
                                 callbacks=tensorboard_cb)
result_2 = nn_integrator_2.model.fit(train_batches,epochs=EPOCHS,steps_per_epoch=STEPS_PER_EPOCH,
                                 callbacks=tensorboard_cb)
result_3 = nn_integrator_3.model.fit(train_batches,epochs=EPOCHS,steps_per_epoch=STEPS_PER_EPOCH,
                                callbacks=tensorboard_cb)
result_4 = nn_integrator_4.model.fit(train_batches,epochs=EPOCHS,steps_per_epoch=STEPS_PER_EPOCH,
                                 callbacks=tensorboard_cb)
result_5 = nn_integrator_5.model.fit(train_batches,epochs=EPOCHS,steps_per_epoch=STEPS_PER_EPOCH,
                                 callbacks=tensorboard_cb)
result_6 = nn_integrator_6.model.fit(train_batches,epochs=EPOCHS,steps_per_epoch=STEPS_PER_EPOCH,
                                 callbacks=tensorboard_cb)
# Out:
# Epoch 1/100
# 100/100 [==============================] - 9s 80ms/step - loss: 0.0889
# Epoch 2/100
# 100/100 [==============================] - 8s 80ms/step - loss: 0.0293
# Epoch 3/100
# 100/100 [==============================] - 8s 80ms/step - loss: 0.0146
# Epoch 4/100
# 100/100 [==============================] - 8s 81ms/step - loss: 0.0082
# Epoch 5/100
# 100/100 [==============================] - 9s 85ms/step - loss: 0.0058
# Epoch 6/100
# 100/100 [==============================] - 8s 81ms/step - loss: 0.0045
# Epoch 7/100
# 100/100 [==============================] - 8s 83ms/step - loss: 0.0038
# Epoch 8/100
# 100/100 [==============================] - 8s 80ms/step - loss: 0.0031
# Epoch 9/100
# 100/100 [==============================] - 8s 80ms/step - loss: 0.0024
# Epoch 10/100
# 100/100 [==============================] - 8s 80ms/step - loss: 0.0021
# Epoch 11/100
# 100/100 [==============================] - 8s 80ms/step - loss: 0.0022
# Epoch 12/100
# 100/100 [==============================] - 8s 81ms/step - loss: 0.0021
# Epoch 13/100
# 100/100 [==============================] - 8s 81ms/step - loss: 0.0015
# Epoch 14/100
# 100/100 [==============================] - 8s 80ms/step - loss: 0.0016
# Epoch 15/100
# 100/100 [==============================] - 8s 80ms/step - loss: 0.0016
# Epoch 16/100
# 100/100 [==============================] - 8s 80ms/step - loss: 0.0015
# Epoch 17/100
# 100/100 [==============================] - 8s 80ms/step - loss: 0.0012
# Epoch 18/100
# 100/100 [==============================] - 8s 80ms/step - loss: 0.0012
# Epoch 19/100
# 100/100 [==============================] - 8s 80ms/step - loss: 0.0010
# Epoch 20/100
# 100/100 [==============================] - 8s 80ms/step - loss: 9.2555e-04
# Epoch 21/100
# 100/100 [==============================] - 8s 80ms/step - loss: 9.9035e-04
# Epoch 22/100
# 100/100 [==============================] - 8s 80ms/step - loss: 6.2228e-04
# Epoch 23/100
# 100/100 [==============================] - 8s 79ms/step - loss: 6.8268e-04
# Epoch 24/100
# 100/100 [==============================] - 8s 80ms/step - loss: 4.7515e-04
# Epoch 25/100
# 100/100 [==============================] - 8s 80ms/step - loss: 5.2042e-04
# Epoch 26/100
# 100/100 [==============================] - 8s 80ms/step - loss: 5.0467e-04
# Epoch 27/100
# 100/100 [==============================] - 8s 80ms/step - loss: 4.7423e-04
# Epoch 28/100
# 100/100 [==============================] - 8s 79ms/step - loss: 3.3698e-04
# Epoch 29/100
# 100/100 [==============================] - 8s 80ms/step - loss: 3.6445e-04
# Epoch 30/100
# 100/100 [==============================] - 8s 80ms/step - loss: 3.8120e-04
# Epoch 31/100
# 100/100 [==============================] - 8s 80ms/step - loss: 4.7414e-04
# Epoch 32/100
# 100/100 [==============================] - 8s 80ms/step - loss: 2.9642e-04
# Epoch 33/100
# 100/100 [==============================] - 8s 80ms/step - loss: 3.2150e-04
# Epoch 34/100
# 100/100 [==============================] - 8s 80ms/step - loss: 3.0014e-04
# Epoch 35/100
# 100/100 [==============================] - 8s 80ms/step - loss: 2.5877e-04
# Epoch 36/100
# 100/100 [==============================] - 8s 79ms/step - loss: 3.3521e-04
# Epoch 37/100
# 100/100 [==============================] - 8s 80ms/step - loss: 3.1866e-04
# Epoch 38/100
# 100/100 [==============================] - 8s 80ms/step - loss: 2.6278e-04
# Epoch 39/100
# 100/100 [==============================] - 8s 80ms/step - loss: 2.0673e-04
# Epoch 40/100
# 100/100 [==============================] - 8s 80ms/step - loss: 2.8635e-04
# Epoch 41/100
# 100/100 [==============================] - 8s 80ms/step - loss: 2.5597e-04
# Epoch 42/100
# 100/100 [==============================] - 8s 80ms/step - loss: 2.4905e-04
# Epoch 43/100
# 100/100 [==============================] - 8s 80ms/step - loss: 2.8851e-04
# Epoch 44/100
# 100/100 [==============================] - 8s 81ms/step - loss: 2.2047e-04
# Epoch 45/100
# 100/100 [==============================] - 8s 81ms/step - loss: 2.0814e-04
# Epoch 46/100
# 100/100 [==============================] - 8s 80ms/step - loss: 1.8842e-04
# Epoch 47/100
# 100/100 [==============================] - 8s 80ms/step - loss: 2.0885e-04
# Epoch 48/100
# 100/100 [==============================] - 8s 80ms/step - loss: 1.9551e-04
# Epoch 49/100
# 100/100 [==============================] - 8s 80ms/step - loss: 1.6816e-04
# Epoch 50/100
# 100/100 [==============================] - 8s 80ms/step - loss: 2.2083e-04
# Epoch 51/100
# 100/100 [==============================] - 8s 80ms/step - loss: 2.1835e-04
# Epoch 52/100
# 100/100 [==============================] - 8s 81ms/step - loss: 1.8535e-04
# Epoch 53/100
# 100/100 [==============================] - 8s 81ms/step - loss: 2.5626e-04
# Epoch 54/100
# 100/100 [==============================] - 8s 80ms/step - loss: 1.8337e-04
# Epoch 55/100
# 100/100 [==============================] - 8s 80ms/step - loss: 1.8660e-04
# Epoch 56/100
# 100/100 [==============================] - 8s 80ms/step - loss: 1.3213e-04
# Epoch 57/100
# 100/100 [==============================] - 8s 80ms/step - loss: 1.4853e-04
# Epoch 58/100
# 100/100 [==============================] - 8s 80ms/step - loss: 1.6811e-04
# Epoch 59/100
# 100/100 [==============================] - 8s 80ms/step - loss: 1.5257e-04
# Epoch 60/100
# 100/100 [==============================] - 8s 80ms/step - loss: 1.3876e-04
# Epoch 61/100
# 100/100 [==============================] - 8s 81ms/step - loss: 1.4495e-04
# Epoch 62/100
# 100/100 [==============================] - 8s 81ms/step - loss: 1.3301e-04
# Epoch 63/100
# 100/100 [==============================] - 8s 80ms/step - loss: 1.6460e-04
# Epoch 64/100
# 100/100 [==============================] - 8s 80ms/step - loss: 1.9682e-04
# Epoch 65/100
# 100/100 [==============================] - 8s 81ms/step - loss: 1.4445e-04
# Epoch 66/100
# 100/100 [==============================] - 8s 80ms/step - loss: 1.2078e-04
# Epoch 67/100
# 100/100 [==============================] - 8s 81ms/step - loss: 9.1281e-05
# Epoch 68/100
# 100/100 [==============================] - 8s 80ms/step - loss: 1.4577e-04
# Epoch 69/100
# 100/100 [==============================] - 8s 81ms/step - loss: 1.4760e-04
# Epoch 70/100
# 100/100 [==============================] - 8s 81ms/step - loss: 1.0572e-04
# Epoch 71/100
# 100/100 [==============================] - 8s 81ms/step - loss: 1.2012e-04
# Epoch 72/100
# 100/100 [==============================] - 8s 80ms/step - loss: 1.5870e-04
# Epoch 73/100
# 100/100 [==============================] - 8s 80ms/step - loss: 1.4181e-04
# Epoch 74/100
# 100/100 [==============================] - 8s 80ms/step - loss: 9.1492e-05
# Epoch 75/100
# 100/100 [==============================] - 8s 80ms/step - loss: 9.7634e-05
# Epoch 76/100
# 100/100 [==============================] - 8s 80ms/step - loss: 1.0732e-04
# Epoch 77/100
# 100/100 [==============================] - 8s 80ms/step - loss: 1.2695e-04
# Epoch 78/100
# 100/100 [==============================] - 8s 80ms/step - loss: 2.1454e-04
# Epoch 79/100
# 100/100 [==============================] - 8s 80ms/step - loss: 1.0029e-04
# Epoch 80/100
# 100/100 [==============================] - 8s 81ms/step - loss: 9.3374e-05
# Epoch 81/100
# 100/100 [==============================] - 8s 81ms/step - loss: 1.2060e-04
# Epoch 82/100
# 100/100 [==============================] - 8s 81ms/step - loss: 1.0638e-04
# Epoch 83/100
# 100/100 [==============================] - 8s 80ms/step - loss: 1.0608e-04
# Epoch 84/100
# 100/100 [==============================] - 8s 81ms/step - loss: 1.2778e-04
# Epoch 85/100
# 100/100 [==============================] - 8s 81ms/step - loss: 8.0478e-05
# Epoch 86/100
# 100/100 [==============================] - 8s 80ms/step - loss: 9.5654e-05
# Epoch 87/100
# 100/100 [==============================] - 8s 80ms/step - loss: 1.0996e-04
# Epoch 88/100
# 100/100 [==============================] - 8s 80ms/step - loss: 7.6380e-05
# Epoch 89/100
# 100/100 [==============================] - 8s 81ms/step - loss: 8.6082e-05
# Epoch 90/100
# 100/100 [==============================] - 8s 79ms/step - loss: 8.1223e-05
# Epoch 91/100
# 100/100 [==============================] - 8s 80ms/step - loss: 8.9036e-05
# Epoch 92/100
# 100/100 [==============================] - 8s 80ms/step - loss: 8.2565e-05
# Epoch 93/100
# 100/100 [==============================] - 8s 80ms/step - loss: 7.2308e-05
# Epoch 94/100
# 100/100 [==============================] - 8s 80ms/step - loss: 8.8703e-05
# Epoch 95/100
# 100/100 [==============================] - 8s 80ms/step - loss: 9.3441e-05
# Epoch 96/100
# 100/100 [==============================] - 8s 80ms/step - loss: 8.4614e-05
# Epoch 97/100
# 100/100 [==============================] - 8s 80ms/step - loss: 7.9734e-05
# Epoch 98/100
# 100/100 [==============================] - 8s 80ms/step - loss: 4.4420e-05
# Epoch 99/100
# 100/100 [==============================] - 8s 81ms/step - loss: 9.0904e-05
# Epoch 100/100
# 100/100 [==============================] - 8s 80ms/step - loss: 7.5452e-05
# Epoch 1/100
# 100/100 [==============================] - 8s 81ms/step - loss: 0.0461
# Epoch 2/100
# 100/100 [==============================] - 8s 80ms/step - loss: 0.0049
# Epoch 3/100
# 100/100 [==============================] - 8s 80ms/step - loss: 0.0027
# Epoch 4/100
# 100/100 [==============================] - 8s 80ms/step - loss: 0.0022
# Epoch 5/100
# 100/100 [==============================] - 8s 80ms/step - loss: 0.0017
# Epoch 6/100
# 100/100 [==============================] - 8s 80ms/step - loss: 0.0012
# Epoch 7/100
# 100/100 [==============================] - 8s 81ms/step - loss: 0.0012
# Epoch 8/100
# 100/100 [==============================] - 8s 81ms/step - loss: 8.9600e-04
# Epoch 9/100
# 100/100 [==============================] - 8s 80ms/step - loss: 8.5696e-04
# Epoch 10/100
# 100/100 [==============================] - 8s 80ms/step - loss: 7.9026e-04
# Epoch 11/100
# 100/100 [==============================] - 8s 80ms/step - loss: 8.9593e-04
# Epoch 12/100
# 100/100 [==============================] - 8s 80ms/step - loss: 6.6271e-04
# Epoch 13/100
# 100/100 [==============================] - 8s 81ms/step - loss: 6.5329e-04
# Epoch 14/100
# 100/100 [==============================] - 8s 80ms/step - loss: 5.5037e-04
# Epoch 15/100
# 100/100 [==============================] - 8s 81ms/step - loss: 5.6737e-04
# Epoch 16/100
# 100/100 [==============================] - 8s 81ms/step - loss: 5.9498e-04
# Epoch 17/100
# 100/100 [==============================] - 8s 81ms/step - loss: 6.1046e-04
# Epoch 18/100
# 100/100 [==============================] - 8s 82ms/step - loss: 5.4271e-04
# Epoch 19/100
# 100/100 [==============================] - 8s 81ms/step - loss: 4.5342e-04
# Epoch 20/100
# 100/100 [==============================] - 8s 81ms/step - loss: 4.1263e-04
# Epoch 21/100
# 100/100 [==============================] - 8s 81ms/step - loss: 3.6483e-04
# Epoch 22/100
# 100/100 [==============================] - 8s 80ms/step - loss: 2.9893e-04
# Epoch 23/100
# 100/100 [==============================] - 8s 81ms/step - loss: 3.3097e-04
# Epoch 24/100
# 100/100 [==============================] - 8s 81ms/step - loss: 3.7657e-04
# Epoch 25/100
# 100/100 [==============================] - 8s 80ms/step - loss: 3.3345e-04
# Epoch 26/100
# 100/100 [==============================] - 8s 81ms/step - loss: 3.2435e-04
# Epoch 27/100
# 100/100 [==============================] - 8s 81ms/step - loss: 3.0284e-04
# Epoch 28/100
# 100/100 [==============================] - 8s 79ms/step - loss: 2.4870e-04
# Epoch 29/100
# 100/100 [==============================] - 8s 81ms/step - loss: 2.2966e-04
# Epoch 30/100
# 100/100 [==============================] - 8s 81ms/step - loss: 2.9433e-04
# Epoch 31/100
# 100/100 [==============================] - 8s 80ms/step - loss: 2.6280e-04
# Epoch 32/100
# 100/100 [==============================] - 8s 80ms/step - loss: 2.7106e-04
# Epoch 33/100
# 100/100 [==============================] - 8s 80ms/step - loss: 2.6139e-04
# Epoch 34/100
# 100/100 [==============================] - 8s 80ms/step - loss: 2.6124e-04
# Epoch 35/100
# 100/100 [==============================] - 8s 81ms/step - loss: 2.1438e-04
# Epoch 36/100
# 100/100 [==============================] - 8s 81ms/step - loss: 2.4403e-04
# Epoch 37/100
# 100/100 [==============================] - 8s 80ms/step - loss: 1.7320e-04
# Epoch 38/100
# 100/100 [==============================] - 8s 80ms/step - loss: 1.8291e-04
# Epoch 39/100
# 100/100 [==============================] - 8s 81ms/step - loss: 1.7107e-04
# Epoch 40/100
# 100/100 [==============================] - 8s 81ms/step - loss: 2.1184e-04
# Epoch 41/100
# 100/100 [==============================] - 8s 81ms/step - loss: 2.2492e-04
# Epoch 42/100
# 100/100 [==============================] - 8s 81ms/step - loss: 1.9850e-04
# Epoch 43/100
# 100/100 [==============================] - 8s 81ms/step - loss: 1.7297e-04
# Epoch 44/100
# 100/100 [==============================] - 8s 82ms/step - loss: 1.4654e-04
# Epoch 45/100
# 100/100 [==============================] - 8s 81ms/step - loss: 1.4614e-04
# Epoch 46/100
# 100/100 [==============================] - 8s 80ms/step - loss: 1.5850e-04
# Epoch 47/100
# 100/100 [==============================] - 8s 81ms/step - loss: 1.5176e-04
# Epoch 48/100
# 100/100 [==============================] - 8s 81ms/step - loss: 1.5376e-04
# Epoch 49/100
# 100/100 [==============================] - 8s 81ms/step - loss: 1.5437e-04
# Epoch 50/100
# 100/100 [==============================] - 8s 81ms/step - loss: 1.7370e-04
# Epoch 51/100
# 100/100 [==============================] - 8s 82ms/step - loss: 1.4362e-04
# Epoch 52/100
# 100/100 [==============================] - 8s 81ms/step - loss: 1.5407e-04
# Epoch 53/100
# 100/100 [==============================] - 8s 81ms/step - loss: 1.3116e-04
# Epoch 54/100
# 100/100 [==============================] - 8s 81ms/step - loss: 1.3302e-04
# Epoch 55/100
# 100/100 [==============================] - 8s 82ms/step - loss: 1.4614e-04
# Epoch 56/100
# 100/100 [==============================] - 8s 81ms/step - loss: 1.1177e-04
# Epoch 57/100
# 100/100 [==============================] - 8s 81ms/step - loss: 1.1570e-04
# Epoch 58/100
# 100/100 [==============================] - 8s 81ms/step - loss: 1.1111e-04
# Epoch 59/100
# 100/100 [==============================] - 8s 81ms/step - loss: 1.0895e-04
# Epoch 60/100
# 100/100 [==============================] - 8s 81ms/step - loss: 1.0861e-04
# Epoch 61/100
# 100/100 [==============================] - 8s 81ms/step - loss: 1.1957e-04
# Epoch 62/100
# 100/100 [==============================] - 8s 81ms/step - loss: 1.4201e-04
# Epoch 63/100
# 100/100 [==============================] - 8s 82ms/step - loss: 1.1256e-04
# Epoch 64/100
# 100/100 [==============================] - 8s 81ms/step - loss: 8.2571e-05
# Epoch 65/100
# 100/100 [==============================] - 8s 81ms/step - loss: 1.2083e-04
# Epoch 66/100
# 100/100 [==============================] - 8s 81ms/step - loss: 1.1442e-04
# Epoch 67/100
# 100/100 [==============================] - 8s 80ms/step - loss: 1.2903e-04
# Epoch 68/100
# 100/100 [==============================] - 8s 81ms/step - loss: 9.2463e-05
# Epoch 69/100
# 100/100 [==============================] - 8s 80ms/step - loss: 1.2956e-04
# Epoch 70/100
# 100/100 [==============================] - 8s 80ms/step - loss: 9.3097e-05
# Epoch 71/100
# 100/100 [==============================] - 8s 81ms/step - loss: 1.3530e-04
# Epoch 72/100
# 100/100 [==============================] - 8s 81ms/step - loss: 1.0086e-04
# Epoch 73/100
# 100/100 [==============================] - 8s 80ms/step - loss: 8.8242e-05
# Epoch 74/100
# 100/100 [==============================] - 8s 81ms/step - loss: 9.6591e-05
# Epoch 75/100
# 100/100 [==============================] - 8s 80ms/step - loss: 1.1484e-04
# Epoch 76/100
# 100/100 [==============================] - 8s 81ms/step - loss: 8.8182e-05
# Epoch 77/100
# 100/100 [==============================] - 8s 81ms/step - loss: 8.2178e-05
# Epoch 78/100
# 100/100 [==============================] - 8s 81ms/step - loss: 9.4613e-05
# Epoch 79/100
# 100/100 [==============================] - 8s 81ms/step - loss: 1.0700e-04
# Epoch 80/100
# 100/100 [==============================] - 8s 81ms/step - loss: 8.9975e-05
# Epoch 81/100
# 100/100 [==============================] - 8s 81ms/step - loss: 9.1484e-05
# Epoch 82/100
# 100/100 [==============================] - 8s 81ms/step - loss: 1.0914e-04
# Epoch 83/100
# 100/100 [==============================] - 8s 81ms/step - loss: 8.9972e-05
# Epoch 84/100
# 100/100 [==============================] - 8s 81ms/step - loss: 9.3253e-05
# Epoch 85/100
# 100/100 [==============================] - 8s 80ms/step - loss: 7.0964e-05
# Epoch 86/100
# 100/100 [==============================] - 8s 81ms/step - loss: 9.4956e-05
# Epoch 87/100
# 100/100 [==============================] - 8s 80ms/step - loss: 9.2465e-05
# Epoch 88/100
# 100/100 [==============================] - 8s 82ms/step - loss: 9.0655e-05
# Epoch 89/100
# 100/100 [==============================] - 8s 81ms/step - loss: 8.2904e-05
# Epoch 90/100
# 100/100 [==============================] - 8s 81ms/step - loss: 6.9551e-05
# Epoch 91/100
# 100/100 [==============================] - 8s 81ms/step - loss: 6.9719e-05
# Epoch 92/100
# 100/100 [==============================] - 8s 82ms/step - loss: 7.9359e-05
# Epoch 93/100
# 100/100 [==============================] - 8s 82ms/step - loss: 8.1812e-05
# Epoch 94/100
# 100/100 [==============================] - 8s 81ms/step - loss: 5.9688e-05
# Epoch 95/100
# 100/100 [==============================] - 8s 81ms/step - loss: 8.3546e-05
# Epoch 96/100
# 100/100 [==============================] - 8s 82ms/step - loss: 6.8455e-05
# Epoch 97/100
# 100/100 [==============================] - 8s 80ms/step - loss: 8.0512e-05
# Epoch 98/100
# 100/100 [==============================] - 8s 82ms/step - loss: 7.5320e-05
# Epoch 99/100
# 100/100 [==============================] - 8s 81ms/step - loss: 6.2095e-05
# Epoch 100/100
# 100/100 [==============================] - 8s 81ms/step - loss: 5.3810e-05
# Epoch 1/100
# 100/100 [==============================] - 8s 81ms/step - loss: 0.0688
# Epoch 2/100
# 100/100 [==============================] - 8s 82ms/step - loss: 0.0192
# Epoch 3/100
# 100/100 [==============================] - 8s 81ms/step - loss: 0.0073
# Epoch 4/100
# 100/100 [==============================] - 8s 81ms/step - loss: 0.0049
# Epoch 5/100
# 100/100 [==============================] - 8s 82ms/step - loss: 0.0037
# Epoch 6/100
# 100/100 [==============================] - 8s 81ms/step - loss: 0.0030
# Epoch 7/100
# 100/100 [==============================] - 8s 81ms/step - loss: 0.0025
# Epoch 8/100
# 100/100 [==============================] - 8s 80ms/step - loss: 0.0019
# Epoch 9/100
# 100/100 [==============================] - 8s 81ms/step - loss: 0.0017
# Epoch 10/100
# 100/100 [==============================] - 8s 81ms/step - loss: 0.0014
# Epoch 11/100
# 100/100 [==============================] - 8s 82ms/step - loss: 0.0012
# Epoch 12/100
# 100/100 [==============================] - 8s 82ms/step - loss: 0.0012
# Epoch 13/100
# 100/100 [==============================] - 8s 81ms/step - loss: 0.0011
# Epoch 14/100
# 100/100 [==============================] - 8s 82ms/step - loss: 9.8100e-04
# Epoch 15/100
# 100/100 [==============================] - 8s 81ms/step - loss: 7.6417e-04
# Epoch 16/100
# 100/100 [==============================] - 8s 82ms/step - loss: 9.3876e-04
# Epoch 17/100
# 100/100 [==============================] - 8s 81ms/step - loss: 7.4141e-04
# Epoch 18/100
# 100/100 [==============================] - 8s 81ms/step - loss: 7.7816e-04
# Epoch 19/100
# 100/100 [==============================] - 8s 82ms/step - loss: 7.0634e-04
# Epoch 20/100
# 100/100 [==============================] - 8s 81ms/step - loss: 6.2257e-04
# Epoch 21/100
# 100/100 [==============================] - 8s 82ms/step - loss: 6.0818e-04
# Epoch 22/100
# 100/100 [==============================] - 8s 81ms/step - loss: 5.2927e-04
# Epoch 23/100
# 100/100 [==============================] - 8s 82ms/step - loss: 5.5952e-04
# Epoch 24/100
# 100/100 [==============================] - 8s 82ms/step - loss: 5.6513e-04
# Epoch 25/100
# 100/100 [==============================] - 8s 81ms/step - loss: 4.5296e-04
# Epoch 26/100
# 100/100 [==============================] - 8s 81ms/step - loss: 4.4478e-04
# Epoch 27/100
# 100/100 [==============================] - 8s 81ms/step - loss: 4.6907e-04
# Epoch 28/100
# 100/100 [==============================] - 8s 82ms/step - loss: 3.8442e-04
# Epoch 29/100
# 100/100 [==============================] - 8s 83ms/step - loss: 3.4834e-04
# Epoch 30/100
# 100/100 [==============================] - 8s 82ms/step - loss: 3.6540e-04
# Epoch 31/100
# 100/100 [==============================] - 8s 82ms/step - loss: 3.5424e-04
# Epoch 32/100
# 100/100 [==============================] - 8s 81ms/step - loss: 3.4754e-04
# Epoch 33/100
# 100/100 [==============================] - 8s 81ms/step - loss: 3.6936e-04
# Epoch 34/100
# 100/100 [==============================] - 8s 81ms/step - loss: 3.7444e-04
# Epoch 35/100
# 100/100 [==============================] - 8s 81ms/step - loss: 3.5224e-04
# Epoch 36/100
# 100/100 [==============================] - 8s 81ms/step - loss: 3.9699e-04
# Epoch 37/100
# 100/100 [==============================] - 8s 81ms/step - loss: 2.8461e-04
# Epoch 38/100
# 100/100 [==============================] - 8s 82ms/step - loss: 2.6447e-04
# Epoch 39/100
# 100/100 [==============================] - 8s 81ms/step - loss: 3.3027e-04
# Epoch 40/100
# 100/100 [==============================] - 8s 81ms/step - loss: 2.6482e-04
# Epoch 41/100
# 100/100 [==============================] - 8s 82ms/step - loss: 3.2542e-04
# Epoch 42/100
# 100/100 [==============================] - 8s 81ms/step - loss: 2.5907e-04
# Epoch 43/100
# 100/100 [==============================] - 8s 81ms/step - loss: 2.5779e-04
# Epoch 44/100
# 100/100 [==============================] - 8s 81ms/step - loss: 2.3665e-04
# Epoch 45/100
# 100/100 [==============================] - 8s 81ms/step - loss: 2.2954e-04
# Epoch 46/100
# 100/100 [==============================] - 8s 81ms/step - loss: 2.2155e-04
# Epoch 47/100
# 100/100 [==============================] - 8s 82ms/step - loss: 2.2778e-04
# Epoch 48/100
# 100/100 [==============================] - 8s 80ms/step - loss: 1.9857e-04
# Epoch 49/100
# 100/100 [==============================] - 8s 81ms/step - loss: 2.2245e-04
# Epoch 50/100
# 100/100 [==============================] - 8s 81ms/step - loss: 2.1354e-04
# Epoch 51/100
# 100/100 [==============================] - 8s 82ms/step - loss: 1.6823e-04
# Epoch 52/100
# 100/100 [==============================] - 8s 82ms/step - loss: 2.5672e-04
# Epoch 53/100
# 100/100 [==============================] - 8s 82ms/step - loss: 2.5610e-04
# Epoch 54/100
# 100/100 [==============================] - 8s 83ms/step - loss: 2.1986e-04
# Epoch 55/100
# 100/100 [==============================] - 8s 81ms/step - loss: 1.8237e-04
# Epoch 56/100
# 100/100 [==============================] - 8s 81ms/step - loss: 1.8396e-04
# Epoch 57/100
# 100/100 [==============================] - 8s 82ms/step - loss: 1.7687e-04
# Epoch 58/100
# 100/100 [==============================] - 8s 82ms/step - loss: 2.2904e-04
# Epoch 59/100
# 100/100 [==============================] - 8s 82ms/step - loss: 2.1085e-04
# Epoch 60/100
# 100/100 [==============================] - 8s 81ms/step - loss: 1.8826e-04
# Epoch 61/100
# 100/100 [==============================] - 8s 82ms/step - loss: 2.0174e-04
# Epoch 62/100
# 100/100 [==============================] - 8s 82ms/step - loss: 1.5154e-04
# Epoch 63/100
# 100/100 [==============================] - 8s 82ms/step - loss: 1.5289e-04
# Epoch 64/100
# 100/100 [==============================] - 8s 82ms/step - loss: 1.5390e-04
# Epoch 65/100
# 100/100 [==============================] - 8s 82ms/step - loss: 2.2593e-04
# Epoch 66/100
# 100/100 [==============================] - 8s 82ms/step - loss: 1.4625e-04
# Epoch 67/100
# 100/100 [==============================] - 8s 81ms/step - loss: 1.7812e-04
# Epoch 68/100
# 100/100 [==============================] - 8s 82ms/step - loss: 1.7817e-04
# Epoch 69/100
# 100/100 [==============================] - 8s 82ms/step - loss: 1.6298e-04
# Epoch 70/100
# 100/100 [==============================] - 8s 81ms/step - loss: 1.6367e-04
# Epoch 71/100
# 100/100 [==============================] - 8s 81ms/step - loss: 2.1027e-04
# Epoch 72/100
# 100/100 [==============================] - 8s 82ms/step - loss: 1.2218e-04
# Epoch 73/100
# 100/100 [==============================] - 8s 82ms/step - loss: 1.4964e-04
# Epoch 74/100
# 100/100 [==============================] - 8s 81ms/step - loss: 1.3892e-04
# Epoch 75/100
# 100/100 [==============================] - 8s 82ms/step - loss: 1.6327e-04
# Epoch 76/100
# 100/100 [==============================] - 8s 82ms/step - loss: 1.6705e-04
# Epoch 77/100
# 100/100 [==============================] - 8s 81ms/step - loss: 1.3536e-04
# Epoch 78/100
# 100/100 [==============================] - 8s 81ms/step - loss: 1.2480e-04
# Epoch 79/100
# 100/100 [==============================] - 8s 83ms/step - loss: 1.5894e-04
# Epoch 80/100
# 100/100 [==============================] - 8s 82ms/step - loss: 1.2278e-04
# Epoch 81/100
# 100/100 [==============================] - 8s 82ms/step - loss: 1.1251e-04
# Epoch 82/100
# 100/100 [==============================] - 8s 82ms/step - loss: 1.2486e-04
# Epoch 83/100
# 100/100 [==============================] - 8s 83ms/step - loss: 1.3779e-04
# Epoch 84/100
# 100/100 [==============================] - 8s 82ms/step - loss: 1.6573e-04
# Epoch 85/100
# 100/100 [==============================] - 8s 82ms/step - loss: 1.2582e-04
# Epoch 86/100
# 100/100 [==============================] - 8s 82ms/step - loss: 1.2783e-04
# Epoch 87/100
# 100/100 [==============================] - 8s 82ms/step - loss: 2.2052e-04
# Epoch 88/100
# 100/100 [==============================] - 8s 82ms/step - loss: 1.0778e-04
# Epoch 89/100
# 100/100 [==============================] - 8s 83ms/step - loss: 1.3759e-04
# Epoch 90/100
# 100/100 [==============================] - 8s 82ms/step - loss: 1.0737e-04
# Epoch 91/100
# 100/100 [==============================] - 8s 82ms/step - loss: 1.0407e-04
# Epoch 92/100
# 100/100 [==============================] - 8s 81ms/step - loss: 1.1654e-04
# Epoch 93/100
# 100/100 [==============================] - 8s 81ms/step - loss: 1.3374e-04
# Epoch 94/100
# 100/100 [==============================] - 8s 81ms/step - loss: 1.3349e-04
# Epoch 95/100
# 100/100 [==============================] - 8s 82ms/step - loss: 1.4318e-04
# Epoch 96/100
# 100/100 [==============================] - 8s 82ms/step - loss: 1.4837e-04
# Epoch 97/100
# 100/100 [==============================] - 8s 82ms/step - loss: 9.5709e-05
# Epoch 98/100
# 100/100 [==============================] - 8s 82ms/step - loss: 1.2192e-04
# Epoch 99/100
# 100/100 [==============================] - 8s 82ms/step - loss: 1.3838e-04
# Epoch 100/100
# 100/100 [==============================] - 8s 83ms/step - loss: 1.1457e-04
# Epoch 1/100
# 100/100 [==============================] - 9s 83ms/step - loss: 0.0609
# Epoch 2/100
# 100/100 [==============================] - 8s 82ms/step - loss: 0.0108
# Epoch 3/100
# 100/100 [==============================] - 8s 82ms/step - loss: 0.0051
# Epoch 4/100
# 100/100 [==============================] - 8s 82ms/step - loss: 0.0041
# Epoch 5/100
# 100/100 [==============================] - 8s 82ms/step - loss: 0.0027
# Epoch 6/100
# 100/100 [==============================] - 8s 82ms/step - loss: 0.0024
# Epoch 7/100
# 100/100 [==============================] - 8s 81ms/step - loss: 0.0022
# Epoch 8/100
# 100/100 [==============================] - 8s 81ms/step - loss: 0.0016
# Epoch 9/100
# 100/100 [==============================] - 8s 82ms/step - loss: 0.0015
# Epoch 10/100
# 100/100 [==============================] - 8s 83ms/step - loss: 0.0013
# Epoch 11/100
# 100/100 [==============================] - 8s 82ms/step - loss: 0.0013
# Epoch 12/100
# 100/100 [==============================] - 8s 82ms/step - loss: 0.0012
# Epoch 13/100
# 100/100 [==============================] - 8s 82ms/step - loss: 8.4950e-04
# Epoch 14/100
# 100/100 [==============================] - 8s 82ms/step - loss: 9.0599e-04
# Epoch 15/100
# 100/100 [==============================] - 8s 81ms/step - loss: 9.1123e-04
# Epoch 16/100
# 100/100 [==============================] - 8s 81ms/step - loss: 6.7628e-04
# Epoch 17/100
# 100/100 [==============================] - 8s 82ms/step - loss: 6.7629e-04
# Epoch 18/100
# 100/100 [==============================] - 8s 82ms/step - loss: 7.0272e-04
# Epoch 19/100
# 100/100 [==============================] - 8s 82ms/step - loss: 5.5122e-04
# Epoch 20/100
# 100/100 [==============================] - 8s 82ms/step - loss: 5.6081e-04
# Epoch 21/100
# 100/100 [==============================] - 8s 81ms/step - loss: 5.7103e-04
# Epoch 22/100
# 100/100 [==============================] - 8s 82ms/step - loss: 5.4481e-04
# Epoch 23/100
# 100/100 [==============================] - 8s 82ms/step - loss: 5.1318e-04
# Epoch 24/100
# 100/100 [==============================] - 8s 82ms/step - loss: 4.3705e-04
# Epoch 25/100
# 100/100 [==============================] - 8s 81ms/step - loss: 4.1971e-04
# Epoch 26/100
# 100/100 [==============================] - 8s 81ms/step - loss: 4.3630e-04
# Epoch 27/100
# 100/100 [==============================] - 8s 82ms/step - loss: 3.9983e-04
# Epoch 28/100
# 100/100 [==============================] - 8s 83ms/step - loss: 4.0722e-04
# Epoch 29/100
# 100/100 [==============================] - 8s 82ms/step - loss: 4.4269e-04
# Epoch 30/100
# 100/100 [==============================] - 8s 81ms/step - loss: 4.2802e-04
# Epoch 31/100
# 100/100 [==============================] - 8s 82ms/step - loss: 4.3376e-04
# Epoch 32/100
# 100/100 [==============================] - 8s 82ms/step - loss: 3.4826e-04
# Epoch 33/100
# 100/100 [==============================] - 8s 82ms/step - loss: 2.7444e-04
# Epoch 34/100
# 100/100 [==============================] - 8s 82ms/step - loss: 3.5571e-04
# Epoch 35/100
# 100/100 [==============================] - 8s 82ms/step - loss: 3.3280e-04
# Epoch 36/100
# 100/100 [==============================] - 8s 82ms/step - loss: 2.9925e-04
# Epoch 37/100
# 100/100 [==============================] - 8s 82ms/step - loss: 3.1361e-04
# Epoch 38/100
# 100/100 [==============================] - 8s 82ms/step - loss: 2.9147e-04
# Epoch 39/100
# 100/100 [==============================] - 8s 82ms/step - loss: 2.2822e-04
# Epoch 40/100
# 100/100 [==============================] - 8s 82ms/step - loss: 2.7259e-04
# Epoch 41/100
# 100/100 [==============================] - 8s 83ms/step - loss: 2.1636e-04
# Epoch 42/100
# 100/100 [==============================] - 8s 82ms/step - loss: 2.5268e-04
# Epoch 43/100
# 100/100 [==============================] - 8s 82ms/step - loss: 2.3479e-04
# Epoch 44/100
# 100/100 [==============================] - 8s 82ms/step - loss: 2.4842e-04
# Epoch 45/100
# 100/100 [==============================] - 8s 81ms/step - loss: 2.2207e-04
# Epoch 46/100
# 100/100 [==============================] - 8s 82ms/step - loss: 1.8410e-04
# Epoch 47/100
# 100/100 [==============================] - 8s 83ms/step - loss: 2.0355e-04
# Epoch 48/100
# 100/100 [==============================] - 8s 82ms/step - loss: 1.8182e-04
# Epoch 49/100
# 100/100 [==============================] - 8s 82ms/step - loss: 2.2869e-04
# Epoch 50/100
# 100/100 [==============================] - 8s 82ms/step - loss: 1.3963e-04
# Epoch 51/100
# 100/100 [==============================] - 8s 83ms/step - loss: 1.5677e-04
# Epoch 52/100
# 100/100 [==============================] - 8s 82ms/step - loss: 1.2951e-04
# Epoch 53/100
# 100/100 [==============================] - 8s 81ms/step - loss: 1.3564e-04
# Epoch 54/100
# 100/100 [==============================] - 8s 82ms/step - loss: 1.1554e-04
# Epoch 55/100
# 100/100 [==============================] - 8s 82ms/step - loss: 1.3810e-04
# Epoch 56/100
# 100/100 [==============================] - 8s 82ms/step - loss: 1.1844e-04
# Epoch 57/100
# 100/100 [==============================] - 8s 82ms/step - loss: 1.4927e-04
# Epoch 58/100
# 100/100 [==============================] - 8s 82ms/step - loss: 1.0934e-04
# Epoch 59/100
# 100/100 [==============================] - 8s 82ms/step - loss: 1.1850e-04
# Epoch 60/100
# 100/100 [==============================] - 8s 82ms/step - loss: 8.7530e-05
# Epoch 61/100
# 100/100 [==============================] - 8s 82ms/step - loss: 1.0710e-04
# Epoch 62/100
# 100/100 [==============================] - 8s 82ms/step - loss: 1.2159e-04
# Epoch 63/100
# 100/100 [==============================] - 8s 82ms/step - loss: 8.7767e-05
# Epoch 64/100
# 100/100 [==============================] - 8s 82ms/step - loss: 6.4444e-05
# Epoch 65/100
# 100/100 [==============================] - 8s 82ms/step - loss: 6.7683e-05
# Epoch 66/100
# 100/100 [==============================] - 8s 82ms/step - loss: 9.4529e-05
# Epoch 67/100
# 100/100 [==============================] - 8s 82ms/step - loss: 7.5058e-05
# Epoch 68/100
# 100/100 [==============================] - 8s 82ms/step - loss: 6.9218e-05
# Epoch 69/100
# 100/100 [==============================] - 8s 82ms/step - loss: 6.8949e-05
# Epoch 70/100
# 100/100 [==============================] - 8s 83ms/step - loss: 6.7757e-05
# Epoch 71/100
# 100/100 [==============================] - 8s 82ms/step - loss: 5.3617e-05
# Epoch 72/100
# 100/100 [==============================] - 8s 82ms/step - loss: 6.1732e-05
# Epoch 73/100
# 100/100 [==============================] - 8s 82ms/step - loss: 6.4575e-05
# Epoch 74/100
# 100/100 [==============================] - 8s 83ms/step - loss: 5.5499e-05
# Epoch 75/100
# 100/100 [==============================] - 8s 82ms/step - loss: 5.8137e-05
# Epoch 76/100
# 100/100 [==============================] - 8s 83ms/step - loss: 4.6678e-05
# Epoch 77/100
# 100/100 [==============================] - 8s 83ms/step - loss: 4.4039e-05
# Epoch 78/100
# 100/100 [==============================] - 8s 82ms/step - loss: 4.8057e-05
# Epoch 79/100
# 100/100 [==============================] - 8s 83ms/step - loss: 4.1996e-05
# Epoch 80/100
# 100/100 [==============================] - 8s 83ms/step - loss: 5.9357e-05
# Epoch 81/100
# 100/100 [==============================] - 8s 82ms/step - loss: 3.8878e-05
# Epoch 82/100
# 100/100 [==============================] - 8s 84ms/step - loss: 3.8370e-05
# Epoch 83/100
# 100/100 [==============================] - 8s 83ms/step - loss: 4.3311e-05
# Epoch 84/100
# 100/100 [==============================] - 8s 83ms/step - loss: 4.3855e-05
# Epoch 85/100
# 100/100 [==============================] - 8s 83ms/step - loss: 4.2014e-05
# Epoch 86/100
# 100/100 [==============================] - 8s 83ms/step - loss: 5.1010e-05
# Epoch 87/100
# 100/100 [==============================] - 8s 83ms/step - loss: 4.0769e-05
# Epoch 88/100
# 100/100 [==============================] - 8s 82ms/step - loss: 4.6669e-05
# Epoch 89/100
# 100/100 [==============================] - 8s 82ms/step - loss: 3.6184e-05
# Epoch 90/100
# 100/100 [==============================] - 8s 82ms/step - loss: 4.2384e-05
# Epoch 91/100
# 100/100 [==============================] - 8s 83ms/step - loss: 4.7486e-05
# Epoch 92/100
# 100/100 [==============================] - 8s 84ms/step - loss: 3.6975e-05
# Epoch 93/100
# 100/100 [==============================] - 8s 82ms/step - loss: 4.1697e-05
# Epoch 94/100
# 100/100 [==============================] - 8s 83ms/step - loss: 3.3697e-05
# Epoch 95/100
# 100/100 [==============================] - 8s 83ms/step - loss: 3.4922e-05
# Epoch 96/100
# 100/100 [==============================] - 8s 83ms/step - loss: 4.1091e-05
# Epoch 97/100
# 100/100 [==============================] - 8s 83ms/step - loss: 3.3512e-05
# Epoch 98/100
# 100/100 [==============================] - 8s 83ms/step - loss: 5.2311e-05
# Epoch 99/100
# 100/100 [==============================] - 8s 83ms/step - loss: 5.1486e-05
# Epoch 100/100
# 100/100 [==============================] - 8s 83ms/step - loss: 2.0847e-05
# Epoch 1/100
# 100/100 [==============================] - 9s 83ms/step - loss: 0.1105
# Epoch 2/100
# 100/100 [==============================] - 8s 83ms/step - loss: 0.0378
# Epoch 3/100
# 100/100 [==============================] - 8s 83ms/step - loss: 0.0211
# Epoch 4/100
# 100/100 [==============================] - 8s 81ms/step - loss: 0.0105
# Epoch 5/100
# 100/100 [==============================] - 8s 83ms/step - loss: 0.0076
# Epoch 6/100
# 100/100 [==============================] - 8s 83ms/step - loss: 0.0058
# Epoch 7/100
# 100/100 [==============================] - 8s 83ms/step - loss: 0.0051
# Epoch 8/100
# 100/100 [==============================] - 8s 83ms/step - loss: 0.0035
# Epoch 9/100
# 100/100 [==============================] - 8s 82ms/step - loss: 0.0041
# Epoch 10/100
# 100/100 [==============================] - 8s 83ms/step - loss: 0.0030
# Epoch 11/100
# 100/100 [==============================] - 8s 83ms/step - loss: 0.0021
# Epoch 12/100
# 100/100 [==============================] - 8s 83ms/step - loss: 0.0019
# Epoch 13/100
# 100/100 [==============================] - 8s 82ms/step - loss: 0.0013
# Epoch 14/100
# 100/100 [==============================] - 8s 83ms/step - loss: 0.0012
# Epoch 15/100
# 100/100 [==============================] - 8s 83ms/step - loss: 0.0012
# Epoch 16/100
# 100/100 [==============================] - 8s 82ms/step - loss: 9.9146e-04
# Epoch 17/100
# 100/100 [==============================] - 8s 83ms/step - loss: 7.4714e-04
# Epoch 18/100
# 100/100 [==============================] - 8s 83ms/step - loss: 8.7840e-04
# Epoch 19/100
# 100/100 [==============================] - 8s 83ms/step - loss: 7.8210e-04
# Epoch 20/100
# 100/100 [==============================] - 8s 83ms/step - loss: 5.2025e-04
# Epoch 21/100
# 100/100 [==============================] - 8s 83ms/step - loss: 7.1399e-04
# Epoch 22/100
# 100/100 [==============================] - 8s 82ms/step - loss: 5.2615e-04
# Epoch 23/100
# 100/100 [==============================] - 8s 83ms/step - loss: 5.3038e-04
# Epoch 24/100
# 100/100 [==============================] - 8s 83ms/step - loss: 4.4943e-04
# Epoch 25/100
# 100/100 [==============================] - 8s 82ms/step - loss: 4.1046e-04
# Epoch 26/100
# 100/100 [==============================] - 8s 82ms/step - loss: 4.6407e-04
# Epoch 27/100
# 100/100 [==============================] - 8s 82ms/step - loss: 4.6114e-04
# Epoch 28/100
# 100/100 [==============================] - 8s 83ms/step - loss: 2.4273e-04
# Epoch 29/100
# 100/100 [==============================] - 8s 82ms/step - loss: 1.7893e-04
# Epoch 30/100
# 100/100 [==============================] - 8s 82ms/step - loss: 3.8141e-04
# Epoch 31/100
# 100/100 [==============================] - 8s 83ms/step - loss: 2.7789e-04
# Epoch 32/100
# 100/100 [==============================] - 8s 83ms/step - loss: 2.2414e-04
# Epoch 33/100
# 100/100 [==============================] - 8s 83ms/step - loss: 1.4733e-04
# Epoch 34/100
# 100/100 [==============================] - 8s 84ms/step - loss: 1.3644e-04
# Epoch 35/100
# 100/100 [==============================] - 8s 84ms/step - loss: 2.4407e-04
# Epoch 36/100
# 100/100 [==============================] - 8s 83ms/step - loss: 2.5283e-04
# Epoch 37/100
# 100/100 [==============================] - 8s 83ms/step - loss: 1.7488e-04
# Epoch 38/100
# 100/100 [==============================] - 8s 83ms/step - loss: 1.8130e-04
# Epoch 39/100
# 100/100 [==============================] - 8s 83ms/step - loss: 2.2061e-04
# Epoch 40/100
# 100/100 [==============================] - 8s 83ms/step - loss: 1.5735e-04
# Epoch 41/100
# 100/100 [==============================] - 8s 83ms/step - loss: 9.5901e-05
# Epoch 42/100
# 100/100 [==============================] - 8s 83ms/step - loss: 1.2195e-04
# Epoch 43/100
# 100/100 [==============================] - 8s 83ms/step - loss: 1.7423e-04
# Epoch 44/100
# 100/100 [==============================] - 8s 84ms/step - loss: 7.4049e-05
# Epoch 45/100
# 100/100 [==============================] - 8s 84ms/step - loss: 9.0393e-05
# Epoch 46/100
# 100/100 [==============================] - 8s 83ms/step - loss: 1.1575e-04
# Epoch 47/100
# 100/100 [==============================] - 8s 83ms/step - loss: 8.2338e-05
# Epoch 48/100
# 100/100 [==============================] - 8s 85ms/step - loss: 1.0285e-04
# Epoch 49/100
# 100/100 [==============================] - 8s 83ms/step - loss: 7.6966e-05
# Epoch 50/100
# 100/100 [==============================] - 8s 83ms/step - loss: 6.8576e-05
# Epoch 51/100
# 100/100 [==============================] - 8s 83ms/step - loss: 1.2382e-04
# Epoch 52/100
# 100/100 [==============================] - 8s 83ms/step - loss: 8.2963e-05
# Epoch 53/100
# 100/100 [==============================] - 8s 83ms/step - loss: 5.5026e-05
# Epoch 54/100
# 100/100 [==============================] - 8s 83ms/step - loss: 1.0052e-04
# Epoch 55/100
# 100/100 [==============================] - 8s 84ms/step - loss: 9.1483e-05
# Epoch 56/100
# 100/100 [==============================] - 8s 83ms/step - loss: 5.1990e-05
# Epoch 57/100
# 100/100 [==============================] - 8s 83ms/step - loss: 7.0746e-05
# Epoch 58/100
# 100/100 [==============================] - 8s 84ms/step - loss: 4.5725e-05
# Epoch 59/100
# 100/100 [==============================] - 8s 84ms/step - loss: 6.1569e-05
# Epoch 60/100
# 100/100 [==============================] - 8s 84ms/step - loss: 5.5430e-05
# Epoch 61/100
# 100/100 [==============================] - 9s 90ms/step - loss: 5.8940e-05
# Epoch 62/100
# 100/100 [==============================] - 9s 86ms/step - loss: 5.2715e-05
# Epoch 63/100
# 100/100 [==============================] - 8s 84ms/step - loss: 4.0935e-05
# Epoch 64/100
# 100/100 [==============================] - 8s 84ms/step - loss: 3.9652e-05
# Epoch 65/100
# 100/100 [==============================] - 8s 84ms/step - loss: 5.7302e-05
# Epoch 66/100
# 100/100 [==============================] - 8s 83ms/step - loss: 6.3060e-05
# Epoch 67/100
# 100/100 [==============================] - 8s 83ms/step - loss: 3.8385e-05
# Epoch 68/100
# 100/100 [==============================] - 8s 83ms/step - loss: 6.1407e-05
# Epoch 69/100
# 100/100 [==============================] - 8s 84ms/step - loss: 3.2759e-05
# Epoch 70/100
# 100/100 [==============================] - 8s 83ms/step - loss: 3.1106e-05
# Epoch 71/100
# 100/100 [==============================] - 8s 83ms/step - loss: 4.0720e-05
# Epoch 72/100
# 100/100 [==============================] - 8s 84ms/step - loss: 3.2545e-05
# Epoch 73/100
# 100/100 [==============================] - 8s 83ms/step - loss: 2.0659e-05
# Epoch 74/100
# 100/100 [==============================] - 8s 83ms/step - loss: 4.4597e-05
# Epoch 75/100
# 100/100 [==============================] - 8s 84ms/step - loss: 1.8704e-05
# Epoch 76/100
# 100/100 [==============================] - 8s 83ms/step - loss: 4.8304e-05
# Epoch 77/100
# 100/100 [==============================] - 8s 83ms/step - loss: 6.1084e-05
# Epoch 78/100
# 100/100 [==============================] - 8s 84ms/step - loss: 2.6437e-05
# Epoch 79/100
# 100/100 [==============================] - 8s 84ms/step - loss: 1.8272e-05
# Epoch 80/100
# 100/100 [==============================] - 8s 83ms/step - loss: 2.7650e-05
# Epoch 81/100
# 100/100 [==============================] - 8s 83ms/step - loss: 3.5059e-05
# Epoch 82/100
# 100/100 [==============================] - 8s 84ms/step - loss: 2.4811e-05
# Epoch 83/100
# 100/100 [==============================] - 8s 83ms/step - loss: 4.4509e-05
# Epoch 84/100
# 100/100 [==============================] - 8s 84ms/step - loss: 2.7424e-05
# Epoch 85/100
# 100/100 [==============================] - 8s 84ms/step - loss: 1.4020e-05
# Epoch 86/100
# 100/100 [==============================] - 8s 84ms/step - loss: 2.1713e-05
# Epoch 87/100
# 100/100 [==============================] - 8s 84ms/step - loss: 3.8648e-05
# Epoch 88/100
# 100/100 [==============================] - 8s 83ms/step - loss: 4.5474e-05
# Epoch 89/100
# 100/100 [==============================] - 8s 83ms/step - loss: 1.7379e-05
# Epoch 90/100
# 100/100 [==============================] - 8s 83ms/step - loss: 2.0673e-05
# Epoch 91/100
# 100/100 [==============================] - 8s 84ms/step - loss: 3.7295e-05
# Epoch 92/100
# 100/100 [==============================] - 8s 85ms/step - loss: 1.0738e-05
# Epoch 93/100
# 100/100 [==============================] - 8s 84ms/step - loss: 2.0124e-05
# Epoch 94/100
# 100/100 [==============================] - 8s 84ms/step - loss: 1.4349e-05
# Epoch 95/100
# 100/100 [==============================] - 8s 84ms/step - loss: 2.5460e-05
# Epoch 96/100
# 100/100 [==============================] - 8s 84ms/step - loss: 1.2259e-05
# Epoch 97/100
# 100/100 [==============================] - 8s 85ms/step - loss: 2.4366e-05
# Epoch 98/100
# 100/100 [==============================] - 8s 84ms/step - loss: 2.5238e-05
# Epoch 99/100
# 100/100 [==============================] - 8s 84ms/step - loss: 2.6079e-05
# Epoch 100/100
# 100/100 [==============================] - 8s 84ms/step - loss: 6.8386e-05
# Epoch 1/100
# 100/100 [==============================] - 9s 84ms/step - loss: 0.0787
# Epoch 2/100
# 100/100 [==============================] - 8s 84ms/step - loss: 0.0199
# Epoch 3/100
# 100/100 [==============================] - 8s 83ms/step - loss: 0.0074
# Epoch 4/100
# 100/100 [==============================] - 8s 83ms/step - loss: 0.0048
# Epoch 5/100
# 100/100 [==============================] - 8s 83ms/step - loss: 0.0031
# Epoch 6/100
# 100/100 [==============================] - 8s 83ms/step - loss: 0.0024
# Epoch 7/100
# 100/100 [==============================] - 8s 84ms/step - loss: 0.0023
# Epoch 8/100
# 100/100 [==============================] - 8s 83ms/step - loss: 0.0018
# Epoch 9/100
# 100/100 [==============================] - 8s 82ms/step - loss: 0.0017
# Epoch 10/100
# 100/100 [==============================] - 8s 84ms/step - loss: 0.0011
# Epoch 11/100
# 100/100 [==============================] - 8s 85ms/step - loss: 0.0010
# Epoch 12/100
# 100/100 [==============================] - 8s 83ms/step - loss: 7.9015e-04
# Epoch 13/100
# 100/100 [==============================] - 8s 84ms/step - loss: 6.5191e-04
# Epoch 14/100
# 100/100 [==============================] - 8s 84ms/step - loss: 6.2845e-04
# Epoch 15/100
# 100/100 [==============================] - 8s 83ms/step - loss: 5.6725e-04
# Epoch 16/100
# 100/100 [==============================] - 8s 84ms/step - loss: 5.3479e-04
# Epoch 17/100
# 100/100 [==============================] - 8s 84ms/step - loss: 4.4519e-04
# Epoch 18/100
# 100/100 [==============================] - 8s 83ms/step - loss: 4.4058e-04
# Epoch 19/100
# 100/100 [==============================] - 8s 84ms/step - loss: 4.2684e-04
# Epoch 20/100
# 100/100 [==============================] - 8s 84ms/step - loss: 3.8603e-04
# Epoch 21/100
# 100/100 [==============================] - 8s 84ms/step - loss: 3.2272e-04
# Epoch 22/100
# 100/100 [==============================] - 8s 84ms/step - loss: 3.2332e-04
# Epoch 23/100
# 100/100 [==============================] - 8s 83ms/step - loss: 3.2800e-04
# Epoch 24/100
# 100/100 [==============================] - 8s 84ms/step - loss: 3.7092e-04
# Epoch 25/100
# 100/100 [==============================] - 8s 84ms/step - loss: 2.3829e-04
# Epoch 26/100
# 100/100 [==============================] - 8s 84ms/step - loss: 2.6515e-04
# Epoch 27/100
# 100/100 [==============================] - 8s 83ms/step - loss: 2.4895e-04
# Epoch 28/100
# 100/100 [==============================] - 8s 84ms/step - loss: 1.9641e-04
# Epoch 29/100
# 100/100 [==============================] - 8s 84ms/step - loss: 2.3539e-04
# Epoch 30/100
# 100/100 [==============================] - 8s 83ms/step - loss: 2.2622e-04
# Epoch 31/100
# 100/100 [==============================] - 8s 84ms/step - loss: 1.8333e-04
# Epoch 32/100
# 100/100 [==============================] - 8s 83ms/step - loss: 1.7680e-04
# Epoch 33/100
# 100/100 [==============================] - 8s 84ms/step - loss: 1.7789e-04
# Epoch 34/100
# 100/100 [==============================] - 8s 84ms/step - loss: 2.3842e-04
# Epoch 35/100
# 100/100 [==============================] - 8s 84ms/step - loss: 2.1334e-04
# Epoch 36/100
# 100/100 [==============================] - 8s 83ms/step - loss: 1.7372e-04
# Epoch 37/100
# 100/100 [==============================] - 8s 84ms/step - loss: 2.4653e-04
# Epoch 38/100
# 100/100 [==============================] - 8s 83ms/step - loss: 1.8153e-04
# Epoch 39/100
# 100/100 [==============================] - 8s 84ms/step - loss: 1.4071e-04
# Epoch 40/100
# 100/100 [==============================] - 8s 84ms/step - loss: 1.4876e-04
# Epoch 41/100
# 100/100 [==============================] - 8s 84ms/step - loss: 1.5683e-04
# Epoch 42/100
# 100/100 [==============================] - 8s 84ms/step - loss: 1.4138e-04
# Epoch 43/100
# 100/100 [==============================] - 8s 84ms/step - loss: 1.6952e-04
# Epoch 44/100
# 100/100 [==============================] - 8s 84ms/step - loss: 1.3028e-04
# Epoch 45/100
# 100/100 [==============================] - 8s 84ms/step - loss: 1.4509e-04
# Epoch 46/100
# 100/100 [==============================] - 8s 84ms/step - loss: 1.1443e-04
# Epoch 47/100
# 100/100 [==============================] - 8s 83ms/step - loss: 1.0316e-04
# Epoch 48/100
# 100/100 [==============================] - 8s 84ms/step - loss: 1.2300e-04
# Epoch 49/100
# 100/100 [==============================] - 8s 85ms/step - loss: 9.3817e-05
# Epoch 50/100
# 100/100 [==============================] - 8s 84ms/step - loss: 8.7705e-05
# Epoch 51/100
# 100/100 [==============================] - 8s 84ms/step - loss: 1.3511e-04
# Epoch 52/100
# 100/100 [==============================] - 8s 84ms/step - loss: 1.1809e-04
# Epoch 53/100
# 100/100 [==============================] - 8s 84ms/step - loss: 1.0296e-04
# Epoch 54/100
# 100/100 [==============================] - 8s 84ms/step - loss: 1.6841e-04
# Epoch 55/100
# 100/100 [==============================] - 8s 85ms/step - loss: 7.9533e-05
# Epoch 56/100
# 100/100 [==============================] - 8s 84ms/step - loss: 6.4419e-05
# Epoch 57/100
# 100/100 [==============================] - 8s 84ms/step - loss: 9.7208e-05
# Epoch 58/100
# 100/100 [==============================] - 8s 84ms/step - loss: 8.7195e-05
# Epoch 59/100
# 100/100 [==============================] - 8s 84ms/step - loss: 1.3364e-04
# Epoch 60/100
# 100/100 [==============================] - 8s 84ms/step - loss: 1.0393e-04
# Epoch 61/100
# 100/100 [==============================] - 8s 83ms/step - loss: 9.8870e-05
# Epoch 62/100
# 100/100 [==============================] - 8s 84ms/step - loss: 7.7367e-05
# Epoch 63/100
# 100/100 [==============================] - 8s 85ms/step - loss: 9.7597e-05
# Epoch 64/100
# 100/100 [==============================] - 8s 84ms/step - loss: 8.6884e-05
# Epoch 65/100
# 100/100 [==============================] - 8s 84ms/step - loss: 1.2398e-04
# Epoch 66/100
# 100/100 [==============================] - 8s 84ms/step - loss: 1.1603e-04
# Epoch 67/100
# 100/100 [==============================] - 8s 84ms/step - loss: 1.1317e-04
# Epoch 68/100
# 100/100 [==============================] - 8s 84ms/step - loss: 1.1626e-04
# Epoch 69/100
# 100/100 [==============================] - 8s 84ms/step - loss: 9.8004e-05
# Epoch 70/100
# 100/100 [==============================] - 8s 85ms/step - loss: 9.6290e-05
# Epoch 71/100
# 100/100 [==============================] - 8s 85ms/step - loss: 9.0942e-05
# Epoch 72/100
# 100/100 [==============================] - 8s 84ms/step - loss: 7.3738e-05
# Epoch 73/100
# 100/100 [==============================] - 8s 84ms/step - loss: 7.3598e-05
# Epoch 74/100
# 100/100 [==============================] - 8s 84ms/step - loss: 6.4515e-05
# Epoch 75/100
# 100/100 [==============================] - 8s 84ms/step - loss: 9.6143e-05
# Epoch 76/100
# 100/100 [==============================] - 8s 83ms/step - loss: 6.7327e-05
# Epoch 77/100
# 100/100 [==============================] - 8s 84ms/step - loss: 8.5367e-05
# Epoch 78/100
# 100/100 [==============================] - 8s 85ms/step - loss: 9.8105e-05
# Epoch 79/100
# 100/100 [==============================] - 9s 85ms/step - loss: 1.0856e-04
# Epoch 80/100
# 100/100 [==============================] - 8s 85ms/step - loss: 7.0368e-05
# Epoch 81/100
# 100/100 [==============================] - 8s 84ms/step - loss: 9.4523e-05
# Epoch 82/100
# 100/100 [==============================] - 8s 84ms/step - loss: 5.7760e-05
# Epoch 83/100
# 100/100 [==============================] - 8s 84ms/step - loss: 7.5911e-05
# Epoch 84/100
# 100/100 [==============================] - 8s 84ms/step - loss: 9.0518e-05
# Epoch 85/100
# 100/100 [==============================] - 8s 85ms/step - loss: 1.0418e-04
# Epoch 86/100
# 100/100 [==============================] - 9s 85ms/step - loss: 9.0208e-05
# Epoch 87/100
# 100/100 [==============================] - 9s 85ms/step - loss: 6.3508e-05
# Epoch 88/100
# 100/100 [==============================] - 8s 85ms/step - loss: 7.0055e-05
# Epoch 89/100
# 100/100 [==============================] - 8s 85ms/step - loss: 6.8243e-05
# Epoch 90/100
# 100/100 [==============================] - 8s 84ms/step - loss: 4.2547e-05
# Epoch 91/100
# 100/100 [==============================] - 8s 85ms/step - loss: 5.3426e-05
# Epoch 92/100
# 100/100 [==============================] - 9s 85ms/step - loss: 7.5548e-05
# Epoch 93/100
# 100/100 [==============================] - 9s 90ms/step - loss: 4.7190e-05
# Epoch 94/100
# 100/100 [==============================] - 9s 88ms/step - loss: 5.6905e-05
# Epoch 95/100
# 100/100 [==============================] - 8s 85ms/step - loss: 7.9323e-05
# Epoch 96/100
# 100/100 [==============================] - 8s 84ms/step - loss: 7.5640e-05
# Epoch 97/100
# 100/100 [==============================] - 8s 84ms/step - loss: 4.7769e-05
# Epoch 98/100
# 100/100 [==============================] - 8s 85ms/step - loss: 1.2861e-04
# Epoch 99/100
# 100/100 [==============================] - 8s 85ms/step - loss: 1.2846e-04
# Epoch 100/100
# 100/100 [==============================] - 8s 84ms/step - loss: 5.7203e-05

# %% [markdown]
# ## Visualise Loss function

# %%
#print(result.history.keys())

plt.rcParams['figure.figsize'] = [10, 10]

# summarize history for loss
plt.plot(result_1.history['loss'])
plt.plot(result_2.history['loss'])
plt.plot(result_3.history['loss'])
plt.plot(result_4.history['loss'])
plt.plot(result_5.history['loss'])
plt.plot(result_6.history['loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.rc('font', size=12)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=20)    # legend fontsize
plt.rc('figure', titlesize=20)  # fontsize of the figure title
plt.legend(['32-64-32 Loss','64 Loss','32-64 Loss','64-64 Loss','64-64-32 Loss','64-64-64 Loss'], loc='upper left')
plt.yscale("log")
plt.show()

# %% [markdown]
# ## Plot trajectories to $t=64$ generated by Verlet integrator and the neural network based integrators

# %%
# Final time
T_final = 64

# Initial conditions
x = np.zeros(1)
v = np.zeros(1)
x[0] = 1.0
v[0] = 0.0
verlet_integrator.set_state(x,v)

# ==== Verlet integrator ====
t = 0.0
t_verlet = []
x_verlet = []
E_verlet = []
while t<T_final:
    t_verlet.append(t)
    E_verlet.append(verlet_integrator.energy())
    x_verlet.append(verlet_integrator.x[0])
    verlet_integrator.integrate(1)
    t += dt_verlet
        

# ==== Neural network integrator ====

# Initialise with Verlet integrator
x_initial_1 = np.zeros((nn_integrator_1.nsteps,nn_integrator_1.dynamical_system.dim))
v_initial_1 = np.zeros((nn_integrator_1.nsteps,nn_integrator_1.dynamical_system.dim))
x_initial_2 = np.zeros((nn_integrator_2.nsteps,nn_integrator_2.dynamical_system.dim))
v_initial_2 = np.zeros((nn_integrator_2.nsteps,nn_integrator_2.dynamical_system.dim))
x_initial_3 = np.zeros((nn_integrator_3.nsteps,nn_integrator_3.dynamical_system.dim))
v_initial_3 = np.zeros((nn_integrator_3.nsteps,nn_integrator_3.dynamical_system.dim))
x_initial_4 = np.zeros((nn_integrator_4.nsteps,nn_integrator_4.dynamical_system.dim))
v_initial_4 = np.zeros((nn_integrator_4.nsteps,nn_integrator_4.dynamical_system.dim))
x_initial_5 = np.zeros((nn_integrator_5.nsteps,nn_integrator_5.dynamical_system.dim))
v_initial_5 = np.zeros((nn_integrator_5.nsteps,nn_integrator_5.dynamical_system.dim))
x_initial_6 = np.zeros((nn_integrator_6.nsteps,nn_integrator_5.dynamical_system.dim))
v_initial_6 = np.zeros((nn_integrator_6.nsteps,nn_integrator_5.dynamical_system.dim))


verlet_integrator.set_state(x,v)
for k in range(nn_integrator_1.nsteps):    
    x_initial_1[k,:] = verlet_integrator.x[:]
    v_initial_1[k,:] = verlet_integrator.v[:]
    verlet_integrator.integrate(int(dt/dt_verlet))
verlet_integrator.set_state(x,v)
for k in range(nn_integrator_2.nsteps):    
    x_initial_2[k,:] = verlet_integrator.x[:]
    v_initial_2[k,:] = verlet_integrator.v[:]
    verlet_integrator.integrate(int(dt/dt_verlet))
verlet_integrator.set_state(x,v)
for k in range(nn_integrator_3.nsteps):    
    x_initial_3[k,:] = verlet_integrator.x[:]
    v_initial_3[k,:] = verlet_integrator.v[:]
    verlet_integrator.integrate(int(dt/dt_verlet))
verlet_integrator.set_state(x,v)
for k in range(nn_integrator_4.nsteps):    
    x_initial_4[k,:] = verlet_integrator.x[:]
    v_initial_4[k,:] = verlet_integrator.v[:]
    verlet_integrator.integrate(int(dt/dt_verlet))
verlet_integrator.set_state(x,v)
for k in range(nn_integrator_5.nsteps):    
    x_initial_5[k,:] = verlet_integrator.x[:]
    v_initial_5[k,:] = verlet_integrator.v[:]
    verlet_integrator.integrate(int(dt/dt_verlet))
for k in range(nn_integrator_5.nsteps):    
    x_initial_6[k,:] = verlet_integrator.x[:]
    v_initial_6[k,:] = verlet_integrator.v[:]
    verlet_integrator.integrate(int(dt/dt_verlet))

nn_integrator_1.set_state(x_initial_1,v_initial_1)
t_1 = (nn_integrator_1.nsteps-1)*nn_integrator_1.dt
nn_integrator_2.set_state(x_initial_2,v_initial_2)
t_2 = (nn_integrator_2.nsteps-1)*nn_integrator_2.dt
nn_integrator_3.set_state(x_initial_3,v_initial_3)
t_3 = (nn_integrator_3.nsteps-1)*nn_integrator_3.dt
nn_integrator_4.set_state(x_initial_4,v_initial_4)
t_4 = (nn_integrator_4.nsteps-1)*nn_integrator_4.dt
nn_integrator_5.set_state(x_initial_5,v_initial_5)
t_5 = (nn_integrator_5.nsteps-1)*nn_integrator_5.dt
nn_integrator_6.set_state(x_initial_6,v_initial_6)
t_6 = (nn_integrator_6.nsteps-1)*nn_integrator_6.dt

# Timestepping loop
t_nn_1 = []
x_nn_1 = []
E_nn_1 = []
t_nn_2 = []
x_nn_2 = []
E_nn_2 = []
t_nn_3 = []
x_nn_3 = []
E_nn_3 = []
t_nn_4 = []
x_nn_4 = []
E_nn_4 = []
t_nn_5 = []
x_nn_5 = []
E_nn_5 = []
t_nn_6 = []
x_nn_6 = []
E_nn_6 = []

while t_1<T_final:
    t_nn_1.append(t_1)
    x_nn_1.append(nn_integrator_1.x[0])
    E_nn_1.append(nn_integrator_1.energy())
    nn_integrator_1.integrate(1)
    t_1 += dt
while t_2<T_final:
    t_nn_2.append(t_2)
    x_nn_2.append(nn_integrator_2.x[0])
    E_nn_2.append(nn_integrator_2.energy())
    nn_integrator_2.integrate(1)
    t_2 += dt
while t_3<T_final:
    t_nn_3.append(t_3)
    x_nn_3.append(nn_integrator_3.x[0])
    E_nn_3.append(nn_integrator_3.energy())
    nn_integrator_3.integrate(1)
    t_3 += dt
while t_4<T_final:
    t_nn_4.append(t_4)
    x_nn_4.append(nn_integrator_4.x[0])
    E_nn_4.append(nn_integrator_4.energy())
    nn_integrator_4.integrate(1)
    t_4 += dt
while t_5<T_final:
    t_nn_5.append(t_5)
    x_nn_5.append(nn_integrator_5.x[0])
    E_nn_5.append(nn_integrator_5.energy())
    nn_integrator_5.integrate(1)
    t_5 += dt
while t_6<T_final:
    t_nn_6.append(t_6)
    x_nn_6.append(nn_integrator_6.x[0])
    E_nn_6.append(nn_integrator_6.energy())
    nn_integrator_6.integrate(1)
    t_6 += dt    


# Plot position as a function of time
plt.plot(t_verlet,x_verlet,label='Verlet',color='blue')
plt.plot(t_nn_1,x_nn_1,label='32-64-32',color='red')
plt.plot(t_nn_2,x_nn_2,label='64',color='green')
plt.plot(t_nn_3,x_nn_3,label='32-64',color='orange')
plt.plot(t_nn_4,x_nn_4,label='64-64',color='purple')
plt.plot(t_nn_5,x_nn_5,label='64-64-32',color='pink')
plt.plot(t_nn_6,x_nn_6,label='64-64-64',color='yellow')
plt.legend(loc='lower right')
ax = plt.gca()
ax.set_xlabel('time $t$')
ax.set_ylabel('position $x(t)$')
ax.set_title('Position')
plt.show()

plt.rcParams['figure.figsize'] = [10, 20]

plt.clf()
# Plot energy as a function of time
# (subtract energy at time t=0 to show energy drift)
fig, axs = plt.subplots(2,1)
axs[0].plot(t_verlet,E_verlet-E_verlet[0],label='Verlet',color='blue')
axs[1].plot(t_nn_1,E_nn_1-E_nn_1[0],label='32-64-32',color='blue')
axs[1].plot(t_nn_2,E_nn_2-E_nn_2[0],label='64',color='orange')
axs[1].plot(t_nn_3,E_nn_3-E_nn_3[0],label='32-64',color='green')
axs[1].plot(t_nn_4,E_nn_4-E_nn_4[0],label='64-64',color='red')
axs[1].plot(t_nn_5,E_nn_5-E_nn_5[0],label='64-64-32',color='purple')
axs[1].plot(t_nn_6,E_nn_6-E_nn_6[0],label='64-64-64',color='brown')
plt.legend(loc='top left')
for ax in axs:
    ax.set_xlabel('time $t$')
    ax.set_ylabel('energy shift $E(t)-E(t_0)$')
plt.rc('font', size=12)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=20)    # legend fontsize
plt.rc('figure', titlesize=20)  # fontsize of the figure title
plt.grid()
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:170: MatplotlibDeprecationWarning: Unrecognized location 'top left'. Falling back on 'best'; valid locations are
# 	best
# 	upper right
# 	upper left
# 	lower left
# 	lower right
# 	right
# 	center left
# 	center right
# 	lower center
# 	upper center
# 	center
# This will raise an exception in 3.3.

# %% [markdown]
# ##Focusing on the best-performing architectures

# %%
plt.clf()
# Plot energy as a function of time
# (subtract energy at time t=0 to show energy drift)
fig, axs = plt.subplots(2,1)
axs[0].plot(t_verlet,E_verlet-E_verlet[0],label='Verlet',color='blue')
axs[1].plot(t_nn_4,E_nn_4-E_nn_4[0],label='64-64',color='red')
axs[1].plot(t_nn_5,E_nn_5-E_nn_5[0],label='64-64-32',color='purple')
axs[1].plot(t_nn_6,E_nn_6-E_nn_6[0],label='64-64-64',color='brown')
plt.legend(loc='top left')
for ax in axs:
    ax.set_xlabel('time $t$')
    ax.set_ylabel('energy shift $E(t)-E(t_0)$')
plt.rc('font', size=12)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=20)    # legend fontsize
plt.rc('figure', titlesize=20)  # fontsize of the figure title
plt.grid()
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:12: MatplotlibDeprecationWarning: Unrecognized location 'top left'. Falling back on 'best'; valid locations are
# 	best
# 	upper right
# 	upper left
# 	lower left
# 	lower right
# 	right
# 	center left
# 	center right
# 	lower center
# 	upper center
# 	center
# This will raise an exception in 3.3.
#   if sys.path[0] == '':
