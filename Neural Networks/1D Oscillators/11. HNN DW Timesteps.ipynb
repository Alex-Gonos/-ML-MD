# %% [markdown]
# # Hamiltonian neural network based integrator simulating DW system

# %%
import sys
sys.path.append('..')

import numpy as np
from matplotlib import pyplot as plt
from Code.dynamical_system import *
from Code.time_integrator import *
from Code.neuralnet import *

np.random.seed(2512517)

# %% [markdown]
# ## Hamiltonian Neural network integrator

# %% [markdown]
# Set system parameters, construct dynamical system and integrator.
#
# The model system we are using here is the double-well oscillator.
#
# The timestep size of the Neural network integrator takes values in $\Delta t_{\text{Verlet}},20\Delta t_{\text{Verlet}},40\Delta t_{\text{Verlet}},100\Delta t_{\text{Verlet}}$ where $\Delta t_{\text{Verlet}}$ is the step size of the Verlet integrator that is used for training.

# %%
# mass of particle
mass = 1.2

# timestep for Verlet integrator
dt_verlet = 0.005
# timestep for neural network integrator
dt_1 = dt_verlet
dt_2 = 20*dt_verlet
dt_3 = 40*dt_verlet
dt_4 = 100*dt_verlet

doublewell = DoubleWell(mass)

verlet_SHO = VerletIntegrator(doublewell,dt_verlet)

# Layers for the potential and kinetic parts of the hamiltonian

V_pot_layers = [keras.layers.Dense(32,activation='tanh'),
                    keras.layers.Dense(32,activation='tanh')]
T_kin_layers = [keras.layers.Dense(32,activation='tanh'),
                    keras.layers.Dense(32,activation='tanh')]

hnn_integrator_1 = HamiltonianNNIntegrator(doublewell,dt_1,V_pot_layers,T_kin_layers)
hnn_integrator_2 = HamiltonianNNIntegrator(doublewell,dt_2,V_pot_layers,T_kin_layers)
hnn_integrator_3 = HamiltonianNNIntegrator(doublewell,dt_3,V_pot_layers,T_kin_layers)
hnn_integrator_4 = HamiltonianNNIntegrator(doublewell,dt_4,V_pot_layers,T_kin_layers)

# visualise the neural network model
hnn_integrator_1.model.summary()
keras.utils.plot_model(hnn_integrator_1.model, show_shapes=True)
# Out:
# Model: "verlet_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               multiple                  64
#
#  dense_1 (Dense)             multiple                  1056
#
#  dense_2 (Dense)             multiple                  64
#
#  dense_3 (Dense)             multiple                  1056
#
#  dense_8 (Dense)             multiple                  32
#
#  dense_9 (Dense)             multiple                  32
#
# =================================================================
# Total params: 2,304
# Trainable params: 2,304
# Non-trainable params: 0
# _________________________________________________________________

# %%
BATCH_SIZE=64

data_generator_1 = DataGenerator(hnn_integrator_1,verlet_SHO)
train_batches_1 = data_generator_1.dataset.batch(BATCH_SIZE)

data_generator_2 = DataGenerator(hnn_integrator_2,verlet_SHO)
train_batches_2 = data_generator_2.dataset.batch(BATCH_SIZE)

data_generator_3 = DataGenerator(hnn_integrator_3,verlet_SHO)
train_batches_3 = data_generator_3.dataset.batch(BATCH_SIZE)

data_generator_4 = DataGenerator(hnn_integrator_4,verlet_SHO)
train_batches_4 = data_generator_4.dataset.batch(BATCH_SIZE)

# %% [markdown]
# ## Train neural network based integrator

# %%
EPOCHS=1000
STEPS_PER_EPOCH=100
log_dir = './tb_logs/'
tensorboard_cb = tf.keras.callbacks.TensorBoard(log_dir=log_dir)

result_1 = hnn_integrator_1.model.fit(train_batches_1,epochs=EPOCHS,steps_per_epoch=STEPS_PER_EPOCH,
                                 callbacks=tensorboard_cb)
result_2 = hnn_integrator_2.model.fit(train_batches_2,epochs=EPOCHS,steps_per_epoch=STEPS_PER_EPOCH,
                                 callbacks=tensorboard_cb)
result_3 = hnn_integrator_3.model.fit(train_batches_3,epochs=EPOCHS,steps_per_epoch=STEPS_PER_EPOCH,
                                callbacks=tensorboard_cb)
result_4 = hnn_integrator_4.model.fit(train_batches_4,epochs=EPOCHS,steps_per_epoch=STEPS_PER_EPOCH,
                                 callbacks=tensorboard_cb)
# Out:
# Streaming output truncated to the last 5000 lines.
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0434
# Epoch 502/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0554
# Epoch 503/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0360
# Epoch 504/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0770
# Epoch 505/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0220
# Epoch 506/1000
# 100/100 [==============================] - 4s 35ms/step - loss: 0.0627
# Epoch 507/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0343
# Epoch 508/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0563
# Epoch 509/1000
# 100/100 [==============================] - 3s 35ms/step - loss: 0.0768
# Epoch 510/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0415
# Epoch 511/1000
# 100/100 [==============================] - 3s 35ms/step - loss: 0.0440
# Epoch 512/1000
# 100/100 [==============================] - 4s 35ms/step - loss: 0.0663
# Epoch 513/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0714
# Epoch 514/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0740
# Epoch 515/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0505
# Epoch 516/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0472
# Epoch 517/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0278
# Epoch 518/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0321
# Epoch 519/1000
# 100/100 [==============================] - 4s 35ms/step - loss: 0.0347
# Epoch 520/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0513
# Epoch 521/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0693
# Epoch 522/1000
# 100/100 [==============================] - 4s 38ms/step - loss: 0.0302
# Epoch 523/1000
# 100/100 [==============================] - 4s 35ms/step - loss: 0.0293
# Epoch 524/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0375
# Epoch 525/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0403
# Epoch 526/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0465
# Epoch 527/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0771
# Epoch 528/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0353
# Epoch 529/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0145
# Epoch 530/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0567
# Epoch 531/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0701
# Epoch 532/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0285
# Epoch 533/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0508
# Epoch 534/1000
# 100/100 [==============================] - 3s 35ms/step - loss: 0.0364
# Epoch 535/1000
# 100/100 [==============================] - 3s 35ms/step - loss: 0.0807
# Epoch 536/1000
# 100/100 [==============================] - 4s 35ms/step - loss: 0.0895
# Epoch 537/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0169
# Epoch 538/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0124
# Epoch 539/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0449
# Epoch 540/1000
# 100/100 [==============================] - 4s 35ms/step - loss: 0.0507
# Epoch 541/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0226
# Epoch 542/1000
# 100/100 [==============================] - 3s 35ms/step - loss: 0.0232
# Epoch 543/1000
# 100/100 [==============================] - 4s 35ms/step - loss: 0.0405
# Epoch 544/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0458
# Epoch 545/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0539
# Epoch 546/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0479
# Epoch 547/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0359
# Epoch 548/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0082
# Epoch 549/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0737
# Epoch 550/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0435
# Epoch 551/1000
# 100/100 [==============================] - 4s 35ms/step - loss: 0.0385
# Epoch 552/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0206
# Epoch 553/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0319
# Epoch 554/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0237
# Epoch 555/1000
# 100/100 [==============================] - 3s 35ms/step - loss: 0.0637
# Epoch 556/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0177
# Epoch 557/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0508
# Epoch 558/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0079
# Epoch 559/1000
# 100/100 [==============================] - 4s 35ms/step - loss: 0.0320
# Epoch 560/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0322
# Epoch 561/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0386
# Epoch 562/1000
# 100/100 [==============================] - 4s 35ms/step - loss: 0.0137
# Epoch 563/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0573
# Epoch 564/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0382
# Epoch 565/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0197
# Epoch 566/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0239
# Epoch 567/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0164
# Epoch 568/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0288
# Epoch 569/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0228
# Epoch 570/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0284
# Epoch 571/1000
# 100/100 [==============================] - 4s 35ms/step - loss: 0.0273
# Epoch 572/1000
# 100/100 [==============================] - 4s 35ms/step - loss: 0.0082
# Epoch 573/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.1122
# Epoch 574/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0286
# Epoch 575/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0269
# Epoch 576/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0395
# Epoch 577/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0283
# Epoch 578/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0048
# Epoch 579/1000
# 100/100 [==============================] - 4s 35ms/step - loss: 0.0134
# Epoch 580/1000
# 100/100 [==============================] - 4s 35ms/step - loss: 0.0115
# Epoch 581/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0651
# Epoch 582/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0043
# Epoch 583/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0184
# Epoch 584/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0354
# Epoch 585/1000
# 100/100 [==============================] - 4s 38ms/step - loss: 0.0650
# Epoch 586/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0355
# Epoch 587/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0332
# Epoch 588/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0216
# Epoch 589/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0077
# Epoch 590/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0528
# Epoch 591/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0434
# Epoch 592/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0176
# Epoch 593/1000
# 100/100 [==============================] - 4s 35ms/step - loss: 0.0409
# Epoch 594/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0421
# Epoch 595/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0266
# Epoch 596/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0436
# Epoch 597/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0805
# Epoch 598/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0328
# Epoch 599/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0387
# Epoch 600/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0364
# Epoch 601/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0353
# Epoch 602/1000
# 100/100 [==============================] - 4s 35ms/step - loss: 0.0437
# Epoch 603/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0557
# Epoch 604/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0151
# Epoch 605/1000
# 100/100 [==============================] - 4s 35ms/step - loss: 0.0171
# Epoch 606/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0614
# Epoch 607/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0375
# Epoch 608/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0558
# Epoch 609/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0247
# Epoch 610/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0219
# Epoch 611/1000
# 100/100 [==============================] - 4s 35ms/step - loss: 0.0347
# Epoch 612/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0174
# Epoch 613/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0064
# Epoch 614/1000
# 100/100 [==============================] - 4s 35ms/step - loss: 0.0477
# Epoch 615/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0313
# Epoch 616/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0261
# Epoch 617/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0052
# Epoch 618/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0562
# Epoch 619/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0825
# Epoch 620/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0608
# Epoch 621/1000
# 100/100 [==============================] - 4s 35ms/step - loss: 0.0265
# Epoch 622/1000
# 100/100 [==============================] - 4s 35ms/step - loss: 0.0447
# Epoch 623/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0312
# Epoch 624/1000
# 100/100 [==============================] - 4s 35ms/step - loss: 0.0445
# Epoch 625/1000
# 100/100 [==============================] - 4s 35ms/step - loss: 0.0167
# Epoch 626/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0144
# Epoch 627/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0179
# Epoch 628/1000
# 100/100 [==============================] - 4s 35ms/step - loss: 0.0703
# Epoch 629/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0213
# Epoch 630/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0238
# Epoch 631/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0046
# Epoch 632/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0541
# Epoch 633/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0111
# Epoch 634/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0158
# Epoch 635/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0139
# Epoch 636/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0018
# Epoch 637/1000
# 100/100 [==============================] - 4s 35ms/step - loss: 0.0739
# Epoch 638/1000
# 100/100 [==============================] - 4s 35ms/step - loss: 0.0187
# Epoch 639/1000
# 100/100 [==============================] - 3s 35ms/step - loss: 0.0095
# Epoch 640/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0626
# Epoch 641/1000
# 100/100 [==============================] - 4s 35ms/step - loss: 0.0212
# Epoch 642/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0132
# Epoch 643/1000
# 100/100 [==============================] - 4s 38ms/step - loss: 0.0417
# Epoch 644/1000
# 100/100 [==============================] - 4s 35ms/step - loss: 0.0211
# Epoch 645/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0506
# Epoch 646/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0355
# Epoch 647/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0457
# Epoch 648/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0086
# Epoch 649/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0184
# Epoch 650/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0254
# Epoch 651/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0406
# Epoch 652/1000
# 100/100 [==============================] - 4s 38ms/step - loss: 0.0145
# Epoch 653/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0131
# Epoch 654/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0081
# Epoch 655/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0058
# Epoch 656/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0531
# Epoch 657/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0267
# Epoch 658/1000
# 100/100 [==============================] - 4s 35ms/step - loss: 0.0339
# Epoch 659/1000
# 100/100 [==============================] - 4s 35ms/step - loss: 0.0385
# Epoch 660/1000
# 100/100 [==============================] - 4s 35ms/step - loss: 0.0163
# Epoch 661/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0171
# Epoch 662/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0589
# Epoch 663/1000
# 100/100 [==============================] - 4s 35ms/step - loss: 0.0083
# Epoch 664/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0160
# Epoch 665/1000
# 100/100 [==============================] - 4s 35ms/step - loss: 0.0109
# Epoch 666/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0604
# Epoch 667/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0261
# Epoch 668/1000
# 100/100 [==============================] - 4s 35ms/step - loss: 0.0135
# Epoch 669/1000
# 100/100 [==============================] - 3s 35ms/step - loss: 0.0106
# Epoch 670/1000
# 100/100 [==============================] - 4s 35ms/step - loss: 0.0625
# Epoch 671/1000
# 100/100 [==============================] - 3s 35ms/step - loss: 0.0021
# Epoch 672/1000
# 100/100 [==============================] - 4s 35ms/step - loss: 0.0383
# Epoch 673/1000
# 100/100 [==============================] - 3s 35ms/step - loss: 0.0274
# Epoch 674/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0382
# Epoch 675/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0173
# Epoch 676/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0141
# Epoch 677/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0302
# Epoch 678/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0303
# Epoch 679/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0181
# Epoch 680/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0058
# Epoch 681/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0276
# Epoch 682/1000
# 100/100 [==============================] - 4s 38ms/step - loss: 0.0085
# Epoch 683/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0201
# Epoch 684/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0135
# Epoch 685/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0376
# Epoch 686/1000
# 100/100 [==============================] - 4s 35ms/step - loss: 0.0827
# Epoch 687/1000
# 100/100 [==============================] - 4s 38ms/step - loss: 0.0045
# Epoch 688/1000
# 100/100 [==============================] - 4s 35ms/step - loss: 0.0237
# Epoch 689/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0737
# Epoch 690/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0139
# Epoch 691/1000
# 100/100 [==============================] - 4s 35ms/step - loss: 0.0118
# Epoch 692/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0314
# Epoch 693/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0256
# Epoch 694/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0829
# Epoch 695/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0190
# Epoch 696/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0522
# Epoch 697/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0560
# Epoch 698/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0103
# Epoch 699/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0687
# Epoch 700/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0386
# Epoch 701/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0040
# Epoch 702/1000
# 100/100 [==============================] - 4s 35ms/step - loss: 0.0120
# Epoch 703/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0258
# Epoch 704/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0247
# Epoch 705/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0145
# Epoch 706/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0127
# Epoch 707/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0081
# Epoch 708/1000
# 100/100 [==============================] - 4s 35ms/step - loss: 0.0379
# Epoch 709/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0129
# Epoch 710/1000
# 100/100 [==============================] - 4s 35ms/step - loss: 0.0144
# Epoch 711/1000
# 100/100 [==============================] - 4s 35ms/step - loss: 0.0045
# Epoch 712/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0503
# Epoch 713/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0242
# Epoch 714/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0537
# Epoch 715/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0184
# Epoch 716/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0214
# Epoch 717/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0100
# Epoch 718/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0541
# Epoch 719/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0468
# Epoch 720/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0205
# Epoch 721/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0224
# Epoch 722/1000
# 100/100 [==============================] - 4s 35ms/step - loss: 0.0200
# Epoch 723/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0090
# Epoch 724/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0406
# Epoch 725/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0464
# Epoch 726/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0122
# Epoch 727/1000
# 100/100 [==============================] - 4s 35ms/step - loss: 0.1067
# Epoch 728/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0382
# Epoch 729/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0275
# Epoch 730/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0513
# Epoch 731/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0146
# Epoch 732/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0240
# Epoch 733/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0335
# Epoch 734/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0338
# Epoch 735/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0107
# Epoch 736/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0185
# Epoch 737/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0271
# Epoch 738/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0100
# Epoch 739/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0454
# Epoch 740/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0498
# Epoch 741/1000
# 100/100 [==============================] - 4s 35ms/step - loss: 0.0174
# Epoch 742/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0300
# Epoch 743/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0313
# Epoch 744/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0585
# Epoch 745/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0559
# Epoch 746/1000
# 100/100 [==============================] - 4s 38ms/step - loss: 0.0220
# Epoch 747/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0826
# Epoch 748/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0220
# Epoch 749/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0858
# Epoch 750/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0034
# Epoch 751/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0327
# Epoch 752/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0512
# Epoch 753/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0703
# Epoch 754/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0403
# Epoch 755/1000
# 100/100 [==============================] - 4s 35ms/step - loss: 0.0194
# Epoch 756/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0152
# Epoch 757/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0158
# Epoch 758/1000
# 100/100 [==============================] - 4s 35ms/step - loss: 0.0033
# Epoch 759/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0255
# Epoch 760/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0634
# Epoch 761/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0452
# Epoch 762/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0282
# Epoch 763/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0242
# Epoch 764/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0388
# Epoch 765/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0367
# Epoch 766/1000
# 100/100 [==============================] - 4s 38ms/step - loss: 0.0153
# Epoch 767/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0354
# Epoch 768/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0059
# Epoch 769/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0463
# Epoch 770/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0537
# Epoch 771/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0116
# Epoch 772/1000
# 100/100 [==============================] - 3s 35ms/step - loss: 0.0351
# Epoch 773/1000
# 100/100 [==============================] - 4s 38ms/step - loss: 0.0047
# Epoch 774/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0832
# Epoch 775/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0303
# Epoch 776/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0186
# Epoch 777/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0103
# Epoch 778/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0128
# Epoch 779/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0492
# Epoch 780/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0130
# Epoch 781/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0165
# Epoch 782/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0024
# Epoch 783/1000
# 100/100 [==============================] - 4s 38ms/step - loss: 0.0033
# Epoch 784/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0394
# Epoch 785/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0275
# Epoch 786/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0108
# Epoch 787/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0062
# Epoch 788/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0237
# Epoch 789/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0118
# Epoch 790/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0136
# Epoch 791/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0078
# Epoch 792/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0078
# Epoch 793/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0118
# Epoch 794/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0051
# Epoch 795/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0123
# Epoch 796/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0085
# Epoch 797/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0064
# Epoch 798/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0109
# Epoch 799/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0083
# Epoch 800/1000
# 100/100 [==============================] - 4s 38ms/step - loss: 0.0346
# Epoch 801/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0398
# Epoch 802/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0813
# Epoch 803/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0945
# Epoch 804/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0089
# Epoch 805/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0047
# Epoch 806/1000
# 100/100 [==============================] - 4s 38ms/step - loss: 0.0341
# Epoch 807/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0033
# Epoch 808/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0020
# Epoch 809/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0059
# Epoch 810/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0114
# Epoch 811/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0034
# Epoch 812/1000
# 100/100 [==============================] - 4s 38ms/step - loss: 0.0147
# Epoch 813/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0065
# Epoch 814/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0125
# Epoch 815/1000
# 100/100 [==============================] - 4s 38ms/step - loss: 0.0321
# Epoch 816/1000
# 100/100 [==============================] - 4s 38ms/step - loss: 0.0409
# Epoch 817/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0121
# Epoch 818/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0193
# Epoch 819/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0276
# Epoch 820/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0101
# Epoch 821/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0362
# Epoch 822/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0071
# Epoch 823/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0164
# Epoch 824/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0196
# Epoch 825/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0175
# Epoch 826/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0145
# Epoch 827/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0181
# Epoch 828/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0055
# Epoch 829/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0582
# Epoch 830/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0337
# Epoch 831/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0289
# Epoch 832/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0211
# Epoch 833/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0055
# Epoch 834/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0490
# Epoch 835/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0029
# Epoch 836/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0257
# Epoch 837/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0430
# Epoch 838/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0061
# Epoch 839/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0209
# Epoch 840/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0302
# Epoch 841/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0050
# Epoch 842/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0436
# Epoch 843/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0085
# Epoch 844/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0045
# Epoch 845/1000
# 100/100 [==============================] - 4s 38ms/step - loss: 0.0308
# Epoch 846/1000
# 100/100 [==============================] - 4s 38ms/step - loss: 0.0211
# Epoch 847/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0213
# Epoch 848/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0364
# Epoch 849/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0033
# Epoch 850/1000
# 100/100 [==============================] - 4s 38ms/step - loss: 0.0049
# Epoch 851/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0022
# Epoch 852/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0025
# Epoch 853/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0278
# Epoch 854/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0597
# Epoch 855/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0082
# Epoch 856/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0404
# Epoch 857/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0029
# Epoch 858/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0256
# Epoch 859/1000
# 100/100 [==============================] - 4s 38ms/step - loss: 0.0138
# Epoch 860/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0369
# Epoch 861/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0095
# Epoch 862/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0219
# Epoch 863/1000
# 100/100 [==============================] - 4s 38ms/step - loss: 0.0253
# Epoch 864/1000
# 100/100 [==============================] - 4s 38ms/step - loss: 0.0500
# Epoch 865/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0539
# Epoch 866/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0068
# Epoch 867/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0068
# Epoch 868/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0180
# Epoch 869/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0021
# Epoch 870/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0044
# Epoch 871/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0027
# Epoch 872/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0111
# Epoch 873/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0020
# Epoch 874/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0022
# Epoch 875/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0141
# Epoch 876/1000
# 100/100 [==============================] - 4s 38ms/step - loss: 0.0684
# Epoch 877/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0697
# Epoch 878/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0055
# Epoch 879/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0160
# Epoch 880/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0422
# Epoch 881/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0018
# Epoch 882/1000
# 100/100 [==============================] - 4s 38ms/step - loss: 0.0155
# Epoch 883/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0041
# Epoch 884/1000
# 100/100 [==============================] - 4s 38ms/step - loss: 0.0039
# Epoch 885/1000
# 100/100 [==============================] - 4s 38ms/step - loss: 0.0085
# Epoch 886/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0477
# Epoch 887/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0412
# Epoch 888/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0028
# Epoch 889/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0280
# Epoch 890/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0321
# Epoch 891/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0084
# Epoch 892/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0341
# Epoch 893/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0022
# Epoch 894/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0143
# Epoch 895/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0489
# Epoch 896/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0148
# Epoch 897/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0114
# Epoch 898/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0052
# Epoch 899/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0025
# Epoch 900/1000
# 100/100 [==============================] - 4s 38ms/step - loss: 0.0433
# Epoch 901/1000
# 100/100 [==============================] - 4s 38ms/step - loss: 0.0082
# Epoch 902/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0483
# Epoch 903/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0317
# Epoch 904/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0567
# Epoch 905/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0056
# Epoch 906/1000
# 100/100 [==============================] - 4s 38ms/step - loss: 0.0126
# Epoch 907/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0229
# Epoch 908/1000
# 100/100 [==============================] - 4s 35ms/step - loss: 0.0127
# Epoch 909/1000
# 100/100 [==============================] - 4s 38ms/step - loss: 0.0028
# Epoch 910/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0123
# Epoch 911/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0045
# Epoch 912/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0071
# Epoch 913/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0049
# Epoch 914/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0022
# Epoch 915/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0023
# Epoch 916/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0029
# Epoch 917/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0014
# Epoch 918/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0012
# Epoch 919/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0292
# Epoch 920/1000
# 100/100 [==============================] - 4s 38ms/step - loss: 0.0046
# Epoch 921/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0265
# Epoch 922/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0197
# Epoch 923/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0104
# Epoch 924/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0042
# Epoch 925/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0153
# Epoch 926/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0056
# Epoch 927/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0207
# Epoch 928/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0051
# Epoch 929/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0180
# Epoch 930/1000
# 100/100 [==============================] - 4s 38ms/step - loss: 0.0138
# Epoch 931/1000
# 100/100 [==============================] - 4s 38ms/step - loss: 0.0160
# Epoch 932/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0025
# Epoch 933/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0014
# Epoch 934/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0292
# Epoch 935/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0384
# Epoch 936/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0021
# Epoch 937/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0070
# Epoch 938/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0086
# Epoch 939/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0021
# Epoch 940/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0039
# Epoch 941/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0110
# Epoch 942/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0207
# Epoch 943/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0027
# Epoch 944/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0010
# Epoch 945/1000
# 100/100 [==============================] - 4s 38ms/step - loss: 0.0258
# Epoch 946/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0457
# Epoch 947/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0413
# Epoch 948/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0074
# Epoch 949/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0167
# Epoch 950/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0032
# Epoch 951/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0040
# Epoch 952/1000
# 100/100 [==============================] - 4s 38ms/step - loss: 0.0517
# Epoch 953/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0145
# Epoch 954/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0043
# Epoch 955/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0072
# Epoch 956/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0101
# Epoch 957/1000
# 100/100 [==============================] - 4s 38ms/step - loss: 0.0052
# Epoch 958/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0115
# Epoch 959/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0174
# Epoch 960/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0015
# Epoch 961/1000
# 100/100 [==============================] - 4s 38ms/step - loss: 0.0038
# Epoch 962/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0053
# Epoch 963/1000
# 100/100 [==============================] - 4s 38ms/step - loss: 0.0027
# Epoch 964/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0045
# Epoch 965/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0055
# Epoch 966/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0290
# Epoch 967/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0243
# Epoch 968/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0287
# Epoch 969/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0282
# Epoch 970/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0029
# Epoch 971/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0123
# Epoch 972/1000
# 100/100 [==============================] - 4s 38ms/step - loss: 0.0269
# Epoch 973/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0328
# Epoch 974/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0683
# Epoch 975/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0031
# Epoch 976/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0244
# Epoch 977/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0094
# Epoch 978/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0016
# Epoch 979/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0098
# Epoch 980/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0100
# Epoch 981/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0374
# Epoch 982/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0357
# Epoch 983/1000
# 100/100 [==============================] - 4s 38ms/step - loss: 0.0445
# Epoch 984/1000
# 100/100 [==============================] - 4s 38ms/step - loss: 0.0079
# Epoch 985/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0094
# Epoch 986/1000
# 100/100 [==============================] - 4s 38ms/step - loss: 0.0054
# Epoch 987/1000
# 100/100 [==============================] - 4s 38ms/step - loss: 0.0169
# Epoch 988/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0334
# Epoch 989/1000
# 100/100 [==============================] - 4s 38ms/step - loss: 0.0167
# Epoch 990/1000
# 100/100 [==============================] - 4s 38ms/step - loss: 0.0222
# Epoch 991/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0484
# Epoch 992/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0027
# Epoch 993/1000
# 100/100 [==============================] - 4s 38ms/step - loss: 0.0026
# Epoch 994/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0347
# Epoch 995/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0020
# Epoch 996/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0038
# Epoch 997/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0030
# Epoch 998/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0306
# Epoch 999/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0194
# Epoch 1000/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0127
# Epoch 1/1000
# 100/100 [==============================] - 7s 59ms/step - loss: 1.2564
# Epoch 2/1000
# 100/100 [==============================] - 6s 60ms/step - loss: 1.2484
# Epoch 3/1000
# 100/100 [==============================] - 6s 59ms/step - loss: 1.2396
# Epoch 4/1000
# 100/100 [==============================] - 6s 59ms/step - loss: 1.3750
# Epoch 5/1000
# 100/100 [==============================] - 6s 59ms/step - loss: 1.1883
# Epoch 6/1000
# 100/100 [==============================] - 6s 59ms/step - loss: 1.1927
# Epoch 7/1000
# 100/100 [==============================] - 6s 61ms/step - loss: 1.2175
# Epoch 8/1000
# 100/100 [==============================] - 6s 61ms/step - loss: 1.1068
# Epoch 9/1000
# 100/100 [==============================] - 6s 60ms/step - loss: 1.1380
# Epoch 10/1000
# 100/100 [==============================] - 6s 60ms/step - loss: 1.1122
# Epoch 11/1000
# 100/100 [==============================] - 6s 58ms/step - loss: 1.0412
# Epoch 12/1000
# 100/100 [==============================] - 6s 60ms/step - loss: 1.0885
# Epoch 13/1000
# 100/100 [==============================] - 6s 58ms/step - loss: 1.2366
# Epoch 14/1000
# 100/100 [==============================] - 6s 59ms/step - loss: 1.0358
# Epoch 15/1000
# 100/100 [==============================] - 6s 60ms/step - loss: 1.0180
# Epoch 16/1000
# 100/100 [==============================] - 6s 59ms/step - loss: 1.1435
# Epoch 17/1000
# 100/100 [==============================] - 6s 59ms/step - loss: 0.9621
# Epoch 18/1000
# 100/100 [==============================] - 6s 59ms/step - loss: 1.0154
# Epoch 19/1000
# 100/100 [==============================] - 6s 59ms/step - loss: 0.9213
# Epoch 20/1000
# 100/100 [==============================] - 6s 59ms/step - loss: 1.0849
# Epoch 21/1000
# 100/100 [==============================] - 6s 59ms/step - loss: 0.9196
# Epoch 22/1000
# 100/100 [==============================] - 6s 60ms/step - loss: 0.7690
# Epoch 23/1000
# 100/100 [==============================] - 6s 59ms/step - loss: 0.7790
# Epoch 24/1000
# 100/100 [==============================] - 6s 60ms/step - loss: 0.9726
# Epoch 25/1000
# 100/100 [==============================] - 6s 59ms/step - loss: 0.9104
# Epoch 26/1000
# 100/100 [==============================] - 6s 59ms/step - loss: 1.0144
# Epoch 27/1000
# 100/100 [==============================] - 6s 59ms/step - loss: 0.9281
# Epoch 28/1000
# 100/100 [==============================] - 6s 59ms/step - loss: 0.8476
# Epoch 29/1000
# 100/100 [==============================] - 6s 60ms/step - loss: 0.8151
# Epoch 30/1000
# 100/100 [==============================] - 6s 60ms/step - loss: 0.7760
# Epoch 31/1000
# 100/100 [==============================] - 6s 59ms/step - loss: 0.7183
# Epoch 32/1000
# 100/100 [==============================] - 6s 60ms/step - loss: 1.0394
# Epoch 33/1000
# 100/100 [==============================] - 6s 59ms/step - loss: 0.8699
# Epoch 34/1000
# 100/100 [==============================] - 6s 58ms/step - loss: 0.8841
# Epoch 35/1000
# 100/100 [==============================] - 6s 59ms/step - loss: 0.9770
# Epoch 36/1000
# 100/100 [==============================] - 6s 60ms/step - loss: 0.7910
# Epoch 37/1000
# 100/100 [==============================] - 6s 60ms/step - loss: 0.8504
# Epoch 38/1000
# 100/100 [==============================] - 6s 59ms/step - loss: 0.6720
# Epoch 39/1000
# 100/100 [==============================] - 6s 61ms/step - loss: 0.8164
# Epoch 40/1000
# 100/100 [==============================] - 6s 59ms/step - loss: 0.7514
# Epoch 41/1000
# 100/100 [==============================] - 6s 59ms/step - loss: 0.6959
# Epoch 42/1000
# 100/100 [==============================] - 6s 59ms/step - loss: 0.7214
# Epoch 43/1000
# 100/100 [==============================] - 6s 59ms/step - loss: 0.8994
# Epoch 44/1000
# 100/100 [==============================] - 6s 61ms/step - loss: 0.6622
# Epoch 45/1000
# 100/100 [==============================] - 6s 61ms/step - loss: 0.8011
# Epoch 46/1000
# 100/100 [==============================] - 6s 60ms/step - loss: 0.6458
# Epoch 47/1000
# 100/100 [==============================] - 6s 61ms/step - loss: 0.6811
# Epoch 48/1000
# 100/100 [==============================] - 6s 61ms/step - loss: 0.7656
# Epoch 49/1000
# 100/100 [==============================] - 6s 60ms/step - loss: 0.8830
# Epoch 50/1000
# 100/100 [==============================] - 6s 59ms/step - loss: 0.7372
# Epoch 51/1000
# 100/100 [==============================] - 6s 60ms/step - loss: 0.7264
# Epoch 52/1000
# 100/100 [==============================] - 6s 61ms/step - loss: 0.7863
# Epoch 53/1000
# 100/100 [==============================] - 6s 59ms/step - loss: 0.6897
# Epoch 54/1000
# 100/100 [==============================] - 6s 60ms/step - loss: 0.7182
# Epoch 55/1000
# 100/100 [==============================] - 6s 60ms/step - loss: 0.6119
# Epoch 56/1000
# 100/100 [==============================] - 6s 60ms/step - loss: 0.6786
# Epoch 57/1000
# 100/100 [==============================] - 6s 60ms/step - loss: 0.7916
# Epoch 58/1000
# 100/100 [==============================] - 6s 59ms/step - loss: 0.9539
# Epoch 59/1000
# ...
# Epoch 820/1000
# 100/100 [==============================] - 11s 111ms/step - loss: 0.1212
# Epoch 821/1000
# 100/100 [==============================] - 10s 104ms/step - loss: 0.1221
# Epoch 822/1000
# 100/100 [==============================] - 10s 103ms/step - loss: 0.1386
# Epoch 823/1000
# 100/100 [==============================] - 11s 110ms/step - loss: 0.0728
# Epoch 824/1000
# 100/100 [==============================] - 10s 104ms/step - loss: 0.0978
# Epoch 825/1000
# 100/100 [==============================] - 10s 104ms/step - loss: 0.0796
# Epoch 826/1000
# 100/100 [==============================] - 11s 111ms/step - loss: 0.0844
# Epoch 827/1000
# 100/100 [==============================] - 10s 104ms/step - loss: 0.0743
# Epoch 828/1000
# 100/100 [==============================] - 10s 104ms/step - loss: 0.0983
# Epoch 829/1000
# 100/100 [==============================] - 11s 111ms/step - loss: 0.1479
# Epoch 830/1000
# 100/100 [==============================] - 10s 104ms/step - loss: 0.0840
# Epoch 831/1000
# 100/100 [==============================] - 10s 101ms/step - loss: 0.1038
# Epoch 832/1000
# 100/100 [==============================] - 11s 109ms/step - loss: 0.0995
# Epoch 833/1000
# 100/100 [==============================] - 10s 102ms/step - loss: 0.0942
# Epoch 834/1000
# 100/100 [==============================] - 10s 101ms/step - loss: 0.0860
# Epoch 835/1000
# 100/100 [==============================] - 11s 109ms/step - loss: 0.0845
# Epoch 836/1000
# 100/100 [==============================] - 10s 102ms/step - loss: 0.1220
# Epoch 837/1000
# 100/100 [==============================] - 10s 101ms/step - loss: 0.0933
# Epoch 838/1000
# 100/100 [==============================] - 11s 108ms/step - loss: 0.0808
# Epoch 839/1000
# 100/100 [==============================] - 10s 102ms/step - loss: 0.0935
# Epoch 840/1000
# 100/100 [==============================] - 10s 102ms/step - loss: 0.0930
# Epoch 841/1000
# 100/100 [==============================] - 11s 111ms/step - loss: 0.0862
# Epoch 842/1000
# 100/100 [==============================] - 10s 103ms/step - loss: 0.1114
# Epoch 843/1000
# 100/100 [==============================] - 10s 101ms/step - loss: 0.0883
# Epoch 844/1000
# 100/100 [==============================] - 11s 110ms/step - loss: 0.0904
# Epoch 845/1000
# 100/100 [==============================] - 10s 101ms/step - loss: 0.0901
# Epoch 846/1000
# 100/100 [==============================] - 10s 101ms/step - loss: 0.0922
# Epoch 847/1000
# 100/100 [==============================] - 11s 109ms/step - loss: 0.0784
# Epoch 848/1000
# 100/100 [==============================] - 10s 101ms/step - loss: 0.1068
# Epoch 849/1000
# 100/100 [==============================] - 10s 100ms/step - loss: 0.1484
# Epoch 850/1000
# 100/100 [==============================] - 11s 109ms/step - loss: 0.1222
# Epoch 851/1000
# 100/100 [==============================] - 10s 101ms/step - loss: 0.1331
# Epoch 852/1000
# 100/100 [==============================] - 10s 102ms/step - loss: 0.0731
# Epoch 853/1000
# 100/100 [==============================] - 11s 111ms/step - loss: 0.0796
# Epoch 854/1000
# 100/100 [==============================] - 10s 103ms/step - loss: 0.0725
# Epoch 855/1000
# 100/100 [==============================] - 10s 102ms/step - loss: 0.1015
# Epoch 856/1000
# 100/100 [==============================] - 11s 110ms/step - loss: 0.0995
# Epoch 857/1000
# 100/100 [==============================] - 10s 102ms/step - loss: 0.0817
# Epoch 858/1000
# 100/100 [==============================] - 10s 103ms/step - loss: 0.1448
# Epoch 859/1000
# 100/100 [==============================] - 11s 111ms/step - loss: 0.1583
# Epoch 860/1000
# 100/100 [==============================] - 10s 103ms/step - loss: 0.1108
# Epoch 861/1000
# 100/100 [==============================] - 10s 102ms/step - loss: 0.1414
# Epoch 862/1000
# 100/100 [==============================] - 11s 111ms/step - loss: 0.0953
# Epoch 863/1000
# 100/100 [==============================] - 10s 102ms/step - loss: 0.1204
# Epoch 864/1000
# 100/100 [==============================] - 10s 103ms/step - loss: 0.0782
# Epoch 865/1000
# 100/100 [==============================] - 11s 111ms/step - loss: 0.1030
# Epoch 866/1000
# 100/100 [==============================] - 10s 102ms/step - loss: 0.0765
# Epoch 867/1000
# 100/100 [==============================] - 10s 101ms/step - loss: 0.0831
# Epoch 868/1000
# 100/100 [==============================] - 11s 105ms/step - loss: 0.1055
# Epoch 869/1000
# 100/100 [==============================] - 11s 106ms/step - loss: 0.1413
# Epoch 870/1000
# 100/100 [==============================] - 10s 102ms/step - loss: 0.0732
# Epoch 871/1000
# 100/100 [==============================] - 10s 102ms/step - loss: 0.1742
# Epoch 872/1000
# 100/100 [==============================] - 11s 110ms/step - loss: 0.0754
# Epoch 873/1000
# 100/100 [==============================] - 10s 101ms/step - loss: 0.1154
# Epoch 874/1000
# 100/100 [==============================] - 10s 103ms/step - loss: 0.1351
# Epoch 875/1000
# 100/100 [==============================] - 11s 110ms/step - loss: 0.0820
# Epoch 876/1000
# 100/100 [==============================] - 10s 102ms/step - loss: 0.1021
# Epoch 877/1000
# 100/100 [==============================] - 10s 103ms/step - loss: 0.0739
# Epoch 878/1000
# 100/100 [==============================] - 11s 110ms/step - loss: 0.0980
# Epoch 879/1000
# 100/100 [==============================] - 10s 102ms/step - loss: 0.0978
# Epoch 880/1000
# 100/100 [==============================] - 10s 101ms/step - loss: 0.0755
# Epoch 881/1000
# 100/100 [==============================] - 11s 111ms/step - loss: 0.0973
# Epoch 882/1000
# 100/100 [==============================] - 10s 102ms/step - loss: 0.1048
# Epoch 883/1000
# 100/100 [==============================] - 10s 101ms/step - loss: 0.0810
# Epoch 884/1000
# 100/100 [==============================] - 11s 110ms/step - loss: 0.0708
# Epoch 885/1000
# 100/100 [==============================] - 10s 101ms/step - loss: 0.1168
# Epoch 886/1000
# 100/100 [==============================] - 10s 102ms/step - loss: 0.0784
# Epoch 887/1000
# 100/100 [==============================] - 11s 111ms/step - loss: 0.1267
# Epoch 888/1000
# 100/100 [==============================] - 10s 103ms/step - loss: 0.1158
# Epoch 889/1000
# 100/100 [==============================] - 10s 104ms/step - loss: 0.0744
# Epoch 890/1000
# 100/100 [==============================] - 10s 103ms/step - loss: 0.0947
# Epoch 891/1000
# 100/100 [==============================] - 11s 110ms/step - loss: 0.1139
# Epoch 892/1000
# 100/100 [==============================] - 10s 102ms/step - loss: 0.0806
# Epoch 893/1000
# 100/100 [==============================] - 10s 103ms/step - loss: 0.0971
# Epoch 894/1000
# 100/100 [==============================] - 11s 109ms/step - loss: 0.0717
# Epoch 895/1000
# 100/100 [==============================] - 10s 103ms/step - loss: 0.1084
# Epoch 896/1000
# 100/100 [==============================] - 10s 103ms/step - loss: 0.1071
# Epoch 897/1000
# 100/100 [==============================] - 11s 109ms/step - loss: 0.1410
# Epoch 898/1000
# 100/100 [==============================] - 10s 102ms/step - loss: 0.0812
# Epoch 899/1000
# 100/100 [==============================] - 10s 102ms/step - loss: 0.0872
# Epoch 900/1000
# 100/100 [==============================] - 11s 110ms/step - loss: 0.0995
# Epoch 901/1000
# 100/100 [==============================] - 10s 102ms/step - loss: 0.0983
# Epoch 902/1000
# 100/100 [==============================] - 10s 103ms/step - loss: 0.1158
# Epoch 903/1000
# 100/100 [==============================] - 11s 110ms/step - loss: 0.0939
# Epoch 904/1000
# 100/100 [==============================] - 10s 104ms/step - loss: 0.1035
# Epoch 905/1000
# 100/100 [==============================] - 10s 102ms/step - loss: 0.0910
# Epoch 906/1000
# 100/100 [==============================] - 10s 104ms/step - loss: 0.0783
# Epoch 907/1000
# 100/100 [==============================] - 11s 108ms/step - loss: 0.0769
# Epoch 908/1000
# 100/100 [==============================] - 10s 103ms/step - loss: 0.1008
# Epoch 909/1000
# 100/100 [==============================] - 10s 101ms/step - loss: 0.0927
# Epoch 910/1000
# 100/100 [==============================] - 11s 111ms/step - loss: 0.1030
# Epoch 911/1000
# 100/100 [==============================] - 10s 103ms/step - loss: 0.1297
# Epoch 912/1000
# 100/100 [==============================] - 10s 102ms/step - loss: 0.0805
# Epoch 913/1000
# 100/100 [==============================] - 11s 110ms/step - loss: 0.1206
# Epoch 914/1000
# 100/100 [==============================] - 10s 102ms/step - loss: 0.0899
# Epoch 915/1000
# 100/100 [==============================] - 10s 103ms/step - loss: 0.0712
# Epoch 916/1000
# 100/100 [==============================] - 11s 112ms/step - loss: 0.0867
# Epoch 917/1000
# 100/100 [==============================] - 10s 101ms/step - loss: 0.0622
# Epoch 918/1000
# 100/100 [==============================] - 10s 103ms/step - loss: 0.0873
# Epoch 919/1000
# 100/100 [==============================] - 11s 113ms/step - loss: 0.0726
# Epoch 920/1000
# 100/100 [==============================] - 10s 102ms/step - loss: 0.0865
# Epoch 921/1000
# 100/100 [==============================] - 10s 103ms/step - loss: 0.1358
# Epoch 922/1000
# 100/100 [==============================] - 10s 102ms/step - loss: 0.0932
# Epoch 923/1000
# 100/100 [==============================] - 11s 110ms/step - loss: 0.0904
# Epoch 924/1000
# 100/100 [==============================] - 10s 104ms/step - loss: 0.0917
# Epoch 925/1000
# 100/100 [==============================] - 10s 103ms/step - loss: 0.1039
# Epoch 926/1000
# 100/100 [==============================] - 11s 111ms/step - loss: 0.0902
# Epoch 927/1000
# 100/100 [==============================] - 10s 102ms/step - loss: 0.0840
# Epoch 928/1000
# 100/100 [==============================] - 10s 102ms/step - loss: 0.0892
# Epoch 929/1000
# 100/100 [==============================] - 11s 111ms/step - loss: 0.0758
# Epoch 930/1000
# 100/100 [==============================] - 10s 102ms/step - loss: 0.0958
# Epoch 931/1000
# 100/100 [==============================] - 10s 101ms/step - loss: 0.0807
# Epoch 932/1000
# 100/100 [==============================] - 11s 106ms/step - loss: 0.1620
# Epoch 933/1000
# 100/100 [==============================] - 11s 108ms/step - loss: 0.0849
# Epoch 934/1000
# 100/100 [==============================] - 10s 102ms/step - loss: 0.0765
# Epoch 935/1000
# 100/100 [==============================] - 10s 101ms/step - loss: 0.0727
# Epoch 936/1000
# 100/100 [==============================] - 11s 112ms/step - loss: 0.0847
# Epoch 937/1000
# 100/100 [==============================] - 10s 102ms/step - loss: 0.1589
# Epoch 938/1000
# 100/100 [==============================] - 10s 101ms/step - loss: 0.1072
# Epoch 939/1000
# 100/100 [==============================] - 11s 113ms/step - loss: 0.0932
# Epoch 940/1000
# 100/100 [==============================] - 10s 103ms/step - loss: 0.1263
# Epoch 941/1000
# 100/100 [==============================] - 10s 101ms/step - loss: 0.0979
# Epoch 942/1000
# 100/100 [==============================] - 11s 110ms/step - loss: 0.0825
# Epoch 943/1000
# 100/100 [==============================] - 10s 102ms/step - loss: 0.0705
# Epoch 944/1000
# 100/100 [==============================] - 10s 103ms/step - loss: 0.0977
# Epoch 945/1000
# 100/100 [==============================] - 10s 101ms/step - loss: 0.0829
# Epoch 946/1000
# 100/100 [==============================] - 11s 110ms/step - loss: 0.0908
# Epoch 947/1000
# 100/100 [==============================] - 10s 102ms/step - loss: 0.1026
# Epoch 948/1000
# 100/100 [==============================] - 10s 104ms/step - loss: 0.1240
# Epoch 949/1000
# 100/100 [==============================] - 11s 113ms/step - loss: 0.0792
# Epoch 950/1000
# 100/100 [==============================] - 10s 103ms/step - loss: 0.1241
# Epoch 951/1000
# 100/100 [==============================] - 10s 103ms/step - loss: 0.0920
# Epoch 952/1000
# 100/100 [==============================] - 11s 112ms/step - loss: 0.0937
# Epoch 953/1000
# 100/100 [==============================] - 10s 103ms/step - loss: 0.1472
# Epoch 954/1000
# 100/100 [==============================] - 10s 104ms/step - loss: 0.0734
# Epoch 955/1000
# 100/100 [==============================] - 11s 109ms/step - loss: 0.1195
# Epoch 956/1000
# 100/100 [==============================] - 11s 106ms/step - loss: 0.1068
# Epoch 957/1000
# 100/100 [==============================] - 10s 102ms/step - loss: 0.0945
# Epoch 958/1000
# 100/100 [==============================] - 10s 104ms/step - loss: 0.0781
# Epoch 959/1000
# 100/100 [==============================] - 11s 114ms/step - loss: 0.0825
# Epoch 960/1000
# 100/100 [==============================] - 10s 102ms/step - loss: 0.0877
# Epoch 961/1000
# 100/100 [==============================] - 10s 103ms/step - loss: 0.0910
# Epoch 962/1000
# 100/100 [==============================] - 11s 111ms/step - loss: 0.0883
# Epoch 963/1000
# 100/100 [==============================] - 10s 101ms/step - loss: 0.1050
# Epoch 964/1000
# 100/100 [==============================] - 10s 102ms/step - loss: 0.0995
# Epoch 965/1000
# 100/100 [==============================] - 11s 114ms/step - loss: 0.1021
# Epoch 966/1000
# 100/100 [==============================] - 11s 106ms/step - loss: 0.0668
# Epoch 967/1000
# 100/100 [==============================] - 10s 104ms/step - loss: 0.1098
# Epoch 968/1000
# 100/100 [==============================] - 10s 104ms/step - loss: 0.0764
# Epoch 969/1000
# 100/100 [==============================] - 11s 112ms/step - loss: 0.1067
# Epoch 970/1000
# 100/100 [==============================] - 10s 102ms/step - loss: 0.0793
# Epoch 971/1000
# 100/100 [==============================] - 10s 102ms/step - loss: 0.0988
# Epoch 972/1000
# 100/100 [==============================] - 11s 113ms/step - loss: 0.1225
# Epoch 973/1000
# 100/100 [==============================] - 10s 103ms/step - loss: 0.0794
# Epoch 974/1000
# 100/100 [==============================] - 10s 104ms/step - loss: 0.0746
# Epoch 975/1000
# 100/100 [==============================] - 11s 105ms/step - loss: 0.0802
# Epoch 976/1000
# 100/100 [==============================] - 11s 109ms/step - loss: 0.0951
# Epoch 977/1000
# 100/100 [==============================] - 10s 103ms/step - loss: 0.0971
# Epoch 978/1000
# 100/100 [==============================] - 10s 103ms/step - loss: 0.0707
# Epoch 979/1000
# 100/100 [==============================] - 11s 110ms/step - loss: 0.0903
# Epoch 980/1000
# 100/100 [==============================] - 10s 101ms/step - loss: 0.1064
# Epoch 981/1000
# 100/100 [==============================] - 10s 102ms/step - loss: 0.0617
# Epoch 982/1000
# 100/100 [==============================] - 11s 111ms/step - loss: 0.0976
# Epoch 983/1000
# 100/100 [==============================] - 10s 101ms/step - loss: 0.0874
# Epoch 984/1000
# 100/100 [==============================] - 10s 102ms/step - loss: 0.0833
# Epoch 985/1000
# 100/100 [==============================] - 10s 103ms/step - loss: 0.0998
# Epoch 986/1000
# 100/100 [==============================] - 11s 112ms/step - loss: 0.0718
# Epoch 987/1000
# 100/100 [==============================] - 10s 102ms/step - loss: 0.1311
# Epoch 988/1000
# 100/100 [==============================] - 10s 104ms/step - loss: 0.1019
# Epoch 989/1000
# 100/100 [==============================] - 11s 111ms/step - loss: 0.0852
# Epoch 990/1000
# 100/100 [==============================] - 10s 102ms/step - loss: 0.0780
# Epoch 991/1000
# 100/100 [==============================] - 10s 101ms/step - loss: 0.0897
# Epoch 992/1000
# 100/100 [==============================] - 10s 101ms/step - loss: 0.1161
# Epoch 993/1000
# 100/100 [==============================] - 11s 114ms/step - loss: 0.0815
# Epoch 994/1000
# 100/100 [==============================] - 10s 104ms/step - loss: 0.1894
# Epoch 995/1000
# 100/100 [==============================] - 10s 101ms/step - loss: 0.0772
# Epoch 996/1000
# 100/100 [==============================] - 11s 112ms/step - loss: 0.0722
# Epoch 997/1000
# 100/100 [==============================] - 11s 105ms/step - loss: 0.0812
# Epoch 998/1000
# 100/100 [==============================] - 10s 102ms/step - loss: 0.0830
# Epoch 999/1000
# 100/100 [==============================] - 10s 103ms/step - loss: 0.0645
# Epoch 1000/1000
# 100/100 [==============================] - 11s 113ms/step - loss: 0.0851

# %% [markdown]
# ## Visualise Loss function

# %%
#print(result.history.keys())

plt.rcParams['figure.figsize'] = [10, 10]

# summarize history for loss
plt.plot(result_1.history['loss'])
plt.plot(result_2.history['loss'])
plt.plot(result_3.history['loss'])
plt.plot(result_4.history['loss'])

plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.rc('font', size=12)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=20)    # legend fontsize
plt.rc('figure', titlesize=20)  # fontsize of the figure title
plt.legend(['$\Delta_v$','$20\Delta_v$','$40\Delta_v$','$100\Delta_v$'], loc='upper left')
plt.yscale("log")
plt.show()

# %% [markdown]
# ## Plot trajectories generated to $t=32$ by Verlet integrator and neural

# %%
# Final time
T_final = 32

# Initial conditions
x = np.zeros(1)
v = np.zeros(1)
x[0] = 2.40
v[0] = 0.5
verlet_SHO.set_state(x,v)

# ==== Verlet integrator ====
t = 0.0
t_verlet_SHO = []
x_verlet_SHO = []
v_verlet_SHO = []
E_verlet_SHO = []



while t<T_final:
    t_verlet_SHO.append(t)
    E_verlet_SHO.append(verlet_SHO.energy())
    x_verlet_SHO.append(verlet_SHO.x[0])
    v_verlet_SHO.append(verlet_SHO.v[0])
    verlet_SHO.integrate(1)
    t += dt_verlet
        

# ==== Neural network integrator ====



# Initialise with Verlet integrator
x_initial_1 = np.zeros((hnn_integrator_1.nsteps,hnn_integrator_1.dynamical_system.dim))
v_initial_1 = np.zeros((hnn_integrator_1.nsteps,hnn_integrator_1.dynamical_system.dim))
x_initial_2 = np.zeros((hnn_integrator_2.nsteps,hnn_integrator_2.dynamical_system.dim))
v_initial_2 = np.zeros((hnn_integrator_2.nsteps,hnn_integrator_2.dynamical_system.dim))
x_initial_3 = np.zeros((hnn_integrator_3.nsteps,hnn_integrator_3.dynamical_system.dim))
v_initial_3 = np.zeros((hnn_integrator_3.nsteps,hnn_integrator_3.dynamical_system.dim))
x_initial_4 = np.zeros((hnn_integrator_4.nsteps,hnn_integrator_4.dynamical_system.dim))
v_initial_4 = np.zeros((hnn_integrator_4.nsteps,hnn_integrator_4.dynamical_system.dim))



verlet_SHO.set_state(x,v)
for k in range(hnn_integrator_1.nsteps):    
    x_initial_1[k,:] = verlet_SHO.x[:]
    v_initial_1[k,:] = verlet_SHO.v[:]
    verlet_SHO.integrate(int(dt_1/dt_verlet))
verlet_SHO.set_state(x,v)
for k in range(hnn_integrator_2.nsteps):    
    x_initial_2[k,:] = verlet_SHO.x[:]
    v_initial_2[k,:] = verlet_SHO.v[:]
    verlet_SHO.integrate(int(dt_2/dt_verlet))
verlet_SHO.set_state(x,v)
for k in range(hnn_integrator_3.nsteps):    
    x_initial_3[k,:] = verlet_SHO.x[:]
    v_initial_3[k,:] = verlet_SHO.v[:]
    verlet_SHO.integrate(int(dt_3/dt_verlet))
verlet_SHO.set_state(x,v)
for k in range(hnn_integrator_4.nsteps):    
    x_initial_4[k,:] = verlet_SHO.x[:]
    v_initial_4[k,:] = verlet_SHO.v[:]
    verlet_SHO.integrate(int(dt_4/dt_verlet))


hnn_integrator_1.set_state(x_initial_1,v_initial_1)
t_1 = (hnn_integrator_1.nsteps-1)*hnn_integrator_1.dt
hnn_integrator_2.set_state(x_initial_2,v_initial_2)
t_2 = (hnn_integrator_2.nsteps-1)*hnn_integrator_2.dt
hnn_integrator_3.set_state(x_initial_3,v_initial_3)
t_3 = (hnn_integrator_3.nsteps-1)*hnn_integrator_3.dt
hnn_integrator_4.set_state(x_initial_4,v_initial_4)
t_4 = (hnn_integrator_4.nsteps-1)*hnn_integrator_4.dt



# Timestepping loop
t_hnn_1 = []
x_hnn_1 = []
v_hnn_1 = []
E_hnn_1 = []
t_hnn_2 = []
x_hnn_2 = []
v_hnn_2 = []
E_hnn_2 = []
t_hnn_3 = []
x_hnn_3 = []
v_hnn_3 = []
E_hnn_3 = []
t_hnn_4 = []
x_hnn_4 = []
v_hnn_4 = []
E_hnn_4 = []


while t_1<T_final:
    t_hnn_1.append(t_1)
    x_hnn_1.append(hnn_integrator_1.x[0])
    v_hnn_1.append(hnn_integrator_1.v[0])
    E_hnn_1.append(hnn_integrator_1.energy())
    hnn_integrator_1.integrate(1)
    t_1 += dt_1
while t_2<T_final:
    t_hnn_2.append(t_2)
    x_hnn_2.append(hnn_integrator_2.x[0])
    v_hnn_2.append(hnn_integrator_2.v[0])
    E_hnn_2.append(hnn_integrator_2.energy())
    hnn_integrator_2.integrate(1)
    t_2 += dt_2
while t_3<T_final:
    t_hnn_3.append(t_3)
    x_hnn_3.append(hnn_integrator_3.x[0])
    v_hnn_3.append(hnn_integrator_3.v[0])
    E_hnn_3.append(hnn_integrator_3.energy())
    hnn_integrator_3.integrate(1)
    t_3 += dt_3
while t_4<T_final:
    t_hnn_4.append(t_4)
    x_hnn_4.append(hnn_integrator_4.x[0])
    v_hnn_4.append(hnn_integrator_4.v[0])
    E_hnn_4.append(hnn_integrator_4.energy())
    hnn_integrator_4.integrate(1)
    t_4 += dt_4
 



x_hnn_1 = np.array(x_hnn_1)
x_hnn_2 = np.array(x_hnn_2)
x_hnn_3 = np.array(x_hnn_3)
x_hnn_4 = np.array(x_hnn_4)
x_verlet_SHO = np.array(x_verlet_SHO)
v_hnn_1 = np.array(v_hnn_1)
v_hnn_2 = np.array(v_hnn_2)
v_hnn_3 = np.array(v_hnn_3)
v_hnn_4 = np.array(v_hnn_4)
v_verlet_SHO = np.array(v_verlet_SHO)

# %%
nsteps = 1

# Plot position error as a function of time
plt.clf()
plt.rcParams['figure.figsize'] = [10, 10]

plt.plot(t_hnn_1,x_hnn_1-x_verlet_SHO[int((nsteps-1)*dt_1/dt_verlet)::int(dt_1/dt_verlet)],label='$\Delta_v$',color='blue')
plt.plot(t_hnn_2,x_hnn_2-x_verlet_SHO[int((nsteps-1)*dt_2/dt_verlet):int(np.size(x_verlet_SHO)-dt_2/dt_verlet):int(dt_2/dt_verlet)],label='$20\Delta_v$',color='orange')
plt.plot(t_hnn_3,x_hnn_3-x_verlet_SHO[int((nsteps-1)*dt_3/dt_verlet)::int(dt_3/dt_verlet)],label='$40\Delta_v$',color='green')
plt.plot(t_hnn_4,x_hnn_4-x_verlet_SHO[int((nsteps-1)*dt_4/dt_verlet):int(np.size(x_verlet_SHO)-dt_4/dt_verlet):int(dt_4/dt_verlet)],label='$100\Delta_v$',color='red')
plt.legend(loc='upper left')
ax = plt.gca()
ax.set_xlabel('time $t$')
ax.set_ylabel('position Error $x_{NN}(t)-x_V(t)$')
ax.set_title('Position Error')
plt.rc('font', size=12)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=20)    # legend fontsize
plt.rc('figure', titlesize=20)  # fontsize of the figure title
#plt.grid()
plt.show()

# Plot velocity error as a function of time

plt.plot(t_hnn_1,v_hnn_1-v_verlet_SHO[int((nsteps-1)*dt_1/dt_verlet)::int(dt_1/dt_verlet)],label='$\Delta_v$',color='blue')
plt.plot(t_hnn_2,v_hnn_2-v_verlet_SHO[int((nsteps-1)*dt_2/dt_verlet):int(np.size(v_verlet_SHO)-dt_2/dt_verlet):int(dt_2/dt_verlet)],label='$20\Delta_v$',color='orange')
plt.plot(t_hnn_3,v_hnn_3-v_verlet_SHO[int((nsteps-1)*dt_3/dt_verlet)::int(dt_3/dt_verlet)],label='$40\Delta_v$',color='green')
plt.plot(t_hnn_4,v_hnn_4-v_verlet_SHO[int((nsteps-1)*dt_4/dt_verlet):int(np.size(v_verlet_SHO)-dt_4/dt_verlet):int(dt_4/dt_verlet)],label='$100\Delta_v$',color='red')
plt.legend(loc='upper left')
ax = plt.gca()
ax.set_xlabel('time $t$')
ax.set_ylabel('Velocity Error $v_{NN}(t)-v_V(t)$')
ax.set_title('Velocity Error')
plt.rc('font', size=12)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=20)    # legend fontsize
plt.rc('figure', titlesize=20)  # fontsize of the figure title
#plt.grid()
plt.show()

# Plot L2 error as a function of time

plt.plot(t_hnn_1,((v_hnn_1-v_verlet_SHO[int((nsteps-1)*dt_1/dt_verlet)::int(dt_1/dt_verlet)])**2+(x_hnn_1-x_verlet_SHO[int((nsteps-1)*dt_1/dt_verlet)::int(dt_1/dt_verlet)])**2)**0.5,label='$\Delta_v$',color='blue')
plt.plot(t_hnn_2,((v_hnn_2-v_verlet_SHO[int((nsteps-1)*dt_2/dt_verlet):int(np.size(v_verlet_SHO)-dt_2/dt_verlet):int(dt_2/dt_verlet)])**2+(x_hnn_2-x_verlet_SHO[int((nsteps-1)*dt_2/dt_verlet):int(np.size(x_verlet_SHO)-dt_2/dt_verlet):int(dt_2/dt_verlet)])**2)**0.5,label='$20\Delta_v$',color='orange')
plt.plot(t_hnn_3,((v_hnn_3-v_verlet_SHO[int((nsteps-1)*dt_3/dt_verlet)::int(dt_3/dt_verlet)])**2+(x_hnn_3-x_verlet_SHO[int((nsteps-1)*dt_3/dt_verlet)::int(dt_3/dt_verlet)])**2)**0.5,label='$40\Delta_v$',color='green')
plt.plot(t_hnn_4,((v_hnn_4-v_verlet_SHO[int((nsteps-1)*dt_4/dt_verlet):int(np.size(v_verlet_SHO)-dt_4/dt_verlet):int(dt_4/dt_verlet)])**2+(x_hnn_4-x_verlet_SHO[int((nsteps-1)*dt_4/dt_verlet):int(np.size(x_verlet_SHO)-dt_4/dt_verlet):int(dt_4/dt_verlet)])**2)**0.5,label='$100\Delta_v$',color='red')
plt.legend(loc='upper left')
ax = plt.gca()
ax.set_xlabel('time $t$')
ax.set_ylabel('L2 Error')
ax.set_title('L2 Error')
plt.rc('font', size=12)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=20)    # legend fontsize
plt.rc('figure', titlesize=20)  # fontsize of the figure title
#plt.grid()
plt.show()


plt.clf()
# Plot energy as a function of time
# (subtract energy at time t=0 to show energy drift)

plt.plot(t_verlet_SHO,E_verlet_SHO-E_verlet_SHO[0],label='Verlet',color='black')
plt.plot(t_hnn_1,E_hnn_1-E_hnn_1[0],label='$\Delta_v$',color='blue')
plt.plot(t_hnn_2,E_hnn_2-E_hnn_2[0],label='$20\Delta_v$',color='orange')
plt.plot(t_hnn_3,E_hnn_3-E_hnn_3[0],label='$40\Delta_v$',color='green')
plt.plot(t_hnn_4,E_hnn_4-E_hnn_4[0],label='$100\Delta_v$',color='red')
plt.legend(loc='upper left')
ax = plt.gca()
ax.set_xlabel('time $t$')
ax.set_ylabel('energy shift $E(t)-E(t_0)$')
#ax.grid()
plt.rc('font', size=12)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=20)    # legend fontsize
plt.rc('figure', titlesize=20)  # fontsize of the figure title

plt.show()

#subplots of position versus velocity for all 4

plt.rcParams['figure.figsize'] = [10, 10]

plt.clf()
plt.plot(x_verlet_SHO,v_verlet_SHO,label='Verlet',color='black')
plt.plot(x_hnn_1,v_hnn_1,label='$\Delta_v$',color='blue')
plt.plot(x_hnn_2,v_hnn_2,label='$20\Delta_v$',color='orange')
plt.plot(x_hnn_3,v_hnn_3,label='$40\Delta_v$',color='green')
plt.plot(x_hnn_4,v_hnn_4,label='$100\Delta_v$',color='red')
plt.legend(loc='upper left')
ax = plt.gca()
ax.set_ylabel('Velocity $v(t)$')
ax.set_xlabel('Position $q(t)$')
plt.rc('font', size=12)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=20)    # legend fontsize
plt.rc('figure', titlesize=20)  # fontsize of the figure title
plt.show()

# %% [markdown]
# ## Plot trajectories generated to $t=128$ by Verlet integrator and neural

# %%
# Final time
T_final = 128

# Initial conditions
x = np.zeros(1)
v = np.zeros(1)
x[0] = 2.40
v[0] = 0.5
verlet_SHO.set_state(x,v)

# ==== Verlet integrator ====
t = 0.0
t_verlet_SHO = []
x_verlet_SHO = []
v_verlet_SHO = []
E_verlet_SHO = []



while t<T_final:
    t_verlet_SHO.append(t)
    E_verlet_SHO.append(verlet_SHO.energy())
    x_verlet_SHO.append(verlet_SHO.x[0])
    v_verlet_SHO.append(verlet_SHO.v[0])
    verlet_SHO.integrate(1)
    t += dt_verlet
        

# ==== Neural network integrator ====

# Initialise with Verlet integrator
x_initial_1 = np.zeros((hnn_integrator_1.nsteps,hnn_integrator_1.dynamical_system.dim))
v_initial_1 = np.zeros((hnn_integrator_1.nsteps,hnn_integrator_1.dynamical_system.dim))
x_initial_2 = np.zeros((hnn_integrator_2.nsteps,hnn_integrator_2.dynamical_system.dim))
v_initial_2 = np.zeros((hnn_integrator_2.nsteps,hnn_integrator_2.dynamical_system.dim))
x_initial_3 = np.zeros((hnn_integrator_3.nsteps,hnn_integrator_3.dynamical_system.dim))
v_initial_3 = np.zeros((hnn_integrator_3.nsteps,hnn_integrator_3.dynamical_system.dim))
x_initial_4 = np.zeros((hnn_integrator_4.nsteps,hnn_integrator_4.dynamical_system.dim))
v_initial_4 = np.zeros((hnn_integrator_4.nsteps,hnn_integrator_4.dynamical_system.dim))



verlet_SHO.set_state(x,v)
for k in range(hnn_integrator_1.nsteps):    
    x_initial_1[k,:] = verlet_SHO.x[:]
    v_initial_1[k,:] = verlet_SHO.v[:]
    verlet_SHO.integrate(int(dt_1/dt_verlet))
verlet_SHO.set_state(x,v)
for k in range(hnn_integrator_2.nsteps):    
    x_initial_2[k,:] = verlet_SHO.x[:]
    v_initial_2[k,:] = verlet_SHO.v[:]
    verlet_SHO.integrate(int(dt_2/dt_verlet))
verlet_SHO.set_state(x,v)
for k in range(hnn_integrator_3.nsteps):    
    x_initial_3[k,:] = verlet_SHO.x[:]
    v_initial_3[k,:] = verlet_SHO.v[:]
    verlet_SHO.integrate(int(dt_3/dt_verlet))
verlet_SHO.set_state(x,v)
for k in range(hnn_integrator_4.nsteps):    
    x_initial_4[k,:] = verlet_SHO.x[:]
    v_initial_4[k,:] = verlet_SHO.v[:]
    verlet_SHO.integrate(int(dt_4/dt_verlet))


hnn_integrator_1.set_state(x_initial_1,v_initial_1)
t_1 = (hnn_integrator_1.nsteps-1)*hnn_integrator_1.dt
hnn_integrator_2.set_state(x_initial_2,v_initial_2)
t_2 = (hnn_integrator_2.nsteps-1)*hnn_integrator_2.dt
hnn_integrator_3.set_state(x_initial_3,v_initial_3)
t_3 = (hnn_integrator_3.nsteps-1)*hnn_integrator_3.dt
hnn_integrator_4.set_state(x_initial_4,v_initial_4)
t_4 = (hnn_integrator_4.nsteps-1)*hnn_integrator_4.dt



# Timestepping loop
t_hnn_1 = []
x_hnn_1 = []
v_hnn_1 = []
E_hnn_1 = []
t_hnn_2 = []
x_hnn_2 = []
v_hnn_2 = []
E_hnn_2 = []
t_hnn_3 = []
x_hnn_3 = []
v_hnn_3 = []
E_hnn_3 = []
t_hnn_4 = []
x_hnn_4 = []
v_hnn_4 = []
E_hnn_4 = []


while t_1<T_final:
    t_hnn_1.append(t_1)
    x_hnn_1.append(hnn_integrator_1.x[0])
    v_hnn_1.append(hnn_integrator_1.v[0])
    E_hnn_1.append(hnn_integrator_1.energy())
    hnn_integrator_1.integrate(1)
    t_1 += dt_1
while t_2<T_final:
    t_hnn_2.append(t_2)
    x_hnn_2.append(hnn_integrator_2.x[0])
    v_hnn_2.append(hnn_integrator_2.v[0])
    E_hnn_2.append(hnn_integrator_2.energy())
    hnn_integrator_2.integrate(1)
    t_2 += dt_2
while t_3<T_final:
    t_hnn_3.append(t_3)
    x_hnn_3.append(hnn_integrator_3.x[0])
    v_hnn_3.append(hnn_integrator_3.v[0])
    E_hnn_3.append(hnn_integrator_3.energy())
    hnn_integrator_3.integrate(1)
    t_3 += dt_3
while t_4<T_final:
    t_hnn_4.append(t_4)
    x_hnn_4.append(hnn_integrator_4.x[0])
    v_hnn_4.append(hnn_integrator_4.v[0])
    E_hnn_4.append(hnn_integrator_4.energy())
    hnn_integrator_4.integrate(1)
    t_4 += dt_4
 



x_hnn_1 = np.array(x_hnn_1)
x_hnn_2 = np.array(x_hnn_2)
x_hnn_3 = np.array(x_hnn_3)
x_hnn_4 = np.array(x_hnn_4)
x_verlet_SHO = np.array(x_verlet_SHO)
v_hnn_1 = np.array(v_hnn_1)
v_hnn_2 = np.array(v_hnn_2)
v_hnn_3 = np.array(v_hnn_3)
v_hnn_4 = np.array(v_hnn_4)
v_verlet_SHO = np.array(v_verlet_SHO)


# Plot position error as a function of time

nsteps = 1


plt.clf()
plt.rcParams['figure.figsize'] = [10, 10]

plt.plot(t_hnn_1,x_hnn_1-x_verlet_SHO[int((nsteps-1)*dt_1/dt_verlet)::int(dt_1/dt_verlet)],label='$\Delta_v$',color='blue')
plt.plot(t_hnn_2,x_hnn_2-x_verlet_SHO[int((nsteps-1)*dt_2/dt_verlet)::int(dt_2/dt_verlet)],label='$20\Delta_v$',color='orange')
plt.plot(t_hnn_3,x_hnn_3-x_verlet_SHO[int((nsteps-1)*dt_3/dt_verlet):int(np.size(x_verlet_SHO)-dt_3/dt_verlet):int(dt_3/dt_verlet)],label='$40\Delta_v$',color='green')
plt.plot(t_hnn_4,x_hnn_4-x_verlet_SHO[int((nsteps-1)*dt_4/dt_verlet):int(np.size(x_verlet_SHO)-dt_4/dt_verlet):int(dt_4/dt_verlet)],label='$100\Delta_v$',color='red')
plt.legend(loc='upper left')
ax = plt.gca()
ax.set_xlabel('time $t$')
ax.set_ylabel('position Error $x_{NN}(t)-x_V(t)$')
ax.set_title('Position Error')
plt.rc('font', size=12)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=20)    # legend fontsize
plt.rc('figure', titlesize=20)  # fontsize of the figure title
#plt.grid()
plt.show()

# Plot velocity error as a function of time

plt.plot(t_hnn_1,v_hnn_1-v_verlet_SHO[int((nsteps-1)*dt_1/dt_verlet)::int(dt_1/dt_verlet)],label='$\Delta_v$',color='blue')
plt.plot(t_hnn_2,v_hnn_2-v_verlet_SHO[int((nsteps-1)*dt_2/dt_verlet)::int(dt_2/dt_verlet)],label='$20\Delta_v$',color='orange')
plt.plot(t_hnn_3,v_hnn_3-v_verlet_SHO[int((nsteps-1)*dt_3/dt_verlet):int(np.size(v_verlet_SHO)-dt_3/dt_verlet):int(dt_3/dt_verlet)],label='$40\Delta_v$',color='green')
plt.plot(t_hnn_4,v_hnn_4-v_verlet_SHO[int((nsteps-1)*dt_4/dt_verlet):int(np.size(v_verlet_SHO)-dt_4/dt_verlet):int(dt_4/dt_verlet)],label='$100\Delta_v$',color='red')
plt.legend(loc='upper left')
ax = plt.gca()
ax.set_xlabel('time $t$')
ax.set_ylabel('Velocity Error $v_{NN}(t)-v_V(t)$')
ax.set_title('Velocity Error')
plt.rc('font', size=12)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=20)    # legend fontsize
plt.rc('figure', titlesize=20)  # fontsize of the figure title
#plt.grid()
plt.show()

# Plot L2 error as a function of time

plt.plot(t_hnn_1,((v_hnn_1-v_verlet_SHO[int((nsteps-1)*dt_1/dt_verlet)::int(dt_1/dt_verlet)])**2+(x_hnn_1-x_verlet_SHO[int((nsteps-1)*dt_1/dt_verlet)::int(dt_1/dt_verlet)])**2)**0.5,label='$\Delta_v$',color='blue')
plt.plot(t_hnn_2,((v_hnn_2-v_verlet_SHO[int((nsteps-1)*dt_2/dt_verlet)::int(dt_2/dt_verlet)])**2+(x_hnn_2-x_verlet_SHO[int((nsteps-1)*dt_2/dt_verlet)::int(dt_2/dt_verlet)])**2)**0.5,label='$20\Delta_v$',color='orange')
plt.plot(t_hnn_3,((v_hnn_3-v_verlet_SHO[int((nsteps-1)*dt_3/dt_verlet):int(np.size(v_verlet_SHO)-dt_3/dt_verlet):int(dt_3/dt_verlet)])**2+(x_hnn_3-x_verlet_SHO[int((nsteps-1)*dt_3/dt_verlet):int(np.size(x_verlet_SHO)-dt_3/dt_verlet):int(dt_3/dt_verlet)])**2)**0.5,label='$40\Delta_v$',color='green')
plt.plot(t_hnn_4,((v_hnn_4-v_verlet_SHO[int((nsteps-1)*dt_4/dt_verlet):int(np.size(v_verlet_SHO)-dt_4/dt_verlet):int(dt_4/dt_verlet)])**2+(x_hnn_4-x_verlet_SHO[int((nsteps-1)*dt_4/dt_verlet):int(np.size(x_verlet_SHO)-dt_4/dt_verlet):int(dt_4/dt_verlet)])**2)**0.5,label='$100\Delta_v$',color='red')
plt.legend(loc='upper left')
ax = plt.gca()
ax.set_xlabel('time $t$')
ax.set_ylabel('L2 Error')
ax.set_title('L2 Error')
plt.rc('font', size=12)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=20)    # legend fontsize
plt.rc('figure', titlesize=20)  # fontsize of the figure title
#plt.grid()
plt.show()


plt.clf()
# Plot energy as a function of time
# (subtract energy at time t=0 to show energy drift)

plt.plot(t_verlet_SHO,E_verlet_SHO-E_verlet_SHO[0],label='Verlet',color='black')
plt.plot(t_hnn_1,E_hnn_1-E_hnn_1[0],label='$\Delta_v$',color='blue')
plt.plot(t_hnn_2,E_hnn_2-E_hnn_2[0],label='$20\Delta_v$',color='orange')
plt.plot(t_hnn_3,E_hnn_3-E_hnn_3[0],label='$40\Delta_v$',color='green')
plt.plot(t_hnn_4,E_hnn_4-E_hnn_4[0],label='$100\Delta_v$',color='red')
plt.legend(loc='upper left')
ax = plt.gca()
ax.set_xlabel('time $t$')
ax.set_ylabel('energy shift $E(t)-E(t_0)$')
#ax.grid()
plt.rc('font', size=12)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=20)    # legend fontsize
plt.rc('figure', titlesize=20)  # fontsize of the figure title

plt.show()

#subplots of position versus velocity for all 4

plt.rcParams['figure.figsize'] = [10, 10]

plt.clf()
plt.plot(x_verlet_SHO,v_verlet_SHO,label='Verlet',color='black')
plt.plot(x_hnn_1,v_hnn_1,label='$\Delta_v$',color='blue')
plt.plot(x_hnn_2,v_hnn_2,label='$20\Delta_v$',color='orange')
plt.plot(x_hnn_3,v_hnn_3,label='$40\Delta_v$',color='green')
plt.plot(x_hnn_4,v_hnn_4,label='$100\Delta_v$',color='red')
plt.legend(loc='upper left')
ax = plt.gca()
ax.set_ylabel('Velocity $v(t)$')
ax.set_xlabel('Position $q(t)$')
plt.rc('font', size=12)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=20)    # legend fontsize
plt.rc('figure', titlesize=20)  # fontsize of the figure title
plt.show()

# %% [markdown]
# ## Plot trajectories generated to $t=512$ by Verlet integrator and neural

# %%
# Final time
T_final = 512

# Initial conditions
x = np.zeros(1)
v = np.zeros(1)
x[0] = 2.40
v[0] = 0.5
verlet_SHO.set_state(x,v)

# ==== Verlet integrator ====
t = 0.0
t_verlet_SHO = []
x_verlet_SHO = []
v_verlet_SHO = []
E_verlet_SHO = []



while t<T_final:
    t_verlet_SHO.append(t)
    E_verlet_SHO.append(verlet_SHO.energy())
    x_verlet_SHO.append(verlet_SHO.x[0])
    v_verlet_SHO.append(verlet_SHO.v[0])
    verlet_SHO.integrate(1)
    t += dt_verlet
        

# ==== Neural network integrator ====

# Initialise with Verlet integrator
x_initial_1 = np.zeros((hnn_integrator_1.nsteps,hnn_integrator_1.dynamical_system.dim))
v_initial_1 = np.zeros((hnn_integrator_1.nsteps,hnn_integrator_1.dynamical_system.dim))
x_initial_2 = np.zeros((hnn_integrator_2.nsteps,hnn_integrator_2.dynamical_system.dim))
v_initial_2 = np.zeros((hnn_integrator_2.nsteps,hnn_integrator_2.dynamical_system.dim))
x_initial_3 = np.zeros((hnn_integrator_3.nsteps,hnn_integrator_3.dynamical_system.dim))
v_initial_3 = np.zeros((hnn_integrator_3.nsteps,hnn_integrator_3.dynamical_system.dim))
x_initial_4 = np.zeros((hnn_integrator_4.nsteps,hnn_integrator_4.dynamical_system.dim))
v_initial_4 = np.zeros((hnn_integrator_4.nsteps,hnn_integrator_4.dynamical_system.dim))



verlet_SHO.set_state(x,v)
for k in range(hnn_integrator_1.nsteps):    
    x_initial_1[k,:] = verlet_SHO.x[:]
    v_initial_1[k,:] = verlet_SHO.v[:]
    verlet_SHO.integrate(int(dt_1/dt_verlet))
verlet_SHO.set_state(x,v)
for k in range(hnn_integrator_2.nsteps):    
    x_initial_2[k,:] = verlet_SHO.x[:]
    v_initial_2[k,:] = verlet_SHO.v[:]
    verlet_SHO.integrate(int(dt_2/dt_verlet))
verlet_SHO.set_state(x,v)
for k in range(hnn_integrator_3.nsteps):    
    x_initial_3[k,:] = verlet_SHO.x[:]
    v_initial_3[k,:] = verlet_SHO.v[:]
    verlet_SHO.integrate(int(dt_3/dt_verlet))
verlet_SHO.set_state(x,v)
for k in range(hnn_integrator_4.nsteps):    
    x_initial_4[k,:] = verlet_SHO.x[:]
    v_initial_4[k,:] = verlet_SHO.v[:]
    verlet_SHO.integrate(int(dt_4/dt_verlet))


hnn_integrator_1.set_state(x_initial_1,v_initial_1)
t_1 = (hnn_integrator_1.nsteps-1)*hnn_integrator_1.dt
hnn_integrator_2.set_state(x_initial_2,v_initial_2)
t_2 = (hnn_integrator_2.nsteps-1)*hnn_integrator_2.dt
hnn_integrator_3.set_state(x_initial_3,v_initial_3)
t_3 = (hnn_integrator_3.nsteps-1)*hnn_integrator_3.dt
hnn_integrator_4.set_state(x_initial_4,v_initial_4)
t_4 = (hnn_integrator_4.nsteps-1)*hnn_integrator_4.dt



# Timestepping loop
t_hnn_1 = []
x_hnn_1 = []
v_hnn_1 = []
E_hnn_1 = []
t_hnn_2 = []
x_hnn_2 = []
v_hnn_2 = []
E_hnn_2 = []
t_hnn_3 = []
x_hnn_3 = []
v_hnn_3 = []
E_hnn_3 = []
t_hnn_4 = []
x_hnn_4 = []
v_hnn_4 = []
E_hnn_4 = []


while t_1<T_final:
    t_hnn_1.append(t_1)
    x_hnn_1.append(hnn_integrator_1.x[0])
    v_hnn_1.append(hnn_integrator_1.v[0])
    E_hnn_1.append(hnn_integrator_1.energy())
    hnn_integrator_1.integrate(1)
    t_1 += dt_1
while t_2<T_final:
    t_hnn_2.append(t_2)
    x_hnn_2.append(hnn_integrator_2.x[0])
    v_hnn_2.append(hnn_integrator_2.v[0])
    E_hnn_2.append(hnn_integrator_2.energy())
    hnn_integrator_2.integrate(1)
    t_2 += dt_2
while t_3<T_final:
    t_hnn_3.append(t_3)
    x_hnn_3.append(hnn_integrator_3.x[0])
    v_hnn_3.append(hnn_integrator_3.v[0])
    E_hnn_3.append(hnn_integrator_3.energy())
    hnn_integrator_3.integrate(1)
    t_3 += dt_3
while t_4<T_final:
    t_hnn_4.append(t_4)
    x_hnn_4.append(hnn_integrator_4.x[0])
    v_hnn_4.append(hnn_integrator_4.v[0])
    E_hnn_4.append(hnn_integrator_4.energy())
    hnn_integrator_4.integrate(1)
    t_4 += dt_4
 



x_hnn_1 = np.array(x_hnn_1)
x_hnn_2 = np.array(x_hnn_2)
x_hnn_3 = np.array(x_hnn_3)
x_hnn_4 = np.array(x_hnn_4)
x_verlet_SHO = np.array(x_verlet_SHO)
v_hnn_1 = np.array(v_hnn_1)
v_hnn_2 = np.array(v_hnn_2)
v_hnn_3 = np.array(v_hnn_3)
v_hnn_4 = np.array(v_hnn_4)
v_verlet_SHO = np.array(v_verlet_SHO)

# %%
nsteps = 1

# Plot position error as a function of time
plt.clf()
plt.rcParams['figure.figsize'] = [10, 10]

plt.plot(t_hnn_1,x_hnn_1-x_verlet_SHO[int((nsteps-1)*dt_1/dt_verlet)::int(dt_1/dt_verlet)],label='$\Delta_v$',color='blue')
plt.plot(t_hnn_2,x_hnn_2-x_verlet_SHO[int((nsteps-1)*dt_2/dt_verlet):int(np.size(x_verlet_SHO)-dt_2/dt_verlet):int(dt_2/dt_verlet)],label='$20\Delta_v$',color='orange')
plt.plot(t_hnn_3,x_hnn_3-x_verlet_SHO[int((nsteps-1)*dt_3/dt_verlet)::int(dt_3/dt_verlet)],label='$40\Delta_v$',color='green')
plt.plot(t_hnn_4,x_hnn_4-x_verlet_SHO[int((nsteps-1)*dt_4/dt_verlet):int(np.size(x_verlet_SHO)-dt_4/dt_verlet):int(dt_4/dt_verlet)],label='$100\Delta_v$',color='red')
plt.legend(loc='upper left')
ax = plt.gca()
ax.set_xlabel('time $t$')
ax.set_ylabel('position Error $x_{NN}(t)-x_V(t)$')
ax.set_title('Position Error')
plt.rc('font', size=12)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=20)    # legend fontsize
plt.rc('figure', titlesize=20)  # fontsize of the figure title
#plt.grid()
plt.show()

# Plot velocity error as a function of time

plt.plot(t_hnn_1,v_hnn_1-v_verlet_SHO[int((nsteps-1)*dt_1/dt_verlet)::int(dt_1/dt_verlet)],label='$\Delta_v$',color='blue')
plt.plot(t_hnn_2,v_hnn_2-v_verlet_SHO[int((nsteps-1)*dt_2/dt_verlet):int(np.size(v_verlet_SHO)-dt_2/dt_verlet):int(dt_2/dt_verlet)],label='$20\Delta_v$',color='orange')
plt.plot(t_hnn_3,v_hnn_3-v_verlet_SHO[int((nsteps-1)*dt_3/dt_verlet)::int(dt_3/dt_verlet)],label='$40\Delta_v$',color='green')
plt.plot(t_hnn_4,v_hnn_4-v_verlet_SHO[int((nsteps-1)*dt_4/dt_verlet):int(np.size(v_verlet_SHO)-dt_4/dt_verlet):int(dt_4/dt_verlet)],label='$100\Delta_v$',color='red')
plt.legend(loc='upper left')
ax = plt.gca()
ax.set_xlabel('time $t$')
ax.set_ylabel('Velocity Error $v_{NN}(t)-v_V(t)$')
ax.set_title('Velocity Error')
plt.rc('font', size=12)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=20)    # legend fontsize
plt.rc('figure', titlesize=20)  # fontsize of the figure title
#plt.grid()
plt.show()

# Plot L2 error as a function of time

plt.plot(t_hnn_1,((v_hnn_1-v_verlet_SHO[int((nsteps-1)*dt_1/dt_verlet)::int(dt_1/dt_verlet)])**2+(x_hnn_1-x_verlet_SHO[int((nsteps-1)*dt_1/dt_verlet)::int(dt_1/dt_verlet)])**2)**0.5,label='$\Delta_v$',color='blue')
plt.plot(t_hnn_2,((v_hnn_2-v_verlet_SHO[int((nsteps-1)*dt_2/dt_verlet):int(np.size(v_verlet_SHO)-dt_2/dt_verlet):int(dt_2/dt_verlet)])**2+(x_hnn_2-x_verlet_SHO[int((nsteps-1)*dt_2/dt_verlet):int(np.size(x_verlet_SHO)-dt_2/dt_verlet):int(dt_2/dt_verlet)])**2)**0.5,label='$20\Delta_v$',color='orange')
plt.plot(t_hnn_3,((v_hnn_3-v_verlet_SHO[int((nsteps-1)*dt_3/dt_verlet)::int(dt_3/dt_verlet)])**2+(x_hnn_3-x_verlet_SHO[int((nsteps-1)*dt_3/dt_verlet)::int(dt_3/dt_verlet)])**2)**0.5,label='$40\Delta_v$',color='green')
plt.plot(t_hnn_4,((v_hnn_4-v_verlet_SHO[int((nsteps-1)*dt_4/dt_verlet):int(np.size(v_verlet_SHO)-dt_4/dt_verlet):int(dt_4/dt_verlet)])**2+(x_hnn_4-x_verlet_SHO[int((nsteps-1)*dt_4/dt_verlet):int(np.size(x_verlet_SHO)-dt_4/dt_verlet):int(dt_4/dt_verlet)])**2)**0.5,label='$100\Delta_v$',color='red')
plt.legend(loc='upper left')
ax = plt.gca()
ax.set_xlabel('time $t$')
ax.set_ylabel('L2 Error')
ax.set_title('L2 Error')
plt.rc('font', size=12)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=20)    # legend fontsize
plt.rc('figure', titlesize=20)  # fontsize of the figure title
#plt.grid()
plt.show()


plt.clf()
# Plot energy as a function of time
# (subtract energy at time t=0 to show energy drift)

plt.plot(t_verlet_SHO,E_verlet_SHO-E_verlet_SHO[0],label='Verlet',color='black')
plt.plot(t_hnn_1,E_hnn_1-E_hnn_1[0],label='$\Delta_v$',color='blue')
plt.plot(t_hnn_2,E_hnn_2-E_hnn_2[0],label='$20\Delta_v$',color='orange')
plt.plot(t_hnn_3,E_hnn_3-E_hnn_3[0],label='$40\Delta_v$',color='green')
plt.plot(t_hnn_4,E_hnn_4-E_hnn_4[0],label='$100\Delta_v$',color='red')
plt.legend(loc='upper left')
ax = plt.gca()
ax.set_xlabel('time $t$')
ax.set_ylabel('energy shift $E(t)-E(t_0)$')
#ax.grid()
plt.rc('font', size=12)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=20)    # legend fontsize
plt.rc('figure', titlesize=20)  # fontsize of the figure title

plt.show()

#subplots of position versus velocity for all 4

plt.rcParams['figure.figsize'] = [10, 10]

plt.clf()
plt.plot(x_verlet_SHO,v_verlet_SHO,label='Verlet',color='black')
plt.plot(x_hnn_1,v_hnn_1,label='$\Delta_v$',color='blue')
plt.plot(x_hnn_2,v_hnn_2,label='$20\Delta_v$',color='orange')
plt.plot(x_hnn_3,v_hnn_3,label='$40\Delta_v$',color='green')
plt.plot(x_hnn_4,v_hnn_4,label='$100\Delta_v$',color='red')
plt.legend(loc='upper left')
ax = plt.gca()
ax.set_ylabel('Velocity $v(t)$')
ax.set_xlabel('Position $q(t)$')
plt.rc('font', size=12)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=20)    # legend fontsize
plt.rc('figure', titlesize=20)  # fontsize of the figure title
plt.show()
