# %% [markdown]
# # LSTM Recurrent neural network based integrator simulating SHO

# %%
import sys
sys.path.append('..')

import numpy as np
from matplotlib import pyplot as plt
from Code.dynamical_system import *
from Code.time_integrator import *
from Code.neuralnet import *

np.random.seed(2512517)

# %% [markdown]
# ## Neural network integrator

# %% [markdown]
# Set system parameters, construct dynamical system and integrator.
#
# The model system we are using here is the harmonic oscillator, defined by the equations of motion
#
# $$
# \frac{dx}{dt} = v,\qquad\qquad
# \frac{dv}{dt} = -\frac{k}{m}x
# $$
#
# The timestep size of the Neural network integrator takes values in $\Delta t_{\text{Verlet}},20\Delta t_{\text{Verlet}},40\Delta t_{\text{Verlet}},100\Delta t_{\text{Verlet}}$ where $\Delta t_{\text{Verlet}}$ is the step size of the Verlet integrator that is used for training.

# %%
# mass of particle
mass = 1.2
# spring constant of harmonic oscillator
k_spring = 0.9
# timestep for Verlet integrator
dt_verlet = 0.005
# timestep for neural network integrator
dt_1 = dt_verlet
dt_2 = 20*dt_verlet
dt_3 = 40*dt_verlet
dt_4 = 100*dt_verlet
# number of steps for neural network integrator
nsteps = 5

harmonic_oscillator = HarmonicOscillator(mass,k_spring)

exact_SHO = ExactIntegrator(harmonic_oscillator,dt_verlet)

lstm_integrator_1 = LSTMFinalIntegrator(harmonic_oscillator,nsteps,dt_1)
lstm_integrator_2 = LSTMFinalIntegrator(harmonic_oscillator,nsteps,dt_2)
lstm_integrator_3 = LSTMFinalIntegrator(harmonic_oscillator,nsteps,dt_3)
lstm_integrator_4 = LSTMFinalIntegrator(harmonic_oscillator,nsteps,dt_4)

# visualise the neural network model
lstm_integrator_1.model.summary()
keras.utils.plot_model(lstm_integrator_1.model, show_shapes=True)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 5, 2)]       0           []
#
#  lstm (LSTM)                    (None, 5, 32)        4480        ['input_1[0][0]']
#
#  lstm_1 (LSTM)                  (None, 32)           8320        ['lstm[0][0]']
#
#  dense (Dense)                  (None, 64)           2112        ['lstm_1[0][0]']
#
#  dense_1 (Dense)                (None, 2)            130         ['dense[0][0]']
#
#  tf.unstack (TFOpLambda)        [(None, 2),          0           ['input_1[0][0]']
#                                  (None, 2),
#                                  (None, 2),
#                                  (None, 2),
#                                  (None, 2)]
#
#  rescaling (Rescaling)          (None, 2)            0           ['dense_1[0][0]']
#
#  add (Add)                      (None, 2)            0           ['tf.unstack[0][4]',
#                                                                   'rescaling[0][0]']
#
# ==================================================================================================
# Total params: 15,042
# Trainable params: 15,042
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
BATCH_SIZE=64

data_generator_1 = DataGenerator(lstm_integrator_1,exact_SHO)
train_batches_1 = data_generator_1.dataset.batch(BATCH_SIZE)

data_generator_2 = DataGenerator(lstm_integrator_2,exact_SHO)
train_batches_2 = data_generator_2.dataset.batch(BATCH_SIZE)

data_generator_3 = DataGenerator(lstm_integrator_3,exact_SHO)
train_batches_3 = data_generator_3.dataset.batch(BATCH_SIZE)

data_generator_4 = DataGenerator(lstm_integrator_4,exact_SHO)
train_batches_4 = data_generator_4.dataset.batch(BATCH_SIZE)

# %% [markdown]
# ## Train neural network based integrator

# %%
EPOCHS=1000
STEPS_PER_EPOCH=100
log_dir = './tb_logs/'
tensorboard_cb = tf.keras.callbacks.TensorBoard(log_dir=log_dir)

result_1 = lstm_integrator_1.model.fit(train_batches_1,epochs=EPOCHS,steps_per_epoch=STEPS_PER_EPOCH,
                                 callbacks=tensorboard_cb)
result_2 = lstm_integrator_2.model.fit(train_batches_2,epochs=EPOCHS,steps_per_epoch=STEPS_PER_EPOCH,
                                 callbacks=tensorboard_cb)
result_3 = lstm_integrator_3.model.fit(train_batches_3,epochs=EPOCHS,steps_per_epoch=STEPS_PER_EPOCH,
                                callbacks=tensorboard_cb)
result_4 = lstm_integrator_4.model.fit(train_batches_4,epochs=EPOCHS,steps_per_epoch=STEPS_PER_EPOCH,
                                 callbacks=tensorboard_cb)
# Out:
# Streaming output truncated to the last 5000 lines.
# 100/100 [==============================] - 3s 30ms/step - loss: 1.5073e-08
# Epoch 502/1000
# 100/100 [==============================] - 3s 30ms/step - loss: 1.1907e-08
# Epoch 503/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 7.8007e-09
# Epoch 504/1000
# 100/100 [==============================] - 3s 30ms/step - loss: 2.6632e-08
# Epoch 505/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 1.4024e-08
# Epoch 506/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 1.0413e-08
# Epoch 507/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 1.1822e-08
# Epoch 508/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 1.1733e-08
# Epoch 509/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 2.1823e-07
# Epoch 510/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 9.0432e-08
# Epoch 511/1000
# 100/100 [==============================] - 3s 30ms/step - loss: 5.2380e-08
# Epoch 512/1000
# 100/100 [==============================] - 3s 30ms/step - loss: 1.0683e-08
# Epoch 513/1000
# 100/100 [==============================] - 3s 30ms/step - loss: 1.3458e-08
# Epoch 514/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 1.8344e-08
# Epoch 515/1000
# 100/100 [==============================] - 3s 30ms/step - loss: 1.8006e-08
# Epoch 516/1000
# 100/100 [==============================] - 3s 30ms/step - loss: 1.6410e-08
# Epoch 517/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 1.2081e-08
# Epoch 518/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 9.8969e-09
# Epoch 519/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 1.7606e-08
# Epoch 520/1000
# 100/100 [==============================] - 3s 30ms/step - loss: 2.2731e-08
# Epoch 521/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 4.3468e-07
# Epoch 522/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 2.3637e-08
# Epoch 523/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 1.9413e-08
# Epoch 524/1000
# 100/100 [==============================] - 3s 30ms/step - loss: 1.7264e-08
# Epoch 525/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 1.2723e-08
# Epoch 526/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 5.6003e-08
# Epoch 527/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 4.1414e-08
# Epoch 528/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 3.1544e-08
# Epoch 529/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 1.5026e-08
# Epoch 530/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 1.0537e-08
# Epoch 531/1000
# 100/100 [==============================] - 3s 30ms/step - loss: 1.6319e-08
# Epoch 532/1000
# 100/100 [==============================] - 3s 30ms/step - loss: 1.0435e-08
# Epoch 533/1000
# 100/100 [==============================] - 3s 32ms/step - loss: 1.3594e-08
# Epoch 534/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 2.1005e-08
# Epoch 535/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 2.4425e-08
# Epoch 536/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 9.7405e-08
# Epoch 537/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 1.3222e-08
# Epoch 538/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 3.9431e-08
# Epoch 539/1000
# 100/100 [==============================] - 3s 30ms/step - loss: 6.7926e-08
# Epoch 540/1000
# 100/100 [==============================] - 3s 30ms/step - loss: 1.1668e-08
# Epoch 541/1000
# 100/100 [==============================] - 3s 30ms/step - loss: 2.9995e-08
# Epoch 542/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 3.6494e-08
# Epoch 543/1000
# 100/100 [==============================] - 3s 30ms/step - loss: 1.4476e-08
# Epoch 544/1000
# 100/100 [==============================] - 3s 30ms/step - loss: 1.3574e-08
# Epoch 545/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 6.0033e-08
# Epoch 546/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 2.0707e-08
# Epoch 547/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 2.6888e-08
# Epoch 548/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 1.7217e-08
# Epoch 549/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 2.9847e-08
# Epoch 550/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 1.6918e-08
# Epoch 551/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 2.1881e-08
# Epoch 552/1000
# 100/100 [==============================] - 3s 32ms/step - loss: 2.2214e-08
# Epoch 553/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 1.9303e-08
# Epoch 554/1000
# 100/100 [==============================] - 3s 30ms/step - loss: 1.1593e-07
# Epoch 555/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 3.1058e-08
# Epoch 556/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 2.0108e-08
# Epoch 557/1000
# 100/100 [==============================] - 3s 32ms/step - loss: 1.1924e-08
# Epoch 558/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 8.4484e-09
# Epoch 559/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 1.1606e-08
# Epoch 560/1000
# 100/100 [==============================] - 3s 30ms/step - loss: 1.3799e-08
# Epoch 561/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 3.0077e-08
# Epoch 562/1000
# 100/100 [==============================] - 3s 30ms/step - loss: 1.1772e-08
# Epoch 563/1000
# 100/100 [==============================] - 3s 30ms/step - loss: 1.5492e-08
# Epoch 564/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 1.3171e-07
# Epoch 565/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 4.0970e-08
# Epoch 566/1000
# 100/100 [==============================] - 3s 30ms/step - loss: 9.5471e-09
# Epoch 567/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 6.9736e-09
# Epoch 568/1000
# 100/100 [==============================] - 3s 30ms/step - loss: 2.2876e-08
# Epoch 569/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 1.2670e-07
# Epoch 570/1000
# 100/100 [==============================] - 3s 30ms/step - loss: 1.3451e-08
# Epoch 571/1000
# 100/100 [==============================] - 3s 30ms/step - loss: 9.8805e-09
# Epoch 572/1000
# 100/100 [==============================] - 3s 30ms/step - loss: 9.9867e-09
# Epoch 573/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 1.0261e-07
# Epoch 574/1000
# 100/100 [==============================] - 3s 32ms/step - loss: 1.0821e-08
# Epoch 575/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 6.4072e-09
# Epoch 576/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 9.0540e-09
# Epoch 577/1000
# 100/100 [==============================] - 3s 30ms/step - loss: 5.8416e-09
# Epoch 578/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 1.0791e-08
# Epoch 579/1000
# 100/100 [==============================] - 3s 30ms/step - loss: 5.3519e-09
# Epoch 580/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 1.1019e-08
# Epoch 581/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 9.0727e-08
# Epoch 582/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 1.8191e-08
# Epoch 583/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 9.4362e-09
# Epoch 584/1000
# 100/100 [==============================] - 3s 30ms/step - loss: 1.4645e-08
# Epoch 585/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 3.5095e-07
# Epoch 586/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 3.6721e-08
# Epoch 587/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 2.3019e-08
# Epoch 588/1000
# 100/100 [==============================] - 3s 30ms/step - loss: 2.0556e-08
# Epoch 589/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 1.2366e-08
# Epoch 590/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 1.3535e-08
# Epoch 591/1000
# 100/100 [==============================] - 3s 30ms/step - loss: 1.6669e-08
# Epoch 592/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 1.3492e-08
# Epoch 593/1000
# 100/100 [==============================] - 3s 30ms/step - loss: 1.7756e-08
# Epoch 594/1000
# 100/100 [==============================] - 3s 30ms/step - loss: 1.4855e-08
# Epoch 595/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 1.8461e-08
# Epoch 596/1000
# 100/100 [==============================] - 3s 30ms/step - loss: 5.6667e-08
# Epoch 597/1000
# 100/100 [==============================] - 3s 30ms/step - loss: 7.8433e-08
# Epoch 598/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 1.3941e-08
# Epoch 599/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 4.9186e-08
# Epoch 600/1000
# 100/100 [==============================] - 3s 30ms/step - loss: 1.9301e-08
# Epoch 601/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 2.1925e-08
# Epoch 602/1000
# 100/100 [==============================] - 3s 30ms/step - loss: 1.9207e-08
# Epoch 603/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 2.7023e-08
# Epoch 604/1000
# 100/100 [==============================] - 3s 30ms/step - loss: 1.1314e-08
# Epoch 605/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 1.0891e-08
# Epoch 606/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 2.5138e-08
# Epoch 607/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 5.8402e-08
# Epoch 608/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 3.5260e-08
# Epoch 609/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 1.8515e-08
# Epoch 610/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 1.0717e-08
# Epoch 611/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 1.3637e-08
# Epoch 612/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 1.1792e-08
# Epoch 613/1000
# 100/100 [==============================] - 3s 30ms/step - loss: 8.7740e-09
# Epoch 614/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 6.3193e-08
# Epoch 615/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 1.3263e-08
# Epoch 616/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 1.1413e-08
# Epoch 617/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 1.8590e-08
# Epoch 618/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 3.5187e-07
# Epoch 619/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 2.1398e-08
# Epoch 620/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 2.5875e-08
# Epoch 621/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 2.7288e-08
# Epoch 622/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 9.8836e-09
# Epoch 623/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 1.2127e-08
# Epoch 624/1000
# 100/100 [==============================] - 3s 30ms/step - loss: 1.2611e-08
# Epoch 625/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 9.9845e-09
# Epoch 626/1000
# 100/100 [==============================] - 3s 30ms/step - loss: 9.2194e-09
# Epoch 627/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 2.3816e-08
# Epoch 628/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 2.0630e-08
# Epoch 629/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 1.0386e-08
# Epoch 630/1000
# 100/100 [==============================] - 3s 30ms/step - loss: 6.5971e-09
# Epoch 631/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 1.3849e-08
# Epoch 632/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 2.2087e-08
# Epoch 633/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 1.0745e-08
# Epoch 634/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 2.0199e-08
# Epoch 635/1000
# 100/100 [==============================] - 3s 30ms/step - loss: 2.3163e-08
# Epoch 636/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 6.6527e-09
# Epoch 637/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 7.0335e-08
# Epoch 638/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 1.5037e-07
# Epoch 639/1000
# 100/100 [==============================] - 3s 32ms/step - loss: 1.1540e-08
# Epoch 640/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 1.3867e-08
# Epoch 641/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 1.3387e-08
# Epoch 642/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 1.5250e-08
# Epoch 643/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 1.3396e-08
# Epoch 644/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 2.0498e-08
# Epoch 645/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 6.6311e-08
# Epoch 646/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 2.0089e-08
# Epoch 647/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 8.7359e-09
# Epoch 648/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 6.0735e-09
# Epoch 649/1000
# 100/100 [==============================] - 3s 32ms/step - loss: 8.4932e-09
# Epoch 650/1000
# 100/100 [==============================] - 3s 32ms/step - loss: 2.3915e-08
# Epoch 651/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 4.1041e-08
# Epoch 652/1000
# 100/100 [==============================] - 3s 32ms/step - loss: 1.0836e-08
# Epoch 653/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 1.4701e-08
# Epoch 654/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 3.2631e-08
# Epoch 655/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 2.3731e-08
# Epoch 656/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 2.6982e-08
# Epoch 657/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 1.4372e-08
# Epoch 658/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 1.2817e-08
# Epoch 659/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 1.1537e-08
# Epoch 660/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 1.4332e-08
# Epoch 661/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 2.4558e-08
# Epoch 662/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 2.7168e-08
# Epoch 663/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 2.3978e-08
# Epoch 664/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 8.7917e-09
# Epoch 665/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 1.0367e-08
# Epoch 666/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 1.1141e-08
# Epoch 667/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 2.1222e-08
# Epoch 668/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 3.8357e-08
# Epoch 669/1000
# 100/100 [==============================] - 3s 30ms/step - loss: 6.6163e-08
# Epoch 670/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 7.3079e-08
# Epoch 671/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 1.7024e-08
# Epoch 672/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 2.9583e-08
# Epoch 673/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 3.1070e-08
# Epoch 674/1000
# 100/100 [==============================] - 3s 30ms/step - loss: 1.4312e-08
# Epoch 675/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 8.2088e-09
# Epoch 676/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 1.2930e-08
# Epoch 677/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 3.3249e-08
# Epoch 678/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 1.6372e-08
# Epoch 679/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 1.3792e-08
# Epoch 680/1000
# 100/100 [==============================] - 3s 30ms/step - loss: 1.6228e-08
# Epoch 681/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 7.2465e-09
# Epoch 682/1000
# 100/100 [==============================] - 3s 32ms/step - loss: 1.3237e-08
# Epoch 683/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 7.2848e-09
# Epoch 684/1000
# 100/100 [==============================] - 3s 30ms/step - loss: 9.5492e-09
# Epoch 685/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 1.1667e-07
# Epoch 686/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 1.7662e-07
# Epoch 687/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 2.3656e-07
# Epoch 688/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 2.0612e-08
# Epoch 689/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 3.8158e-08
# Epoch 690/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 1.4416e-08
# Epoch 691/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 1.8149e-08
# Epoch 692/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 1.9602e-08
# Epoch 693/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 1.5099e-08
# Epoch 694/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 4.8164e-08
# Epoch 695/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 8.5093e-09
# Epoch 696/1000
# 100/100 [==============================] - 3s 30ms/step - loss: 2.8891e-08
# Epoch 697/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 1.3808e-08
# Epoch 698/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 1.0774e-08
# Epoch 699/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 3.9785e-08
# Epoch 700/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 1.3067e-08
# Epoch 701/1000
# 100/100 [==============================] - 3s 30ms/step - loss: 9.3580e-09
# Epoch 702/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 1.1249e-08
# Epoch 703/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 1.1348e-08
# Epoch 704/1000
# 100/100 [==============================] - 3s 30ms/step - loss: 1.1126e-08
# Epoch 705/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 4.0278e-08
# Epoch 706/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 2.1032e-08
# Epoch 707/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 2.2813e-08
# Epoch 708/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 2.0952e-07
# Epoch 709/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 2.4923e-08
# Epoch 710/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 1.7675e-08
# Epoch 711/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 1.6483e-08
# Epoch 712/1000
# 100/100 [==============================] - 3s 30ms/step - loss: 5.5472e-08
# Epoch 713/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 9.5019e-09
# Epoch 714/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 1.7455e-08
# Epoch 715/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 9.5228e-09
# Epoch 716/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 1.1966e-08
# Epoch 717/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 8.4559e-09
# Epoch 718/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 1.7887e-08
# Epoch 719/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 5.1039e-08
# Epoch 720/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 8.6281e-08
# Epoch 721/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 9.2194e-09
# Epoch 722/1000
# 100/100 [==============================] - 3s 30ms/step - loss: 1.7063e-08
# Epoch 723/1000
# 100/100 [==============================] - 3s 32ms/step - loss: 1.2945e-08
# Epoch 724/1000
# 100/100 [==============================] - 3s 30ms/step - loss: 2.7500e-08
# Epoch 725/1000
# 100/100 [==============================] - 3s 32ms/step - loss: 9.5812e-08
# Epoch 726/1000
# 100/100 [==============================] - 3s 30ms/step - loss: 3.7591e-08
# Epoch 727/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 2.5099e-07
# Epoch 728/1000
# 100/100 [==============================] - 3s 30ms/step - loss: 1.4581e-08
# Epoch 729/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 1.3910e-08
# Epoch 730/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 8.0447e-09
# Epoch 731/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 2.4102e-08
# Epoch 732/1000
# 100/100 [==============================] - 3s 30ms/step - loss: 1.1347e-08
# Epoch 733/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 2.1334e-08
# Epoch 734/1000
# 100/100 [==============================] - 3s 32ms/step - loss: 1.5938e-08
# Epoch 735/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 1.0598e-08
# Epoch 736/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 1.6645e-08
# Epoch 737/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 1.6692e-08
# Epoch 738/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 8.2380e-09
# Epoch 739/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 3.2422e-08
# Epoch 740/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 9.0248e-09
# Epoch 741/1000
# 100/100 [==============================] - 3s 30ms/step - loss: 1.3289e-08
# Epoch 742/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 5.1593e-08
# Epoch 743/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 5.0574e-08
# Epoch 744/1000
# 100/100 [==============================] - 3s 30ms/step - loss: 2.7771e-08
# Epoch 745/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 1.6851e-08
# Epoch 746/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 2.0275e-08
# Epoch 747/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 6.5559e-08
# Epoch 748/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 1.4865e-08
# Epoch 749/1000
# 100/100 [==============================] - 3s 32ms/step - loss: 5.4339e-08
# Epoch 750/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 1.1465e-08
# Epoch 751/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 1.0940e-08
# Epoch 752/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 4.9026e-08
# Epoch 753/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 2.3044e-07
# Epoch 754/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 5.6248e-08
# Epoch 755/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 1.6674e-08
# Epoch 756/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 8.8545e-09
# Epoch 757/1000
# 100/100 [==============================] - 3s 30ms/step - loss: 2.1038e-08
# Epoch 758/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 4.0196e-08
# Epoch 759/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 4.2693e-08
# Epoch 760/1000
# 100/100 [==============================] - 3s 30ms/step - loss: 3.2985e-08
# Epoch 761/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 2
1000
# 100/100 [==============================] - 3s 32ms/step - loss: 2.5814e-07
# Epoch 1000/1000
# 100/100 [==============================] - 3s 32ms/step - loss: 3.6527e-07

# %% [markdown]
# ## Visualise Loss function

# %%
#print(result.history.keys())

plt.rcParams['figure.figsize'] = [10, 10]

# summarize history for loss
plt.plot(result_1.history['loss'])
plt.plot(result_2.history['loss'])
plt.plot(result_3.history['loss'])
plt.plot(result_4.history['loss'])

plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.rc('font', size=12)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=20)    # legend fontsize
plt.rc('figure', titlesize=20)  # fontsize of the figure title
plt.legend(['$\Delta_v$','$20\Delta_v$','$40\Delta_v$','$100\Delta_v$'], loc='upper left')
plt.yscale("log")
plt.show()

# %% [markdown]
# ## Plot trajectories generated to $t=32$ by Verlet integrator and neural

# %%
# Final time
T_final = 32

# Initial conditions
x = np.zeros(1)
v = np.zeros(1)
x[0] = 2.70
v[0] = -0.6
exact_SHO.set_state(x,v)

# ==== Verlet integrator ====
t = 0.0
t_exact_SHO = []
x_exact_SHO = []
v_exact_SHO = []
E_exact_SHO = []



while t<T_final:
    t_exact_SHO.append(t)
    E_exact_SHO.append(exact_SHO.energy())
    x_exact_SHO.append(exact_SHO.x[0])
    v_exact_SHO.append(exact_SHO.v[0])
    exact_SHO.integrate(1)
    t += dt_verlet
        

# ==== Neural network integrator ====

# Initialise with Verlet integrator
x_initial_1 = np.zeros((lstm_integrator_1.nsteps,lstm_integrator_1.dynamical_system.dim))
v_initial_1 = np.zeros((lstm_integrator_1.nsteps,lstm_integrator_1.dynamical_system.dim))
x_initial_2 = np.zeros((lstm_integrator_2.nsteps,lstm_integrator_2.dynamical_system.dim))
v_initial_2 = np.zeros((lstm_integrator_2.nsteps,lstm_integrator_2.dynamical_system.dim))
x_initial_3 = np.zeros((lstm_integrator_3.nsteps,lstm_integrator_3.dynamical_system.dim))
v_initial_3 = np.zeros((lstm_integrator_3.nsteps,lstm_integrator_3.dynamical_system.dim))
x_initial_4 = np.zeros((lstm_integrator_4.nsteps,lstm_integrator_4.dynamical_system.dim))
v_initial_4 = np.zeros((lstm_integrator_4.nsteps,lstm_integrator_4.dynamical_system.dim))



exact_SHO.set_state(x,v)
for k in range(lstm_integrator_1.nsteps):    
    x_initial_1[k,:] = exact_SHO.x[:]
    v_initial_1[k,:] = exact_SHO.v[:]
    exact_SHO.integrate(int(dt_1/dt_verlet))
exact_SHO.set_state(x,v)
for k in range(lstm_integrator_2.nsteps):    
    x_initial_2[k,:] = exact_SHO.x[:]
    v_initial_2[k,:] = exact_SHO.v[:]
    exact_SHO.integrate(int(dt_2/dt_verlet))
exact_SHO.set_state(x,v)
for k in range(lstm_integrator_3.nsteps):    
    x_initial_3[k,:] = exact_SHO.x[:]
    v_initial_3[k,:] = exact_SHO.v[:]
    exact_SHO.integrate(int(dt_3/dt_verlet))
exact_SHO.set_state(x,v)
for k in range(lstm_integrator_4.nsteps):    
    x_initial_4[k,:] = exact_SHO.x[:]
    v_initial_4[k,:] = exact_SHO.v[:]
    exact_SHO.integrate(int(dt_4/dt_verlet))


lstm_integrator_1.set_state(x_initial_1,v_initial_1)
t_1 = (lstm_integrator_1.nsteps-1)*lstm_integrator_1.dt
lstm_integrator_2.set_state(x_initial_2,v_initial_2)
t_2 = (lstm_integrator_2.nsteps-1)*lstm_integrator_2.dt
lstm_integrator_3.set_state(x_initial_3,v_initial_3)
t_3 = (lstm_integrator_3.nsteps-1)*lstm_integrator_3.dt
lstm_integrator_4.set_state(x_initial_4,v_initial_4)
t_4 = (lstm_integrator_4.nsteps-1)*lstm_integrator_4.dt



# Timestepping loop
t_lstm_1 = []
x_lstm_1 = []
v_lstm_1 = []
E_lstm_1 = []
t_lstm_2 = []
x_lstm_2 = []
v_lstm_2 = []
E_lstm_2 = []
t_lstm_3 = []
x_lstm_3 = []
v_lstm_3 = []
E_lstm_3 = []
t_lstm_4 = []
x_lstm_4 = []
v_lstm_4 = []
E_lstm_4 = []


while t_1<T_final:
    t_lstm_1.append(t_1)
    x_lstm_1.append(lstm_integrator_1.x[0])
    v_lstm_1.append(lstm_integrator_1.v[0])
    E_lstm_1.append(lstm_integrator_1.energy())
    lstm_integrator_1.integrate(1)
    t_1 += dt_1
while t_2<T_final:
    t_lstm_2.append(t_2)
    x_lstm_2.append(lstm_integrator_2.x[0])
    v_lstm_2.append(lstm_integrator_2.v[0])
    E_lstm_2.append(lstm_integrator_2.energy())
    lstm_integrator_2.integrate(1)
    t_2 += dt_2
while t_3<T_final:
    t_lstm_3.append(t_3)
    x_lstm_3.append(lstm_integrator_3.x[0])
    v_lstm_3.append(lstm_integrator_3.v[0])
    E_lstm_3.append(lstm_integrator_3.energy())
    lstm_integrator_3.integrate(1)
    t_3 += dt_3
while t_4<T_final:
    t_lstm_4.append(t_4)
    x_lstm_4.append(lstm_integrator_4.x[0])
    v_lstm_4.append(lstm_integrator_4.v[0])
    E_lstm_4.append(lstm_integrator_4.energy())
    lstm_integrator_4.integrate(1)
    t_4 += dt_4
 



x_lstm_1 = np.array(x_lstm_1)
x_lstm_2 = np.array(x_lstm_2)
x_lstm_3 = np.array(x_lstm_3)
x_lstm_4 = np.array(x_lstm_4)
x_exact_SHO = np.array(x_exact_SHO)
v_lstm_1 = np.array(v_lstm_1)
v_lstm_2 = np.array(v_lstm_2)
v_lstm_3 = np.array(v_lstm_3)
v_lstm_4 = np.array(v_lstm_4)
v_exact_SHO = np.array(v_exact_SHO)


# Plot position error as a function of time
plt.clf()
plt.rcParams['figure.figsize'] = [10, 10]

plt.plot(t_lstm_1,x_lstm_1-x_exact_SHO[int((nsteps-1)*dt_1/dt_verlet)::int(dt_1/dt_verlet)],label='$\Delta_v$',color='blue')
plt.plot(t_lstm_2,x_lstm_2-x_exact_SHO[int((nsteps-1)*dt_2/dt_verlet):int(np.size(x_exact_SHO)-dt_2/dt_verlet):int(dt_2/dt_verlet)],label='$20\Delta_v$',color='orange')
plt.plot(t_lstm_3,x_lstm_3-x_exact_SHO[int((nsteps-1)*dt_3/dt_verlet)::int(dt_3/dt_verlet)],label='$40\Delta_v$',color='green')
plt.plot(t_lstm_4,x_lstm_4-x_exact_SHO[int((nsteps-1)*dt_4/dt_verlet):int(np.size(x_exact_SHO)-dt_4/dt_verlet):int(dt_4/dt_verlet)],label='$100\Delta_v$',color='red')
plt.legend(loc='upper left')
ax = plt.gca()
ax.set_xlabel('time $t$')
ax.set_ylabel('position Error $x_{NN}(t)-x_V(t)$')
ax.set_title('Position Error')
plt.rc('font', size=12)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=20)    # legend fontsize
plt.rc('figure', titlesize=20)  # fontsize of the figure title
#plt.grid()
plt.show()

# Plot velocity error as a function of time

plt.plot(t_lstm_1,v_lstm_1-v_exact_SHO[int((nsteps-1)*dt_1/dt_verlet)::int(dt_1/dt_verlet)],label='$\Delta_v$',color='blue')
plt.plot(t_lstm_2,v_lstm_2-v_exact_SHO[int((nsteps-1)*dt_2/dt_verlet):int(np.size(v_exact_SHO)-dt_2/dt_verlet):int(dt_2/dt_verlet)],label='$20\Delta_v$',color='orange')
plt.plot(t_lstm_3,v_lstm_3-v_exact_SHO[int((nsteps-1)*dt_3/dt_verlet)::int(dt_3/dt_verlet)],label='$40\Delta_v$',color='green')
plt.plot(t_lstm_4,v_lstm_4-v_exact_SHO[int((nsteps-1)*dt_4/dt_verlet):int(np.size(v_exact_SHO)-dt_4/dt_verlet):int(dt_4/dt_verlet)],label='$100\Delta_v$',color='red')
plt.legend(loc='upper left')
ax = plt.gca()
ax.set_xlabel('time $t$')
ax.set_ylabel('Velocity Error $v_{NN}(t)-v_V(t)$')
ax.set_title('Velocity Error')
plt.rc('font', size=12)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=20)    # legend fontsize
plt.rc('figure', titlesize=20)  # fontsize of the figure title
#plt.grid()
plt.show()

# Plot L2 error as a function of time

plt.plot(t_lstm_1,((v_lstm_1-v_exact_SHO[int((nsteps-1)*dt_1/dt_verlet)::int(dt_1/dt_verlet)])**2+(x_lstm_1-x_exact_SHO[int((nsteps-1)*dt_1/dt_verlet)::int(dt_1/dt_verlet)])**2)**0.5,label='$\Delta_v$',color='blue')
plt.plot(t_lstm_2,((v_lstm_2-v_exact_SHO[int((nsteps-1)*dt_2/dt_verlet):int(np.size(v_exact_SHO)-dt_2/dt_verlet):int(dt_2/dt_verlet)])**2+(x_lstm_2-x_exact_SHO[int((nsteps-1)*dt_2/dt_verlet):int(np.size(x_exact_SHO)-dt_2/dt_verlet):int(dt_2/dt_verlet)])**2)**0.5,label='$20\Delta_v$',color='orange')
plt.plot(t_lstm_3,((v_lstm_3-v_exact_SHO[int((nsteps-1)*dt_3/dt_verlet)::int(dt_3/dt_verlet)])**2+(x_lstm_3-x_exact_SHO[int((nsteps-1)*dt_3/dt_verlet)::int(dt_3/dt_verlet)])**2)**0.5,label='$40\Delta_v$',color='green')
plt.plot(t_lstm_4,((v_lstm_4-v_exact_SHO[int((nsteps-1)*dt_4/dt_verlet):int(np.size(v_exact_SHO)-dt_4/dt_verlet):int(dt_4/dt_verlet)])**2+(x_lstm_4-x_exact_SHO[int((nsteps-1)*dt_4/dt_verlet):int(np.size(x_exact_SHO)-dt_4/dt_verlet):int(dt_4/dt_verlet)])**2)**0.5,label='$100\Delta_v$',color='red')
plt.legend(loc='upper left')
ax = plt.gca()
ax.set_xlabel('time $t$')
ax.set_ylabel('L2 Error')
ax.set_title('L2 Error')
plt.rc('font', size=12)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=20)    # legend fontsize
plt.rc('figure', titlesize=20)  # fontsize of the figure title
#plt.grid()
plt.show()


plt.clf()
# Plot energy as a function of time
# (subtract energy at time t=0 to show energy drift)

plt.plot(t_exact_SHO,E_exact_SHO-E_exact_SHO[0],label='Verlet',color='black')
plt.plot(t_lstm_1,E_lstm_1-E_lstm_1[0],label='$\Delta_v$',color='blue')
plt.plot(t_lstm_2,E_lstm_2-E_lstm_2[0],label='$20\Delta_v$',color='orange')
plt.plot(t_lstm_3,E_lstm_3-E_lstm_3[0],label='$40\Delta_v$',color='green')
plt.plot(t_lstm_4,E_lstm_4-E_lstm_4[0],label='$100\Delta_v$',color='red')
plt.legend(loc='upper left')
ax = plt.gca()
ax.set_xlabel('time $t$')
ax.set_ylabel('energy shift $E(t)-E(t_0)$')
#ax.grid()
plt.rc('font', size=12)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=20)    # legend fontsize
plt.rc('figure', titlesize=20)  # fontsize of the figure title

plt.show()

#subplots of position versus velocity for all 4

plt.rcParams['figure.figsize'] = [10, 10]

plt.clf()
plt.plot(x_exact_SHO,v_exact_SHO,label='Verlet',color='black')
plt.plot(x_lstm_1,v_lstm_1,label='$\Delta_v$',color='blue')
plt.plot(x_lstm_2,v_lstm_2,label='$20\Delta_v$',color='orange')
plt.plot(x_lstm_3,v_lstm_3,label='$40\Delta_v$',color='green')
plt.plot(x_lstm_4,v_lstm_4,label='$100\Delta_v$',color='red')
plt.legend(loc='upper left')
ax = plt.gca()
ax.set_ylabel('Velocity $v(t)$')
ax.set_xlabel('Position $q(t)$')
plt.rc('font', size=12)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=20)    # legend fontsize
plt.rc('figure', titlesize=20)  # fontsize of the figure title
plt.show()

# %% [markdown]
# ## Plot trajectories generated to $t=128$ by Verlet integrator and neural

# %%
# Final time
T_final = 128

# Initial conditions
x = np.zeros(1)
v = np.zeros(1)
x[0] = 2.70
v[0] = -0.6
exact_SHO.set_state(x,v)

# ==== Verlet integrator ====
t = 0.0
t_exact_SHO = []
x_exact_SHO = []
v_exact_SHO = []
E_exact_SHO = []



while t<T_final:
    t_exact_SHO.append(t)
    E_exact_SHO.append(exact_SHO.energy())
    x_exact_SHO.append(exact_SHO.x[0])
    v_exact_SHO.append(exact_SHO.v[0])
    exact_SHO.integrate(1)
    t += dt_verlet
        

# ==== Neural network integrator ====

# Initialise with Verlet integrator
x_initial_1 = np.zeros((lstm_integrator_1.nsteps,lstm_integrator_1.dynamical_system.dim))
v_initial_1 = np.zeros((lstm_integrator_1.nsteps,lstm_integrator_1.dynamical_system.dim))
x_initial_2 = np.zeros((lstm_integrator_2.nsteps,lstm_integrator_2.dynamical_system.dim))
v_initial_2 = np.zeros((lstm_integrator_2.nsteps,lstm_integrator_2.dynamical_system.dim))
x_initial_3 = np.zeros((lstm_integrator_3.nsteps,lstm_integrator_3.dynamical_system.dim))
v_initial_3 = np.zeros((lstm_integrator_3.nsteps,lstm_integrator_3.dynamical_system.dim))
x_initial_4 = np.zeros((lstm_integrator_4.nsteps,lstm_integrator_4.dynamical_system.dim))
v_initial_4 = np.zeros((lstm_integrator_4.nsteps,lstm_integrator_4.dynamical_system.dim))



exact_SHO.set_state(x,v)
for k in range(lstm_integrator_1.nsteps):    
    x_initial_1[k,:] = exact_SHO.x[:]
    v_initial_1[k,:] = exact_SHO.v[:]
    exact_SHO.integrate(int(dt_1/dt_verlet))
exact_SHO.set_state(x,v)
for k in range(lstm_integrator_2.nsteps):    
    x_initial_2[k,:] = exact_SHO.x[:]
    v_initial_2[k,:] = exact_SHO.v[:]
    exact_SHO.integrate(int(dt_2/dt_verlet))
exact_SHO.set_state(x,v)
for k in range(lstm_integrator_3.nsteps):    
    x_initial_3[k,:] = exact_SHO.x[:]
    v_initial_3[k,:] = exact_SHO.v[:]
    exact_SHO.integrate(int(dt_3/dt_verlet))
exact_SHO.set_state(x,v)
for k in range(lstm_integrator_4.nsteps):    
    x_initial_4[k,:] = exact_SHO.x[:]
    v_initial_4[k,:] = exact_SHO.v[:]
    exact_SHO.integrate(int(dt_4/dt_verlet))


lstm_integrator_1.set_state(x_initial_1,v_initial_1)
t_1 = (lstm_integrator_1.nsteps-1)*lstm_integrator_1.dt
lstm_integrator_2.set_state(x_initial_2,v_initial_2)
t_2 = (lstm_integrator_2.nsteps-1)*lstm_integrator_2.dt
lstm_integrator_3.set_state(x_initial_3,v_initial_3)
t_3 = (lstm_integrator_3.nsteps-1)*lstm_integrator_3.dt
lstm_integrator_4.set_state(x_initial_4,v_initial_4)
t_4 = (lstm_integrator_4.nsteps-1)*lstm_integrator_4.dt



# Timestepping loop
t_lstm_1 = []
x_lstm_1 = []
v_lstm_1 = []
E_lstm_1 = []
t_lstm_2 = []
x_lstm_2 = []
v_lstm_2 = []
E_lstm_2 = []
t_lstm_3 = []
x_lstm_3 = []
v_lstm_3 = []
E_lstm_3 = []
t_lstm_4 = []
x_lstm_4 = []
v_lstm_4 = []
E_lstm_4 = []


while t_1<T_final:
    t_lstm_1.append(t_1)
    x_lstm_1.append(lstm_integrator_1.x[0])
    v_lstm_1.append(lstm_integrator_1.v[0])
    E_lstm_1.append(lstm_integrator_1.energy())
    lstm_integrator_1.integrate(1)
    t_1 += dt_1
while t_2<T_final:
    t_lstm_2.append(t_2)
    x_lstm_2.append(lstm_integrator_2.x[0])
    v_lstm_2.append(lstm_integrator_2.v[0])
    E_lstm_2.append(lstm_integrator_2.energy())
    lstm_integrator_2.integrate(1)
    t_2 += dt_2
while t_3<T_final:
    t_lstm_3.append(t_3)
    x_lstm_3.append(lstm_integrator_3.x[0])
    v_lstm_3.append(lstm_integrator_3.v[0])
    E_lstm_3.append(lstm_integrator_3.energy())
    lstm_integrator_3.integrate(1)
    t_3 += dt_3
while t_4<T_final:
    t_lstm_4.append(t_4)
    x_lstm_4.append(lstm_integrator_4.x[0])
    v_lstm_4.append(lstm_integrator_4.v[0])
    E_lstm_4.append(lstm_integrator_4.energy())
    lstm_integrator_4.integrate(1)
    t_4 += dt_4
 



x_lstm_1 = np.array(x_lstm_1)
x_lstm_2 = np.array(x_lstm_2)
x_lstm_3 = np.array(x_lstm_3)
x_lstm_4 = np.array(x_lstm_4)
x_exact_SHO = np.array(x_exact_SHO)
v_lstm_1 = np.array(v_lstm_1)
v_lstm_2 = np.array(v_lstm_2)
v_lstm_3 = np.array(v_lstm_3)
v_lstm_4 = np.array(v_lstm_4)
v_exact_SHO = np.array(v_exact_SHO)


# Plot position error as a function of time
plt.clf()
plt.rcParams['figure.figsize'] = [10, 10]

plt.plot(t_lstm_1,x_lstm_1-x_exact_SHO[int((nsteps-1)*dt_1/dt_verlet)::int(dt_1/dt_verlet)],label='$\Delta_v$',color='blue')
plt.plot(t_lstm_2,x_lstm_2-x_exact_SHO[int((nsteps-1)*dt_2/dt_verlet)::int(dt_2/dt_verlet)],label='$20\Delta_v$',color='orange')
plt.plot(t_lstm_3,x_lstm_3-x_exact_SHO[int((nsteps-1)*dt_3/dt_verlet):int(np.size(x_exact_SHO)-dt_3/dt_verlet):int(dt_3/dt_verlet)],label='$40\Delta_v$',color='green')
plt.plot(t_lstm_4,x_lstm_4-x_exact_SHO[int((nsteps-1)*dt_4/dt_verlet):int(np.size(x_exact_SHO)-dt_4/dt_verlet):int(dt_4/dt_verlet)],label='$100\Delta_v$',color='red')
plt.legend(loc='upper left')
ax = plt.gca()
ax.set_xlabel('time $t$')
ax.set_ylabel('position Error $x_{NN}(t)-x_V(t)$')
ax.set_title('Position Error')
plt.rc('font', size=12)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=20)    # legend fontsize
plt.rc('figure', titlesize=20)  # fontsize of the figure title
#plt.grid()
plt.show()

# Plot velocity error as a function of time

plt.plot(t_lstm_1,v_lstm_1-v_exact_SHO[int((nsteps-1)*dt_1/dt_verlet)::int(dt_1/dt_verlet)],label='$\Delta_v$',color='blue')
plt.plot(t_lstm_2,v_lstm_2-v_exact_SHO[int((nsteps-1)*dt_2/dt_verlet)::int(dt_2/dt_verlet)],label='$20\Delta_v$',color='orange')
plt.plot(t_lstm_3,v_lstm_3-v_exact_SHO[int((nsteps-1)*dt_3/dt_verlet):int(np.size(v_exact_SHO)-dt_3/dt_verlet):int(dt_3/dt_verlet)],label='$40\Delta_v$',color='green')
plt.plot(t_lstm_4,v_lstm_4-v_exact_SHO[int((nsteps-1)*dt_4/dt_verlet):int(np.size(v_exact_SHO)-dt_4/dt_verlet):int(dt_4/dt_verlet)],label='$100\Delta_v$',color='red')
plt.legend(loc='upper left')
ax = plt.gca()
ax.set_xlabel('time $t$')
ax.set_ylabel('Velocity Error $v_{NN}(t)-v_V(t)$')
ax.set_title('Velocity Error')
plt.rc('font', size=12)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=20)    # legend fontsize
plt.rc('figure', titlesize=20)  # fontsize of the figure title
#plt.grid()
plt.show()

# Plot L2 error as a function of time

plt.plot(t_lstm_1,((v_lstm_1-v_exact_SHO[int((nsteps-1)*dt_1/dt_verlet)::int(dt_1/dt_verlet)])**2+(x_lstm_1-x_exact_SHO[int((nsteps-1)*dt_1/dt_verlet)::int(dt_1/dt_verlet)])**2)**0.5,label='$\Delta_v$',color='blue')
plt.plot(t_lstm_2,((v_lstm_2-v_exact_SHO[int((nsteps-1)*dt_2/dt_verlet)::int(dt_2/dt_verlet)])**2+(x_lstm_2-x_exact_SHO[int((nsteps-1)*dt_2/dt_verlet)::int(dt_2/dt_verlet)])**2)**0.5,label='$20\Delta_v$',color='orange')
plt.plot(t_lstm_3,((v_lstm_3-v_exact_SHO[int((nsteps-1)*dt_3/dt_verlet):int(np.size(v_exact_SHO)-dt_3/dt_verlet):int(dt_3/dt_verlet)])**2+(x_lstm_3-x_exact_SHO[int((nsteps-1)*dt_3/dt_verlet):int(np.size(x_exact_SHO)-dt_3/dt_verlet):int(dt_3/dt_verlet)])**2)**0.5,label='$40\Delta_v$',color='green')
plt.plot(t_lstm_4,((v_lstm_4-v_exact_SHO[int((nsteps-1)*dt_4/dt_verlet):int(np.size(v_exact_SHO)-dt_4/dt_verlet):int(dt_4/dt_verlet)])**2+(x_lstm_4-x_exact_SHO[int((nsteps-1)*dt_4/dt_verlet):int(np.size(x_exact_SHO)-dt_4/dt_verlet):int(dt_4/dt_verlet)])**2)**0.5,label='$100\Delta_v$',color='red')
plt.legend(loc='upper left')
ax = plt.gca()
ax.set_xlabel('time $t$')
ax.set_ylabel('L2 Error')
ax.set_title('L2 Error')
plt.rc('font', size=12)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=20)    # legend fontsize
plt.rc('figure', titlesize=20)  # fontsize of the figure title
#plt.grid()
plt.show()


plt.clf()
# Plot energy as a function of time
# (subtract energy at time t=0 to show energy drift)

plt.plot(t_exact_SHO,E_exact_SHO-E_exact_SHO[0],label='Verlet',color='black')
plt.plot(t_lstm_1,E_lstm_1-E_lstm_1[0],label='$\Delta_v$',color='blue')
plt.plot(t_lstm_2,E_lstm_2-E_lstm_2[0],label='$20\Delta_v$',color='orange')
plt.plot(t_lstm_3,E_lstm_3-E_lstm_3[0],label='$40\Delta_v$',color='green')
plt.plot(t_lstm_4,E_lstm_4-E_lstm_4[0],label='$100\Delta_v$',color='red')
plt.legend(loc='upper left')
ax = plt.gca()
ax.set_xlabel('time $t$')
ax.set_ylabel('energy shift $E(t)-E(t_0)$')
#ax.grid()
plt.rc('font', size=12)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=20)    # legend fontsize
plt.rc('figure', titlesize=20)  # fontsize of the figure title

plt.show()

#subplots of position versus velocity for all 4

plt.rcParams['figure.figsize'] = [10, 10]

plt.clf()
plt.plot(x_exact_SHO,v_exact_SHO,label='Verlet',color='black')
plt.plot(x_lstm_1,v_lstm_1,label='$\Delta_v$',color='blue')
plt.plot(x_lstm_2,v_lstm_2,label='$20\Delta_v$',color='orange')
plt.plot(x_lstm_3,v_lstm_3,label='$40\Delta_v$',color='green')
plt.plot(x_lstm_4,v_lstm_4,label='$100\Delta_v$',color='red')
plt.legend(loc='upper left')
ax = plt.gca()
ax.set_ylabel('Velocity $v(t)$')
ax.set_xlabel('Position $q(t)$')
plt.rc('font', size=12)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=20)    # legend fontsize
plt.rc('figure', titlesize=20)  # fontsize of the figure title
plt.show()

# %% [markdown]
# ## Plot trajectories generated to $t=512$ by Verlet integrator and neural

# %%
# Final time
T_final = 512

# Initial conditions
x = np.zeros(1)
v = np.zeros(1)
x[0] = 2.70
v[0] = -0.6
exact_SHO.set_state(x,v)

# ==== Verlet integrator ====
t = 0.0
t_exact_SHO = []
x_exact_SHO = []
v_exact_SHO = []
E_exact_SHO = []



while t<T_final:
    t_exact_SHO.append(t)
    E_exact_SHO.append(exact_SHO.energy())
    x_exact_SHO.append(exact_SHO.x[0])
    v_exact_SHO.append(exact_SHO.v[0])
    exact_SHO.integrate(1)
    t += dt_verlet
        

# ==== Neural network integrator ====

# Initialise with Verlet integrator
x_initial_1 = np.zeros((lstm_integrator_1.nsteps,lstm_integrator_1.dynamical_system.dim))
v_initial_1 = np.zeros((lstm_integrator_1.nsteps,lstm_integrator_1.dynamical_system.dim))
x_initial_2 = np.zeros((lstm_integrator_2.nsteps,lstm_integrator_2.dynamical_system.dim))
v_initial_2 = np.zeros((lstm_integrator_2.nsteps,lstm_integrator_2.dynamical_system.dim))
x_initial_3 = np.zeros((lstm_integrator_3.nsteps,lstm_integrator_3.dynamical_system.dim))
v_initial_3 = np.zeros((lstm_integrator_3.nsteps,lstm_integrator_3.dynamical_system.dim))
x_initial_4 = np.zeros((lstm_integrator_4.nsteps,lstm_integrator_4.dynamical_system.dim))
v_initial_4 = np.zeros((lstm_integrator_4.nsteps,lstm_integrator_4.dynamical_system.dim))



exact_SHO.set_state(x,v)
for k in range(lstm_integrator_1.nsteps):    
    x_initial_1[k,:] = exact_SHO.x[:]
    v_initial_1[k,:] = exact_SHO.v[:]
    exact_SHO.integrate(int(dt_1/dt_verlet))
exact_SHO.set_state(x,v)
for k in range(lstm_integrator_2.nsteps):    
    x_initial_2[k,:] = exact_SHO.x[:]
    v_initial_2[k,:] = exact_SHO.v[:]
    exact_SHO.integrate(int(dt_2/dt_verlet))
exact_SHO.set_state(x,v)
for k in range(lstm_integrator_3.nsteps):    
    x_initial_3[k,:] = exact_SHO.x[:]
    v_initial_3[k,:] = exact_SHO.v[:]
    exact_SHO.integrate(int(dt_3/dt_verlet))
exact_SHO.set_state(x,v)
for k in range(lstm_integrator_4.nsteps):    
    x_initial_4[k,:] = exact_SHO.x[:]
    v_initial_4[k,:] = exact_SHO.v[:]
    exact_SHO.integrate(int(dt_4/dt_verlet))


lstm_integrator_1.set_state(x_initial_1,v_initial_1)
t_1 = (lstm_integrator_1.nsteps-1)*lstm_integrator_1.dt
lstm_integrator_2.set_state(x_initial_2,v_initial_2)
t_2 = (lstm_integrator_2.nsteps-1)*lstm_integrator_2.dt
lstm_integrator_3.set_state(x_initial_3,v_initial_3)
t_3 = (lstm_integrator_3.nsteps-1)*lstm_integrator_3.dt
lstm_integrator_4.set_state(x_initial_4,v_initial_4)
t_4 = (lstm_integrator_4.nsteps-1)*lstm_integrator_4.dt



# Timestepping loop
t_lstm_1 = []
x_lstm_1 = []
v_lstm_1 = []
E_lstm_1 = []
t_lstm_2 = []
x_lstm_2 = []
v_lstm_2 = []
E_lstm_2 = []
t_lstm_3 = []
x_lstm_3 = []
v_lstm_3 = []
E_lstm_3 = []
t_lstm_4 = []
x_lstm_4 = []
v_lstm_4 = []
E_lstm_4 = []


while t_1<T_final:
    t_lstm_1.append(t_1)
    x_lstm_1.append(lstm_integrator_1.x[0])
    v_lstm_1.append(lstm_integrator_1.v[0])
    E_lstm_1.append(lstm_integrator_1.energy())
    lstm_integrator_1.integrate(1)
    t_1 += dt_1
while t_2<T_final:
    t_lstm_2.append(t_2)
    x_lstm_2.append(lstm_integrator_2.x[0])
    v_lstm_2.append(lstm_integrator_2.v[0])
    E_lstm_2.append(lstm_integrator_2.energy())
    lstm_integrator_2.integrate(1)
    t_2 += dt_2
while t_3<T_final:
    t_lstm_3.append(t_3)
    x_lstm_3.append(lstm_integrator_3.x[0])
    v_lstm_3.append(lstm_integrator_3.v[0])
    E_lstm_3.append(lstm_integrator_3.energy())
    lstm_integrator_3.integrate(1)
    t_3 += dt_3
while t_4<T_final:
    t_lstm_4.append(t_4)
    x_lstm_4.append(lstm_integrator_4.x[0])
    v_lstm_4.append(lstm_integrator_4.v[0])
    E_lstm_4.append(lstm_integrator_4.energy())
    lstm_integrator_4.integrate(1)
    t_4 += dt_4
 



x_lstm_1 = np.array(x_lstm_1)
x_lstm_2 = np.array(x_lstm_2)
x_lstm_3 = np.array(x_lstm_3)
x_lstm_4 = np.array(x_lstm_4)
x_exact_SHO = np.array(x_exact_SHO)
v_lstm_1 = np.array(v_lstm_1)
v_lstm_2 = np.array(v_lstm_2)
v_lstm_3 = np.array(v_lstm_3)
v_lstm_4 = np.array(v_lstm_4)
v_exact_SHO = np.array(v_exact_SHO)


# Plot position error as a function of time
plt.clf()
plt.rcParams['figure.figsize'] = [10, 10]

plt.plot(t_lstm_1,x_lstm_1-x_exact_SHO[int((nsteps-1)*dt_1/dt_verlet)::int(dt_1/dt_verlet)],label='$\Delta_v$',color='blue')
plt.plot(t_lstm_2,x_lstm_2-x_exact_SHO[int((nsteps-1)*dt_2/dt_verlet):int(np.size(x_exact_SHO)-dt_2/dt_verlet):int(dt_2/dt_verlet)],label='$20\Delta_v$',color='orange')
plt.plot(t_lstm_3,x_lstm_3-x_exact_SHO[int((nsteps-1)*dt_3/dt_verlet)::int(dt_3/dt_verlet)],label='$40\Delta_v$',color='green')
plt.plot(t_lstm_4,x_lstm_4-x_exact_SHO[int((nsteps-1)*dt_4/dt_verlet):int(np.size(x_exact_SHO)-dt_4/dt_verlet):int(dt_4/dt_verlet)],label='$100\Delta_v$',color='red')
plt.legend(loc='upper left')
ax = plt.gca()
ax.set_xlabel('time $t$')
ax.set_ylabel('position Error $x_{NN}(t)-x_V(t)$')
ax.set_title('Position Error')
plt.rc('font', size=12)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=20)    # legend fontsize
plt.rc('figure', titlesize=20)  # fontsize of the figure title
#plt.grid()
plt.show()

# Plot velocity error as a function of time

plt.plot(t_lstm_1,v_lstm_1-v_exact_SHO[int((nsteps-1)*dt_1/dt_verlet)::int(dt_1/dt_verlet)],label='$\Delta_v$',color='blue')
plt.plot(t_lstm_2,v_lstm_2-v_exact_SHO[int((nsteps-1)*dt_2/dt_verlet):int(np.size(v_exact_SHO)-dt_2/dt_verlet):int(dt_2/dt_verlet)],label='$20\Delta_v$',color='orange')
plt.plot(t_lstm_3,v_lstm_3-v_exact_SHO[int((nsteps-1)*dt_3/dt_verlet)::int(dt_3/dt_verlet)],label='$40\Delta_v$',color='green')
plt.plot(t_lstm_4,v_lstm_4-v_exact_SHO[int((nsteps-1)*dt_4/dt_verlet):int(np.size(v_exact_SHO)-dt_4/dt_verlet):int(dt_4/dt_verlet)],label='$100\Delta_v$',color='red')
plt.legend(loc='upper left')
ax = plt.gca()
ax.set_xlabel('time $t$')
ax.set_ylabel('Velocity Error $v_{NN}(t)-v_V(t)$')
ax.set_title('Velocity Error')
plt.rc('font', size=12)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=20)    # legend fontsize
plt.rc('figure', titlesize=20)  # fontsize of the figure title
#plt.grid()
plt.show()

# Plot L2 error as a function of time

plt.plot(t_lstm_1,((v_lstm_1-v_exact_SHO[int((nsteps-1)*dt_1/dt_verlet)::int(dt_1/dt_verlet)])**2+(x_lstm_1-x_exact_SHO[int((nsteps-1)*dt_1/dt_verlet)::int(dt_1/dt_verlet)])**2)**0.5,label='$\Delta_v$',color='blue')
plt.plot(t_lstm_2,((v_lstm_2-v_exact_SHO[int((nsteps-1)*dt_2/dt_verlet):int(np.size(v_exact_SHO)-dt_2/dt_verlet):int(dt_2/dt_verlet)])**2+(x_lstm_2-x_exact_SHO[int((nsteps-1)*dt_2/dt_verlet):int(np.size(x_exact_SHO)-dt_2/dt_verlet):int(dt_2/dt_verlet)])**2)**0.5,label='$20\Delta_v$',color='orange')
plt.plot(t_lstm_3,((v_lstm_3-v_exact_SHO[int((nsteps-1)*dt_3/dt_verlet)::int(dt_3/dt_verlet)])**2+(x_lstm_3-x_exact_SHO[int((nsteps-1)*dt_3/dt_verlet)::int(dt_3/dt_verlet)])**2)**0.5,label='$40\Delta_v$',color='green')
plt.plot(t_lstm_4,((v_lstm_4-v_exact_SHO[int((nsteps-1)*dt_4/dt_verlet):int(np.size(v_exact_SHO)-dt_4/dt_verlet):int(dt_4/dt_verlet)])**2+(x_lstm_4-x_exact_SHO[int((nsteps-1)*dt_4/dt_verlet):int(np.size(x_exact_SHO)-dt_4/dt_verlet):int(dt_4/dt_verlet)])**2)**0.5,label='$100\Delta_v$',color='red')
plt.legend(loc='upper left')
ax = plt.gca()
ax.set_xlabel('time $t$')
ax.set_ylabel('L2 Error')
ax.set_title('L2 Error')
plt.rc('font', size=12)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=20)    # legend fontsize
plt.rc('figure', titlesize=20)  # fontsize of the figure title
#plt.grid()
plt.show()


plt.clf()
# Plot energy as a function of time
# (subtract energy at time t=0 to show energy drift)

plt.plot(t_exact_SHO,E_exact_SHO-E_exact_SHO[0],label='Verlet',color='black')
plt.plot(t_lstm_1,E_lstm_1-E_lstm_1[0],label='$\Delta_v$',color='blue')
plt.plot(t_lstm_2,E_lstm_2-E_lstm_2[0],label='$20\Delta_v$',color='orange')
plt.plot(t_lstm_3,E_lstm_3-E_lstm_3[0],label='$40\Delta_v$',color='green')
plt.plot(t_lstm_4,E_lstm_4-E_lstm_4[0],label='$100\Delta_v$',color='red')
plt.legend(loc='upper left')
ax = plt.gca()
ax.set_xlabel('time $t$')
ax.set_ylabel('energy shift $E(t)-E(t_0)$')
#ax.grid()
plt.rc('font', size=12)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=20)    # legend fontsize
plt.rc('figure', titlesize=20)  # fontsize of the figure title

plt.show()

#subplots of position versus velocity for all 4

plt.rcParams['figure.figsize'] = [10, 10]

plt.clf()
plt.plot(x_exact_SHO,v_exact_SHO,label='Verlet',color='black')
plt.plot(x_lstm_1,v_lstm_1,label='$\Delta_v$',color='blue')
plt.plot(x_lstm_2,v_lstm_2,label='$20\Delta_v$',color='orange')
plt.plot(x_lstm_3,v_lstm_3,label='$40\Delta_v$',color='green')
plt.plot(x_lstm_4,v_lstm_4,label='$100\Delta_v$',color='red')
plt.legend(loc='upper left')
ax = plt.gca()
ax.set_ylabel('Velocity $v(t)$')
ax.set_xlabel('Position $q(t)$')
plt.rc('font', size=12)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=20)    # legend fontsize
plt.rc('figure', titlesize=20)  # fontsize of the figure title
plt.show()

# %%
# Plot position error as a function of time
plt.clf()
plt.rcParams['figure.figsize'] = [10, 10]

#plt.plot(t_lstm_1,x_lstm_1-x_exact_SHO[int((nsteps-1)*dt_1/dt_verlet)::int(dt_1/dt_verlet)],label='$\Delta_v$',color='blue')
plt.plot(t_lstm_2,x_lstm_2-x_exact_SHO[int((nsteps-1)*dt_2/dt_verlet):int(np.size(x_exact_SHO)-dt_2/dt_verlet):int(dt_2/dt_verlet)],label='$20\Delta_v$',color='orange')
plt.plot(t_lstm_3,x_lstm_3-x_exact_SHO[int((nsteps-1)*dt_3/dt_verlet)::int(dt_3/dt_verlet)],label='$40\Delta_v$',color='green')
plt.plot(t_lstm_4,x_lstm_4-x_exact_SHO[int((nsteps-1)*dt_4/dt_verlet):int(np.size(x_exact_SHO)-dt_4/dt_verlet):int(dt_4/dt_verlet)],label='$100\Delta_v$',color='red')
plt.legend(loc='upper left')
ax = plt.gca()
ax.set_xlabel('time $t$')
ax.set_ylabel('position Error $x_{NN}(t)-x_V(t)$')
ax.set_title('Position Error')
plt.rc('font', size=12)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=20)    # legend fontsize
plt.rc('figure', titlesize=20)  # fontsize of the figure title
#plt.grid()
plt.show()

# Plot velocity error as a function of time

#plt.plot(t_lstm_1,v_lstm_1-v_exact_SHO[int((nsteps-1)*dt_1/dt_verlet)::int(dt_1/dt_verlet)],label='$\Delta_v$',color='blue')
plt.plot(t_lstm_2,v_lstm_2-v_exact_SHO[int((nsteps-1)*dt_2/dt_verlet):int(np.size(v_exact_SHO)-dt_2/dt_verlet):int(dt_2/dt_verlet)],label='$20\Delta_v$',color='orange')
plt.plot(t_lstm_3,v_lstm_3-v_exact_SHO[int((nsteps-1)*dt_3/dt_verlet)::int(dt_3/dt_verlet)],label='$40\Delta_v$',color='green')
plt.plot(t_lstm_4,v_lstm_4-v_exact_SHO[int((nsteps-1)*dt_4/dt_verlet):int(np.size(v_exact_SHO)-dt_4/dt_verlet):int(dt_4/dt_verlet)],label='$100\Delta_v$',color='red')
plt.legend(loc='upper left')
ax = plt.gca()
ax.set_xlabel('time $t$')
ax.set_ylabel('Velocity Error $v_{NN}(t)-v_V(t)$')
ax.set_title('Velocity Error')
plt.rc('font', size=12)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=20)    # legend fontsize
plt.rc('figure', titlesize=20)  # fontsize of the figure title
#plt.grid()
plt.show()

# Plot L2 error as a function of time

#plt.plot(t_lstm_1,((v_lstm_1-v_exact_SHO[int((nsteps-1)*dt_1/dt_verlet)::int(dt_1/dt_verlet)])**2+(x_lstm_1-x_exact_SHO[int((nsteps-1)*dt_1/dt_verlet)::int(dt_1/dt_verlet)])**2)**0.5,label='$\Delta_v$',color='blue')
plt.plot(t_lstm_2,((v_lstm_2-v_exact_SHO[int((nsteps-1)*dt_2/dt_verlet):int(np.size(v_exact_SHO)-dt_2/dt_verlet):int(dt_2/dt_verlet)])**2+(x_lstm_2-x_exact_SHO[int((nsteps-1)*dt_2/dt_verlet):int(np.size(x_exact_SHO)-dt_2/dt_verlet):int(dt_2/dt_verlet)])**2)**0.5,label='$20\Delta_v$',color='orange')
plt.plot(t_lstm_3,((v_lstm_3-v_exact_SHO[int((nsteps-1)*dt_3/dt_verlet)::int(dt_3/dt_verlet)])**2+(x_lstm_3-x_exact_SHO[int((nsteps-1)*dt_3/dt_verlet)::int(dt_3/dt_verlet)])**2)**0.5,label='$40\Delta_v$',color='green')
plt.plot(t_lstm_4,((v_lstm_4-v_exact_SHO[int((nsteps-1)*dt_4/dt_verlet):int(np.size(v_exact_SHO)-dt_4/dt_verlet):int(dt_4/dt_verlet)])**2+(x_lstm_4-x_exact_SHO[int((nsteps-1)*dt_4/dt_verlet):int(np.size(x_exact_SHO)-dt_4/dt_verlet):int(dt_4/dt_verlet)])**2)**0.5,label='$100\Delta_v$',color='red')
plt.legend(loc='upper left')
ax = plt.gca()
ax.set_xlabel('time $t$')
ax.set_ylabel('L2 Error')
ax.set_title('L2 Error')
plt.rc('font', size=12)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=20)    # legend fontsize
plt.rc('figure', titlesize=20)  # fontsize of the figure title
#plt.grid()
plt.show()


plt.clf()
# Plot energy as a function of time
# (subtract energy at time t=0 to show energy drift)

plt.plot(t_exact_SHO,E_exact_SHO-E_exact_SHO[0],label='Verlet',color='black')
#plt.plot(t_lstm_1,E_lstm_1-E_lstm_1[0],label='$\Delta_v$',color='blue')
plt.plot(t_lstm_2,E_lstm_2-E_lstm_2[0],label='$20\Delta_v$',color='orange')
plt.plot(t_lstm_3,E_lstm_3-E_lstm_3[0],label='$40\Delta_v$',color='green')
plt.plot(t_lstm_4,E_lstm_4-E_lstm_4[0],label='$100\Delta_v$',color='red')
plt.legend(loc='upper left')
ax = plt.gca()
ax.set_xlabel('time $t$')
ax.set_ylabel('energy shift $E(t)-E(t_0)$')
#ax.grid()
plt.rc('font', size=12)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=20)    # legend fontsize
plt.rc('figure', titlesize=20)  # fontsize of the figure title

plt.show()

#subplots of position versus velocity for all 4

plt.rcParams['figure.figsize'] = [10, 10]

plt.clf()
plt.plot(x_exact_SHO,v_exact_SHO,label='Verlet',color='black')
#plt.plot(x_lstm_1,v_lstm_1,label='$\Delta_v$',color='blue')
plt.plot(x_lstm_2,v_lstm_2,label='$20\Delta_v$',color='orange')
plt.plot(x_lstm_3,v_lstm_3,label='$40\Delta_v$',color='green')
plt.plot(x_lstm_4,v_lstm_4,label='$100\Delta_v$',color='red')
plt.legend(loc='upper left')
ax = plt.gca()
ax.set_ylabel('Velocity $v(t)$')
ax.set_xlabel('Position $q(t)$')
plt.rc('font', size=12)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=20)    # legend fontsize
plt.rc('figure', titlesize=20)  # fontsize of the figure title
plt.show()
