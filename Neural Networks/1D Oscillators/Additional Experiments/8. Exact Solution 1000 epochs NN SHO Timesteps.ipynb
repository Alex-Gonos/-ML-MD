# %% [markdown]
# # Neural network based integrator simulating SHO

# %%
import sys
sys.path.append('..')

import numpy as np
from matplotlib import pyplot as plt
from Code.dynamical_system import *
from Code.time_integrator import *
from Code.neuralnet import *

np.random.seed(2512517)

# %% [markdown]
# ## Neural network integrator

# %% [markdown]
# Set system parameters, construct dynamical system and integrator.
#
# The model system we are using here is the harmonic oscillator, defined by the equations of motion
#
# $$
# \frac{dx}{dt} = v,\qquad\qquad
# \frac{dv}{dt} = -\frac{k}{m}x
# $$
#
# The timestep size of the Neural network integrator takes values in $\Delta t_{\text{Verlet}},20\Delta t_{\text{Verlet}},40\Delta t_{\text{Verlet}},100\Delta t_{\text{Verlet}}$ where $\Delta t_{\text{Verlet}}$ is the step size of the Verlet integrator that is used for training.

# %%
# mass of particle
mass = 1.2
# spring constant of harmonic oscillator
k_spring = 0.9
# timestep for Verlet integrator
dt_verlet = 0.005
# timestep for neural network integrator
dt_1 = dt_verlet
dt_2 = 20*dt_verlet
dt_3 = 40*dt_verlet
dt_4 = 100*dt_verlet
# number of steps for neural network integrator
nsteps = 4

harmonic_oscillator = HarmonicOscillator(mass,k_spring)

exact_SHO = ExactIntegrator(harmonic_oscillator,dt_verlet)

nn_integrator_1 = NN5LR3Integrator(harmonic_oscillator,nsteps,dt_1)
nn_integrator_2 = NN5LR3Integrator(harmonic_oscillator,nsteps,dt_2)
nn_integrator_3 = NN5LR3Integrator(harmonic_oscillator,nsteps,dt_3)
nn_integrator_4 = NN5LR3Integrator(harmonic_oscillator,nsteps,dt_4)

# visualise the neural network model
nn_integrator_1.model.summary()
keras.utils.plot_model(nn_integrator_1.model, show_shapes=True)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 5, 2)]       0           []
#
#  flatten (Flatten)              (None, 10)           0           ['input_1[0][0]']
#
#  dense (Dense)                  (None, 64)           704         ['flatten[0][0]']
#
#  dense_1 (Dense)                (None, 64)           4160        ['dense[0][0]']
#
#  dense_2 (Dense)                (None, 32)           2080        ['dense_1[0][0]']
#
#  dense_3 (Dense)                (None, 2)            66          ['dense_2[0][0]']
#
#  tf.unstack (TFOpLambda)        [(None, 2),          0           ['input_1[0][0]']
#                                  (None, 2),
#                                  (None, 2),
#                                  (None, 2),
#                                  (None, 2)]
#
#  rescaling (Rescaling)          (None, 2)            0           ['dense_3[0][0]']
#
#  add (Add)                      (None, 2)            0           ['tf.unstack[0][4]',
#                                                                   'rescaling[0][0]']
#
# ==================================================================================================
# Total params: 7,010
# Trainable params: 7,010
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
BATCH_SIZE=64

data_generator_1 = DataGenerator(nn_integrator_1,exact_SHO)
train_batches_1 = data_generator_1.dataset.batch(BATCH_SIZE)

data_generator_2 = DataGenerator(nn_integrator_2,exact_SHO)
train_batches_2 = data_generator_2.dataset.batch(BATCH_SIZE)

data_generator_3 = DataGenerator(nn_integrator_3,exact_SHO)
train_batches_3 = data_generator_3.dataset.batch(BATCH_SIZE)

data_generator_4 = DataGenerator(nn_integrator_4,exact_SHO)
train_batches_4 = data_generator_4.dataset.batch(BATCH_SIZE)

# %% [markdown]
# ## Train neural network based integrator

# %%
EPOCHS=1000
STEPS_PER_EPOCH=100
log_dir = './tb_logs/'
tensorboard_cb = tf.keras.callbacks.TensorBoard(log_dir=log_dir)

result_1 = nn_integrator_1.model.fit(train_batches_1,epochs=EPOCHS,steps_per_epoch=STEPS_PER_EPOCH,
                                 callbacks=tensorboard_cb)
result_2 = nn_integrator_2.model.fit(train_batches_2,epochs=EPOCHS,steps_per_epoch=STEPS_PER_EPOCH,
                                 callbacks=tensorboard_cb)
result_3 = nn_integrator_3.model.fit(train_batches_3,epochs=EPOCHS,steps_per_epoch=STEPS_PER_EPOCH,
                                callbacks=tensorboard_cb)
result_4 = nn_integrator_4.model.fit(train_batches_4,epochs=EPOCHS,steps_per_epoch=STEPS_PER_EPOCH,
                                 callbacks=tensorboard_cb)
# Out:
# Streaming output truncated to the last 5000 lines.
# 100/100 [==============================] - 3s 27ms/step - loss: 1.3236e-08
# Epoch 502/1000
# 100/100 [==============================] - 3s 27ms/step - loss: 1.7534e-08
# Epoch 503/1000
# 100/100 [==============================] - 3s 28ms/step - loss: 2.7627e-08
# Epoch 504/1000
# 100/100 [==============================] - 3s 27ms/step - loss: 3.0762e-08
# Epoch 505/1000
# 100/100 [==============================] - 3s 28ms/step - loss: 1.5355e-08
# Epoch 506/1000
# 100/100 [==============================] - 3s 27ms/step - loss: 1.1084e-08
# Epoch 507/1000
# 100/100 [==============================] - 3s 28ms/step - loss: 2.3446e-08
# Epoch 508/1000
# 100/100 [==============================] - 3s 29ms/step - loss: 9.1250e-09
# Epoch 509/1000
# 100/100 [==============================] - 3s 27ms/step - loss: 1.6522e-08
# Epoch 510/1000
# 100/100 [==============================] - 3s 28ms/step - loss: 3.1812e-08
# Epoch 511/1000
# 100/100 [==============================] - 3s 27ms/step - loss: 2.0179e-07
# Epoch 512/1000
# 100/100 [==============================] - 3s 28ms/step - loss: 1.1566e-08
# Epoch 513/1000
# 100/100 [==============================] - 3s 27ms/step - loss: 2.4875e-09
# Epoch 514/1000
# 100/100 [==============================] - 3s 27ms/step - loss: 6.5856e-09
# Epoch 515/1000
# 100/100 [==============================] - 3s 27ms/step - loss: 7.0206e-09
# Epoch 516/1000
# 100/100 [==============================] - 3s 27ms/step - loss: 1.3874e-08
# Epoch 517/1000
# 100/100 [==============================] - 3s 27ms/step - loss: 6.7754e-08
# Epoch 518/1000
# 100/100 [==============================] - 3s 27ms/step - loss: 6.2963e-09
# Epoch 519/1000
# 100/100 [==============================] - 3s 26ms/step - loss: 9.9227e-09
# Epoch 520/1000
# 100/100 [==============================] - 3s 27ms/step - loss: 1.6205e-08
# Epoch 521/1000
# 100/100 [==============================] - 3s 27ms/step - loss: 6.6978e-08
# Epoch 522/1000
# 100/100 [==============================] - 3s 26ms/step - loss: 9.3969e-08
# Epoch 523/1000
# 100/100 [==============================] - 3s 28ms/step - loss: 4.3457e-08
# Epoch 524/1000
# 100/100 [==============================] - 3s 26ms/step - loss: 9.2083e-09
# Epoch 525/1000
# 100/100 [==============================] - 3s 27ms/step - loss: 5.4658e-09
# Epoch 526/1000
# 100/100 [==============================] - 3s 26ms/step - loss: 6.0402e-09
# Epoch 527/1000
# 100/100 [==============================] - 3s 27ms/step - loss: 3.1596e-09
# Epoch 528/1000
# 100/100 [==============================] - 3s 26ms/step - loss: 3.7729e-09
# Epoch 529/1000
# 100/100 [==============================] - 3s 26ms/step - loss: 4.0714e-09
# Epoch 530/1000
# 100/100 [==============================] - 3s 27ms/step - loss: 5.7678e-08
# Epoch 531/1000
# 100/100 [==============================] - 3s 27ms/step - loss: 1.2600e-07
# Epoch 532/1000
# 100/100 [==============================] - 3s 26ms/step - loss: 6.7063e-09
# Epoch 533/1000
# 100/100 [==============================] - 3s 27ms/step - loss: 3.4636e-09
# Epoch 534/1000
# 100/100 [==============================] - 3s 27ms/step - loss: 9.3756e-09
# Epoch 535/1000
# 100/100 [==============================] - 3s 27ms/step - loss: 1.1627e-08
# Epoch 536/1000
# 100/100 [==============================] - 3s 28ms/step - loss: 9.4851e-08
# Epoch 537/1000
# 100/100 [==============================] - 3s 27ms/step - loss: 1.3266e-08
# Epoch 538/1000
# 100/100 [==============================] - 3s 27ms/step - loss: 3.7327e-09
# Epoch 539/1000
# 100/100 [==============================] - 3s 27ms/step - loss: 2.7181e-09
# Epoch 540/1000
# 100/100 [==============================] - 3s 26ms/step - loss: 1.4291e-08
# Epoch 541/1000
# 100/100 [==============================] - 3s 28ms/step - loss: 1.1063e-07
# Epoch 542/1000
# 100/100 [==============================] - 3s 27ms/step - loss: 3.2927e-08
# Epoch 543/1000
# 100/100 [==============================] - 3s 26ms/step - loss: 8.5097e-09
# Epoch 544/1000
# 100/100 [==============================] - 3s 27ms/step - loss: 1.2692e-08
# Epoch 545/1000
# 100/100 [==============================] - 3s 26ms/step - loss: 4.0738e-09
# Epoch 546/1000
# 100/100 [==============================] - 3s 26ms/step - loss: 6.5282e-08
# Epoch 547/1000
# 100/100 [==============================] - 3s 27ms/step - loss: 9.1479e-09
# Epoch 548/1000
# 100/100 [==============================] - 3s 26ms/step - loss: 6.1018e-09
# Epoch 549/1000
# 100/100 [==============================] - 3s 27ms/step - loss: 4.5966e-09
# Epoch 550/1000
# 100/100 [==============================] - 3s 27ms/step - loss: 2.0447e-08
# Epoch 551/1000
# 100/100 [==============================] - 3s 26ms/step - loss: 6.7081e-08
# Epoch 552/1000
# 100/100 [==============================] - 3s 27ms/step - loss: 9.6552e-09
# Epoch 553/1000
# 100/100 [==============================] - 3s 26ms/step - loss: 1.3779e-08
# Epoch 554/1000
# 100/100 [==============================] - 3s 27ms/step - loss: 7.2354e-09
# Epoch 555/1000
# 100/100 [==============================] - 3s 25ms/step - loss: 3.7804e-09
# Epoch 556/1000
# 100/100 [==============================] - 3s 27ms/step - loss: 1.7211e-08
# Epoch 557/1000
# 100/100 [==============================] - 3s 27ms/step - loss: 3.0213e-08
# Epoch 558/1000
# 100/100 [==============================] - 3s 27ms/step - loss: 9.1601e-08
# Epoch 559/1000
# 100/100 [==============================] - 3s 27ms/step - loss: 2.0976e-08
# Epoch 560/1000
# 100/100 [==============================] - 3s 27ms/step - loss: 4.9578e-08
# Epoch 561/1000
# 100/100 [==============================] - 3s 26ms/step - loss: 1.5543e-08
# Epoch 562/1000
# 100/100 [==============================] - 3s 27ms/step - loss: 4.2361e-08
# Epoch 563/1000
# 100/100 [==============================] - 3s 27ms/step - loss: 4.2655e-08
# Epoch 564/1000
# 100/100 [==============================] - 3s 28ms/step - loss: 1.3415e-08
# Epoch 565/1000
# 100/100 [==============================] - 3s 29ms/step - loss: 2.6826e-08
# Epoch 566/1000
# 100/100 [==============================] - 3s 27ms/step - loss: 1.0735e-08
# Epoch 567/1000
# 100/100 [==============================] - 3s 28ms/step - loss: 3.5293e-09
# Epoch 568/1000
# 100/100 [==============================] - 3s 26ms/step - loss:
1000
# 100/100 [==============================] - 3s 26ms/step - loss: 3.7535e-07
# Epoch 983/1000
# 100/100 [==============================] - 3s 26ms/step - loss: 5.6102e-07
# Epoch 984/1000
# 100/100 [==============================] - 3s 26ms/step - loss: 1.0358e-06
# Epoch 985/1000
# 100/100 [==============================] - 3s 26ms/step - loss: 5.8975e-07
# Epoch 986/1000
# 100/100 [==============================] - 3s 27ms/step - loss: 1.6904e-07
# Epoch 987/1000
# 100/100 [==============================] - 2s 25ms/step - loss: 9.9577e-07
# Epoch 988/1000
# 100/100 [==============================] - 3s 26ms/step - loss: 2.4266e-06
# Epoch 989/1000
# 100/100 [==============================] - 3s 26ms/step - loss: 9.7144e-07
# Epoch 990/1000
# 100/100 [==============================] - 3s 26ms/step - loss: 1.1193e-07
# Epoch 991/1000
# 100/100 [==============================] - 3s 27ms/step - loss: 3.4932e-08
# Epoch 992/1000
# 100/100 [==============================] - 3s 27ms/step - loss: 3.2836e-08
# Epoch 993/1000
# 100/100 [==============================] - 3s 26ms/step - loss: 4.8635e-08
# Epoch 994/1000
# 100/100 [==============================] - 3s 27ms/step - loss: 3.2912e-07
# Epoch 995/1000
# 100/100 [==============================] - 3s 26ms/step - loss: 1.1465e-06
# Epoch 996/1000
# 100/100 [==============================] - 3s 26ms/step - loss: 5.0968e-07
# Epoch 997/1000
# 100/100 [==============================] - 3s 25ms/step - loss: 7.1937e-07
# Epoch 998/1000
# 100/100 [==============================] - 3s 26ms/step - loss: 5.2742e-08
# Epoch 999/1000
# 100/100 [==============================] - 3s 26ms/step - loss: 4.2945e-08
# Epoch 1000/1000
# 100/100 [==============================] - 3s 25ms/step - loss: 8.0572e-07

# %% [markdown]
# ## Visualise Loss function

# %%
#print(result.history.keys())

plt.rcParams['figure.figsize'] = [10, 10]

# summarize history for loss
plt.plot(result_1.history['loss'])
plt.plot(result_2.history['loss'])
plt.plot(result_3.history['loss'])
plt.plot(result_4.history['loss'])

plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.rc('font', size=12)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=20)    # legend fontsize
plt.rc('figure', titlesize=20)  # fontsize of the figure title
plt.legend(['$\Delta_v$','$20\Delta_v$','$40\Delta_v$','$100\Delta_v$'], loc='upper left')
plt.yscale("log")
plt.show()

# %% [markdown]
# ## Plot trajectories generated to $t=32$ by Verlet integrator and neural

# %%
# Final time
T_final = 32

# Initial conditions
x = np.zeros(1)
v = np.zeros(1)
x[0] = 2.70
v[0] = -0.6
exact_SHO.set_state(x,v)

# ==== Verlet integrator ====
t = 0.0
t_exact_SHO = []
x_exact_SHO = []
v_exact_SHO = []
E_exact_SHO = []



while t<T_final:
    t_exact_SHO.append(t)
    E_exact_SHO.append(exact_SHO.energy())
    x_exact_SHO.append(exact_SHO.x[0])
    v_exact_SHO.append(exact_SHO.v[0])
    exact_SHO.integrate(1)
    t += dt_verlet
        

# ==== Neural network integrator ====

# Initialise with Verlet integrator
x_initial_1 = np.zeros((nn_integrator_1.nsteps,nn_integrator_1.dynamical_system.dim))
v_initial_1 = np.zeros((nn_integrator_1.nsteps,nn_integrator_1.dynamical_system.dim))
x_initial_2 = np.zeros((nn_integrator_2.nsteps,nn_integrator_2.dynamical_system.dim))
v_initial_2 = np.zeros((nn_integrator_2.nsteps,nn_integrator_2.dynamical_system.dim))
x_initial_3 = np.zeros((nn_integrator_3.nsteps,nn_integrator_3.dynamical_system.dim))
v_initial_3 = np.zeros((nn_integrator_3.nsteps,nn_integrator_3.dynamical_system.dim))
x_initial_4 = np.zeros((nn_integrator_4.nsteps,nn_integrator_4.dynamical_system.dim))
v_initial_4 = np.zeros((nn_integrator_4.nsteps,nn_integrator_4.dynamical_system.dim))



exact_SHO.set_state(x,v)
for k in range(nn_integrator_1.nsteps):    
    x_initial_1[k,:] = exact_SHO.x[:]
    v_initial_1[k,:] = exact_SHO.v[:]
    exact_SHO.integrate(int(dt_1/dt_verlet))
exact_SHO.set_state(x,v)
for k in range(nn_integrator_2.nsteps):    
    x_initial_2[k,:] = exact_SHO.x[:]
    v_initial_2[k,:] = exact_SHO.v[:]
    exact_SHO.integrate(int(dt_2/dt_verlet))
exact_SHO.set_state(x,v)
for k in range(nn_integrator_3.nsteps):    
    x_initial_3[k,:] = exact_SHO.x[:]
    v_initial_3[k,:] = exact_SHO.v[:]
    exact_SHO.integrate(int(dt_3/dt_verlet))
exact_SHO.set_state(x,v)
for k in range(nn_integrator_4.nsteps):    
    x_initial_4[k,:] = exact_SHO.x[:]
    v_initial_4[k,:] = exact_SHO.v[:]
    exact_SHO.integrate(int(dt_4/dt_verlet))


nn_integrator_1.set_state(x_initial_1,v_initial_1)
t_1 = (nn_integrator_1.nsteps-1)*nn_integrator_1.dt
nn_integrator_2.set_state(x_initial_2,v_initial_2)
t_2 = (nn_integrator_2.nsteps-1)*nn_integrator_2.dt
nn_integrator_3.set_state(x_initial_3,v_initial_3)
t_3 = (nn_integrator_3.nsteps-1)*nn_integrator_3.dt
nn_integrator_4.set_state(x_initial_4,v_initial_4)
t_4 = (nn_integrator_4.nsteps-1)*nn_integrator_4.dt



# Timestepping loop
t_nn_1 = []
x_nn_1 = []
v_nn_1 = []
E_nn_1 = []
t_nn_2 = []
x_nn_2 = []
v_nn_2 = []
E_nn_2 = []
t_nn_3 = []
x_nn_3 = []
v_nn_3 = []
E_nn_3 = []
t_nn_4 = []
x_nn_4 = []
v_nn_4 = []
E_nn_4 = []


while t_1<T_final:
    t_nn_1.append(t_1)
    x_nn_1.append(nn_integrator_1.x[0])
    v_nn_1.append(nn_integrator_1.v[0])
    E_nn_1.append(nn_integrator_1.energy())
    nn_integrator_1.integrate(1)
    t_1 += dt_1
while t_2<T_final:
    t_nn_2.append(t_2)
    x_nn_2.append(nn_integrator_2.x[0])
    v_nn_2.append(nn_integrator_2.v[0])
    E_nn_2.append(nn_integrator_2.energy())
    nn_integrator_2.integrate(1)
    t_2 += dt_2
while t_3<T_final:
    t_nn_3.append(t_3)
    x_nn_3.append(nn_integrator_3.x[0])
    v_nn_3.append(nn_integrator_3.v[0])
    E_nn_3.append(nn_integrator_3.energy())
    nn_integrator_3.integrate(1)
    t_3 += dt_3
while t_4<T_final:
    t_nn_4.append(t_4)
    x_nn_4.append(nn_integrator_4.x[0])
    v_nn_4.append(nn_integrator_4.v[0])
    E_nn_4.append(nn_integrator_4.energy())
    nn_integrator_4.integrate(1)
    t_4 += dt_4
 



x_nn_1 = np.array(x_nn_1)
x_nn_2 = np.array(x_nn_2)
x_nn_3 = np.array(x_nn_3)
x_nn_4 = np.array(x_nn_4)
x_exact_SHO = np.array(x_exact_SHO)
v_nn_1 = np.array(v_nn_1)
v_nn_2 = np.array(v_nn_2)
v_nn_3 = np.array(v_nn_3)
v_nn_4 = np.array(v_nn_4)
v_exact_SHO = np.array(v_exact_SHO)


# Plot position error as a function of time
plt.clf()
plt.rcParams['figure.figsize'] = [10, 10]

plt.plot(t_nn_1,x_nn_1-x_exact_SHO[int((nsteps-1)*dt_1/dt_verlet)::int(dt_1/dt_verlet)],label='$\Delta_v$',color='blue')
plt.plot(t_nn_2,x_nn_2-x_exact_SHO[int((nsteps-1)*dt_2/dt_verlet):int(np.size(x_exact_SHO)-dt_2/dt_verlet):int(dt_2/dt_verlet)],label='$20\Delta_v$',color='orange')
plt.plot(t_nn_3,x_nn_3-x_exact_SHO[int((nsteps-1)*dt_3/dt_verlet)::int(dt_3/dt_verlet)],label='$40\Delta_v$',color='green')
plt.plot(t_nn_4,x_nn_4-x_exact_SHO[int((nsteps-1)*dt_4/dt_verlet):int(np.size(x_exact_SHO)-dt_4/dt_verlet):int(dt_4/dt_verlet)],label='$100\Delta_v$',color='red')
plt.legend(loc='upper left')
ax = plt.gca()
ax.set_xlabel('time $t$')
ax.set_ylabel('position Error $x_{NN}(t)-x_V(t)$')
ax.set_title('Position Error')
plt.rc('font', size=12)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=20)    # legend fontsize
plt.rc('figure', titlesize=20)  # fontsize of the figure title
#plt.grid()
plt.show()

# Plot velocity error as a function of time

plt.plot(t_nn_1,v_nn_1-v_exact_SHO[int((nsteps-1)*dt_1/dt_verlet)::int(dt_1/dt_verlet)],label='$\Delta_v$',color='blue')
plt.plot(t_nn_2,v_nn_2-v_exact_SHO[int((nsteps-1)*dt_2/dt_verlet):int(np.size(v_exact_SHO)-dt_2/dt_verlet):int(dt_2/dt_verlet)],label='$20\Delta_v$',color='orange')
plt.plot(t_nn_3,v_nn_3-v_exact_SHO[int((nsteps-1)*dt_3/dt_verlet)::int(dt_3/dt_verlet)],label='$40\Delta_v$',color='green')
plt.plot(t_nn_4,v_nn_4-v_exact_SHO[int((nsteps-1)*dt_4/dt_verlet):int(np.size(v_exact_SHO)-dt_4/dt_verlet):int(dt_4/dt_verlet)],label='$100\Delta_v$',color='red')
plt.legend(loc='upper left')
ax = plt.gca()
ax.set_xlabel('time $t$')
ax.set_ylabel('Velocity Error $v_{NN}(t)-v_V(t)$')
ax.set_title('Velocity Error')
plt.rc('font', size=12)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=20)    # legend fontsize
plt.rc('figure', titlesize=20)  # fontsize of the figure title
#plt.grid()
plt.show()

# Plot L2 error as a function of time

plt.plot(t_nn_1,((v_nn_1-v_exact_SHO[int((nsteps-1)*dt_1/dt_verlet)::int(dt_1/dt_verlet)])**2+(x_nn_1-x_exact_SHO[int((nsteps-1)*dt_1/dt_verlet)::int(dt_1/dt_verlet)])**2)**0.5,label='$\Delta_v$',color='blue')
plt.plot(t_nn_2,((v_nn_2-v_exact_SHO[int((nsteps-1)*dt_2/dt_verlet):int(np.size(v_exact_SHO)-dt_2/dt_verlet):int(dt_2/dt_verlet)])**2+(x_nn_2-x_exact_SHO[int((nsteps-1)*dt_2/dt_verlet):int(np.size(x_exact_SHO)-dt_2/dt_verlet):int(dt_2/dt_verlet)])**2)**0.5,label='$20\Delta_v$',color='orange')
plt.plot(t_nn_3,((v_nn_3-v_exact_SHO[int((nsteps-1)*dt_3/dt_verlet)::int(dt_3/dt_verlet)])**2+(x_nn_3-x_exact_SHO[int((nsteps-1)*dt_3/dt_verlet)::int(dt_3/dt_verlet)])**2)**0.5,label='$40\Delta_v$',color='green')
plt.plot(t_nn_4,((v_nn_4-v_exact_SHO[int((nsteps-1)*dt_4/dt_verlet):int(np.size(v_exact_SHO)-dt_4/dt_verlet):int(dt_4/dt_verlet)])**2+(x_nn_4-x_exact_SHO[int((nsteps-1)*dt_4/dt_verlet):int(np.size(x_exact_SHO)-dt_4/dt_verlet):int(dt_4/dt_verlet)])**2)**0.5,label='$100\Delta_v$',color='red')
plt.legend(loc='upper left')
ax = plt.gca()
ax.set_xlabel('time $t$')
ax.set_ylabel('L2 Error')
ax.set_title('L2 Error')
plt.rc('font', size=12)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=20)    # legend fontsize
plt.rc('figure', titlesize=20)  # fontsize of the figure title
#plt.grid()
plt.show()


plt.clf()
# Plot energy as a function of time
# (subtract energy at time t=0 to show energy drift)

plt.plot(t_exact_SHO,E_exact_SHO-E_exact_SHO[0],label='Verlet',color='black')
plt.plot(t_nn_1,E_nn_1-E_nn_1[0],label='$\Delta_v$',color='blue')
plt.plot(t_nn_2,E_nn_2-E_nn_2[0],label='$20\Delta_v$',color='orange')
plt.plot(t_nn_3,E_nn_3-E_nn_3[0],label='$40\Delta_v$',color='green')
plt.plot(t_nn_4,E_nn_4-E_nn_4[0],label='$100\Delta_v$',color='red')
plt.legend(loc='upper left')
ax = plt.gca()
ax.set_xlabel('time $t$')
ax.set_ylabel('energy shift $E(t)-E(t_0)$')
#ax.grid()
plt.rc('font', size=12)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=20)    # legend fontsize
plt.rc('figure', titlesize=20)  # fontsize of the figure title

plt.show()

#subplots of position versus velocity for all 4

plt.rcParams['figure.figsize'] = [10, 10]

plt.clf()
plt.plot(x_exact_SHO,v_exact_SHO,label='Verlet',color='black')
plt.plot(x_nn_1,v_nn_1,label='$\Delta_v$',color='blue')
plt.plot(x_nn_2,v_nn_2,label='$20\Delta_v$',color='orange')
plt.plot(x_nn_3,v_nn_3,label='$40\Delta_v$',color='green')
plt.plot(x_nn_4,v_nn_4,label='$100\Delta_v$',color='red')
plt.legend(loc='upper left')
ax = plt.gca()
ax.set_ylabel('Velocity $v(t)$')
ax.set_xlabel('Position $q(t)$')
plt.rc('font', size=12)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=20)    # legend fontsize
plt.rc('figure', titlesize=20)  # fontsize of the figure title
plt.show()

# %% [markdown]
# ## Plot trajectories generated to $t=128$ by Verlet integrator and neural

# %%
# Final time
T_final = 128

# Initial conditions
x = np.zeros(1)
v = np.zeros(1)
x[0] = 2.70
v[0] = -0.6
exact_SHO.set_state(x,v)

# ==== Verlet integrator ====
t = 0.0
t_exact_SHO = []
x_exact_SHO = []
v_exact_SHO = []
E_exact_SHO = []



while t<T_final:
    t_exact_SHO.append(t)
    E_exact_SHO.append(exact_SHO.energy())
    x_exact_SHO.append(exact_SHO.x[0])
    v_exact_SHO.append(exact_SHO.v[0])
    exact_SHO.integrate(1)
    t += dt_verlet
        

# ==== Neural network integrator ====

# Initialise with Verlet integrator
x_initial_1 = np.zeros((nn_integrator_1.nsteps,nn_integrator_1.dynamical_system.dim))
v_initial_1 = np.zeros((nn_integrator_1.nsteps,nn_integrator_1.dynamical_system.dim))
x_initial_2 = np.zeros((nn_integrator_2.nsteps,nn_integrator_2.dynamical_system.dim))
v_initial_2 = np.zeros((nn_integrator_2.nsteps,nn_integrator_2.dynamical_system.dim))
x_initial_3 = np.zeros((nn_integrator_3.nsteps,nn_integrator_3.dynamical_system.dim))
v_initial_3 = np.zeros((nn_integrator_3.nsteps,nn_integrator_3.dynamical_system.dim))
x_initial_4 = np.zeros((nn_integrator_4.nsteps,nn_integrator_4.dynamical_system.dim))
v_initial_4 = np.zeros((nn_integrator_4.nsteps,nn_integrator_4.dynamical_system.dim))



exact_SHO.set_state(x,v)
for k in range(nn_integrator_1.nsteps):    
    x_initial_1[k,:] = exact_SHO.x[:]
    v_initial_1[k,:] = exact_SHO.v[:]
    exact_SHO.integrate(int(dt_1/dt_verlet))
exact_SHO.set_state(x,v)
for k in range(nn_integrator_2.nsteps):    
    x_initial_2[k,:] = exact_SHO.x[:]
    v_initial_2[k,:] = exact_SHO.v[:]
    exact_SHO.integrate(int(dt_2/dt_verlet))
exact_SHO.set_state(x,v)
for k in range(nn_integrator_3.nsteps):    
    x_initial_3[k,:] = exact_SHO.x[:]
    v_initial_3[k,:] = exact_SHO.v[:]
    exact_SHO.integrate(int(dt_3/dt_verlet))
exact_SHO.set_state(x,v)
for k in range(nn_integrator_4.nsteps):    
    x_initial_4[k,:] = exact_SHO.x[:]
    v_initial_4[k,:] = exact_SHO.v[:]
    exact_SHO.integrate(int(dt_4/dt_verlet))


nn_integrator_1.set_state(x_initial_1,v_initial_1)
t_1 = (nn_integrator_1.nsteps-1)*nn_integrator_1.dt
nn_integrator_2.set_state(x_initial_2,v_initial_2)
t_2 = (nn_integrator_2.nsteps-1)*nn_integrator_2.dt
nn_integrator_3.set_state(x_initial_3,v_initial_3)
t_3 = (nn_integrator_3.nsteps-1)*nn_integrator_3.dt
nn_integrator_4.set_state(x_initial_4,v_initial_4)
t_4 = (nn_integrator_4.nsteps-1)*nn_integrator_4.dt



# Timestepping loop
t_nn_1 = []
x_nn_1 = []
v_nn_1 = []
E_nn_1 = []
t_nn_2 = []
x_nn_2 = []
v_nn_2 = []
E_nn_2 = []
t_nn_3 = []
x_nn_3 = []
v_nn_3 = []
E_nn_3 = []
t_nn_4 = []
x_nn_4 = []
v_nn_4 = []
E_nn_4 = []


while t_1<T_final:
    t_nn_1.append(t_1)
    x_nn_1.append(nn_integrator_1.x[0])
    v_nn_1.append(nn_integrator_1.v[0])
    E_nn_1.append(nn_integrator_1.energy())
    nn_integrator_1.integrate(1)
    t_1 += dt_1
while t_2<T_final:
    t_nn_2.append(t_2)
    x_nn_2.append(nn_integrator_2.x[0])
    v_nn_2.append(nn_integrator_2.v[0])
    E_nn_2.append(nn_integrator_2.energy())
    nn_integrator_2.integrate(1)
    t_2 += dt_2
while t_3<T_final:
    t_nn_3.append(t_3)
    x_nn_3.append(nn_integrator_3.x[0])
    v_nn_3.append(nn_integrator_3.v[0])
    E_nn_3.append(nn_integrator_3.energy())
    nn_integrator_3.integrate(1)
    t_3 += dt_3
while t_4<T_final:
    t_nn_4.append(t_4)
    x_nn_4.append(nn_integrator_4.x[0])
    v_nn_4.append(nn_integrator_4.v[0])
    E_nn_4.append(nn_integrator_4.energy())
    nn_integrator_4.integrate(1)
    t_4 += dt_4
 



x_nn_1 = np.array(x_nn_1)
x_nn_2 = np.array(x_nn_2)
x_nn_3 = np.array(x_nn_3)
x_nn_4 = np.array(x_nn_4)
x_exact_SHO = np.array(x_exact_SHO)
v_nn_1 = np.array(v_nn_1)
v_nn_2 = np.array(v_nn_2)
v_nn_3 = np.array(v_nn_3)
v_nn_4 = np.array(v_nn_4)
v_exact_SHO = np.array(v_exact_SHO)


# Plot position error as a function of time
plt.clf()
plt.rcParams['figure.figsize'] = [10, 10]

plt.plot(t_nn_1,x_nn_1-x_exact_SHO[int((nsteps-1)*dt_1/dt_verlet)::int(dt_1/dt_verlet)],label='$\Delta_v$',color='blue')
plt.plot(t_nn_2,x_nn_2-x_exact_SHO[int((nsteps-1)*dt_2/dt_verlet)::int(dt_2/dt_verlet)],label='$20\Delta_v$',color='orange')
plt.plot(t_nn_3,x_nn_3-x_exact_SHO[int((nsteps-1)*dt_3/dt_verlet):int(np.size(x_exact_SHO)-dt_3/dt_verlet):int(dt_3/dt_verlet)],label='$40\Delta_v$',color='green')
plt.plot(t_nn_4,x_nn_4-x_exact_SHO[int((nsteps-1)*dt_4/dt_verlet):int(np.size(x_exact_SHO)-dt_4/dt_verlet):int(dt_4/dt_verlet)],label='$100\Delta_v$',color='red')
plt.legend(loc='upper left')
ax = plt.gca()
ax.set_xlabel('time $t$')
ax.set_ylabel('position Error $x_{NN}(t)-x_V(t)$')
ax.set_title('Position Error')
plt.rc('font', size=12)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=20)    # legend fontsize
plt.rc('figure', titlesize=20)  # fontsize of the figure title
#plt.grid()
plt.show()

# Plot velocity error as a function of time

plt.plot(t_nn_1,v_nn_1-v_exact_SHO[int((nsteps-1)*dt_1/dt_verlet)::int(dt_1/dt_verlet)],label='$\Delta_v$',color='blue')
plt.plot(t_nn_2,v_nn_2-v_exact_SHO[int((nsteps-1)*dt_2/dt_verlet)::int(dt_2/dt_verlet)],label='$20\Delta_v$',color='orange')
plt.plot(t_nn_3,v_nn_3-v_exact_SHO[int((nsteps-1)*dt_3/dt_verlet):int(np.size(v_exact_SHO)-dt_3/dt_verlet):int(dt_3/dt_verlet)],label='$40\Delta_v$',color='green')
plt.plot(t_nn_4,v_nn_4-v_exact_SHO[int((nsteps-1)*dt_4/dt_verlet):int(np.size(v_exact_SHO)-dt_4/dt_verlet):int(dt_4/dt_verlet)],label='$100\Delta_v$',color='red')
plt.legend(loc='upper left')
ax = plt.gca()
ax.set_xlabel('time $t$')
ax.set_ylabel('Velocity Error $v_{NN}(t)-v_V(t)$')
ax.set_title('Velocity Error')
plt.rc('font', size=12)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=20)    # legend fontsize
plt.rc('figure', titlesize=20)  # fontsize of the figure title
#plt.grid()
plt.show()

# Plot L2 error as a function of time

plt.plot(t_nn_1,((v_nn_1-v_exact_SHO[int((nsteps-1)*dt_1/dt_verlet)::int(dt_1/dt_verlet)])**2+(x_nn_1-x_exact_SHO[int((nsteps-1)*dt_1/dt_verlet)::int(dt_1/dt_verlet)])**2)**0.5,label='$\Delta_v$',color='blue')
plt.plot(t_nn_2,((v_nn_2-v_exact_SHO[int((nsteps-1)*dt_2/dt_verlet)::int(dt_2/dt_verlet)])**2+(x_nn_2-x_exact_SHO[int((nsteps-1)*dt_2/dt_verlet)::int(dt_2/dt_verlet)])**2)**0.5,label='$20\Delta_v$',color='orange')
plt.plot(t_nn_3,((v_nn_3-v_exact_SHO[int((nsteps-1)*dt_3/dt_verlet):int(np.size(v_exact_SHO)-dt_3/dt_verlet):int(dt_3/dt_verlet)])**2+(x_nn_3-x_exact_SHO[int((nsteps-1)*dt_3/dt_verlet):int(np.size(x_exact_SHO)-dt_3/dt_verlet):int(dt_3/dt_verlet)])**2)**0.5,label='$40\Delta_v$',color='green')
plt.plot(t_nn_4,((v_nn_4-v_exact_SHO[int((nsteps-1)*dt_4/dt_verlet):int(np.size(v_exact_SHO)-dt_4/dt_verlet):int(dt_4/dt_verlet)])**2+(x_nn_4-x_exact_SHO[int((nsteps-1)*dt_4/dt_verlet):int(np.size(x_exact_SHO)-dt_4/dt_verlet):int(dt_4/dt_verlet)])**2)**0.5,label='$100\Delta_v$',color='red')
plt.legend(loc='upper left')
ax = plt.gca()
ax.set_xlabel('time $t$')
ax.set_ylabel('L2 Error')
ax.set_title('L2 Error')
plt.rc('font', size=12)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=20)    # legend fontsize
plt.rc('figure', titlesize=20)  # fontsize of the figure title
#plt.grid()
plt.show()


plt.clf()
# Plot energy as a function of time
# (subtract energy at time t=0 to show energy drift)

plt.plot(t_exact_SHO,E_exact_SHO-E_exact_SHO[0],label='Verlet',color='black')
plt.plot(t_nn_1,E_nn_1-E_nn_1[0],label='$\Delta_v$',color='blue')
plt.plot(t_nn_2,E_nn_2-E_nn_2[0],label='$20\Delta_v$',color='orange')
plt.plot(t_nn_3,E_nn_3-E_nn_3[0],label='$40\Delta_v$',color='green')
plt.plot(t_nn_4,E_nn_4-E_nn_4[0],label='$100\Delta_v$',color='red')
plt.legend(loc='upper left')
ax = plt.gca()
ax.set_xlabel('time $t$')
ax.set_ylabel('energy shift $E(t)-E(t_0)$')
#ax.grid()
plt.rc('font', size=12)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=20)    # legend fontsize
plt.rc('figure', titlesize=20)  # fontsize of the figure title

plt.show()

#subplots of position versus velocity for all 4

plt.rcParams['figure.figsize'] = [10, 10]

plt.clf()
plt.plot(x_exact_SHO,v_exact_SHO,label='Verlet',color='black')
plt.plot(x_nn_1,v_nn_1,label='$\Delta_v$',color='blue')
plt.plot(x_nn_2,v_nn_2,label='$20\Delta_v$',color='orange')
plt.plot(x_nn_3,v_nn_3,label='$40\Delta_v$',color='green')
plt.plot(x_nn_4,v_nn_4,label='$100\Delta_v$',color='red')
plt.legend(loc='upper left')
ax = plt.gca()
ax.set_ylabel('Velocity $v(t)$')
ax.set_xlabel('Position $q(t)$')
plt.rc('font', size=12)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=20)    # legend fontsize
plt.rc('figure', titlesize=20)  # fontsize of the figure title
plt.show()

# %% [markdown]
# ## Plot trajectories generated to $t=512$ by Verlet integrator and neural

# %%
# Final time
T_final = 512

# Initial conditions
x = np.zeros(1)
v = np.zeros(1)
x[0] = 2.70
v[0] = -0.6
exact_SHO.set_state(x,v)

# ==== Verlet integrator ====
t = 0.0
t_exact_SHO = []
x_exact_SHO = []
v_exact_SHO = []
E_exact_SHO = []



while t<T_final:
    t_exact_SHO.append(t)
    E_exact_SHO.append(exact_SHO.energy())
    x_exact_SHO.append(exact_SHO.x[0])
    v_exact_SHO.append(exact_SHO.v[0])
    exact_SHO.integrate(1)
    t += dt_verlet
        

# ==== Neural network integrator ====

# Initialise with Verlet integrator
x_initial_1 = np.zeros((nn_integrator_1.nsteps,nn_integrator_1.dynamical_system.dim))
v_initial_1 = np.zeros((nn_integrator_1.nsteps,nn_integrator_1.dynamical_system.dim))
x_initial_2 = np.zeros((nn_integrator_2.nsteps,nn_integrator_2.dynamical_system.dim))
v_initial_2 = np.zeros((nn_integrator_2.nsteps,nn_integrator_2.dynamical_system.dim))
x_initial_3 = np.zeros((nn_integrator_3.nsteps,nn_integrator_3.dynamical_system.dim))
v_initial_3 = np.zeros((nn_integrator_3.nsteps,nn_integrator_3.dynamical_system.dim))
x_initial_4 = np.zeros((nn_integrator_4.nsteps,nn_integrator_4.dynamical_system.dim))
v_initial_4 = np.zeros((nn_integrator_4.nsteps,nn_integrator_4.dynamical_system.dim))



exact_SHO.set_state(x,v)
for k in range(nn_integrator_1.nsteps):    
    x_initial_1[k,:] = exact_SHO.x[:]
    v_initial_1[k,:] = exact_SHO.v[:]
    exact_SHO.integrate(int(dt_1/dt_verlet))
exact_SHO.set_state(x,v)
for k in range(nn_integrator_2.nsteps):    
    x_initial_2[k,:] = exact_SHO.x[:]
    v_initial_2[k,:] = exact_SHO.v[:]
    exact_SHO.integrate(int(dt_2/dt_verlet))
exact_SHO.set_state(x,v)
for k in range(nn_integrator_3.nsteps):    
    x_initial_3[k,:] = exact_SHO.x[:]
    v_initial_3[k,:] = exact_SHO.v[:]
    exact_SHO.integrate(int(dt_3/dt_verlet))
exact_SHO.set_state(x,v)
for k in range(nn_integrator_4.nsteps):    
    x_initial_4[k,:] = exact_SHO.x[:]
    v_initial_4[k,:] = exact_SHO.v[:]
    exact_SHO.integrate(int(dt_4/dt_verlet))


nn_integrator_1.set_state(x_initial_1,v_initial_1)
t_1 = (nn_integrator_1.nsteps-1)*nn_integrator_1.dt
nn_integrator_2.set_state(x_initial_2,v_initial_2)
t_2 = (nn_integrator_2.nsteps-1)*nn_integrator_2.dt
nn_integrator_3.set_state(x_initial_3,v_initial_3)
t_3 = (nn_integrator_3.nsteps-1)*nn_integrator_3.dt
nn_integrator_4.set_state(x_initial_4,v_initial_4)
t_4 = (nn_integrator_4.nsteps-1)*nn_integrator_4.dt



# Timestepping loop
t_nn_1 = []
x_nn_1 = []
v_nn_1 = []
E_nn_1 = []
t_nn_2 = []
x_nn_2 = []
v_nn_2 = []
E_nn_2 = []
t_nn_3 = []
x_nn_3 = []
v_nn_3 = []
E_nn_3 = []
t_nn_4 = []
x_nn_4 = []
v_nn_4 = []
E_nn_4 = []


while t_1<T_final:
    t_nn_1.append(t_1)
    x_nn_1.append(nn_integrator_1.x[0])
    v_nn_1.append(nn_integrator_1.v[0])
    E_nn_1.append(nn_integrator_1.energy())
    nn_integrator_1.integrate(1)
    t_1 += dt_1
while t_2<T_final:
    t_nn_2.append(t_2)
    x_nn_2.append(nn_integrator_2.x[0])
    v_nn_2.append(nn_integrator_2.v[0])
    E_nn_2.append(nn_integrator_2.energy())
    nn_integrator_2.integrate(1)
    t_2 += dt_2
while t_3<T_final:
    t_nn_3.append(t_3)
    x_nn_3.append(nn_integrator_3.x[0])
    v_nn_3.append(nn_integrator_3.v[0])
    E_nn_3.append(nn_integrator_3.energy())
    nn_integrator_3.integrate(1)
    t_3 += dt_3
while t_4<T_final:
    t_nn_4.append(t_4)
    x_nn_4.append(nn_integrator_4.x[0])
    v_nn_4.append(nn_integrator_4.v[0])
    E_nn_4.append(nn_integrator_4.energy())
    nn_integrator_4.integrate(1)
    t_4 += dt_4
 



x_nn_1 = np.array(x_nn_1)
x_nn_2 = np.array(x_nn_2)
x_nn_3 = np.array(x_nn_3)
x_nn_4 = np.array(x_nn_4)
x_exact_SHO = np.array(x_exact_SHO)
v_nn_1 = np.array(v_nn_1)
v_nn_2 = np.array(v_nn_2)
v_nn_3 = np.array(v_nn_3)
v_nn_4 = np.array(v_nn_4)
v_exact_SHO = np.array(v_exact_SHO)


# Plot position error as a function of time
plt.clf()
plt.rcParams['figure.figsize'] = [10, 10]

plt.plot(t_nn_1,x_nn_1-x_exact_SHO[int((nsteps-1)*dt_1/dt_verlet)::int(dt_1/dt_verlet)],label='$\Delta_v$',color='blue')
plt.plot(t_nn_2,x_nn_2-x_exact_SHO[int((nsteps-1)*dt_2/dt_verlet):int(np.size(x_exact_SHO)-dt_2/dt_verlet):int(dt_2/dt_verlet)],label='$20\Delta_v$',color='orange')
plt.plot(t_nn_3,x_nn_3-x_exact_SHO[int((nsteps-1)*dt_3/dt_verlet)::int(dt_3/dt_verlet)],label='$40\Delta_v$',color='green')
plt.plot(t_nn_4,x_nn_4-x_exact_SHO[int((nsteps-1)*dt_4/dt_verlet):int(np.size(x_exact_SHO)-dt_4/dt_verlet):int(dt_4/dt_verlet)],label='$100\Delta_v$',color='red')
plt.legend(loc='upper left')
ax = plt.gca()
ax.set_xlabel('time $t$')
ax.set_ylabel('position Error $x_{NN}(t)-x_V(t)$')
ax.set_title('Position Error')
plt.rc('font', size=12)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=20)    # legend fontsize
plt.rc('figure', titlesize=20)  # fontsize of the figure title
#plt.grid()
plt.show()

# Plot velocity error as a function of time

plt.plot(t_nn_1,v_nn_1-v_exact_SHO[int((nsteps-1)*dt_1/dt_verlet)::int(dt_1/dt_verlet)],label='$\Delta_v$',color='blue')
plt.plot(t_nn_2,v_nn_2-v_exact_SHO[int((nsteps-1)*dt_2/dt_verlet):int(np.size(v_exact_SHO)-dt_2/dt_verlet):int(dt_2/dt_verlet)],label='$20\Delta_v$',color='orange')
plt.plot(t_nn_3,v_nn_3-v_exact_SHO[int((nsteps-1)*dt_3/dt_verlet)::int(dt_3/dt_verlet)],label='$40\Delta_v$',color='green')
plt.plot(t_nn_4,v_nn_4-v_exact_SHO[int((nsteps-1)*dt_4/dt_verlet):int(np.size(v_exact_SHO)-dt_4/dt_verlet):int(dt_4/dt_verlet)],label='$100\Delta_v$',color='red')
plt.legend(loc='upper left')
ax = plt.gca()
ax.set_xlabel('time $t$')
ax.set_ylabel('Velocity Error $v_{NN}(t)-v_V(t)$')
ax.set_title('Velocity Error')
plt.rc('font', size=12)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=20)    # legend fontsize
plt.rc('figure', titlesize=20)  # fontsize of the figure title
#plt.grid()
plt.show()

# Plot L2 error as a function of time

plt.plot(t_nn_1,((v_nn_1-v_exact_SHO[int((nsteps-1)*dt_1/dt_verlet)::int(dt_1/dt_verlet)])**2+(x_nn_1-x_exact_SHO[int((nsteps-1)*dt_1/dt_verlet)::int(dt_1/dt_verlet)])**2)**0.5,label='$\Delta_v$',color='blue')
plt.plot(t_nn_2,((v_nn_2-v_exact_SHO[int((nsteps-1)*dt_2/dt_verlet):int(np.size(v_exact_SHO)-dt_2/dt_verlet):int(dt_2/dt_verlet)])**2+(x_nn_2-x_exact_SHO[int((nsteps-1)*dt_2/dt_verlet):int(np.size(x_exact_SHO)-dt_2/dt_verlet):int(dt_2/dt_verlet)])**2)**0.5,label='$20\Delta_v$',color='orange')
plt.plot(t_nn_3,((v_nn_3-v_exact_SHO[int((nsteps-1)*dt_3/dt_verlet)::int(dt_3/dt_verlet)])**2+(x_nn_3-x_exact_SHO[int((nsteps-1)*dt_3/dt_verlet)::int(dt_3/dt_verlet)])**2)**0.5,label='$40\Delta_v$',color='green')
plt.plot(t_nn_4,((v_nn_4-v_exact_SHO[int((nsteps-1)*dt_4/dt_verlet):int(np.size(v_exact_SHO)-dt_4/dt_verlet):int(dt_4/dt_verlet)])**2+(x_nn_4-x_exact_SHO[int((nsteps-1)*dt_4/dt_verlet):int(np.size(x_exact_SHO)-dt_4/dt_verlet):int(dt_4/dt_verlet)])**2)**0.5,label='$100\Delta_v$',color='red')
plt.legend(loc='upper left')
ax = plt.gca()
ax.set_xlabel('time $t$')
ax.set_ylabel('L2 Error')
ax.set_title('L2 Error')
plt.rc('font', size=12)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=20)    # legend fontsize
plt.rc('figure', titlesize=20)  # fontsize of the figure title
#plt.grid()
plt.show()


plt.clf()
# Plot energy as a function of time
# (subtract energy at time t=0 to show energy drift)

plt.plot(t_exact_SHO,E_exact_SHO-E_exact_SHO[0],label='Verlet',color='black')
plt.plot(t_nn_1,E_nn_1-E_nn_1[0],label='$\Delta_v$',color='blue')
plt.plot(t_nn_2,E_nn_2-E_nn_2[0],label='$20\Delta_v$',color='orange')
plt.plot(t_nn_3,E_nn_3-E_nn_3[0],label='$40\Delta_v$',color='green')
plt.plot(t_nn_4,E_nn_4-E_nn_4[0],label='$100\Delta_v$',color='red')
plt.legend(loc='upper left')
ax = plt.gca()
ax.set_xlabel('time $t$')
ax.set_ylabel('energy shift $E(t)-E(t_0)$')
#ax.grid()
plt.rc('font', size=12)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=20)    # legend fontsize
plt.rc('figure', titlesize=20)  # fontsize of the figure title

plt.show()

#subplots of position versus velocity for all 4

plt.rcParams['figure.figsize'] = [10, 10]

plt.clf()
plt.plot(x_exact_SHO,v_exact_SHO,label='Verlet',color='black')
plt.plot(x_nn_1,v_nn_1,label='$\Delta_v$',color='blue')
plt.plot(x_nn_2,v_nn_2,label='$20\Delta_v$',color='orange')
plt.plot(x_nn_3,v_nn_3,label='$40\Delta_v$',color='green')
plt.plot(x_nn_4,v_nn_4,label='$100\Delta_v$',color='red')
plt.legend(loc='upper left')
ax = plt.gca()
ax.set_ylabel('Velocity $v(t)$')
ax.set_xlabel('Position $q(t)$')
plt.rc('font', size=12)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=20)    # legend fontsize
plt.rc('figure', titlesize=20)  # fontsize of the figure title
plt.show()
