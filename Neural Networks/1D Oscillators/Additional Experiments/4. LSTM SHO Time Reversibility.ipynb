# %% [markdown]
# # Neural network based integrator time-reversibility

# %%
import sys
sys.path.append('..')

import numpy as np
from matplotlib import pyplot as plt
from Code.dynamical_system import *
from Code.time_integrator import *
from Code.neuralnet import *

np.random.seed(2512517)

# %% [markdown]
# ## Recurrent neural network integrator
# This class is used to evaluate the time-reversed performance of the LSTM neural network integrator.

# %% [markdown]
# Set system parameters, construct dynamical system and integrator.
#
# The model system we are using here is the harmonic oscillator, defined by the equations of motion
#
# $$
# \frac{dx}{dt} = v,\qquad\qquad
# \frac{dv}{dt} = -\frac{k}{m}x
# $$
#
# The timestep size of the Neural network integrator is set to $\Delta t=\Delta t_{\text{Verlet}}$ where $\Delta t_{\text{Verlet}}$ is the step size of the Verlet integrator that is used for training.

# %%
# mass of particle
mass = 1.2
# spring constant of harmonic oscillator
k_spring = 0.9
# timestep for Verlet integrator
dt_verlet = 0.005
# timestep for neural network integrator
dt_1 = dt_verlet

# number of steps for neural network integrator
nsteps = 5

harmonic_oscillator = HarmonicOscillator(mass,k_spring)

verlet_SHO = VerletIntegrator(harmonic_oscillator,dt_verlet)

nn_integrator_1 = LSTMFinalIntegrator(harmonic_oscillator,nsteps,dt_1)

#Reversed neural network

nn_integrator_2 = LSTMFinalIntegrator(harmonic_oscillator,nsteps,-dt_1)


# visualise the neural network model
nn_integrator_1.model.summary()
keras.utils.plot_model(nn_integrator_1.model, show_shapes=True)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 5, 2)]       0           []
#
#  lstm (LSTM)                    (None, 5, 32)        4480        ['input_1[0][0]']
#
#  lstm_1 (LSTM)                  (None, 32)           8320        ['lstm[0][0]']
#
#  dense (Dense)                  (None, 64)           2112        ['lstm_1[0][0]']
#
#  dense_1 (Dense)                (None, 2)            130         ['dense[0][0]']
#
#  tf.unstack (TFOpLambda)        [(None, 2),          0           ['input_1[0][0]']
#                                  (None, 2),
#                                  (None, 2),
#                                  (None, 2),
#                                  (None, 2)]
#
#  rescaling (Rescaling)          (None, 2)            0           ['dense_1[0][0]']
#
#  add (Add)                      (None, 2)            0           ['tf.unstack[0][4]',
#                                                                   'rescaling[0][0]']
#
# ==================================================================================================
# Total params: 15,042
# Trainable params: 15,042
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
BATCH_SIZE=64

data_generator_1 = DataGenerator(nn_integrator_1,verlet_SHO)
train_batches_1 = data_generator_1.dataset.batch(BATCH_SIZE)

# %% [markdown]
# ## Train neural network based integrator

# %%
EPOCHS=300
STEPS_PER_EPOCH=100
log_dir = './tb_logs/'
tensorboard_cb = tf.keras.callbacks.TensorBoard(log_dir=log_dir)

result_1 = nn_integrator_1.model.fit(train_batches_1,epochs=EPOCHS,steps_per_epoch=STEPS_PER_EPOCH,
                                 callbacks=tensorboard_cb)
# Out:
# Epoch 1/300
# 100/100 [==============================] - 9s 36ms/step - loss: 6.0412e-05
# Epoch 2/300
# 100/100 [==============================] - 4s 39ms/step - loss: 4.2029e-05
# Epoch 3/300
# 100/100 [==============================] - 4s 37ms/step - loss: 2.3710e-05
# Epoch 4/300
# 100/100 [==============================] - 4s 38ms/step - loss: 1.7620e-05
# Epoch 5/300
# 100/100 [==============================] - 4s 37ms/step - loss: 1.4736e-05
# Epoch 6/300
# 100/100 [==============================] - 4s 36ms/step - loss: 1.3647e-05
# Epoch 7/300
# 100/100 [==============================] - 4s 39ms/step - loss: 1.0243e-05
# Epoch 8/300
# 100/100 [==============================] - 4s 37ms/step - loss: 7.6129e-06
# Epoch 9/300
# 100/100 [==============================] - 4s 36ms/step - loss: 4.9098e-06
# Epoch 10/300
# 100/100 [==============================] - 4s 37ms/step - loss: 3.1071e-06
# Epoch 11/300
# 100/100 [==============================] - 4s 38ms/step - loss: 2.6247e-06
# Epoch 12/300
# 100/100 [==============================] - 4s 41ms/step - loss: 2.1080e-06
# Epoch 13/300
# 100/100 [==============================] - 4s 37ms/step - loss: 1.9485e-06
# Epoch 14/300
# 100/100 [==============================] - 4s 36ms/step - loss: 1.5347e-06
# Epoch 15/300
# 100/100 [==============================] - 4s 36ms/step - loss: 1.3248e-06
# Epoch 16/300
# 100/100 [==============================] - 3s 35ms/step - loss: 1.2101e-06
# Epoch 17/300
# 100/100 [==============================] - 3s 35ms/step - loss: 9.8676e-07
# Epoch 18/300
# 100/100 [==============================] - 4s 35ms/step - loss: 8.8655e-07
# Epoch 19/300
# 100/100 [==============================] - 3s 35ms/step - loss: 8.0425e-07
# Epoch 20/300
# 100/100 [==============================] - 3s 34ms/step - loss: 6.3580e-07
# Epoch 21/300
# 100/100 [==============================] - 4s 36ms/step - loss: 6.0487e-07
# Epoch 22/300
# 100/100 [==============================] - 4s 35ms/step - loss: 5.6946e-07
# Epoch 23/300
# 100/100 [==============================] - 4s 38ms/step - loss: 4.6792e-07
# Epoch 24/300
# 100/100 [==============================] - 4s 37ms/step - loss: 4.2901e-07
# Epoch 25/300
# 100/100 [==============================] - 4s 36ms/step - loss: 4.0525e-07
# Epoch 26/300
# 100/100 [==============================] - 4s 36ms/step - loss: 3.6551e-07
# Epoch 27/300
# 100/100 [==============================] - 4s 38ms/step - loss: 3.5430e-07
# Epoch 28/300
# 100/100 [==============================] - 4s 36ms/step - loss: 2.8720e-07
# Epoch 29/300
# 100/100 [==============================] - 4s 36ms/step - loss: 2.7409e-07
# Epoch 30/300
# 100/100 [==============================] - 4s 36ms/step - loss: 2.6492e-07
# Epoch 31/300
# 100/100 [==============================] - 4s 36ms/step - loss: 2.2495e-07
# Epoch 32/300
# 100/100 [==============================] - 4s 36ms/step - loss: 2.6355e-07
# Epoch 33/300
# 100/100 [==============================] - 4s 37ms/step - loss: 2.1183e-07
# Epoch 34/300
# 100/100 [==============================] - 4s 37ms/step - loss: 1.7762e-07
# Epoch 35/300
# 100/100 [==============================] - 4s 36ms/step - loss: 1.8142e-07
# Epoch 36/300
# 100/100 [==============================] - 4s 38ms/step - loss: 1.6584e-07
# Epoch 37/300
# 100/100 [==============================] - 3s 35ms/step - loss: 1.6873e-07
# Epoch 38/300
# 100/100 [==============================] - 4s 37ms/step - loss: 1.4406e-07
# Epoch 39/300
# 100/100 [==============================] - 4s 37ms/step - loss: 1.6746e-07
# Epoch 40/300
# 100/100 [==============================] - 4s 35ms/step - loss: 1.1920e-07
# Epoch 41/300
# 100/100 [==============================] - 4s 38ms/step - loss: 1.2454e-07
# Epoch 42/300
# 100/100 [==============================] - 4s 38ms/step - loss: 1.4778e-07
# Epoch 43/300
# 100/100 [==============================] - 4s 36ms/step - loss: 1.1913e-07
# Epoch 44/300
# 100/100 [==============================] - 4s 37ms/step - loss: 1.0544e-07
# Epoch 45/300
# 100/100 [==============================] - 4s 36ms/step - loss: 9.3115e-08
# Epoch 46/300
# 100/100 [==============================] - 3s 35ms/step - loss: 9.3183e-08
# Epoch 47/300
# 100/100 [==============================] - 4s 36ms/step - loss: 8.9337e-08
# Epoch 48/300
# 100/100 [==============================] - 4s 36ms/step - loss: 9.5111e-08
# Epoch 49/300
# 100/100 [==============================] - 4s 37ms/step - loss: 7.8079e-08
# Epoch 50/300
# 100/100 [==============================] - 3s 35ms/step - loss: 8.4439e-08
# Epoch 51/300
# 100/100 [==============================] - 4s 35ms/step - loss: 6.9208e-08
# Epoch 52/300
# 100/100 [==============================] - 3s 35ms/step - loss: 8.5130e-08
# Epoch 53/300
# 100/100 [==============================] - 4s 36ms/step - loss: 6.7341e-08
# Epoch 54/300
# 100/100 [==============================] - 4s 37ms/step - loss: 6.1383e-08
# Epoch 55/300
# 100/100 [==============================] - 4s 36ms/step - loss: 5.5280e-08
# Epoch 56/300
# 100/100 [==============================] - 4s 36ms/step - loss: 6.9146e-08
# Epoch 57/300
# 100/100 [==============================] - 4s 38ms/step - loss: 5.6807e-08
# Epoch 58/300
# 100/100 [==============================] - 4s 37ms/step - loss: 5.2360e-08
# Epoch 59/300
# 100/100 [==============================] - 4s 38ms/step - loss: 7.4756e-08
# Epoch 60/300
# 100/100 [==============================] - 4s 39ms/step - loss: 5.2448e-08
# Epoch 61/300
# 100/100 [==============================] - 4s 37ms/step - loss: 3.8592e-08
# Epoch 62/300
# 100/100 [==============================] - 4s 36ms/step - loss: 5.0338e-08
# Epoch 63/300
# 100/100 [==============================] - 4s 39ms/step - loss: 4.5534e-08
# Epoch 64/300
# 100/100 [==============================] - 4s 38ms/step - loss: 3.6510e-08
# Epoch 65/300
# 100/100 [==============================] - 4s 35ms/step - loss: 3.4533e-08
# Epoch 66/300
# 100/100 [==============================] - 4s 37ms/step - loss: 4.4395e-08
# Epoch 67/300
# 100/100 [==============================] - 4s 36ms/step - loss: 5.1669e-08
# Epoch 68/300
# 100/100 [==============================] - 4s 35ms/step - loss: 3.6750e-08
# Epoch 69/300
# 100/100 [==============================] - 4s 35ms/step - loss: 3.1562e-08
# Epoch 70/300
# 100/100 [==============================] - 4s 36ms/step - loss: 3.3974e-08
# Epoch 71/300
# 100/100 [==============================] - 4s 36ms/step - loss: 4.4663e-08
# Epoch 72/300
# 100/100 [==============================] - 4s 37ms/step - loss: 2.6787e-08
# Epoch 73/300
# 100/100 [==============================] - 4s 37ms/step - loss: 2.7877e-08
# Epoch 74/300
# 100/100 [==============================] - 4s 38ms/step - loss: 2.4618e-08
# Epoch 75/300
# 100/100 [==============================] - 4s 39ms/step - loss: 2.7784e-08
# Epoch 76/300
# 100/100 [==============================] - 4s 38ms/step - loss: 2.7623e-08
# Epoch 77/300
# 100/100 [==============================] - 4s 38ms/step - loss: 2.4931e-08
# Epoch 78/300
# 100/100 [==============================] - 4s 38ms/step - loss: 2.2275e-08
# Epoch 79/300
# 100/100 [==============================] - 4s 36ms/step - loss: 2.0617e-08
# Epoch 80/300
# 100/100 [==============================] - 4s 36ms/step - loss: 2.1490e-08
# Epoch 81/300
# 100/100 [==============================] - 4s 35ms/step - loss: 2.2444e-08
# Epoch 82/300
# 100/100 [==============================] - 4s 36ms/step - loss: 1.7588e-08
# Epoch 83/300
# 100/100 [==============================] - 4s 35ms/step - loss: 2.2400e-08
# Epoch 84/300
# 100/100 [==============================] - 4s 36ms/step - loss: 3.5516e-08
# Epoch 85/300
# 100/100 [==============================] - 4s 40ms/step - loss: 2.3436e-08
# Epoch 86/300
# 100/100 [==============================] - 4s 37ms/step - loss: 1.9840e-08
# Epoch 87/300
# 100/100 [==============================] - 4s 37ms/step - loss: 1.7498e-08
# Epoch 88/300
# 100/100 [==============================] - 4s 38ms/step - loss: 2.0174e-08
# Epoch 89/300
# 100/100 [==============================] - 4s 38ms/step - loss: 1.9696e-08
# Epoch 90/300
# 100/100 [==============================] - 4s 36ms/step - loss: 1.9169e-08
# Epoch 91/300
# 100/100 [==============================] - 4s 38ms/step - loss: 2.6040e-08
# Epoch 92/300
# 100/100 [==============================] - 4s 41ms/step - loss: 2.0081e-08
# Epoch 93/300
# 100/100 [==============================] - 4s 39ms/step - loss: 1.4443e-08
# Epoch 94/300
# 100/100 [==============================] - 4s 38ms/step - loss: 1.5077e-08
# Epoch 95/300
# 100/100 [==============================] - 4s 42ms/step - loss: 1.2277e-08
# Epoch 96/300
# 100/100 [==============================] - 4s 38ms/step - loss: 1.5861e-08
# Epoch 97/300
# 100/100 [==============================] - 4s 38ms/step - loss: 1.3315e-08
# Epoch 98/300
# 100/100 [==============================] - 4s 41ms/step - loss: 1.2573e-08
# Epoch 99/300
# 100/100 [==============================] - 4s 39ms/step - loss: 2.1552e-08
# Epoch 100/300
# 100/100 [==============================] - 4s 40ms/step - loss: 1.0360e-08
# Epoch 101/300
# 100/100 [==============================] - 4s 36ms/step - loss: 1.9267e-08
# Epoch 102/300
# 100/100 [==============================] - 4s 37ms/step - loss: 1.2240e-08
# Epoch 103/300
# 100/100 [==============================] - 4s 39ms/step - loss: 1.3592e-08
# Epoch 104/300
# 100/100 [==============================] - 4s 43ms/step - loss: 1.1818e-08
# Epoch 105/300
# 100/100 [==============================] - 4s 44ms/step - loss: 1.0369e-08
# Epoch 106/300
# 100/100 [==============================] - 4s 39ms/step - loss: 9.7947e-09
# Epoch 107/300
# 100/100 [==============================] - 4s 38ms/step - loss: 1.2129e-08
# Epoch 108/300
# 100/100 [==============================] - 4s 41ms/step - loss: 1.4778e-08
# Epoch 109/300
# 100/100 [==============================] - 4s 38ms/step - loss: 1.2225e-08
# Epoch 110/300
# 100/100 [==============================] - 4s 40ms/step - loss: 8.5973e-09
# Epoch 111/300
# 100/100 [==============================] - 4s 38ms/step - loss: 9.7074e-09
# Epoch 112/300
# 100/100 [==============================] - 4s 39ms/step - loss: 1.2334e-08
# Epoch 113/300
# 100/100 [==============================] - 4s 38ms/step - loss: 8.8912e-09
# Epoch 114/300
# 100/100 [==============================] - 4s 39ms/step - loss: 9.8783e-09
# Epoch 115/300
# 100/100 [==============================] - 4s 41ms/step - loss: 6.3001e-09
# Epoch 116/300
# 100/100 [==============================] - 4s 38ms/step - loss: 7.7476e-09
# Epoch 117/300
# 100/100 [==============================] - 4s 44ms/step - loss: 9.8206e-09
# Epoch 118/300
# 100/100 [==============================] - 4s 42ms/step - loss: 8.1567e-09
# Epoch 119/300
# 100/100 [==============================] - 4s 43ms/step - loss: 6.3036e-09
# Epoch 120/300
# 100/100 [==============================] - 4s 44ms/step - loss: 1.1230e-08
# Epoch 121/300
# 100/100 [==============================] - 4s 41ms/step - loss: 8.2261e-09
# Epoch 122/300
# 100/100 [==============================] - 5s 45ms/step - loss: 7.0271e-09
# Epoch 123/300
# 100/100 [==============================] - 4s 41ms/step - loss: 6.0829e-09
# Epoch 124/300
# 100/100 [==============================] - 4s 39ms/step - loss: 6.8396e-09
# Epoch 125/300
# 100/100 [==============================] - 4s 39ms/step - loss: 8.0816e-09
# Epoch 126/300
# 100/100 [==============================] - 4s 39ms/step - loss: 6.0561e-09
# Epoch 127/300
# 100/100 [==============================] - 4s 37ms/step - loss: 1.3570e-08
# Epoch 128/300
# 100/100 [==============================] - 4s 39ms/step - loss: 5.9011e-09
# Epoch 129/300
# 100/100 [==============================] - 4s 42ms/step - loss: 6.6337e-09
# Epoch 130/300
# 100/100 [==============================] - 4s 39ms/step - loss: 8.4736e-09
# Epoch 131/300
# 100/100 [==============================] - 4s 38ms/step - loss: 6.3841e-09
# Epoch 132/300
# 100/100 [==============================] - 4s 43ms/step - loss: 5.6361e-09
# Epoch 133/300
# 100/100 [==============================] - 4s 42ms/step - loss: 1.1988e-08
# Epoch 134/300
# 100/100 [==============================] - 4s 40ms/step - loss: 1.0250e-08
# Epoch 135/300
# 100/100 [==============================] - 5s 48ms/step - loss: 5.6373e-09
# Epoch 136/300
# 100/100 [==============================] - 5s 48ms/step - loss: 5.4098e-09
# Epoch 137/300
# 100/100 [==============================] - 4s 43ms/step - loss: 6.3156e-09
# Epoch 138/300
# 100/100 [==============================] - 4s 40ms/step - loss: 6.4417e-09
# Epoch 139/300
# 100/100 [==============================] - 4s 43ms/step - loss: 5.0752e-09
# Epoch 140/300
# 100/100 [==============================] - 4s 39ms/step - loss: 5.1378e-09
# Epoch 141/300
# 100/100 [==============================] - 4s 39ms/step - loss: 4.7211e-09
# Epoch 142/300
# 100/100 [==============================] - 4s 39ms/step - loss: 7.6352e-09
# Epoch 143/300
# 100/100 [==============================] - 4s 38ms/step - loss: 6.6990e-09
# Epoch 144/300
# 100/100 [==============================] - 4s 38ms/step - loss: 1.0146e-08
# Epoch 145/300
# 100/100 [==============================] - 4s 38ms/step - loss: 4.3793e-09
# Epoch 146/300
# 100/100 [==============================] - 4s 38ms/step - loss: 4.1108e-09
# Epoch 147/300
# 100/100 [==============================] - 4s 39ms/step - loss: 7.3972e-09
# Epoch 148/300
# 100/100 [==============================] - 4s 37ms/step - loss: 7.2794e-09
# Epoch 149/300
# 100/100 [==============================] - 4s 38ms/step - loss: 6.5820e-09
# Epoch 150/300
# 100/100 [==============================] - 4s 39ms/step - loss: 4.1956e-09
# Epoch 151/300
# 100/100 [==============================] - 4s 40ms/step - loss: 4.2586e-09
# Epoch 152/300
# 100/100 [==============================] - 4s 40ms/step - loss: 7.7320e-09
# Epoch 153/300
# 100/100 [==============================] - 4s 38ms/step - loss: 5.9030e-09
# Epoch 154/300
# 100/100 [==============================] - 4s 37ms/step - loss: 9.1828e-09
# Epoch 155/300
# 100/100 [==============================] - 4s 37ms/step - loss: 6.9563e-09
# Epoch 156/300
# 100/100 [==============================] - 4s 38ms/step - loss: 6.9202e-09
# Epoch 157/300
# 100/100 [==============================] - 4s 40ms/step - loss: 5.2755e-09
# Epoch 158/300
# 100/100 [==============================] - 4s 44ms/step - loss: 5.7109e-09
# Epoch 159/300
# 100/100 [==============================] - 4s 40ms/step - loss: 8.9716e-09
# Epoch 160/300
# 100/100 [==============================] - 4s 39ms/step - loss: 5.0715e-09
# Epoch 161/300
# 100/100 [==============================] - 4s 38ms/step - loss: 4.4371e-09
# Epoch 162/300
# 100/100 [==============================] - 4s 41ms/step - loss: 3.4099e-09
# Epoch 163/300
# 100/100 [==============================] - 5s 45ms/step - loss: 3.7045e-09
# Epoch 164/300
# 100/100 [==============================] - 4s 40ms/step - loss: 6.2165e-09
# Epoch 165/300
# 100/100 [==============================] - 4s 41ms/step - loss: 5.7273e-09
# Epoch 166/300
# 100/100 [==============================] - 5s 46ms/step - loss: 4.7991e-09
# Epoch 167/300
# 100/100 [==============================] - 4s 40ms/step - loss: 5.1047e-09
# Epoch 168/300
# 100/100 [==============================] - 4s 40ms/step - loss: 3.8493e-09
# Epoch 169/300
# 100/100 [==============================] - 4s 40ms/step - loss: 3.1513e-09
# Epoch 170/300
# 100/100 [==============================] - 4s 38ms/step - loss: 2.8680e-09
# Epoch 171/300
# 100/100 [==============================] - 4s 37ms/step - loss: 4.3190e-09
# Epoch 172/300
# 100/100 [==============================] - 4s 38ms/step - loss: 4.0240e-09
# Epoch 173/300
# 100/100 [==============================] - 4s 37ms/step - loss: 2.4772e-09
# Epoch 174/300
# 100/100 [==============================] - 4s 37ms/step - loss: 3.3392e-09
# Epoch 175/300
# 100/100 [==============================] - 4s 38ms/step - loss: 4.7496e-09
# Epoch 176/300
# 100/100 [==============================] - 4s 38ms/step - loss: 3.5171e-09
# Epoch 177/300
# 100/100 [==============================] - 4s 40ms/step - loss: 2.6433e-09
# Epoch 178/300
# 100/100 [==============================] - 4s 36ms/step - loss: 3.0868e-09
# Epoch 179/300
# 100/100 [==============================] - 4s 38ms/step - loss: 3.5918e-09
# Epoch 180/300
# 100/100 [==============================] - 4s 40ms/step - loss: 3.4609e-09
# Epoch 181/300
# 100/100 [==============================] - 4s 40ms/step - loss: 6.2886e-09
# Epoch 182/300
# 100/100 [==============================] - 4s 40ms/step - loss: 2.2210e-09
# Epoch 183/300
# 100/100 [==============================] - 4s 39ms/step - loss: 4.7259e-09
# Epoch 184/300
# 100/100 [==============================] - 4s 39ms/step - loss: 4.9038e-09
# Epoch 185/300
# 100/100 [==============================] - 4s 42ms/step - loss: 3.9913e-09
# Epoch 186/300
# 100/100 [==============================] - 4s 42ms/step - loss: 4.9721e-09
# Epoch 187/300
# 100/100 [==============================] - 4s 43ms/step - loss: 3.9395e-09
# Epoch 188/300
# 100/100 [==============================] - 4s 38ms/step - loss: 3.7222e-09
# Epoch 189/300
# 100/100 [==============================] - 4s 38ms/step - loss: 2.6859e-09
# Epoch 190/300
# 100/100 [==============================] - 4s 38ms/step - loss: 4.6699e-09
# Epoch 191/300
# 100/100 [==============================] - 4s 37ms/step - loss: 2.9365e-09
# Epoch 192/300
# 100/100 [==============================] - 4s 37ms/step - loss: 4.0453e-09
# Epoch 193/300
# 100/100 [==============================] - 4s 37ms/step - loss: 3.4224e-09
# Epoch 194/300
# 100/100 [==============================] - 4s 40ms/step - loss: 4.1168e-09
# Epoch 195/300
# 100/100 [==============================] - 4s 40ms/step - loss: 3.6607e-09
# Epoch 196/300
# 100/100 [==============================] - 4s 39ms/step - loss: 4.9193e-09
# Epoch 197/300
# 100/100 [==============================] - 4s 39ms/step - loss: 3.9056e-09
# Epoch 198/300
# 100/100 [==============================] - 4s 40ms/step - loss: 4.0983e-09
# Epoch 199/300
# 100/100 [==============================] - 4s 38ms/step - loss: 8.0475e-09
# Epoch 200/300
# 100/100 [==============================] - 4s 39ms/step - loss: 2.5540e-09
# Epoch 201/300
# 100/100 [==============================] - 4s 38ms/step - loss: 7.9582e-09
# Epoch 202/300
# 100/100 [==============================] - 4s 38ms/step - loss: 1.9943e-09
# Epoch 203/300
# 100/100 [==============================] - 4s 40ms/step - loss: 4.0993e-09
# Epoch 204/300
# 100/100 [==============================] - 4s 39ms/step - loss: 3.0876e-09
# Epoch 205/300
# 100/100 [==============================] - 4s 37ms/step - loss: 3.1510e-09
# Epoch 206/300
# 100/100 [==============================] - 4s 38ms/step - loss: 3.3723e-09
# Epoch 207/300
# 100/100 [==============================] - 4s 39ms/step - loss: 1.9978e-09
# Epoch 208/300
# 100/100 [==============================] - 4s 41ms/step - loss: 3.6457e-09
# Epoch 209/300
# 100/100 [==============================] - 4s 38ms/step - loss: 3.4798e-09
# Epoch 210/300
# 100/100 [==============================] - 4s 38ms/step - loss: 3.2988e-09
# Epoch 211/300
# 100/100 [==============================] - 4s 37ms/step - loss: 3.2246e-09
# Epoch 212/300
# 100/100 [==============================] - 4s 38ms/step - loss: 4.9619e-09
# Epoch 213/300
# 100/100 [==============================] - 4s 38ms/step - loss: 5.2484e-09
# Epoch 214/300
# 100/100 [==============================] - 4s 40ms/step - loss: 5.1021e-09
# Epoch 215/300
# 100/100 [==============================] - 4s 40ms/step - loss: 3.0857e-09
# Epoch 216/300
# 100/100 [==============================] - 4s 39ms/step - loss: 3.7245e-09
# Epoch 217/300
# 100/100 [==============================] - 4s 40ms/step - loss: 1.7499e-09
# Epoch 218/300
# 100/100 [==============================] - 4s 41ms/step - loss: 4.3436e-09
# Epoch 219/300
# 100/100 [==============================] - 4s 38ms/step - loss: 2.8157e-09
# Epoch 220/300
# 100/100 [==============================] - 4s 40ms/step - loss: 4.9095e-09
# Epoch 221/300
# 100/100 [==============================] - 4s 40ms/step - loss: 2.3111e-09
# Epoch 222/300
# 100/100 [==============================] - 4s 38ms/step - loss: 6.2037e-09
# Epoch 223/300
# 100/100 [==============================] - 4s 38ms/step - loss: 2.3458e-09
# Epoch 224/300
# 100/100 [==============================] - 4s 37ms/step - loss: 2.2892e-09
# Epoch 225/300
# 100/100 [==============================] - 4s 39ms/step - loss: 2.2511e-09
# Epoch 226/300
# 100/100 [==============================] - 4s 39ms/step - loss: 5.1914e-09
# Epoch 227/300
# 100/100 [==============================] - 4s 38ms/step - loss: 2.9475e-09
# Epoch 228/300
# 100/100 [==============================] - 4s 40ms/step - loss: 2.9532e-09
# Epoch 229/300
# 100/100 [==============================] - 4s 40ms/step - loss: 2.6517e-09
# Epoch 230/300
# 100/100 [==============================] - 4s 38ms/step - loss: 2.4385e-09
# Epoch 231/300
# 100/100 [==============================] - 4s 36ms/step - loss: 4.9021e-09
# Epoch 232/300
# 100/100 [==============================] - 4s 37ms/step - loss: 1.6955e-09
# Epoch 233/300
# 100/100 [==============================] - 4s 37ms/step - loss: 2.9055e-09
# Epoch 234/300
# 100/100 [==============================] - 4s 39ms/step - loss: 3.3336e-09
# Epoch 235/300
# 100/100 [==============================] - 4s 39ms/step - loss: 2.0877e-09
# Epoch 236/300
# 100/100 [==============================] - 4s 38ms/step - loss: 3.2433e-09
# Epoch 237/300
# 100/100 [==============================] - 4s 38ms/step - loss: 1.6470e-09
# Epoch 238/300
# 100/100 [==============================] - 4s 37ms/step - loss: 2.6560e-09
# Epoch 239/300
# 100/100 [==============================] - 4s 37ms/step - loss: 4.2966e-09
# Epoch 240/300
# 100/100 [==============================] - 4s 38ms/step - loss: 1.8957e-09
# Epoch 241/300
# 100/100 [==============================] - 4s 38ms/step - loss: 2.4528e-09
# Epoch 242/300
# 100/100 [==============================] - 4s 43ms/step - loss: 3.4625e-09
# Epoch 243/300
# 100/100 [==============================] - 4s 39ms/step - loss: 1.6172e-09
# Epoch 244/300
# 100/100 [==============================] - 4s 37ms/step - loss: 4.1058e-09
# Epoch 245/300
# 100/100 [==============================] - 4s 38ms/step - loss: 2.2944e-09
# Epoch 246/300
# 100/100 [==============================] - 4s 39ms/step - loss: 2.4277e-09
# Epoch 247/300
# 100/100 [==============================] - 4s 40ms/step - loss: 1.9606e-09
# Epoch 248/300
# 100/100 [==============================] - 4s 37ms/step - loss: 2.2572e-09
# Epoch 249/300
# 100/100 [==============================] - 4s 39ms/step - loss: 4.0564e-09
# Epoch 250/300
# 100/100 [==============================] - 4s 37ms/step - loss: 7.6104e-09
# Epoch 251/300
# 100/100 [==============================] - 4s 38ms/step - loss: 1.6152e-09
# Epoch 252/300
# 100/100 [==============================] - 4s 39ms/step - loss: 1.8463e-09
# Epoch 253/300
# 100/100 [==============================] - 4s 38ms/step - loss: 2.2735e-09
# Epoch 254/300
# 100/100 [==============================] - 4s 38ms/step - loss: 3.4902e-09
# Epoch 255/300
# 100/100 [==============================] - 4s 40ms/step - loss: 1.6204e-09
# Epoch 256/300
# 100/100 [==============================] - 4s 40ms/step - loss: 1.5351e-09
# Epoch 257/300
# 100/100 [==============================] - 4s 38ms/step - loss: 2.2869e-09
# Epoch 258/300
# 100/100 [==============================] - 4s 39ms/step - loss: 2.6969e-09
# Epoch 259/300
# 100/100 [==============================] - 4s 40ms/step - loss: 1.3348e-09
# Epoch 260/300
# 100/100 [==============================] - 4s 41ms/step - loss: 1.7350e-09
# Epoch 261/300
# 100/100 [==============================] - 4s 39ms/step - loss: 2.1353e-09
# Epoch 262/300
# 100/100 [==============================] - 5s 45ms/step - loss: 3.1282e-09
# Epoch 263/300
# 100/100 [==============================] - 4s 40ms/step - loss: 2.4801e-09
# Epoch 264/300
# 100/100 [==============================] - 4s 40ms/step - loss: 3.5089e-09
# Epoch 265/300
# 100/100 [==============================] - 4s 41ms/step - loss: 2.4048e-09
# Epoch 266/300
# 100/100 [==============================] - 4s 40ms/step - loss: 1.8043e-09
# Epoch 267/300
# 100/100 [==============================] - 4s 40ms/step - loss: 5.7380e-09
# Epoch 268/300
# 100/100 [==============================] - 4s 39ms/step - loss: 3.2971e-09
# Epoch 269/300
# 100/100 [==============================] - 5s 45ms/step - loss: 2.2514e-09
# Epoch 270/300
# 100/100 [==============================] - 4s 39ms/step - loss: 1.8012e-09
# Epoch 271/300
# 100/100 [==============================] - 4s 42ms/step - loss: 2.5141e-09
# Epoch 272/300
# 100/100 [==============================] - 4s 41ms/step - loss: 3.0972e-09
# Epoch 273/300
# 100/100 [==============================] - 4s 39ms/step - loss: 2.6131e-09
# Epoch 274/300
# 100/100 [==============================] - 4s 40ms/step - loss: 1.4463e-09
# Epoch 275/300
# 100/100 [==============================] - 4s 38ms/step - loss: 1.2875e-09
# Epoch 276/300
# 100/100 [==============================] - 4s 39ms/step - loss: 3.8254e-09
# Epoch 277/300
# 100/100 [==============================] - 4s 38ms/step - loss: 2.1747e-09
# Epoch 278/300
# 100/100 [==============================] - 4s 37ms/step - loss: 8.6542e-10
# Epoch 279/300
# 100/100 [==============================] - 4s 39ms/step - loss: 1.6022e-09
# Epoch 280/300
# 100/100 [==============================] - 4s 41ms/step - loss: 1.7628e-09
# Epoch 281/300
# 100/100 [==============================] - 4s 41ms/step - loss: 2.5322e-09
# Epoch 282/300
# 100/100 [==============================] - 4s 40ms/step - loss: 1.7624e-09
# Epoch 283/300
# 100/100 [==============================] - 4s 39ms/step - loss: 3.4442e-09
# Epoch 284/300
# 100/100 [==============================] - 4s 40ms/step - loss: 6.0698e-09
# Epoch 285/300
# 100/100 [==============================] - 4s 39ms/step - loss: 2.1635e-09
# Epoch 286/300
# 100/100 [==============================] - 4s 38ms/step - loss: 1.7916e-09
# Epoch 287/300
# 100/100 [==============================] - 4s 39ms/step - loss: 9.9567e-10
# Epoch 288/300
# 100/100 [==============================] - 4s 42ms/step - loss: 1.5762e-09
# Epoch 289/300
# 100/100 [==============================] - 4s 39ms/step - loss: 1.5345e-09
# Epoch 290/300
# 100/100 [==============================] - 4s 38ms/step - loss: 2.3954e-09
# Epoch 291/300
# 100/100 [==============================] - 4s 38ms/step - loss: 5.1841e-09
# Epoch 292/300
# 100/100 [==============================] - 4s 39ms/step - loss: 1.7412e-09
# Epoch 293/300
# 100/100 [==============================] - 4s 39ms/step - loss: 3.4666e-09
# Epoch 294/300
# 100/100 [==============================] - 4s 37ms/step - loss: 1.8526e-09
# Epoch 295/300
# 100/100 [==============================] - 4s 37ms/step - loss: 1.7877e-09
# Epoch 296/300
# 100/100 [==============================] - 4s 38ms/step - loss: 1.7950e-09
# Epoch 297/300
# 100/100 [==============================] - 4s 38ms/step - loss: 1.6136e-09
# Epoch 298/300
# 100/100 [==============================] - 4s 38ms/step - loss: 2.0413e-09
# Epoch 299/300
# 100/100 [==============================] - 4s 40ms/step - loss: 2.7689e-09
# Epoch 300/300
# 100/100 [==============================] - 4s 42ms/step - loss: 2.7185e-09

# %% [markdown]
# ## Visualise Loss function

# %%
#print(result.history.keys())

plt.rcParams['figure.figsize'] = [10, 10]

# summarize history for loss
plt.plot(result_1.history['loss'])


plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.rc('font', size=12)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=20)    # legend fontsize
plt.rc('figure', titlesize=20)  # fontsize of the figure title
plt.legend(['$\Delta_v$'], loc='upper left')
plt.yscale("log")
plt.show()

# %% [markdown]
# ## Plot trajectories generated to $t=32$ by Verlet integrator and neural

# %%
# Final time
T_final = 32

# Initial conditions
x = np.zeros(1)
v = np.zeros(1)
x[0] = 2.70
v[0] = -0.6
verlet_SHO.set_state(x,v)

#Save the weights of the nn integrator for later

nn_integrator_1.model.save_weights('forward_weights.h5')


# ==== Verlet integrator ====
t = 0.0
t_verlet_SHO = []
x_verlet_SHO = []
v_verlet_SHO = []
E_verlet_SHO = []



while t<T_final:
    t_verlet_SHO.append(t)
    E_verlet_SHO.append(verlet_SHO.energy())
    x_verlet_SHO.append(verlet_SHO.x[0])
    v_verlet_SHO.append(verlet_SHO.v[0])
    verlet_SHO.integrate(1)
    t += dt_verlet
        

# ==== Neural network integrator ====

#Forward integration direction
nn_integrator_1.dt = dt_1

# Initialise with Verlet integrator
x_initial_1 = np.zeros((nn_integrator_1.nsteps,nn_integrator_1.dynamical_system.dim))
v_initial_1 = np.zeros((nn_integrator_1.nsteps,nn_integrator_1.dynamical_system.dim))
t_nn_1 = []
x_nn_1 = []
v_nn_1 = []
E_nn_1 = []

verlet_SHO.set_state(x,v)
for k in range(nn_integrator_1.nsteps):    
    x_initial_1[k,:] = verlet_SHO.x[:]
    v_initial_1[k,:] = verlet_SHO.v[:]
    verlet_SHO.integrate(int(dt_1/dt_verlet))

nn_integrator_1.set_state(x_initial_1,v_initial_1)
t_1 = (nn_integrator_1.nsteps-1)*nn_integrator_1.dt


#Integrate forwards in time using NN

while t_1<T_final:
    t_nn_1.append(t_1)
    x_nn_1.append(nn_integrator_1.x[0])
    v_nn_1.append(nn_integrator_1.v[0])
    E_nn_1.append(nn_integrator_1.energy())
    nn_integrator_1.integrate(1)
    t_1 += dt_1

# %% [markdown]
# ##Plot reversed time network integration

# %%
#Replicate weights in forward-time NN into backward time NN
nn_integrator_2.model.load_weights('forward_weights.h5')
nn_integrator_2.model

#Initialise reverse-time NN

x_initial_2 = np.zeros((nn_integrator_2.nsteps,nn_integrator_2.dynamical_system.dim))
v_initial_2 = np.zeros((nn_integrator_2.nsteps,nn_integrator_2.dynamical_system.dim))
t_nn_2 = []
x_nn_2 = []
v_nn_2 = []
E_nn_2 = []


#Initialise backward direction with final 4 states of forward direction
for k in range(nn_integrator_2.nsteps):
    x_initial_2[k,:] = x_nn_1[-(k+1)]
    v_initial_2[k,:] = v_nn_1[-(k+1)]

nn_integrator_2.set_state(x_initial_2,v_initial_2)
t_2 = 32-(nn_integrator_2.nsteps-1)*(-nn_integrator_2.dt)

#Integrate backwards in time x

while t_2>(nn_integrator_2.nsteps-1)*(-nn_integrator_2.dt):
    t_nn_2.append(t_2)
    x_nn_2.append(nn_integrator_2.x[0])
    v_nn_2.append(nn_integrator_2.v[0])
    E_nn_2.append(nn_integrator_2.energy())
    nn_integrator_2.integrate(1)
    t_2 -= dt_1




x_nn_1 = np.array(x_nn_1)
x_nn_2 = np.array(x_nn_2)
x_verlet_SHO = np.array(x_verlet_SHO)
v_nn_1 = np.array(v_nn_1)
v_nn_2 = np.array(v_nn_2)
v_verlet_SHO = np.array(v_verlet_SHO)
#t_nn_2.reverse() #reverse t_nn_2 for backwards direction

# %%
# Plot position as a function of time
plt.clf()
plt.rcParams['figure.figsize'] = [10, 10]

plt.plot(t_nn_1,x_nn_1,label='Forward Direction',color='blue')
plt.plot(t_nn_2,x_nn_2,label='Backward Direction',color='orange')
plt.legend(loc='upper left')
ax = plt.gca()
ax.set_xlabel('time $t$')
ax.set_ylabel('position $x_{NN}(t)$')
ax.set_title('Position')
plt.rc('font', size=12)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=20)    # legend fontsize
plt.rc('figure', titlesize=20)  # fontsize of the figure title
#plt.grid()
plt.show()

# Plot velocity as a function of time

plt.plot(t_nn_1,v_nn_1,label='Forward Direction',color='blue')
plt.plot(t_nn_2,v_nn_2,label='Backward Direction',color='orange')
plt.legend(loc='upper left')
ax = plt.gca()
ax.set_xlabel('time $t$')
ax.set_ylabel('Velocity $v_{NN}(t)$')
ax.set_title('Velocity')
plt.rc('font', size=12)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=20)    # legend fontsize
plt.rc('figure', titlesize=20)  # fontsize of the figure title
#plt.grid()
plt.show()

# Plot Position error between the two as a function of time

plt.plot(t_nn_1[0:6393],x_nn_1[0:-(nn_integrator_1.nsteps)+1]-np.flip(x_nn_2),color='blue')
plt.legend(loc='upper left')
ax = plt.gca()
ax.set_xlabel('time $t$')
ax.set_ylabel('Position Error')
ax.set_title('Position Error')
plt.rc('font', size=12)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=20)    # legend fontsize
plt.rc('figure', titlesize=20)  # fontsize of the figure title
#plt.grid()
plt.show()


# Plot velocity error between the two as a function of time

plt.plot(t_nn_1[0:6393],v_nn_1[0:-(nn_integrator_1.nsteps)+1]-np.flip(v_nn_2),color='blue')
plt.legend(loc='upper left')
ax = plt.gca()
ax.set_xlabel('time $t$')
ax.set_ylabel('Velocity Error')
ax.set_title('Velocity Error')
plt.rc('font', size=12)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=20)    # legend fontsize
plt.rc('figure', titlesize=20)  # fontsize of the figure title
#plt.grid()
plt.show()


plt.clf()
# Plot energy as a function of time
# (subtract energy at time t=0 to show energy drift)

plt.plot(t_verlet_SHO,E_verlet_SHO-E_verlet_SHO[0],label='Verlet',color='black')
plt.plot(t_nn_1,E_nn_1-E_nn_1[0],label='Forward Direction',color='blue')
plt.plot(t_nn_2,E_nn_2-E_nn_1[0],label='Backward Direction',color='orange')
plt.legend(loc='upper left')
ax = plt.gca()
ax.set_xlabel('time $t$')
ax.set_ylabel('energy shift $E(t)-E(t_0)$')
#ax.grid()
plt.rc('font', size=12)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=20)    # legend fontsize
plt.rc('figure', titlesize=20)  # fontsize of the figure title

plt.show()

#subplots of position versus velocity for both directions

plt.rcParams['figure.figsize'] = [10, 10]

plt.clf()
plt.plot(x_verlet_SHO,v_verlet_SHO,label='Verlet',color='black')
plt.plot(x_nn_1,v_nn_1,label='Forward Direction',color='blue')
plt.plot(x_nn_2,v_nn_2,label='Backward Direction',color='orange')
plt.legend(loc='upper left')
ax = plt.gca()
ax.set_ylabel('Velocity $v(t)$')
ax.set_xlabel('Position $q(t)$')
plt.rc('font', size=12)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=20)    # legend fontsize
plt.rc('figure', titlesize=20)  # fontsize of the figure title
plt.show()
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
