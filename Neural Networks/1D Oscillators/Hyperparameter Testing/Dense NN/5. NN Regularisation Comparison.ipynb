# %% [markdown]
# #Regularisation method comparison for a dense neural network based integrator

# %%
import sys
sys.path.append('..')

import numpy as np
from matplotlib import pyplot as plt
from Code.dynamical_system import *
from Code.time_integrator import *
from Code.neuralnet import *

np.random.seed(2512517)

# %% [markdown]
# ## Neural network integrator
# This notebook helps determine whether regularisation methods are effective on a naive neural network based integrator with a $4$-step method.

# %% [markdown]
# The model system we are using here is the harmonic oscillator, defined by the equations of motion
#
# $$
# \frac{dx}{dt} = v,\qquad\qquad
# \frac{dv}{dt} = -\frac{k}{m}x
# $$
#
# The timestep size of the Neural network integrator is set to $\Delta t=40\Delta t_{\text{Verlet}}$ where $\Delta t_{\text{Verlet}}$ is the step size of the Verlet integrator that is used for training.

# %%
# mass of particle
mass = 1.2
# spring constant of harmonic oscillator
k_spring = 0.9
# timestep for Verlet integrator
dt_verlet = 0.005
# timestep for neural network integrator
dt = 0.2
# number of steps for neural network integrator
nsteps = 4

harmonic_oscillator = HarmonicOscillator(mass,k_spring)
verlet_integrator = VerletIntegrator(harmonic_oscillator,dt_verlet)
nn_integrator_1 = NN5LR3Integrator(harmonic_oscillator,nsteps,dt)
nn_integrator_2 = NNNormIntegrator(harmonic_oscillator,nsteps,dt)


# visualise the neural network model
nn_integrator_2.model.summary()
keras.utils.plot_model(nn_integrator_1.model, show_shapes=True)
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 4, 2)]       0           []
#
#  flatten_1 (Flatten)            (None, 8)            0           ['input_2[0][0]']
#
#  dense_4 (Dense)                (None, 64)           576         ['flatten_1[0][0]']
#
#  batch_normalization (BatchNorm  (None, 64)          256         ['dense_4[0][0]']
#  alization)
#
#  activation (Activation)        (None, 64)           0           ['batch_normalization[0][0]']
#
#  dropout (Dropout)              (None, 64)           0           ['activation[0][0]']
#
#  dense_5 (Dense)                (None, 64)           4160        ['dropout[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 64)          256         ['dense_5[0][0]']
#  rmalization)
#
#  activation_1 (Activation)      (None, 64)           0           ['batch_normalization_1[0][0]']
#
#  dropout_1 (Dropout)            (None, 64)           0           ['activation_1[0][0]']
#
#  dense_6 (Dense)                (None, 32)           2080        ['dropout_1[0][0]']
#
#  dense_7 (Dense)                (None, 2)            66          ['dense_6[0][0]']
#
#  tf.unstack_1 (TFOpLambda)      [(None, 2),          0           ['input_2[0][0]']
#                                  (None, 2),
#                                  (None, 2),
#                                  (None, 2)]
#
#  rescaling_1 (Rescaling)        (None, 2)            0           ['dense_7[0][0]']
#
#  add_1 (Add)                    (None, 2)            0           ['tf.unstack_1[0][3]',
#                                                                   'rescaling_1[0][0]']
#
# ==================================================================================================
# Total params: 7,394
# Trainable params: 7,138
# Non-trainable params: 256
# __________________________________________________________________________________________________

# %%
BATCH_SIZE=64
data_generator = DataGenerator(nn_integrator_1,verlet_integrator)


train_batches = data_generator.dataset.batch(BATCH_SIZE)

# %% [markdown]
# ## Train neural network based integrator

# %%
EPOCHS=150
STEPS_PER_EPOCH=100
log_dir = './tb_logs/'
tensorboard_cb = tf.keras.callbacks.TensorBoard(log_dir=log_dir)

result_1 = nn_integrator_1.model.fit(train_batches,epochs=EPOCHS,steps_per_epoch=STEPS_PER_EPOCH,
                                 callbacks=tensorboard_cb)
result_2 = nn_integrator_2.model.fit(train_batches,epochs=EPOCHS,steps_per_epoch=STEPS_PER_EPOCH,
                                 callbacks=tensorboard_cb)
# Out:
# Epoch 1/150
# 100/100 [==============================] - 15s 146ms/step - loss: 0.0845
# Epoch 2/150
# 100/100 [==============================] - 15s 146ms/step - loss: 0.0214
# Epoch 3/150
# 100/100 [==============================] - 15s 145ms/step - loss: 0.0014
# Epoch 4/150
# 100/100 [==============================] - 14s 143ms/step - loss: 1.6824e-04
# Epoch 5/150
# 100/100 [==============================] - 15s 151ms/step - loss: 8.3187e-05
# Epoch 6/150
# 100/100 [==============================] - 14s 144ms/step - loss: 6.1928e-05
# Epoch 7/150
# 100/100 [==============================] - 14s 144ms/step - loss: 4.5693e-05
# Epoch 8/150
# 100/100 [==============================] - 14s 143ms/step - loss: 3.7864e-05
# Epoch 9/150
# 100/100 [==============================] - 14s 144ms/step - loss: 3.1167e-05
# Epoch 10/150
# 100/100 [==============================] - 14s 144ms/step - loss: 2.6737e-05
# Epoch 11/150
# 100/100 [==============================] - 15s 145ms/step - loss: 2.2655e-05
# Epoch 12/150
# 100/100 [==============================] - 14s 145ms/step - loss: 1.9375e-05
# Epoch 13/150
# 100/100 [==============================] - 14s 143ms/step - loss: 1.6367e-05
# Epoch 14/150
# 100/100 [==============================] - 14s 145ms/step - loss: 1.3409e-05
# Epoch 15/150
# 100/100 [==============================] - 14s 143ms/step - loss: 1.1380e-05
# Epoch 16/150
# 100/100 [==============================] - 14s 143ms/step - loss: 9.4296e-06
# Epoch 17/150
# 100/100 [==============================] - 14s 142ms/step - loss: 7.8424e-06
# Epoch 18/150
# 100/100 [==============================] - 14s 144ms/step - loss: 6.4381e-06
# Epoch 19/150
# 100/100 [==============================] - 14s 144ms/step - loss: 5.6635e-06
# Epoch 20/150
# 100/100 [==============================] - 14s 144ms/step - loss: 4.5342e-06
# Epoch 21/150
# 100/100 [==============================] - 14s 143ms/step - loss: 3.9602e-06
# Epoch 22/150
# 100/100 [==============================] - 14s 143ms/step - loss: 3.2954e-06
# Epoch 23/150
# 100/100 [==============================] - 14s 144ms/step - loss: 2.7621e-06
# Epoch 24/150
# 100/100 [==============================] - 14s 144ms/step - loss: 2.4329e-06
# Epoch 25/150
# 100/100 [==============================] - 14s 143ms/step - loss: 2.2148e-06
# Epoch 26/150
# 100/100 [==============================] - 14s 143ms/step - loss: 1.9801e-06
# Epoch 27/150
# 100/100 [==============================] - 14s 144ms/step - loss: 1.6931e-06
# Epoch 28/150
# 100/100 [==============================] - 14s 143ms/step - loss: 1.5218e-06
# Epoch 29/150
# 100/100 [==============================] - 14s 143ms/step - loss: 1.3958e-06
# Epoch 30/150
# 100/100 [==============================] - 14s 142ms/step - loss: 1.3706e-06
# Epoch 31/150
# 100/100 [==============================] - 14s 144ms/step - loss: 1.2469e-06
# Epoch 32/150
# 100/100 [==============================] - 14s 144ms/step - loss: 1.1600e-06
# Epoch 33/150
# 100/100 [==============================] - 15s 146ms/step - loss: 1.0501e-06
# Epoch 34/150
# 100/100 [==============================] - 14s 143ms/step - loss: 1.0245e-06
# Epoch 35/150
# 100/100 [==============================] - 14s 143ms/step - loss: 9.9397e-07
# Epoch 36/150
# 100/100 [==============================] - 14s 144ms/step - loss: 9.3960e-07
# Epoch 37/150
# 100/100 [==============================] - 14s 144ms/step - loss: 8.6934e-07
# Epoch 38/150
# 100/100 [==============================] - 14s 143ms/step - loss: 8.1816e-07
# Epoch 39/150
# 100/100 [==============================] - 14s 144ms/step - loss: 7.4485e-07
# Epoch 40/150
# 100/100 [==============================] - 14s 144ms/step - loss: 7.7115e-07
# Epoch 41/150
# 100/100 [==============================] - 14s 144ms/step - loss: 7.4321e-07
# Epoch 42/150
# 100/100 [==============================] - 14s 145ms/step - loss: 6.7305e-07
# Epoch 43/150
# 100/100 [==============================] - 14s 144ms/step - loss: 6.5406e-07
# Epoch 44/150
# 100/100 [==============================] - 15s 147ms/step - loss: 5.9483e-07
# Epoch 45/150
# 100/100 [==============================] - 14s 145ms/step - loss: 5.8212e-07
# Epoch 46/150
# 100/100 [==============================] - 15s 145ms/step - loss: 5.6199e-07
# Epoch 47/150
# 100/100 [==============================] - 14s 145ms/step - loss: 5.1036e-07
# Epoch 48/150
# 100/100 [==============================] - 15s 145ms/step - loss: 5.0293e-07
# Epoch 49/150
# 100/100 [==============================] - 14s 144ms/step - loss: 4.7268e-07
# Epoch 50/150
# 100/100 [==============================] - 14s 145ms/step - loss: 4.3225e-07
# Epoch 51/150
# 100/100 [==============================] - 14s 144ms/step - loss: 4.2909e-07
# Epoch 52/150
# 100/100 [==============================] - 15s 145ms/step - loss: 4.0526e-07
# Epoch 53/150
# 100/100 [==============================] - 15s 145ms/step - loss: 3.7785e-07
# Epoch 54/150
# 100/100 [==============================] - 15s 146ms/step - loss: 3.7722e-07
# Epoch 55/150
# 100/100 [==============================] - 15s 147ms/step - loss: 3.4746e-07
# Epoch 56/150
# 100/100 [==============================] - 14s 145ms/step - loss: 4.0547e-07
# Epoch 57/150
# 100/100 [==============================] - 14s 145ms/step - loss: 3.2236e-07
# Epoch 58/150
# 100/100 [==============================] - 15s 145ms/step - loss: 3.3023e-07
# Epoch 59/150
# 100/100 [==============================] - 14s 144ms/step - loss: 3.2827e-07
# Epoch 60/150
# 100/100 [==============================] - 14s 145ms/step - loss: 2.9304e-07
# Epoch 61/150
# 100/100 [==============================] - 15s 145ms/step - loss: 2.8885e-07
# Epoch 62/150
# 100/100 [==============================] - 14s 144ms/step - loss: 3.3043e-07
# Epoch 63/150
# 100/100 [==============================] - 14s 144ms/step - loss: 2.6162e-07
# Epoch 64/150
# 100/100 [==============================] - 15s 145ms/step - loss: 2.5199e-07
# Epoch 65/150
# 100/100 [==============================] - 15s 146ms/step - loss: 2.9985e-07
# Epoch 66/150
# 100/100 [==============================] - 14s 145ms/step - loss: 2.6626e-07
# Epoch 67/150
# 100/100 [==============================] - 14s 144ms/step - loss: 2.6139e-07
# Epoch 68/150
# 100/100 [==============================] - 14s 144ms/step - loss: 2.6894e-07
# Epoch 69/150
# 100/100 [==============================] - 14s 145ms/step - loss: 2.3679e-07
# Epoch 70/150
# 100/100 [==============================] - 14s 144ms/step - loss: 2.0804e-07
# Epoch 71/150
# 100/100 [==============================] - 14s 144ms/step - loss: 1.9715e-07
# Epoch 72/150
# 100/100 [==============================] - 14s 145ms/step - loss: 1.7578e-07
# Epoch 73/150
# 100/100 [==============================] - 14s 144ms/step - loss: 1.8404e-07
# Epoch 74/150
# 100/100 [==============================] - 14s 144ms/step - loss: 2.6448e-07
# Epoch 75/150
# 100/100 [==============================] - 14s 144ms/step - loss: 1.9566e-07
# Epoch 76/150
# 100/100 [==============================] - 15s 147ms/step - loss: 1.9962e-07
# Epoch 77/150
# 100/100 [==============================] - 14s 144ms/step - loss: 1.7453e-07
# Epoch 78/150
# 100/100 [==============================] - 15s 145ms/step - loss: 1.3891e-07
# Epoch 79/150
# 100/100 [==============================] - 14s 144ms/step - loss: 1.6643e-07
# Epoch 80/150
# 100/100 [==============================] - 14s 145ms/step - loss: 1.5938e-07
# Epoch 81/150
# 100/100 [==============================] - 14s 144ms/step - loss: 2.0154e-07
# Epoch 82/150
# 100/100 [==============================] - 15s 145ms/step - loss: 3.6075e-07
# Epoch 83/150
# 100/100 [==============================] - 14s 145ms/step - loss: 1.6971e-07
# Epoch 84/150
# 100/100 [==============================] - 14s 145ms/step - loss: 2.6132e-07
# Epoch 85/150
# 100/100 [==============================] - 15s 146ms/step - loss: 1.6130e-07
# Epoch 86/150
# 100/100 [==============================] - 15s 145ms/step - loss: 3.3093e-07
# Epoch 87/150
# 100/100 [==============================] - 14s 144ms/step - loss: 1.2904e-07
# Epoch 88/150
# 100/100 [==============================] - 14s 144ms/step - loss: 1.2038e-07
# Epoch 89/150
# 100/100 [==============================] - 15s 146ms/step - loss: 1.0496e-07
# Epoch 90/150
# 100/100 [==============================] - 14s 144ms/step - loss: 1.3960e-07
# Epoch 91/150
# 100/100 [==============================] - 14s 144ms/step - loss: 1.2945e-07
# Epoch 92/150
# 100/100 [==============================] - 14s 144ms/step - loss: 1.2304e-07
# Epoch 93/150
# 100/100 [==============================] - 14s 144ms/step - loss: 1.6597e-07
# Epoch 94/150
# 100/100 [==============================] - 15s 145ms/step - loss: 1.2328e-07
# Epoch 95/150
# 100/100 [==============================] - 14s 144ms/step - loss: 1.4946e-07
# Epoch 96/150
# 100/100 [==============================] - 15s 146ms/step - loss: 9.7093e-08
# Epoch 97/150
# 100/100 [==============================] - 15s 150ms/step - loss: 7.5670e-07
# Epoch 98/150
# 100/100 [==============================] - 15s 150ms/step - loss: 2.9414e-06
# Epoch 99/150
# 100/100 [==============================] - 15s 146ms/step - loss: 1.4500e-07
# Epoch 100/150
# 100/100 [==============================] - 14s 144ms/step - loss: 1.1624e-07
# Epoch 101/150
# 100/100 [==============================] - 14s 145ms/step - loss: 1.1577e-07
# Epoch 102/150
# 100/100 [==============================] - 15s 145ms/step - loss: 1.0210e-07
# Epoch 103/150
# 100/100 [==============================] - 14s 145ms/step - loss: 1.0649e-07
# Epoch 104/150
# 100/100 [==============================] - 14s 144ms/step - loss: 1.0057e-07
# Epoch 105/150
# 100/100 [==============================] - 15s 146ms/step - loss: 1.0246e-07
# Epoch 106/150
# 100/100 [==============================] - 15s 146ms/step - loss: 8.3627e-08
# Epoch 107/150
# 100/100 [==============================] - 15s 146ms/step - loss: 8.7657e-08
# Epoch 108/150
# 100/100 [==============================] - 14s 145ms/step - loss: 9.6290e-08
# Epoch 109/150
# 100/100 [==============================] - 14s 145ms/step - loss: 1.0243e-07
# Epoch 110/150
# 100/100 [==============================] - 14s 144ms/step - loss: 8.2604e-08
# Epoch 111/150
# 100/100 [==============================] - 14s 145ms/step - loss: 1.2960e-07
# Epoch 112/150
# 100/100 [==============================] - 14s 144ms/step - loss: 9.1150e-08
# Epoch 113/150
# 100/100 [==============================] - 14s 144ms/step - loss: 9.4632e-08
# Epoch 114/150
# 100/100 [==============================] - 15s 145ms/step - loss: 4.5499e-07
# Epoch 115/150
# 100/100 [==============================] - 15s 145ms/step - loss: 2.7174e-07
# Epoch 116/150
# 100/100 [==============================] - 14s 145ms/step - loss: 1.0755e-07
# Epoch 117/150
# 100/100 [==============================] - 14s 145ms/step - loss: 2.3196e-07
# Epoch 118/150
# 100/100 [==============================] - 15s 146ms/step - loss: 2.2089e-07
# Epoch 119/150
# 100/100 [==============================] - 15s 147ms/step - loss: 6.8219e-08
# Epoch 120/150
# 100/100 [==============================] - 14s 145ms/step - loss: 8.0222e-08
# Epoch 121/150
# 100/100 [==============================] - 14s 145ms/step - loss: 1.1740e-07
# Epoch 122/150
# 100/100 [==============================] - 14s 145ms/step - loss: 4.1475e-07
# Epoch 123/150
# 100/100 [==============================] - 14s 145ms/step - loss: 7.3619e-08
# Epoch 124/150
# 100/100 [==============================] - 15s 145ms/step - loss: 6.7464e-08
# Epoch 125/150
# 100/100 [==============================] - 14s 144ms/step - loss: 1.2483e-06
# Epoch 126/150
# 100/100 [==============================] - 15s 145ms/step - loss: 5.5447e-07
# Epoch 127/150
# 100/100 [==============================] - 15s 147ms/step - loss: 6.5232e-08
# Epoch 128/150
# 100/100 [==============================] - 14s 144ms/step - loss: 4.7140e-08
# Epoch 129/150
# 100/100 [==============================] - 15s 145ms/step - loss: 5.3593e-08
# Epoch 130/150
# 100/100 [==============================] - 14s 144ms/step - loss: 5.6998e-08
# Epoch 131/150
# 100/100 [==============================] - 14s 145ms/step - loss: 4.2715e-08
# Epoch 132/150
# 100/100 [==============================] - 15s 146ms/step - loss: 4.4022e-08
# Epoch 133/150
# 100/100 [==============================] - 15s 145ms/step - loss: 8.6328e-08
# Epoch 134/150
# 100/100 [==============================] - 15s 146ms/step - loss: 6.5118e-08
# Epoch 135/150
# 100/100 [==============================] - 15s 146ms/step - loss: 2.6298e-07
# Epoch 136/150
# 100/100 [==============================] - 15s 147ms/step - loss: 9.1771e-07
# Epoch 137/150
# 100/100 [==============================] - 15s 146ms/step - loss: 1.6313e-07
# Epoch 138/150
# 100/100 [==============================] - 15s 146ms/step - loss: 1.1097e-07
# Epoch 139/150
# 100/100 [==============================] - 15s 146ms/step - loss: 5.2254e-08
# Epoch 140/150
# 100/100 [==============================] - 15s 150ms/step - loss: 9.2355e-08
# Epoch 141/150
# 100/100 [==============================] - 15s 146ms/step - loss: 9.5980e-08
# Epoch 142/150
# 100/100 [==============================] - 15s 145ms/step - loss: 8.9770e-08
# Epoch 143/150
# 100/100 [==============================] - 15s 145ms/step - loss: 6.8990e-08
# Epoch 144/150
# 100/100 [==============================] - 15s 147ms/step - loss: 4.4627e-08
# Epoch 145/150
# 100/100 [==============================] - 15s 146ms/step - loss: 7.8370e-08
# Epoch 146/150
# 100/100 [==============================] - 15s 146ms/step - loss: 7.9698e-08
# Epoch 147/150
# 100/100 [==============================] - 15s 148ms/step - loss: 8.9073e-08
# Epoch 148/150
# 100/100 [==============================] - 15s 148ms/step - loss: 8.3990e-07
# Epoch 149/150
# 100/100 [==============================] - 15s 147ms/step - loss: 5.2147e-07
# Epoch 150/150
# 100/100 [==============================] - 15s 146ms/step - loss: 5.6725e-08
# Epoch 1/150
# 100/100 [==============================] - 16s 145ms/step - loss: 0.0917
# Epoch 2/150
# 100/100 [==============================] - 15s 146ms/step - loss: 0.0316
# Epoch 3/150
# 100/100 [==============================] - 15s 146ms/step - loss: 0.0162
# Epoch 4/150
# 100/100 [==============================] - 15s 147ms/step - loss: 0.0130
# Epoch 5/150
# 100/100 [==============================] - 15s 147ms/step - loss: 0.0124
# Epoch 6/150
# 100/100 [==============================] - 15s 146ms/step - loss: 0.0112
# Epoch 7/150
# 100/100 [==============================] - 15s 146ms/step - loss: 0.0107
# Epoch 8/150
# 100/100 [==============================] - 15s 146ms/step - loss: 0.0103
# Epoch 9/150
# 100/100 [==============================] - 15s 146ms/step - loss: 0.0095
# Epoch 10/150
# 100/100 [==============================] - 15s 146ms/step - loss: 0.0089
# Epoch 11/150
# 100/100 [==============================] - 15s 148ms/step - loss: 0.0098
# Epoch 12/150
# 100/100 [==============================] - 15s 146ms/step - loss: 0.0083
# Epoch 13/150
# 100/100 [==============================] - 15s 146ms/step - loss: 0.0082
# Epoch 14/150
# 100/100 [==============================] - 15s 146ms/step - loss: 0.0082
# Epoch 15/150
# 100/100 [==============================] - 15s 146ms/step - loss: 0.0085
# Epoch 16/150
# 100/100 [==============================] - 15s 146ms/step - loss: 0.0082
# Epoch 17/150
# 100/100 [==============================] - 15s 147ms/step - loss: 0.0076
# Epoch 18/150
# 100/100 [==============================] - 15s 147ms/step - loss: 0.0070
# Epoch 19/150
# 100/100 [==============================] - 15s 146ms/step - loss: 0.0080
# Epoch 20/150
# 100/100 [==============================] - 15s 145ms/step - loss: 0.0075
# Epoch 21/150
# 100/100 [==============================] - 15s 147ms/step - loss: 0.0068
# Epoch 22/150
# 100/100 [==============================] - 15s 146ms/step - loss: 0.0066
# Epoch 23/150
# 100/100 [==============================] - 15s 145ms/step - loss: 0.0066
# Epoch 24/150
# 100/100 [==============================] - 15s 146ms/step - loss: 0.0070
# Epoch 25/150
# 100/100 [==============================] - 15s 146ms/step - loss: 0.0073
# Epoch 26/150
# 100/100 [==============================] - 15s 145ms/step - loss: 0.0064
# Epoch 27/150
# 100/100 [==============================] - 15s 146ms/step - loss: 0.0064
# Epoch 28/150
# 100/100 [==============================] - 15s 146ms/step - loss: 0.0062
# Epoch 29/150
# 100/100 [==============================] - 15s 146ms/step - loss: 0.0066
# Epoch 30/150
# 100/100 [==============================] - 15s 146ms/step - loss: 0.0060
# Epoch 31/150
# 100/100 [==============================] - 15s 146ms/step - loss: 0.0066
# Epoch 32/150
# 100/100 [==============================] - 15s 147ms/step - loss: 0.0060
# Epoch 33/150
# 100/100 [==============================] - 15s 148ms/step - loss: 0.0060
# Epoch 34/150
# 100/100 [==============================] - 15s 146ms/step - loss: 0.0062
# Epoch 35/150
# 100/100 [==============================] - 15s 147ms/step - loss: 0.0064
# Epoch 36/150
# 100/100 [==============================] - 15s 147ms/step - loss: 0.0064
# Epoch 37/150
# 100/100 [==============================] - 15s 147ms/step - loss: 0.0065
# Epoch 38/150
# 100/100 [==============================] - 15s 147ms/step - loss: 0.0060
# Epoch 39/150
# 100/100 [==============================] - 15s 147ms/step - loss: 0.0054
# Epoch 40/150
# 100/100 [==============================] - 15s 146ms/step - loss: 0.0059
# Epoch 41/150
# 100/100 [==============================] - 15s 146ms/step - loss: 0.0058
# Epoch 42/150
# 100/100 [==============================] - 15s 146ms/step - loss: 0.0062
# Epoch 43/150
# 100/100 [==============================] - 15s 146ms/step - loss: 0.0060
# Epoch 44/150
# 100/100 [==============================] - 15s 147ms/step - loss: 0.0058
# Epoch 45/150
# 100/100 [==============================] - 15s 146ms/step - loss: 0.0057
# Epoch 46/150
# 100/100 [==============================] - 15s 147ms/step - loss: 0.0058
# Epoch 47/150
# 100/100 [==============================] - 15s 146ms/step - loss: 0.0061
# Epoch 48/150
# 100/100 [==============================] - 15s 146ms/step - loss: 0.0060
# Epoch 49/150
# 100/100 [==============================] - 15s 145ms/step - loss: 0.0054
# Epoch 50/150
# 100/100 [==============================] - 15s 146ms/step - loss: 0.0054
# Epoch 51/150
# 100/100 [==============================] - 15s 147ms/step - loss: 0.0055
# Epoch 52/150
# 100/100 [==============================] - 15s 146ms/step - loss: 0.0057
# Epoch 53/150
# 100/100 [==============================] - 15s 148ms/step - loss: 0.0053
# Epoch 54/150
# 100/100 [==============================] - 15s 149ms/step - loss: 0.0055
# Epoch 55/150
# 100/100 [==============================] - 15s 147ms/step - loss: 0.0059
# Epoch 56/150
# 100/100 [==============================] - 15s 147ms/step - loss: 0.0052
# Epoch 57/150
# 100/100 [==============================] - 15s 149ms/step - loss: 0.0055
# Epoch 58/150
# 100/100 [==============================] - 15s 149ms/step - loss: 0.0059
# Epoch 59/150
# 100/100 [==============================] - 15s 149ms/step - loss: 0.0052
# Epoch 60/150
# 100/100 [==============================] - 15s 147ms/step - loss: 0.0047
# Epoch 61/150
# 100/100 [==============================] - 15s 146ms/step - loss: 0.0055
# Epoch 62/150
# 100/100 [==============================] - 15s 148ms/step - loss: 0.0054
# Epoch 63/150
# 100/100 [==============================] - 15s 147ms/step - loss: 0.0052
# Epoch 64/150
# 100/100 [==============================] - 15s 146ms/step - loss: 0.0055
# Epoch 65/150
# 100/100 [==============================] - 15s 146ms/step - loss: 0.0046
# Epoch 66/150
# 100/100 [==============================] - 15s 147ms/step - loss: 0.0048
# Epoch 67/150
# 100/100 [==============================] - 15s 146ms/step - loss: 0.0049
# Epoch 68/150
# 100/100 [==============================] - 15s 146ms/step - loss: 0.0049
# Epoch 69/150
# 100/100 [==============================] - 15s 146ms/step - loss: 0.0049
# Epoch 70/150
# 100/100 [==============================] - 15s 147ms/step - loss: 0.0050
# Epoch 71/150
# 100/100 [==============================] - 15s 146ms/step - loss: 0.0046
# Epoch 72/150
# 100/100 [==============================] - 15s 147ms/step - loss: 0.0052
# Epoch 73/150
# 100/100 [==============================] - 15s 146ms/step - loss: 0.0046
# Epoch 74/150
# 100/100 [==============================] - 15s 148ms/step - loss: 0.0056
# Epoch 75/150
# 100/100 [==============================] - 15s 148ms/step - loss: 0.0051
# Epoch 76/150
# 100/100 [==============================] - 15s 146ms/step - loss: 0.0054
# Epoch 77/150
# 100/100 [==============================] - 15s 146ms/step - loss: 0.0053
# Epoch 78/150
# 100/100 [==============================] - 15s 146ms/step - loss: 0.0050
# Epoch 79/150
# 100/100 [==============================] - 15s 147ms/step - loss: 0.0051
# Epoch 80/150
# 100/100 [==============================] - 15s 147ms/step - loss: 0.0049
# Epoch 81/150
# 100/100 [==============================] - 15s 146ms/step - loss: 0.0050
# Epoch 82/150
# 100/100 [==============================] - 15s 146ms/step - loss: 0.0047
# Epoch 83/150
# 100/100 [==============================] - 15s 146ms/step - loss: 0.0051
# Epoch 84/150
# 100/100 [==============================] - 15s 147ms/step - loss: 0.0052
# Epoch 85/150
# 100/100 [==============================] - 15s 146ms/step - loss: 0.0051
# Epoch 86/150
# 100/100 [==============================] - 15s 147ms/step - loss: 0.0053
# Epoch 87/150
# 100/100 [==============================] - 15s 147ms/step - loss: 0.0050
# Epoch 88/150
# 100/100 [==============================] - 15s 147ms/step - loss: 0.0045
# Epoch 89/150
# 100/100 [==============================] - 15s 147ms/step - loss: 0.0053
# Epoch 90/150
# 100/100 [==============================] - 15s 147ms/step - loss: 0.0046
# Epoch 91/150
# 100/100 [==============================] - 15s 148ms/step - loss: 0.0049
# Epoch 92/150
# 100/100 [==============================] - 15s 148ms/step - loss: 0.0049
# Epoch 93/150
# 100/100 [==============================] - 15s 147ms/step - loss: 0.0047
# Epoch 94/150
# 100/100 [==============================] - 15s 147ms/step - loss: 0.0055
# Epoch 95/150
# 100/100 [==============================] - 15s 148ms/step - loss: 0.0049
# Epoch 96/150
# 100/100 [==============================] - 15s 149ms/step - loss: 0.0054
# Epoch 97/150
# 100/100 [==============================] - 15s 147ms/step - loss: 0.0048
# Epoch 98/150
# 100/100 [==============================] - 15s 148ms/step - loss: 0.0046
# Epoch 99/150
# 100/100 [==============================] - 15s 148ms/step - loss: 0.0047
# Epoch 100/150
# 100/100 [==============================] - 15s 147ms/step - loss: 0.0050
# Epoch 101/150
# 100/100 [==============================] - 15s 148ms/step - loss: 0.0047
# Epoch 102/150
# 100/100 [==============================] - 15s 148ms/step - loss: 0.0049
# Epoch 103/150
# 100/100 [==============================] - 15s 148ms/step - loss: 0.0046
# Epoch 104/150
# 100/100 [==============================] - 15s 147ms/step - loss: 0.0050
# Epoch 105/150
# 100/100 [==============================] - 15s 147ms/step - loss: 0.0048
# Epoch 106/150
# 100/100 [==============================] - 15s 147ms/step - loss: 0.0044
# Epoch 107/150
# 100/100 [==============================] - 15s 147ms/step - loss: 0.0045
# Epoch 108/150
# 100/100 [==============================] - 15s 148ms/step - loss: 0.0047
# Epoch 109/150
# 100/100 [==============================] - 15s 149ms/step - loss: 0.0051
# Epoch 110/150
# 100/100 [==============================] - 15s 149ms/step - loss: 0.0042
# Epoch 111/150
# 100/100 [==============================] - 15s 149ms/step - loss: 0.0047
# Epoch 112/150
# 100/100 [==============================] - 15s 148ms/step - loss: 0.0044
# Epoch 113/150
# 100/100 [==============================] - 15s 149ms/step - loss: 0.0048
# Epoch 114/150
# 100/100 [==============================] - 15s 149ms/step - loss: 0.0045
# Epoch 115/150
# 100/100 [==============================] - 15s 148ms/step - loss: 0.0046
# Epoch 116/150
# 100/100 [==============================] - 15s 148ms/step - loss: 0.0047
# Epoch 117/150
# 100/100 [==============================] - 15s 149ms/step - loss: 0.0049
# Epoch 118/150
# 100/100 [==============================] - 15s 147ms/step - loss: 0.0044
# Epoch 119/150
# 100/100 [==============================] - 15s 147ms/step - loss: 0.0047
# Epoch 120/150
# 100/100 [==============================] - 15s 150ms/step - loss: 0.0048
# Epoch 121/150
# 100/100 [==============================] - 15s 148ms/step - loss: 0.0047
# Epoch 122/150
# 100/100 [==============================] - 15s 147ms/step - loss: 0.0041
# Epoch 123/150
# 100/100 [==============================] - 15s 147ms/step - loss: 0.0046
# Epoch 124/150
# 100/100 [==============================] - 15s 147ms/step - loss: 0.0047
# Epoch 125/150
# 100/100 [==============================] - 15s 146ms/step - loss: 0.0047
# Epoch 126/150
# 100/100 [==============================] - 15s 146ms/step - loss: 0.0042
# Epoch 127/150
# 100/100 [==============================] - 15s 147ms/step - loss: 0.0043
# Epoch 128/150
# 100/100 [==============================] - 15s 147ms/step - loss: 0.0045
# Epoch 129/150
# 100/100 [==============================] - 15s 146ms/step - loss: 0.0043
# Epoch 130/150
# 100/100 [==============================] - 15s 147ms/step - loss: 0.0043
# Epoch 131/150
# 100/100 [==============================] - 15s 147ms/step - loss: 0.0042
# Epoch 132/150
# 100/100 [==============================] - 15s 146ms/step - loss: 0.0044
# Epoch 133/150
# 100/100 [==============================] - 15s 146ms/step - loss: 0.0046
# Epoch 134/150
# 100/100 [==============================] - 15s 147ms/step - loss: 0.0050
# Epoch 135/150
# 100/100 [==============================] - 15s 146ms/step - loss: 0.0045
# Epoch 136/150
# 100/100 [==============================] - 15s 147ms/step - loss: 0.0047
# Epoch 137/150
# 100/100 [==============================] - 15s 147ms/step - loss: 0.0046
# Epoch 138/150
# 100/100 [==============================] - 15s 148ms/step - loss: 0.0050
# Epoch 139/150
# 100/100 [==============================] - 15s 147ms/step - loss: 0.0045
# Epoch 140/150
# 100/100 [==============================] - 15s 149ms/step - loss: 0.0043
# Epoch 141/150
# 100/100 [==============================] - 15s 149ms/step - loss: 0.0046
# Epoch 142/150
# 100/100 [==============================] - 15s 146ms/step - loss: 0.0040
# Epoch 143/150
# 100/100 [==============================] - 15s 146ms/step - loss: 0.0048
# Epoch 144/150
# 100/100 [==============================] - 15s 147ms/step - loss: 0.0047
# Epoch 145/150
# 100/100 [==============================] - 15s 148ms/step - loss: 0.0051
# Epoch 146/150
# 100/100 [==============================] - 15s 146ms/step - loss: 0.0046
# Epoch 147/150
# 100/100 [==============================] - 15s 147ms/step - loss: 0.0042
# Epoch 148/150
# 100/100 [==============================] - 15s 147ms/step - loss: 0.0046
# Epoch 149/150
# 100/100 [==============================] - 15s 147ms/step - loss: 0.0048
# Epoch 150/150
# 100/100 [==============================] - 15s 147ms/step - loss: 0.0043

# %% [markdown]
# ## Visualise Loss function

# %%
#print(result.history.keys())

plt.rcParams['figure.figsize'] = [10, 10]

# summarize history for loss
plt.plot(result_1.history['loss'])
plt.plot(result_2.history['loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.rc('font', size=12)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=20)    # legend fontsize
plt.rc('figure', titlesize=20)  # fontsize of the figure title
plt.legend(['W/O Normalisation','W/ Normalisation'], loc='upper left')
plt.yscale("log")
plt.show()

# %% [markdown]
# ## Plot trajectories to $t=64$ generated by Verlet integrator and the neural network based integrators

# %%
# Final time
T_final = 64

# Initial conditions
x = np.zeros(1)
v = np.zeros(1)
x[0] = 1.0
v[0] = 0.0
verlet_integrator.set_state(x,v)

# ==== Verlet integrator ====
t = 0.0
t_verlet = []
x_verlet = []
E_verlet = []
while t<T_final:
    t_verlet.append(t)
    E_verlet.append(verlet_integrator.energy())
    x_verlet.append(verlet_integrator.x[0])
    verlet_integrator.integrate(1)
    t += dt_verlet
        

# ==== Neural network integrator ====

# Initialise with Verlet integrator
x_initial_1 = np.zeros((nn_integrator_1.nsteps,nn_integrator_1.dynamical_system.dim))
v_initial_1 = np.zeros((nn_integrator_1.nsteps,nn_integrator_1.dynamical_system.dim))
x_initial_2 = np.zeros((nn_integrator_2.nsteps,nn_integrator_2.dynamical_system.dim))
v_initial_2 = np.zeros((nn_integrator_2.nsteps,nn_integrator_2.dynamical_system.dim))


verlet_integrator.set_state(x,v)
for k in range(nn_integrator_1.nsteps):    
    x_initial_1[k,:] = verlet_integrator.x[:]
    v_initial_1[k,:] = verlet_integrator.v[:]
    verlet_integrator.integrate(int(dt/dt_verlet))
verlet_integrator.set_state(x,v)
for k in range(nn_integrator_2.nsteps):    
    x_initial_2[k,:] = verlet_integrator.x[:]
    v_initial_2[k,:] = verlet_integrator.v[:]
    verlet_integrator.integrate(int(dt/dt_verlet))



nn_integrator_1.set_state(x_initial_1,v_initial_1)
t_1 = (nn_integrator_1.nsteps-1)*nn_integrator_1.dt
nn_integrator_2.set_state(x_initial_2,v_initial_2)
t_2 = (nn_integrator_2.nsteps-1)*nn_integrator_2.dt



# Timestepping loop
t_nn_1 = []
x_nn_1 = []
E_nn_1 = []
t_nn_2 = []
x_nn_2 = []
E_nn_2 = []



while t_1<T_final:
    t_nn_1.append(t_1)
    x_nn_1.append(nn_integrator_1.x[0])
    E_nn_1.append(nn_integrator_1.energy())
    nn_integrator_1.integrate(1)
    t_1 += dt
while t_2<T_final:
    t_nn_2.append(t_2)
    x_nn_2.append(nn_integrator_2.x[0])
    E_nn_2.append(nn_integrator_2.energy())
    nn_integrator_2.integrate(1)
    t_2 += dt




# Plot position as a function of time
plt.plot(t_verlet,x_verlet,label='Verlet',color='blue')
plt.plot(t_nn_1,x_nn_1,label='W/O Normalisation',color='red')
plt.plot(t_nn_2,x_nn_2,label='W/ Normalisation',color='green')


plt.legend(loc='lower right')
ax = plt.gca()
ax.set_xlabel('time $t$')
ax.set_ylabel('position $x(t)$')
ax.set_title('Position')
plt.show()

plt.rcParams['figure.figsize'] = [10, 20]

plt.clf()
# Plot energy as a function of time
# (subtract energy at time t=0 to show energy drift)
fig, axs = plt.subplots(2,1)
axs[0].plot(t_verlet,E_verlet-E_verlet[0],label='Verlet',color='blue')
axs[1].plot(t_nn_1,E_nn_1-E_nn_1[0],label='W/O Normalisation',color='blue')
axs[1].plot(t_nn_2,E_nn_2-E_nn_2[0],label='W/ Normalisation',color='orange')

plt.legend(loc='top left')
for ax in axs:
    ax.set_xlabel('time $t$')
    ax.set_ylabel('energy shift $E(t)-E(t_0)$')
plt.rc('font', size=12)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=20)    # legend fontsize
plt.rc('figure', titlesize=20)  # fontsize of the figure title
plt.grid()
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:102: MatplotlibDeprecationWarning: Unrecognized location 'top left'. Falling back on 'best'; valid locations are
# 	best
# 	upper right
# 	upper left
# 	lower left
# 	lower right
# 	right
# 	center left
# 	center right
# 	lower center
# 	upper center
# 	center
# This will raise an exception in 3.3.
