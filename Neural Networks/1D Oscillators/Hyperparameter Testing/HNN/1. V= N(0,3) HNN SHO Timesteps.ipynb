# %% [markdown]
# # Hamiltonian neural network based integrator

# %%
import sys
sys.path.append('..')

import numpy as np
from matplotlib import pyplot as plt
from Code.dynamical_system import *
from Code.time_integrator import *
from Code.neuralnet import *

np.random.seed(2512517)

# %% [markdown]
# ## Hamiltonian Neural network integrator

# %% [markdown]
# Set system parameters, construct dynamical system and integrator.
#
# The model system we are using here is the harmonic oscillator, defined by the equations of motion
#
# $$
# \frac{dx}{dt} = v,\qquad\qquad
# \frac{dv}{dt} = -\frac{k}{m}x
# $$
#
# The timestep size of the Neural network integrator takes values in $\Delta t_{\text{Verlet}},20\Delta t_{\text{Verlet}},40\Delta t_{\text{Verlet}},100\Delta t_{\text{Verlet}}$ where $\Delta t_{\text{Verlet}}$ is the step size of the Verlet integrator that is used for training. The initial velocities for the training trajectories are taken at random from a $N(0,3)$ distribution.

# %%
# mass of particle
mass = 1.2
# spring constant of harmonic oscillator
k_spring = 0.9
# timestep for Verlet integrator
dt_verlet = 0.005
# timestep for neural network integrator
dt_1 = 0.005
dt_2 = 0.1
dt_3 = 0.2
dt_4 = 0.5

harmonic_oscillator = HarmonicOscillator2(mass,k_spring)

verlet_SHO = VerletIntegrator(harmonic_oscillator,dt_verlet)

# Layers for the potential and kinetic parts of the hamiltonian

V_pot_layers = [keras.layers.Dense(32,activation='tanh'),
                    keras.layers.Dense(32,activation='tanh')]
T_kin_layers = [keras.layers.Dense(32,activation='tanh'),
                    keras.layers.Dense(32,activation='tanh')]

hnn_integrator_1 = HamiltonianNNIntegrator(harmonic_oscillator,dt_1,V_pot_layers,T_kin_layers)
hnn_integrator_2 = HamiltonianNNIntegrator(harmonic_oscillator,dt_2,V_pot_layers,T_kin_layers)
hnn_integrator_3 = HamiltonianNNIntegrator(harmonic_oscillator,dt_3,V_pot_layers,T_kin_layers)
hnn_integrator_4 = HamiltonianNNIntegrator(harmonic_oscillator,dt_4,V_pot_layers,T_kin_layers)

# visualise the neural network model
hnn_integrator_1.model.summary()
keras.utils.plot_model(hnn_integrator_1.model, show_shapes=True)
# Out:
# Model: "verlet_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               multiple                  64
#
#  dense_1 (Dense)             multiple                  1056
#
#  dense_2 (Dense)             multiple                  64
#
#  dense_3 (Dense)             multiple                  1056
#
#  dense_8 (Dense)             multiple                  32
#
#  dense_9 (Dense)             multiple                  32
#
# =================================================================
# Total params: 2,304
# Trainable params: 2,304
# Non-trainable params: 0
# _________________________________________________________________

# %%
BATCH_SIZE=64

data_generator_1 = DataGenerator(hnn_integrator_1,verlet_SHO)
train_batches_1 = data_generator_1.dataset.batch(BATCH_SIZE)

data_generator_2 = DataGenerator(hnn_integrator_2,verlet_SHO)
train_batches_2 = data_generator_2.dataset.batch(BATCH_SIZE)

data_generator_3 = DataGenerator(hnn_integrator_3,verlet_SHO)
train_batches_3 = data_generator_3.dataset.batch(BATCH_SIZE)

data_generator_4 = DataGenerator(hnn_integrator_4,verlet_SHO)
train_batches_4 = data_generator_4.dataset.batch(BATCH_SIZE)

# %% [markdown]
# ## Train neural network based integrator

# %%
EPOCHS=300
STEPS_PER_EPOCH=100
log_dir = './tb_logs/'
tensorboard_cb = tf.keras.callbacks.TensorBoard(log_dir=log_dir)

result_1 = hnn_integrator_1.model.fit(train_batches_1,epochs=EPOCHS,steps_per_epoch=STEPS_PER_EPOCH,
                                 callbacks=tensorboard_cb)
result_2 = hnn_integrator_2.model.fit(train_batches_2,epochs=EPOCHS,steps_per_epoch=STEPS_PER_EPOCH,
                                 callbacks=tensorboard_cb)
result_3 = hnn_integrator_3.model.fit(train_batches_3,epochs=EPOCHS,steps_per_epoch=STEPS_PER_EPOCH,
                                callbacks=tensorboard_cb)
result_4 = hnn_integrator_4.model.fit(train_batches_4,epochs=EPOCHS,steps_per_epoch=STEPS_PER_EPOCH,
                                 callbacks=tensorboard_cb)
# Out:
# Epoch 1/300
# 100/100 [==============================] - 5s 17ms/step - loss: 1.7375e-04
# Epoch 2/300
# 100/100 [==============================] - 2s 17ms/step - loss: 1.7788e-04
# Epoch 3/300
# 100/100 [==============================] - 2s 17ms/step - loss: 1.7883e-04
# Epoch 4/300
# 100/100 [==============================] - 2s 17ms/step - loss: 1.7470e-04
# Epoch 5/300
# 100/100 [==============================] - 2s 17ms/step - loss: 1.6526e-04
# Epoch 6/300
# 100/100 [==============================] - 2s 16ms/step - loss: 1.6900e-04
# Epoch 7/300
# 100/100 [==============================] - 2s 17ms/step - loss: 1.6137e-04
# Epoch 8/300
# 100/100 [==============================] - 2s 16ms/step - loss: 1.5973e-04
# Epoch 9/300
# 100/100 [==============================] - 2s 17ms/step - loss: 1.6122e-04
# Epoch 10/300
# 100/100 [==============================] - 2s 17ms/step - loss: 1.5139e-04
# Epoch 11/300
# 100/100 [==============================] - 2s 17ms/step - loss: 1.4587e-04
# Epoch 12/300
# 100/100 [==============================] - 2s 17ms/step - loss: 1.4376e-04
# Epoch 13/300
# 100/100 [==============================] - 2s 17ms/step - loss: 1.4327e-04
# Epoch 14/300
# 100/100 [==============================] - 2s 17ms/step - loss: 1.3261e-04
# Epoch 15/300
# 100/100 [==============================] - 2s 16ms/step - loss: 1.2450e-04
# Epoch 16/300
# 100/100 [==============================] - 2s 17ms/step - loss: 1.2102e-04
# Epoch 17/300
# 100/100 [==============================] - 2s 17ms/step - loss: 1.1239e-04
# Epoch 18/300
# 100/100 [==============================] - 2s 16ms/step - loss: 1.0445e-04
# Epoch 19/300
# 100/100 [==============================] - 2s 17ms/step - loss: 1.0100e-04
# Epoch 20/300
# 100/100 [==============================] - 2s 16ms/step - loss: 9.1413e-05
# Epoch 21/300
# 100/100 [==============================] - 2s 17ms/step - loss: 9.2171e-05
# Epoch 22/300
# 100/100 [==============================] - 2s 17ms/step - loss: 8.6471e-05
# Epoch 23/300
# 100/100 [==============================] - 2s 17ms/step - loss: 7.7802e-05
# Epoch 24/300
# 100/100 [==============================] - 2s 17ms/step - loss: 7.7345e-05
# Epoch 25/300
# 100/100 [==============================] - 2s 17ms/step - loss: 6.9894e-05
# Epoch 26/300
# 100/100 [==============================] - 2s 16ms/step - loss: 6.7261e-05
# Epoch 27/300
# 100/100 [==============================] - 2s 16ms/step - loss: 6.3278e-05
# Epoch 28/300
# 100/100 [==============================] - 2s 17ms/step - loss: 5.7334e-05
# Epoch 29/300
# 100/100 [==============================] - 2s 17ms/step - loss: 5.5643e-05
# Epoch 30/300
# 100/100 [==============================] - 2s 17ms/step - loss: 5.4181e-05
# Epoch 31/300
# 100/100 [==============================] - 2s 17ms/step - loss: 4.9566e-05
# Epoch 32/300
# 100/100 [==============================] - 2s 17ms/step - loss: 5.0702e-05
# Epoch 33/300
# 100/100 [==============================] - 2s 17ms/step - loss: 4.6555e-05
# Epoch 34/300
# 100/100 [==============================] - 2s 17ms/step - loss: 4.5598e-05
# Epoch 35/300
# 100/100 [==============================] - 2s 16ms/step - loss: 4.5243e-05
# Epoch 36/300
# 100/100 [==============================] - 2s 16ms/step - loss: 4.4064e-05
# Epoch 37/300
# 100/100 [==============================] - 2s 17ms/step - loss: 4.1491e-05
# Epoch 38/300
# 100/100 [==============================] - 2s 17ms/step - loss: 4.0513e-05
# Epoch 39/300
# 100/100 [==============================] - 2s 16ms/step - loss: 3.9320e-05
# Epoch 40/300
# 100/100 [==============================] - 2s 17ms/step - loss: 3.8178e-05
# Epoch 41/300
# 100/100 [==============================] - 2s 16ms/step - loss: 3.7853e-05
# Epoch 42/300
# 100/100 [==============================] - 2s 17ms/step - loss: 3.6542e-05
# Epoch 43/300
# 100/100 [==============================] - 2s 17ms/step - loss: 3.7062e-05
# Epoch 44/300
# 100/100 [==============================] - 2s 16ms/step - loss: 3.2240e-05
# Epoch 45/300
# 100/100 [==============================] - 2s 17ms/step - loss: 3.4410e-05
# Epoch 46/300
# 100/100 [==============================] - 2s 17ms/step - loss: 3.3039e-05
# Epoch 47/300
# 100/100 [==============================] - 2s 18ms/step - loss: 3.1086e-05
# Epoch 48/300
# 100/100 [==============================] - 2s 17ms/step - loss: 3.3173e-05
# Epoch 49/300
# 100/100 [==============================] - 2s 17ms/step - loss: 2.8156e-05
# Epoch 50/300
# 100/100 [==============================] - 2s 17ms/step - loss: 3.1671e-05
# Epoch 51/300
# 100/100 [==============================] - 2s 17ms/step - loss: 2.8454e-05
# Epoch 52/300
# 100/100 [==============================] - 2s 17ms/step - loss: 2.9281e-05
# Epoch 53/300
# 100/100 [==============================] - 2s 16ms/step - loss: 2.5852e-05
# Epoch 54/300
# 100/100 [==============================] - 2s 17ms/step - loss: 2.7218e-05
# Epoch 55/300
# 100/100 [==============================] - 2s 17ms/step - loss: 2.6174e-05
# Epoch 56/300
# 100/100 [==============================] - 2s 17ms/step - loss: 2.5264e-05
# Epoch 57/300
# 100/100 [==============================] - 2s 17ms/step - loss: 2.3518e-05
# Epoch 58/300
# 100/100 [==============================] - 2s 17ms/step - loss: 2.2587e-05
# Epoch 59/300
# 100/100 [==============================] - 2s 17ms/step - loss: 2.6920e-05
# Epoch 60/300
# 100/100 [==============================] - 2s 17ms/step - loss: 2.3531e-05
# Epoch 61/300
# 100/100 [==============================] - 2s 17ms/step - loss: 2.1050e-05
# Epoch 62/300
# 100/100 [==============================] - 2s 17ms/step - loss: 2.1662e-05
# Epoch 63/300
# 100/100 [==============================] - 2s 17ms/step - loss: 1.9521e-05
# Epoch 64/300
# 100/100 [==============================] - 2s 16ms/step - loss: 2.0765e-05
# Epoch 65/300
# 100/100 [==============================] - 2s 17ms/step - loss: 1.8595e-05
# Epoch 66/300
# 100/100 [==============================] - 2s 17ms/step - loss: 2.0051e-05
# Epoch 67/300
# 100/100 [==============================] - 2s 16ms/step - loss: 2.1053e-05
# Epoch 68/300
# 100/100 [==============================] - 2s 16ms/step - loss: 1.8328e-05
# Epoch 69/300
# 100/100 [==============================] - 2s 17ms/step - loss: 1.7710e-05
# Epoch 70/300
# 100/100 [==============================] - 2s 16ms/step - loss: 1.5966e-05
# Epoch 71/300
# 100/100 [==============================] - 2s 17ms/step - loss: 1.6711e-05
# Epoch 72/300
# 100/100 [==============================] - 2s 16ms/step - loss: 1.8239e-05
# Epoch 73/300
# 100/100 [==============================] - 2s 17ms/step - loss: 1.5579e-05
# Epoch 74/300
# 100/100 [==============================] - 2s 17ms/step - loss: 1.4665e-05
# Epoch 75/300
# 100/100 [==============================] - 2s 17ms/step - loss: 1.6624e-05
# Epoch 76/300
# 100/100 [==============================] - 2s 17ms/step - loss: 1.5503e-05
# Epoch 77/300
# 100/100 [==============================] - 2s 17ms/step - loss: 1.4234e-05
# Epoch 78/300
# 100/100 [==============================] - 2s 17ms/step - loss: 1.4752e-05
# Epoch 79/300
# 100/100 [==============================] - 2s 16ms/step - loss: 1.3680e-05
# Epoch 80/300
# 100/100 [==============================] - 2s 17ms/step - loss: 1.3382e-05
# Epoch 81/300
# 100/100 [==============================] - 2s 17ms/step - loss: 1.3046e-05
# Epoch 82/300
# 100/100 [==============================] - 2s 17ms/step - loss: 1.3414e-05
# Epoch 83/300
# 100/100 [==============================] - 2s 17ms/step - loss: 1.2781e-05
# Epoch 84/300
# 100/100 [==============================] - 2s 17ms/step - loss: 1.1721e-05
# Epoch 85/300
# 100/100 [==============================] - 2s 17ms/step - loss: 1.2718e-05
# Epoch 86/300
# 100/100 [==============================] - 2s 17ms/step - loss: 1.1994e-05
# Epoch 87/300
# 100/100 [==============================] - 2s 17ms/step - loss: 1.1654e-05
# Epoch 88/300
# 100/100 [==============================] - 2s 16ms/step - loss: 1.3473e-05
# Epoch 89/300
# 100/100 [==============================] - 2s 17ms/step - loss: 1.1142e-05
# Epoch 90/300
# 100/100 [==============================] - 2s 17ms/step - loss: 9.9675e-06
# Epoch 91/300
# 100/100 [==============================] - 2s 17ms/step - loss: 1.0590e-05
# Epoch 92/300
# 100/100 [==============================] - 2s 17ms/step - loss: 1.0845e-05
# Epoch 93/300
# 100/100 [==============================] - 2s 17ms/step - loss: 1.0820e-05
# Epoch 94/300
# 100/100 [==============================] - 2s 17ms/step - loss: 9.8812e-06
# Epoch 95/300
# 100/100 [==============================] - 2s 17ms/step - loss: 8.6015e-06
# Epoch 96/300
# 100/100 [==============================] - 2s 17ms/step - loss: 9.7245e-06
# Epoch 97/300
# 100/100 [==============================] - 2s 16ms/step - loss: 9.0180e-06
# Epoch 98/300
# 100/100 [==============================] - 2s 16ms/step - loss: 1.0010e-05
# Epoch 99/300
# 100/100 [==============================] - 2s 17ms/step - loss: 9.0491e-06
# Epoch 100/300
# 100/100 [==============================] - 2s 17ms/step - loss: 8.6780e-06
# Epoch 101/300
# 100/100 [==============================] - 2s 17ms/step - loss: 8.9818e-06
# Epoch 102/300
# 100/100 [==============================] - 2s 16ms/step - loss: 7.8997e-06
# Epoch 103/300
# 100/100 [==============================] - 2s 16ms/step - loss: 9.4265e-06
# Epoch 104/300
# 100/100 [==============================] - 2s 17ms/step - loss: 8.8429e-06
# Epoch 105/300
# 100/100 [==============================] - 2s 17ms/step - loss: 7.5610e-06
# Epoch 106/300
# 100/100 [==============================] - 2s 17ms/step - loss: 7.0825e-06
# Epoch 107/300
# 100/100 [==============================] - 2s 17ms/step - loss: 7.7307e-06
# Epoch 108/300
# 100/100 [==============================] - 2s 17ms/step - loss: 8.4055e-06
# Epoch 109/300
# 100/100 [==============================] - 2s 17ms/step - loss: 8.6033e-06
# Epoch 110/300
# 100/100 [==============================] - 2s 17ms/step - loss: 7
300
# 100/100 [==============================] - 9s 90ms/step - loss: 0.0145
# Epoch 211/300
# 100/100 [==============================] - 9s 91ms/step - loss: 0.0215
# Epoch 212/300
# 100/100 [==============================] - 9s 90ms/step - loss: 0.0134
# Epoch 213/300
# 100/100 [==============================] - 9s 93ms/step - loss: 0.0217
# Epoch 214/300
# 100/100 [==============================] - 9s 93ms/step - loss: 0.0163
# Epoch 215/300
# 100/100 [==============================] - 9s 91ms/step - loss: 0.0123
# Epoch 216/300
# 100/100 [==============================] - 9s 91ms/step - loss: 0.0206
# Epoch 217/300
# 100/100 [==============================] - 9s 91ms/step - loss: 0.0143
# Epoch 218/300
# 100/100 [==============================] - 9s 91ms/step - loss: 0.0129
# Epoch 219/300
# 100/100 [==============================] - 9s 91ms/step - loss: 0.0170
# Epoch 220/300
# 100/100 [==============================] - 9s 91ms/step - loss: 0.0155
# Epoch 221/300
# 100/100 [==============================] - 9s 90ms/step - loss: 0.0152
# Epoch 222/300
# 100/100 [==============================] - 9s 91ms/step - loss: 0.0181
# Epoch 223/300
# 100/100 [==============================] - 9s 91ms/step - loss: 0.0144
# Epoch 224/300
# 100/100 [==============================] - 9s 90ms/step - loss: 0.0143
# Epoch 225/300
# 100/100 [==============================] - 9s 91ms/step - loss: 0.0147
# Epoch 226/300
# 100/100 [==============================] - 9s 90ms/step - loss: 0.0125
# Epoch 227/300
# 100/100 [==============================] - 9s 91ms/step - loss: 0.0166
# Epoch 228/300
# 100/100 [==============================] - 9s 91ms/step - loss: 0.0117
# Epoch 229/300
# 100/100 [==============================] - 9s 90ms/step - loss: 0.0063
# Epoch 230/300
# 100/100 [==============================] - 9s 91ms/step - loss: 0.0158
# Epoch 231/300
# 100/100 [==============================] - 9s 91ms/step - loss: 0.0132
# Epoch 232/300
# 100/100 [==============================] - 9s 91ms/step - loss: 0.0106
# Epoch 233/300
# 100/100 [==============================] - 9s 91ms/step - loss: 0.0082
# Epoch 234/300
# 100/100 [==============================] - 9s 90ms/step - loss: 0.0088
# Epoch 235/300
# 100/100 [==============================] - 9s 90ms/step - loss: 0.0121
# Epoch 236/300
# 100/100 [==============================] - 9s 90ms/step - loss: 0.0223
# Epoch 237/300
# 100/100 [==============================] - 9s 91ms/step - loss: 0.0125
# Epoch 238/300
# 100/100 [==============================] - 9s 90ms/step - loss: 0.0120
# Epoch 239/300
# 100/100 [==============================] - 9s 90ms/step - loss: 0.0118
# Epoch 240/300
# 100/100 [==============================] - 9s 91ms/step - loss: 0.0074
# Epoch 241/300
# 100/100 [==============================] - 9s 91ms/step - loss: 0.0119
# Epoch 242/300
# 100/100 [==============================] - 9s 91ms/step - loss: 0.0085
# Epoch 243/300
# 100/100 [==============================] - 9s 91ms/step - loss: 0.0071
# Epoch 244/300
# 100/100 [==============================] - 9s 91ms/step - loss: 0.0140
# Epoch 245/300
# 100/100 [==============================] - 9s 91ms/step - loss: 0.0169
# Epoch 246/300
# 100/100 [==============================] - 9s 91ms/step - loss: 0.0084
# Epoch 247/300
# 100/100 [==============================] - 9s 92ms/step - loss: 0.0117
# Epoch 248/300
# 100/100 [==============================] - 9s 92ms/step - loss: 0.0047
# Epoch 249/300
# 100/100 [==============================] - 9s 91ms/step - loss: 0.0083
# Epoch 250/300
# 100/100 [==============================] - 9s 91ms/step - loss: 0.0107
# Epoch 251/300
# 100/100 [==============================] - 9s 91ms/step - loss: 0.0096
# Epoch 252/300
# 100/100 [==============================] - 9s 91ms/step - loss: 0.0139
# Epoch 253/300
# 100/100 [==============================] - 9s 91ms/step - loss: 0.0089
# Epoch 254/300
# 100/100 [==============================] - 9s 91ms/step - loss: 0.0182
# Epoch 255/300
# 100/100 [==============================] - 9s 91ms/step - loss: 0.0112
# Epoch 256/300
# 100/100 [==============================] - 9s 91ms/step - loss: 0.0081
# Epoch 257/300
# 100/100 [==============================] - 9s 91ms/step - loss: 0.0102
# Epoch 258/300
# 100/100 [==============================] - 9s 92ms/step - loss: 0.0041
# Epoch 259/300
# 100/100 [==============================] - 9s 90ms/step - loss: 0.0079
# Epoch 260/300
# 100/100 [==============================] - 9s 90ms/step - loss: 0.0102
# Epoch 261/300
# 100/100 [==============================] - 9s 90ms/step - loss: 0.0061
# Epoch 262/300
# 100/100 [==============================] - 9s 90ms/step - loss: 0.0018
# Epoch 263/300
# 100/100 [==============================] - 9s 91ms/step - loss: 0.0059
# Epoch 264/300
# 100/100 [==============================] - 9s 91ms/step - loss: 0.0049
# Epoch 265/300
# 100/100 [==============================] - 9s 92ms/step - loss: 0.0129
# Epoch 266/300
# 100/100 [==============================] - 9s 91ms/step - loss: 0.0045
# Epoch 267/300
# 100/100 [==============================] - 9s 91ms/step - loss: 0.0098
# Epoch 268/300
# 100/100 [==============================] - 9s 90ms/step - loss: 0.0053
# Epoch 269/300
# 100/100 [==============================] - 9s 91ms/step - loss: 0.0028
# Epoch 270/300
# 100/100 [==============================] - 9s 91ms/step - loss: 0.0054
# Epoch 271/300
# 100/100 [==============================] - 9s 91ms/step - loss: 0.0084
# Epoch 272/300
# 100/100 [==============================] - 9s 91ms/step - loss: 0.0084
# Epoch 273/300
# 100/100 [==============================] - 9s 91ms/step - loss: 0.0050
# Epoch 274/300
# 100/100 [==============================] - 9s 91ms/step - loss: 0.0054
# Epoch 275/300
# 100/100 [==============================] - 9s 91ms/step - loss: 0.0094
# Epoch 276/300
# 100/100 [==============================] - 9s 91ms/step - loss: 0.0048
# Epoch 277/300
# 100/100 [==============================] - 9s 91ms/step - loss: 0.0113
# Epoch 278/300
# 100/100 [==============================] - 9s 91ms/step - loss: 0.0037
# Epoch 279/300
# 100/100 [==============================] - 9s 91ms/step - loss: 0.0060
# Epoch 280/300
# 100/100 [==============================] - 9s 91ms/step - loss: 0.0064
# Epoch 281/300
# 100/100 [==============================] - 9s 92ms/step - loss: 0.0059
# Epoch 282/300
# 100/100 [==============================] - 9s 93ms/step - loss: 0.0050
# Epoch 283/300
# 100/100 [==============================] - 9s 91ms/step - loss: 0.0054
# Epoch 284/300
# 100/100 [==============================] - 9s 91ms/step - loss: 0.0068
# Epoch 285/300
# 100/100 [==============================] - 9s 91ms/step - loss: 0.0116
# Epoch 286/300
# 100/100 [==============================] - 9s 91ms/step - loss: 0.0052
# Epoch 287/300
# 100/100 [==============================] - 9s 90ms/step - loss: 0.0053
# Epoch 288/300
# 100/100 [==============================] - 9s 91ms/step - loss: 0.0111
# Epoch 289/300
# 100/100 [==============================] - 9s 91ms/step - loss: 0.0067
# Epoch 290/300
# 100/100 [==============================] - 9s 91ms/step - loss: 0.0035
# Epoch 291/300
# 100/100 [==============================] - 9s 91ms/step - loss: 0.0131
# Epoch 292/300
# 100/100 [==============================] - 9s 90ms/step - loss: 0.0036
# Epoch 293/300
# 100/100 [==============================] - 9s 92ms/step - loss: 0.0043
# Epoch 294/300
# 100/100 [==============================] - 9s 91ms/step - loss: 0.0053
# Epoch 295/300
# 100/100 [==============================] - 9s 91ms/step - loss: 0.0047
# Epoch 296/300
# 100/100 [==============================] - 9s 91ms/step - loss: 0.0036
# Epoch 297/300
# 100/100 [==============================] - 9s 92ms/step - loss: 0.0080
# Epoch 298/300
# 100/100 [==============================] - 9s 91ms/step - loss: 0.0018
# Epoch 299/300
# 100/100 [==============================] - 9s 91ms/step - loss: 0.0034
# Epoch 300/300
# 100/100 [==============================] - 9s 91ms/step - loss: 0.0062

# %% [markdown]
# ## Visualise Loss function

# %%
#print(result.history.keys())

plt.rcParams['figure.figsize'] = [10, 10]

# summarize history for loss
plt.plot(result_1.history['loss'])
plt.plot(result_2.history['loss'])
plt.plot(result_3.history['loss'])
plt.plot(result_4.history['loss'])

plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.rc('font', size=12)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=20)    # legend fontsize
plt.rc('figure', titlesize=20)  # fontsize of the figure title
plt.legend(['$\Delta_v$','$20\Delta_v$','$40\Delta_v$','$100\Delta_v$'], loc='upper left')
plt.yscale("log")
plt.show()

# %% [markdown]
# ## Plot trajectories generated to $t=32$ by Verlet integrator and neural

# %%
# Final time
T_final = 32

# Initial conditions
x = np.zeros(1)
v = np.zeros(1)
x[0] = 2.70
v[0] = -0.6
verlet_SHO.set_state(x,v)

# ==== Verlet integrator ====
t = 0.0
t_verlet_SHO = []
x_verlet_SHO = []
v_verlet_SHO = []
E_verlet_SHO = []



while t<T_final:
    t_verlet_SHO.append(t)
    E_verlet_SHO.append(verlet_SHO.energy())
    x_verlet_SHO.append(verlet_SHO.x[0])
    v_verlet_SHO.append(verlet_SHO.v[0])
    verlet_SHO.integrate(1)
    t += dt_verlet
        

# ==== Neural network integrator ====



# Initialise with Verlet integrator
x_initial_1 = np.zeros((hnn_integrator_1.nsteps,hnn_integrator_1.dynamical_system.dim))
v_initial_1 = np.zeros((hnn_integrator_1.nsteps,hnn_integrator_1.dynamical_system.dim))
x_initial_2 = np.zeros((hnn_integrator_2.nsteps,hnn_integrator_2.dynamical_system.dim))
v_initial_2 = np.zeros((hnn_integrator_2.nsteps,hnn_integrator_2.dynamical_system.dim))
x_initial_3 = np.zeros((hnn_integrator_3.nsteps,hnn_integrator_3.dynamical_system.dim))
v_initial_3 = np.zeros((hnn_integrator_3.nsteps,hnn_integrator_3.dynamical_system.dim))
x_initial_4 = np.zeros((hnn_integrator_4.nsteps,hnn_integrator_4.dynamical_system.dim))
v_initial_4 = np.zeros((hnn_integrator_4.nsteps,hnn_integrator_4.dynamical_system.dim))



verlet_SHO.set_state(x,v)
for k in range(hnn_integrator_1.nsteps):    
    x_initial_1[k,:] = verlet_SHO.x[:]
    v_initial_1[k,:] = verlet_SHO.v[:]
    verlet_SHO.integrate(int(dt_1/dt_verlet))
verlet_SHO.set_state(x,v)
for k in range(hnn_integrator_2.nsteps):    
    x_initial_2[k,:] = verlet_SHO.x[:]
    v_initial_2[k,:] = verlet_SHO.v[:]
    verlet_SHO.integrate(int(dt_2/dt_verlet))
verlet_SHO.set_state(x,v)
for k in range(hnn_integrator_3.nsteps):    
    x_initial_3[k,:] = verlet_SHO.x[:]
    v_initial_3[k,:] = verlet_SHO.v[:]
    verlet_SHO.integrate(int(dt_3/dt_verlet))
verlet_SHO.set_state(x,v)
for k in range(hnn_integrator_4.nsteps):    
    x_initial_4[k,:] = verlet_SHO.x[:]
    v_initial_4[k,:] = verlet_SHO.v[:]
    verlet_SHO.integrate(int(dt_4/dt_verlet))


hnn_integrator_1.set_state(x_initial_1,v_initial_1)
t_1 = (hnn_integrator_1.nsteps-1)*hnn_integrator_1.dt
hnn_integrator_2.set_state(x_initial_2,v_initial_2)
t_2 = (hnn_integrator_2.nsteps-1)*hnn_integrator_2.dt
hnn_integrator_3.set_state(x_initial_3,v_initial_3)
t_3 = (hnn_integrator_3.nsteps-1)*hnn_integrator_3.dt
hnn_integrator_4.set_state(x_initial_4,v_initial_4)
t_4 = (hnn_integrator_4.nsteps-1)*hnn_integrator_4.dt



# Timestepping loop
t_hnn_1 = []
x_hnn_1 = []
v_hnn_1 = []
E_hnn_1 = []
t_hnn_2 = []
x_hnn_2 = []
v_hnn_2 = []
E_hnn_2 = []
t_hnn_3 = []
x_hnn_3 = []
v_hnn_3 = []
E_hnn_3 = []
t_hnn_4 = []
x_hnn_4 = []
v_hnn_4 = []
E_hnn_4 = []


while t_1<T_final:
    t_hnn_1.append(t_1)
    x_hnn_1.append(hnn_integrator_1.x[0])
    v_hnn_1.append(hnn_integrator_1.v[0])
    E_hnn_1.append(hnn_integrator_1.energy())
    hnn_integrator_1.integrate(1)
    t_1 += dt_1
while t_2<T_final:
    t_hnn_2.append(t_2)
    x_hnn_2.append(hnn_integrator_2.x[0])
    v_hnn_2.append(hnn_integrator_2.v[0])
    E_hnn_2.append(hnn_integrator_2.energy())
    hnn_integrator_2.integrate(1)
    t_2 += dt_2
while t_3<T_final:
    t_hnn_3.append(t_3)
    x_hnn_3.append(hnn_integrator_3.x[0])
    v_hnn_3.append(hnn_integrator_3.v[0])
    E_hnn_3.append(hnn_integrator_3.energy())
    hnn_integrator_3.integrate(1)
    t_3 += dt_3
while t_4<T_final:
    t_hnn_4.append(t_4)
    x_hnn_4.append(hnn_integrator_4.x[0])
    v_hnn_4.append(hnn_integrator_4.v[0])
    E_hnn_4.append(hnn_integrator_4.energy())
    hnn_integrator_4.integrate(1)
    t_4 += dt_4
 



x_hnn_1 = np.array(x_hnn_1)
x_hnn_2 = np.array(x_hnn_2)
x_hnn_3 = np.array(x_hnn_3)
x_hnn_4 = np.array(x_hnn_4)
x_verlet_SHO = np.array(x_verlet_SHO)
v_hnn_1 = np.array(v_hnn_1)
v_hnn_2 = np.array(v_hnn_2)
v_hnn_3 = np.array(v_hnn_3)
v_hnn_4 = np.array(v_hnn_4)
v_verlet_SHO = np.array(v_verlet_SHO)

# %%
nsteps = 1

# Plot position error as a function of time
plt.clf()
plt.rcParams['figure.figsize'] = [10, 10]

plt.plot(t_hnn_1,x_hnn_1-x_verlet_SHO[int((nsteps-1)*dt_1/dt_verlet)::int(dt_1/dt_verlet)],label='$\Delta_v$',color='blue')
plt.plot(t_hnn_2,x_hnn_2-x_verlet_SHO[int((nsteps-1)*dt_2/dt_verlet):int(np.size(x_verlet_SHO)-dt_2/dt_verlet):int(dt_2/dt_verlet)],label='$20\Delta_v$',color='orange')
plt.plot(t_hnn_3,x_hnn_3-x_verlet_SHO[int((nsteps-1)*dt_3/dt_verlet)::int(dt_3/dt_verlet)],label='$40\Delta_v$',color='green')
plt.plot(t_hnn_4,x_hnn_4-x_verlet_SHO[int((nsteps-1)*dt_4/dt_verlet):int(np.size(x_verlet_SHO)-dt_4/dt_verlet):int(dt_4/dt_verlet)],label='$100\Delta_v$',color='red')
plt.legend(loc='upper left')
ax = plt.gca()
ax.set_xlabel('time $t$')
ax.set_ylabel('position Error $x_{NN}(t)-x_V(t)$')
ax.set_title('Position Error')
plt.rc('font', size=12)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=20)    # legend fontsize
plt.rc('figure', titlesize=20)  # fontsize of the figure title
#plt.grid()
plt.show()

# Plot velocity error as a function of time

plt.plot(t_hnn_1,v_hnn_1-v_verlet_SHO[int((nsteps-1)*dt_1/dt_verlet)::int(dt_1/dt_verlet)],label='$\Delta_v$',color='blue')
plt.plot(t_hnn_2,v_hnn_2-v_verlet_SHO[int((nsteps-1)*dt_2/dt_verlet):int(np.size(v_verlet_SHO)-dt_2/dt_verlet):int(dt_2/dt_verlet)],label='$20\Delta_v$',color='orange')
plt.plot(t_hnn_3,v_hnn_3-v_verlet_SHO[int((nsteps-1)*dt_3/dt_verlet)::int(dt_3/dt_verlet)],label='$40\Delta_v$',color='green')
plt.plot(t_hnn_4,v_hnn_4-v_verlet_SHO[int((nsteps-1)*dt_4/dt_verlet):int(np.size(v_verlet_SHO)-dt_4/dt_verlet):int(dt_4/dt_verlet)],label='$100\Delta_v$',color='red')
plt.legend(loc='upper left')
ax = plt.gca()
ax.set_xlabel('time $t$')
ax.set_ylabel('Velocity Error $v_{NN}(t)-v_V(t)$')
ax.set_title('Velocity Error')
plt.rc('font', size=12)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=20)    # legend fontsize
plt.rc('figure', titlesize=20)  # fontsize of the figure title
#plt.grid()
plt.show()

# Plot L2 error as a function of time

plt.plot(t_hnn_1,((v_hnn_1-v_verlet_SHO[int((nsteps-1)*dt_1/dt_verlet)::int(dt_1/dt_verlet)])**2+(x_hnn_1-x_verlet_SHO[int((nsteps-1)*dt_1/dt_verlet)::int(dt_1/dt_verlet)])**2)**0.5,label='$\Delta_v$',color='blue')
plt.plot(t_hnn_2,((v_hnn_2-v_verlet_SHO[int((nsteps-1)*dt_2/dt_verlet):int(np.size(v_verlet_SHO)-dt_2/dt_verlet):int(dt_2/dt_verlet)])**2+(x_hnn_2-x_verlet_SHO[int((nsteps-1)*dt_2/dt_verlet):int(np.size(x_verlet_SHO)-dt_2/dt_verlet):int(dt_2/dt_verlet)])**2)**0.5,label='$20\Delta_v$',color='orange')
plt.plot(t_hnn_3,((v_hnn_3-v_verlet_SHO[int((nsteps-1)*dt_3/dt_verlet)::int(dt_3/dt_verlet)])**2+(x_hnn_3-x_verlet_SHO[int((nsteps-1)*dt_3/dt_verlet)::int(dt_3/dt_verlet)])**2)**0.5,label='$40\Delta_v$',color='green')
plt.plot(t_hnn_4,((v_hnn_4-v_verlet_SHO[int((nsteps-1)*dt_4/dt_verlet):int(np.size(v_verlet_SHO)-dt_4/dt_verlet):int(dt_4/dt_verlet)])**2+(x_hnn_4-x_verlet_SHO[int((nsteps-1)*dt_4/dt_verlet):int(np.size(x_verlet_SHO)-dt_4/dt_verlet):int(dt_4/dt_verlet)])**2)**0.5,label='$100\Delta_v$',color='red')
plt.legend(loc='upper left')
ax = plt.gca()
ax.set_xlabel('time $t$')
ax.set_ylabel('L2 Error')
ax.set_title('L2 Error')
plt.rc('font', size=12)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=20)    # legend fontsize
plt.rc('figure', titlesize=20)  # fontsize of the figure title
#plt.grid()
plt.show()


plt.clf()
# Plot energy as a function of time
# (subtract energy at time t=0 to show energy drift)

plt.plot(t_verlet_SHO,E_verlet_SHO-E_verlet_SHO[0],label='Verlet',color='black')
plt.plot(t_hnn_1,E_hnn_1-E_hnn_1[0],label='$\Delta_v$',color='blue')
plt.plot(t_hnn_2,E_hnn_2-E_hnn_2[0],label='$20\Delta_v$',color='orange')
plt.plot(t_hnn_3,E_hnn_3-E_hnn_3[0],label='$40\Delta_v$',color='green')
plt.plot(t_hnn_4,E_hnn_4-E_hnn_4[0],label='$100\Delta_v$',color='red')
plt.legend(loc='upper left')
ax = plt.gca()
ax.set_xlabel('time $t$')
ax.set_ylabel('energy shift $E(t)-E(t_0)$')
#ax.grid()
plt.rc('font', size=12)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=20)    # legend fontsize
plt.rc('figure', titlesize=20)  # fontsize of the figure title

plt.show()

#subplots of position versus velocity for all 4

plt.rcParams['figure.figsize'] = [10, 10]

plt.clf()
plt.plot(x_verlet_SHO,v_verlet_SHO,label='Verlet',color='black')
plt.plot(x_hnn_1,v_hnn_1,label='$\Delta_v$',color='blue')
plt.plot(x_hnn_2,v_hnn_2,label='$20\Delta_v$',color='orange')
plt.plot(x_hnn_3,v_hnn_3,label='$40\Delta_v$',color='green')
plt.plot(x_hnn_4,v_hnn_4,label='$100\Delta_v$',color='red')
plt.legend(loc='upper left')
ax = plt.gca()
ax.set_ylabel('Velocity $v(t)$')
ax.set_xlabel('Position $q(t)$')
plt.rc('font', size=12)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=20)    # legend fontsize
plt.rc('figure', titlesize=20)  # fontsize of the figure title
plt.show()

# %% [markdown]
# ## Plot trajectories generated to $t=128$ by Verlet integrator and neural

# %%
# Final time
T_final = 128

# Initial conditions
x = np.zeros(1)
v = np.zeros(1)
x[0] = 2.70
v[0] = -0.6
verlet_SHO.set_state(x,v)

# ==== Verlet integrator ====
t = 0.0
t_verlet_SHO = []
x_verlet_SHO = []
v_verlet_SHO = []
E_verlet_SHO = []



while t<T_final:
    t_verlet_SHO.append(t)
    E_verlet_SHO.append(verlet_SHO.energy())
    x_verlet_SHO.append(verlet_SHO.x[0])
    v_verlet_SHO.append(verlet_SHO.v[0])
    verlet_SHO.integrate(1)
    t += dt_verlet
        

# ==== Neural network integrator ====

# Initialise with Verlet integrator
x_initial_1 = np.zeros((hnn_integrator_1.nsteps,hnn_integrator_1.dynamical_system.dim))
v_initial_1 = np.zeros((hnn_integrator_1.nsteps,hnn_integrator_1.dynamical_system.dim))
x_initial_2 = np.zeros((hnn_integrator_2.nsteps,hnn_integrator_2.dynamical_system.dim))
v_initial_2 = np.zeros((hnn_integrator_2.nsteps,hnn_integrator_2.dynamical_system.dim))
x_initial_3 = np.zeros((hnn_integrator_3.nsteps,hnn_integrator_3.dynamical_system.dim))
v_initial_3 = np.zeros((hnn_integrator_3.nsteps,hnn_integrator_3.dynamical_system.dim))
x_initial_4 = np.zeros((hnn_integrator_4.nsteps,hnn_integrator_4.dynamical_system.dim))
v_initial_4 = np.zeros((hnn_integrator_4.nsteps,hnn_integrator_4.dynamical_system.dim))



verlet_SHO.set_state(x,v)
for k in range(hnn_integrator_1.nsteps):    
    x_initial_1[k,:] = verlet_SHO.x[:]
    v_initial_1[k,:] = verlet_SHO.v[:]
    verlet_SHO.integrate(int(dt_1/dt_verlet))
verlet_SHO.set_state(x,v)
for k in range(hnn_integrator_2.nsteps):    
    x_initial_2[k,:] = verlet_SHO.x[:]
    v_initial_2[k,:] = verlet_SHO.v[:]
    verlet_SHO.integrate(int(dt_2/dt_verlet))
verlet_SHO.set_state(x,v)
for k in range(hnn_integrator_3.nsteps):    
    x_initial_3[k,:] = verlet_SHO.x[:]
    v_initial_3[k,:] = verlet_SHO.v[:]
    verlet_SHO.integrate(int(dt_3/dt_verlet))
verlet_SHO.set_state(x,v)
for k in range(hnn_integrator_4.nsteps):    
    x_initial_4[k,:] = verlet_SHO.x[:]
    v_initial_4[k,:] = verlet_SHO.v[:]
    verlet_SHO.integrate(int(dt_4/dt_verlet))


hnn_integrator_1.set_state(x_initial_1,v_initial_1)
t_1 = (hnn_integrator_1.nsteps-1)*hnn_integrator_1.dt
hnn_integrator_2.set_state(x_initial_2,v_initial_2)
t_2 = (hnn_integrator_2.nsteps-1)*hnn_integrator_2.dt
hnn_integrator_3.set_state(x_initial_3,v_initial_3)
t_3 = (hnn_integrator_3.nsteps-1)*hnn_integrator_3.dt
hnn_integrator_4.set_state(x_initial_4,v_initial_4)
t_4 = (hnn_integrator_4.nsteps-1)*hnn_integrator_4.dt



# Timestepping loop
t_hnn_1 = []
x_hnn_1 = []
v_hnn_1 = []
E_hnn_1 = []
t_hnn_2 = []
x_hnn_2 = []
v_hnn_2 = []
E_hnn_2 = []
t_hnn_3 = []
x_hnn_3 = []
v_hnn_3 = []
E_hnn_3 = []
t_hnn_4 = []
x_hnn_4 = []
v_hnn_4 = []
E_hnn_4 = []


while t_1<T_final:
    t_hnn_1.append(t_1)
    x_hnn_1.append(hnn_integrator_1.x[0])
    v_hnn_1.append(hnn_integrator_1.v[0])
    E_hnn_1.append(hnn_integrator_1.energy())
    hnn_integrator_1.integrate(1)
    t_1 += dt_1
while t_2<T_final:
    t_hnn_2.append(t_2)
    x_hnn_2.append(hnn_integrator_2.x[0])
    v_hnn_2.append(hnn_integrator_2.v[0])
    E_hnn_2.append(hnn_integrator_2.energy())
    hnn_integrator_2.integrate(1)
    t_2 += dt_2
while t_3<T_final:
    t_hnn_3.append(t_3)
    x_hnn_3.append(hnn_integrator_3.x[0])
    v_hnn_3.append(hnn_integrator_3.v[0])
    E_hnn_3.append(hnn_integrator_3.energy())
    hnn_integrator_3.integrate(1)
    t_3 += dt_3
while t_4<T_final:
    t_hnn_4.append(t_4)
    x_hnn_4.append(hnn_integrator_4.x[0])
    v_hnn_4.append(hnn_integrator_4.v[0])
    E_hnn_4.append(hnn_integrator_4.energy())
    hnn_integrator_4.integrate(1)
    t_4 += dt_4
 



x_hnn_1 = np.array(x_hnn_1)
x_hnn_2 = np.array(x_hnn_2)
x_hnn_3 = np.array(x_hnn_3)
x_hnn_4 = np.array(x_hnn_4)
x_verlet_SHO = np.array(x_verlet_SHO)
v_hnn_1 = np.array(v_hnn_1)
v_hnn_2 = np.array(v_hnn_2)
v_hnn_3 = np.array(v_hnn_3)
v_hnn_4 = np.array(v_hnn_4)
v_verlet_SHO = np.array(v_verlet_SHO)


# Plot position error as a function of time

nsteps = 1


plt.clf()
plt.rcParams['figure.figsize'] = [10, 10]

plt.plot(t_hnn_1,x_hnn_1-x_verlet_SHO[int((nsteps-1)*dt_1/dt_verlet)::int(dt_1/dt_verlet)],label='$\Delta_v$',color='blue')
plt.plot(t_hnn_2,x_hnn_2-x_verlet_SHO[int((nsteps-1)*dt_2/dt_verlet)::int(dt_2/dt_verlet)],label='$20\Delta_v$',color='orange')
plt.plot(t_hnn_3,x_hnn_3-x_verlet_SHO[int((nsteps-1)*dt_3/dt_verlet):int(np.size(x_verlet_SHO)-dt_3/dt_verlet):int(dt_3/dt_verlet)],label='$40\Delta_v$',color='green')
plt.plot(t_hnn_4,x_hnn_4-x_verlet_SHO[int((nsteps-1)*dt_4/dt_verlet):int(np.size(x_verlet_SHO)-dt_4/dt_verlet):int(dt_4/dt_verlet)],label='$100\Delta_v$',color='red')
plt.legend(loc='upper left')
ax = plt.gca()
ax.set_xlabel('time $t$')
ax.set_ylabel('position Error $x_{NN}(t)-x_V(t)$')
ax.set_title('Position Error')
plt.rc('font', size=12)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=20)    # legend fontsize
plt.rc('figure', titlesize=20)  # fontsize of the figure title
#plt.grid()
plt.show()

# Plot velocity error as a function of time

plt.plot(t_hnn_1,v_hnn_1-v_verlet_SHO[int((nsteps-1)*dt_1/dt_verlet)::int(dt_1/dt_verlet)],label='$\Delta_v$',color='blue')
plt.plot(t_hnn_2,v_hnn_2-v_verlet_SHO[int((nsteps-1)*dt_2/dt_verlet)::int(dt_2/dt_verlet)],label='$20\Delta_v$',color='orange')
plt.plot(t_hnn_3,v_hnn_3-v_verlet_SHO[int((nsteps-1)*dt_3/dt_verlet):int(np.size(v_verlet_SHO)-dt_3/dt_verlet):int(dt_3/dt_verlet)],label='$40\Delta_v$',color='green')
plt.plot(t_hnn_4,v_hnn_4-v_verlet_SHO[int((nsteps-1)*dt_4/dt_verlet):int(np.size(v_verlet_SHO)-dt_4/dt_verlet):int(dt_4/dt_verlet)],label='$100\Delta_v$',color='red')
plt.legend(loc='upper left')
ax = plt.gca()
ax.set_xlabel('time $t$')
ax.set_ylabel('Velocity Error $v_{NN}(t)-v_V(t)$')
ax.set_title('Velocity Error')
plt.rc('font', size=12)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=20)    # legend fontsize
plt.rc('figure', titlesize=20)  # fontsize of the figure title
#plt.grid()
plt.show()

# Plot L2 error as a function of time

plt.plot(t_hnn_1,((v_hnn_1-v_verlet_SHO[int((nsteps-1)*dt_1/dt_verlet)::int(dt_1/dt_verlet)])**2+(x_hnn_1-x_verlet_SHO[int((nsteps-1)*dt_1/dt_verlet)::int(dt_1/dt_verlet)])**2)**0.5,label='$\Delta_v$',color='blue')
plt.plot(t_hnn_2,((v_hnn_2-v_verlet_SHO[int((nsteps-1)*dt_2/dt_verlet)::int(dt_2/dt_verlet)])**2+(x_hnn_2-x_verlet_SHO[int((nsteps-1)*dt_2/dt_verlet)::int(dt_2/dt_verlet)])**2)**0.5,label='$20\Delta_v$',color='orange')
plt.plot(t_hnn_3,((v_hnn_3-v_verlet_SHO[int((nsteps-1)*dt_3/dt_verlet):int(np.size(v_verlet_SHO)-dt_3/dt_verlet):int(dt_3/dt_verlet)])**2+(x_hnn_3-x_verlet_SHO[int((nsteps-1)*dt_3/dt_verlet):int(np.size(x_verlet_SHO)-dt_3/dt_verlet):int(dt_3/dt_verlet)])**2)**0.5,label='$40\Delta_v$',color='green')
plt.plot(t_hnn_4,((v_hnn_4-v_verlet_SHO[int((nsteps-1)*dt_4/dt_verlet):int(np.size(v_verlet_SHO)-dt_4/dt_verlet):int(dt_4/dt_verlet)])**2+(x_hnn_4-x_verlet_SHO[int((nsteps-1)*dt_4/dt_verlet):int(np.size(x_verlet_SHO)-dt_4/dt_verlet):int(dt_4/dt_verlet)])**2)**0.5,label='$100\Delta_v$',color='red')
plt.legend(loc='upper left')
ax = plt.gca()
ax.set_xlabel('time $t$')
ax.set_ylabel('L2 Error')
ax.set_title('L2 Error')
plt.rc('font', size=12)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=20)    # legend fontsize
plt.rc('figure', titlesize=20)  # fontsize of the figure title
#plt.grid()
plt.show()


plt.clf()
# Plot energy as a function of time
# (subtract energy at time t=0 to show energy drift)

plt.plot(t_verlet_SHO,E_verlet_SHO-E_verlet_SHO[0],label='Verlet',color='black')
plt.plot(t_hnn_1,E_hnn_1-E_hnn_1[0],label='$\Delta_v$',color='blue')
plt.plot(t_hnn_2,E_hnn_2-E_hnn_2[0],label='$20\Delta_v$',color='orange')
plt.plot(t_hnn_3,E_hnn_3-E_hnn_3[0],label='$40\Delta_v$',color='green')
plt.plot(t_hnn_4,E_hnn_4-E_hnn_4[0],label='$100\Delta_v$',color='red')
plt.legend(loc='upper left')
ax = plt.gca()
ax.set_xlabel('time $t$')
ax.set_ylabel('energy shift $E(t)-E(t_0)$')
#ax.grid()
plt.rc('font', size=12)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=20)    # legend fontsize
plt.rc('figure', titlesize=20)  # fontsize of the figure title

plt.show()

#subplots of position versus velocity for all 4

plt.rcParams['figure.figsize'] = [10, 10]

plt.clf()
plt.plot(x_verlet_SHO,v_verlet_SHO,label='Verlet',color='black')
plt.plot(x_hnn_1,v_hnn_1,label='$\Delta_v$',color='blue')
plt.plot(x_hnn_2,v_hnn_2,label='$20\Delta_v$',color='orange')
plt.plot(x_hnn_3,v_hnn_3,label='$40\Delta_v$',color='green')
plt.plot(x_hnn_4,v_hnn_4,label='$100\Delta_v$',color='red')
plt.legend(loc='upper left')
ax = plt.gca()
ax.set_ylabel('Velocity $v(t)$')
ax.set_xlabel('Position $q(t)$')
plt.rc('font', size=12)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=20)    # legend fontsize
plt.rc('figure', titlesize=20)  # fontsize of the figure title
plt.show()

# %% [markdown]
# ## Plot trajectories generated to $t=512$ by Verlet integrator and neural

# %%
# Final time
T_final = 512

# Initial conditions
x = np.zeros(1)
v = np.zeros(1)
x[0] = 2.70
v[0] = -0.6
verlet_SHO.set_state(x,v)

# ==== Verlet integrator ====
t = 0.0
t_verlet_SHO = []
x_verlet_SHO = []
v_verlet_SHO = []
E_verlet_SHO = []



while t<T_final:
    t_verlet_SHO.append(t)
    E_verlet_SHO.append(verlet_SHO.energy())
    x_verlet_SHO.append(verlet_SHO.x[0])
    v_verlet_SHO.append(verlet_SHO.v[0])
    verlet_SHO.integrate(1)
    t += dt_verlet
        

# ==== Neural network integrator ====

# Initialise with Verlet integrator
x_initial_1 = np.zeros((hnn_integrator_1.nsteps,hnn_integrator_1.dynamical_system.dim))
v_initial_1 = np.zeros((hnn_integrator_1.nsteps,hnn_integrator_1.dynamical_system.dim))
x_initial_2 = np.zeros((hnn_integrator_2.nsteps,hnn_integrator_2.dynamical_system.dim))
v_initial_2 = np.zeros((hnn_integrator_2.nsteps,hnn_integrator_2.dynamical_system.dim))
x_initial_3 = np.zeros((hnn_integrator_3.nsteps,hnn_integrator_3.dynamical_system.dim))
v_initial_3 = np.zeros((hnn_integrator_3.nsteps,hnn_integrator_3.dynamical_system.dim))
x_initial_4 = np.zeros((hnn_integrator_4.nsteps,hnn_integrator_4.dynamical_system.dim))
v_initial_4 = np.zeros((hnn_integrator_4.nsteps,hnn_integrator_4.dynamical_system.dim))



verlet_SHO.set_state(x,v)
for k in range(hnn_integrator_1.nsteps):    
    x_initial_1[k,:] = verlet_SHO.x[:]
    v_initial_1[k,:] = verlet_SHO.v[:]
    verlet_SHO.integrate(int(dt_1/dt_verlet))
verlet_SHO.set_state(x,v)
for k in range(hnn_integrator_2.nsteps):    
    x_initial_2[k,:] = verlet_SHO.x[:]
    v_initial_2[k,:] = verlet_SHO.v[:]
    verlet_SHO.integrate(int(dt_2/dt_verlet))
verlet_SHO.set_state(x,v)
for k in range(hnn_integrator_3.nsteps):    
    x_initial_3[k,:] = verlet_SHO.x[:]
    v_initial_3[k,:] = verlet_SHO.v[:]
    verlet_SHO.integrate(int(dt_3/dt_verlet))
verlet_SHO.set_state(x,v)
for k in range(hnn_integrator_4.nsteps):    
    x_initial_4[k,:] = verlet_SHO.x[:]
    v_initial_4[k,:] = verlet_SHO.v[:]
    verlet_SHO.integrate(int(dt_4/dt_verlet))


hnn_integrator_1.set_state(x_initial_1,v_initial_1)
t_1 = (hnn_integrator_1.nsteps-1)*hnn_integrator_1.dt
hnn_integrator_2.set_state(x_initial_2,v_initial_2)
t_2 = (hnn_integrator_2.nsteps-1)*hnn_integrator_2.dt
hnn_integrator_3.set_state(x_initial_3,v_initial_3)
t_3 = (hnn_integrator_3.nsteps-1)*hnn_integrator_3.dt
hnn_integrator_4.set_state(x_initial_4,v_initial_4)
t_4 = (hnn_integrator_4.nsteps-1)*hnn_integrator_4.dt



# Timestepping loop
t_hnn_1 = []
x_hnn_1 = []
v_hnn_1 = []
E_hnn_1 = []
t_hnn_2 = []
x_hnn_2 = []
v_hnn_2 = []
E_hnn_2 = []
t_hnn_3 = []
x_hnn_3 = []
v_hnn_3 = []
E_hnn_3 = []
t_hnn_4 = []
x_hnn_4 = []
v_hnn_4 = []
E_hnn_4 = []


while t_1<T_final:
    t_hnn_1.append(t_1)
    x_hnn_1.append(hnn_integrator_1.x[0])
    v_hnn_1.append(hnn_integrator_1.v[0])
    E_hnn_1.append(hnn_integrator_1.energy())
    hnn_integrator_1.integrate(1)
    t_1 += dt_1
while t_2<T_final:
    t_hnn_2.append(t_2)
    x_hnn_2.append(hnn_integrator_2.x[0])
    v_hnn_2.append(hnn_integrator_2.v[0])
    E_hnn_2.append(hnn_integrator_2.energy())
    hnn_integrator_2.integrate(1)
    t_2 += dt_2
while t_3<T_final:
    t_hnn_3.append(t_3)
    x_hnn_3.append(hnn_integrator_3.x[0])
    v_hnn_3.append(hnn_integrator_3.v[0])
    E_hnn_3.append(hnn_integrator_3.energy())
    hnn_integrator_3.integrate(1)
    t_3 += dt_3
while t_4<T_final:
    t_hnn_4.append(t_4)
    x_hnn_4.append(hnn_integrator_4.x[0])
    v_hnn_4.append(hnn_integrator_4.v[0])
    E_hnn_4.append(hnn_integrator_4.energy())
    hnn_integrator_4.integrate(1)
    t_4 += dt_4
 



x_hnn_1 = np.array(x_hnn_1)
x_hnn_2 = np.array(x_hnn_2)
x_hnn_3 = np.array(x_hnn_3)
x_hnn_4 = np.array(x_hnn_4)
x_verlet_SHO = np.array(x_verlet_SHO)
v_hnn_1 = np.array(v_hnn_1)
v_hnn_2 = np.array(v_hnn_2)
v_hnn_3 = np.array(v_hnn_3)
v_hnn_4 = np.array(v_hnn_4)
v_verlet_SHO = np.array(v_verlet_SHO)


nsteps = 1

# Plot position error as a function of time
plt.clf()
plt.rcParams['figure.figsize'] = [10, 10]

plt.plot(t_hnn_1,x_hnn_1-x_verlet_SHO[int((nsteps-1)*dt_1/dt_verlet)::int(dt_1/dt_verlet)],label='$\Delta_v$',color='blue')
plt.plot(t_hnn_2,x_hnn_2-x_verlet_SHO[int((nsteps-1)*dt_2/dt_verlet):int(np.size(x_verlet_SHO)-dt_2/dt_verlet):int(dt_2/dt_verlet)],label='$20\Delta_v$',color='orange')
plt.plot(t_hnn_3,x_hnn_3-x_verlet_SHO[int((nsteps-1)*dt_3/dt_verlet)::int(dt_3/dt_verlet)],label='$40\Delta_v$',color='green')
plt.plot(t_hnn_4,x_hnn_4-x_verlet_SHO[int((nsteps-1)*dt_4/dt_verlet):int(np.size(x_verlet_SHO)-dt_4/dt_verlet):int(dt_4/dt_verlet)],label='$100\Delta_v$',color='red')
plt.legend(loc='upper left')
ax = plt.gca()
ax.set_xlabel('time $t$')
ax.set_ylabel('position Error $x_{NN}(t)-x_V(t)$')
ax.set_title('Position Error')
plt.rc('font', size=12)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=20)    # legend fontsize
plt.rc('figure', titlesize=20)  # fontsize of the figure title
#plt.grid()
plt.show()

# Plot velocity error as a function of time

plt.plot(t_hnn_1,v_hnn_1-v_verlet_SHO[int((nsteps-1)*dt_1/dt_verlet)::int(dt_1/dt_verlet)],label='$\Delta_v$',color='blue')
plt.plot(t_hnn_2,v_hnn_2-v_verlet_SHO[int((nsteps-1)*dt_2/dt_verlet):int(np.size(v_verlet_SHO)-dt_2/dt_verlet):int(dt_2/dt_verlet)],label='$20\Delta_v$',color='orange')
plt.plot(t_hnn_3,v_hnn_3-v_verlet_SHO[int((nsteps-1)*dt_3/dt_verlet)::int(dt_3/dt_verlet)],label='$40\Delta_v$',color='green')
plt.plot(t_hnn_4,v_hnn_4-v_verlet_SHO[int((nsteps-1)*dt_4/dt_verlet):int(np.size(v_verlet_SHO)-dt_4/dt_verlet):int(dt_4/dt_verlet)],label='$100\Delta_v$',color='red')
plt.legend(loc='upper left')
ax = plt.gca()
ax.set_xlabel('time $t$')
ax.set_ylabel('Velocity Error $v_{NN}(t)-v_V(t)$')
ax.set_title('Velocity Error')
plt.rc('font', size=12)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=20)    # legend fontsize
plt.rc('figure', titlesize=20)  # fontsize of the figure title
#plt.grid()
plt.show()

# Plot L2 error as a function of time

plt.plot(t_hnn_1,((v_hnn_1-v_verlet_SHO[int((nsteps-1)*dt_1/dt_verlet)::int(dt_1/dt_verlet)])**2+(x_hnn_1-x_verlet_SHO[int((nsteps-1)*dt_1/dt_verlet)::int(dt_1/dt_verlet)])**2)**0.5,label='$\Delta_v$',color='blue')
plt.plot(t_hnn_2,((v_hnn_2-v_verlet_SHO[int((nsteps-1)*dt_2/dt_verlet):int(np.size(v_verlet_SHO)-dt_2/dt_verlet):int(dt_2/dt_verlet)])**2+(x_hnn_2-x_verlet_SHO[int((nsteps-1)*dt_2/dt_verlet):int(np.size(x_verlet_SHO)-dt_2/dt_verlet):int(dt_2/dt_verlet)])**2)**0.5,label='$20\Delta_v$',color='orange')
plt.plot(t_hnn_3,((v_hnn_3-v_verlet_SHO[int((nsteps-1)*dt_3/dt_verlet)::int(dt_3/dt_verlet)])**2+(x_hnn_3-x_verlet_SHO[int((nsteps-1)*dt_3/dt_verlet)::int(dt_3/dt_verlet)])**2)**0.5,label='$40\Delta_v$',color='green')
plt.plot(t_hnn_4,((v_hnn_4-v_verlet_SHO[int((nsteps-1)*dt_4/dt_verlet):int(np.size(v_verlet_SHO)-dt_4/dt_verlet):int(dt_4/dt_verlet)])**2+(x_hnn_4-x_verlet_SHO[int((nsteps-1)*dt_4/dt_verlet):int(np.size(x_verlet_SHO)-dt_4/dt_verlet):int(dt_4/dt_verlet)])**2)**0.5,label='$100\Delta_v$',color='red')
plt.legend(loc='upper left')
ax = plt.gca()
ax.set_xlabel('time $t$')
ax.set_ylabel('L2 Error')
ax.set_title('L2 Error')
plt.rc('font', size=12)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=20)    # legend fontsize
plt.rc('figure', titlesize=20)  # fontsize of the figure title
#plt.grid()
plt.show()


plt.clf()
# Plot energy as a function of time
# (subtract energy at time t=0 to show energy drift)

plt.plot(t_verlet_SHO,E_verlet_SHO-E_verlet_SHO[0],label='Verlet',color='black')
plt.plot(t_hnn_1,E_hnn_1-E_hnn_1[0],label='$\Delta_v$',color='blue')
plt.plot(t_hnn_2,E_hnn_2-E_hnn_2[0],label='$20\Delta_v$',color='orange')
plt.plot(t_hnn_3,E_hnn_3-E_hnn_3[0],label='$40\Delta_v$',color='green')
plt.plot(t_hnn_4,E_hnn_4-E_hnn_4[0],label='$100\Delta_v$',color='red')
plt.legend(loc='upper left')
ax = plt.gca()
ax.set_xlabel('time $t$')
ax.set_ylabel('energy shift $E(t)-E(t_0)$')
#ax.grid()
plt.rc('font', size=12)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=20)    # legend fontsize
plt.rc('figure', titlesize=20)  # fontsize of the figure title

plt.show()

#subplots of position versus velocity for all 4

plt.rcParams['figure.figsize'] = [10, 10]

plt.clf()
plt.plot(x_verlet_SHO,v_verlet_SHO,label='Verlet',color='black')
plt.plot(x_hnn_1,v_hnn_1,label='$\Delta_v$',color='blue')
plt.plot(x_hnn_2,v_hnn_2,label='$20\Delta_v$',color='orange')
plt.plot(x_hnn_3,v_hnn_3,label='$40\Delta_v$',color='green')
plt.plot(x_hnn_4,v_hnn_4,label='$100\Delta_v$',color='red')
plt.legend(loc='upper left')
ax = plt.gca()
ax.set_ylabel('Velocity $v(t)$')
ax.set_xlabel('Position $q(t)$')
plt.rc('font', size=12)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=20)    # legend fontsize
plt.rc('figure', titlesize=20)  # fontsize of the figure title
plt.show()
