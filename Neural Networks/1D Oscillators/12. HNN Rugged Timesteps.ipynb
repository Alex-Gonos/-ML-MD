# %% [markdown]
# # Hamiltonian neural network based integrator simulating rugged system

# %%
import sys
sys.path.append('..')

import numpy as np
from matplotlib import pyplot as plt
from Code.dynamical_system import *
from Code.time_integrator import *
from Code.neuralnet import *

np.random.seed(2512517)

# %% [markdown]
# ## Hamiltonian Neural network integrator

# %% [markdown]
# Set system parameters, construct dynamical system and integrator.
#
# The model system we are using here is the rugged oscillator.
#
# The timestep size of the Neural network integrator takes values in $\Delta t_{\text{Verlet}},20\Delta t_{\text{Verlet}},40\Delta t_{\text{Verlet}},100\Delta t_{\text{Verlet}}$ where $\Delta t_{\text{Verlet}}$ is the step size of the Verlet integrator that is used for training.

# %%
# mass of particle
mass = 1.2
# timestep for Verlet integrator
dt_verlet = 0.005
# timestep for neural network integrator
dt_1 = 0.005
dt_2 = 0.1
dt_3 = 0.2
dt_4 = 0.5

rugged_oscillator = Rugged(mass)

verlet_rugged = VerletIntegrator(rugged_oscillator,dt_verlet)

# Layers for the potential and kinetic parts of the hamiltonian

V_pot_layers = [keras.layers.Dense(32,activation='tanh'),
                    keras.layers.Dense(32,activation='tanh')]
T_kin_layers = [keras.layers.Dense(32,activation='tanh'),
                    keras.layers.Dense(32,activation='tanh')]

hnn_integrator_1 = HamiltonianNNIntegrator(rugged_oscillator,dt_1,V_pot_layers,T_kin_layers)
hnn_integrator_2 = HamiltonianNNIntegrator(rugged_oscillator,dt_2,V_pot_layers,T_kin_layers)
hnn_integrator_3 = HamiltonianNNIntegrator(rugged_oscillator,dt_3,V_pot_layers,T_kin_layers)
hnn_integrator_4 = HamiltonianNNIntegrator(rugged_oscillator,dt_4,V_pot_layers,T_kin_layers)

# visualise the neural network model
hnn_integrator_1.model.summary()
keras.utils.plot_model(hnn_integrator_1.model, show_shapes=True)
# Out:
# Model: "verlet_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               multiple                  64
#
#  dense_1 (Dense)             multiple                  1056
#
#  dense_2 (Dense)             multiple                  64
#
#  dense_3 (Dense)             multiple                  1056
#
#  dense_8 (Dense)             multiple                  32
#
#  dense_9 (Dense)             multiple                  32
#
# =================================================================
# Total params: 2,304
# Trainable params: 2,304
# Non-trainable params: 0
# _________________________________________________________________

# %%
BATCH_SIZE=64

data_generator_1 = DataGenerator(hnn_integrator_1,verlet_rugged)
train_batches_1 = data_generator_1.dataset.batch(BATCH_SIZE)

data_generator_2 = DataGenerator(hnn_integrator_2,verlet_rugged)
train_batches_2 = data_generator_2.dataset.batch(BATCH_SIZE)

data_generator_3 = DataGenerator(hnn_integrator_3,verlet_rugged)
train_batches_3 = data_generator_3.dataset.batch(BATCH_SIZE)

data_generator_4 = DataGenerator(hnn_integrator_4,verlet_rugged)
train_batches_4 = data_generator_4.dataset.batch(BATCH_SIZE)

# %% [markdown]
# ## Train neural network based integrator

# %%
EPOCHS=1000
STEPS_PER_EPOCH=100
log_dir = './tb_logs/'
tensorboard_cb = tf.keras.callbacks.TensorBoard(log_dir=log_dir)

result_1 = hnn_integrator_1.model.fit(train_batches_1,epochs=EPOCHS,steps_per_epoch=STEPS_PER_EPOCH,
                                 callbacks=tensorboard_cb)
result_2 = hnn_integrator_2.model.fit(train_batches_2,epochs=EPOCHS,steps_per_epoch=STEPS_PER_EPOCH,
                                 callbacks=tensorboard_cb)
result_3 = hnn_integrator_3.model.fit(train_batches_3,epochs=EPOCHS,steps_per_epoch=STEPS_PER_EPOCH,
                                callbacks=tensorboard_cb)
result_4 = hnn_integrator_4.model.fit(train_batches_4,epochs=EPOCHS,steps_per_epoch=STEPS_PER_EPOCH,
                                 callbacks=tensorboard_cb)
# Out:
# Streaming output truncated to the last 5000 lines.
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0441
# Epoch 502/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0467
# Epoch 503/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0425
# Epoch 504/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0483
# Epoch 505/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0420
# Epoch 506/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0483
# Epoch 507/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0421
# Epoch 508/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0464
# Epoch 509/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0518
# Epoch 510/1000
# 100/100 [==============================] - 4s 38ms/step - loss: 0.0451
# Epoch 511/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0449
# Epoch 512/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0466
# Epoch 513/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0476
# Epoch 514/1000
# 100/100 [==============================] - 4s 38ms/step - loss: 0.0499
# Epoch 515/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0449
# Epoch 516/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0444
# Epoch 517/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0430
# Epoch 518/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0443
# Epoch 519/1000
# 100/100 [==============================] - 4s 38ms/step - loss: 0.0434
# Epoch 520/1000
# 100/100 [==============================] - 4s 38ms/step - loss: 0.0473
# Epoch 521/1000
# 100/100 [==============================] - 4s 41ms/step - loss: 0.0483
# Epoch 522/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0435
# Epoch 523/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0423
# Epoch 524/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0446
# Epoch 525/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0455
# Epoch 526/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0439
# Epoch 527/1000
# 100/100 [==============================] - 4s 38ms/step - loss: 0.0501
# Epoch 528/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0442
# Epoch 529/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0401
# Epoch 530/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0456
# Epoch 531/1000
# 100/100 [==============================] - 4s 38ms/step - loss: 0.0488
# Epoch 532/1000
# 100/100 [==============================] - 4s 38ms/step - loss: 0.0408
# Epoch 533/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0450
# Epoch 534/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0420
# Epoch 535/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0508
# Epoch 536/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0527
# Epoch 537/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0412
# Epoch 538/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0400
# Epoch 539/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0440
# Epoch 540/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0465
# Epoch 541/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0418
# Epoch 542/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0419
# Epoch 543/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0449
# Epoch 544/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0460
# Epoch 545/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0473
# Epoch 546/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0440
# Epoch 547/1000
# 100/100 [==============================] - 4s 38ms/step - loss: 0.0435
# Epoch 548/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0405
# Epoch 549/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0474
# Epoch 550/1000
# 100/100 [==============================] - 4s 38ms/step - loss: 0.0436
# Epoch 551/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0437
# Epoch 552/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0398
# Epoch 553/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0427
# Epoch 554/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0413
# Epoch 555/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0454
# Epoch 556/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0402
# Epoch 557/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0451
# Epoch 558/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0392
# Epoch 559/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0441
# Epoch 560/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0425
# Epoch 561/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0444
# Epoch 562/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0414
# Epoch 563/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0450
# Epoch 564/1000
# 100/100 [==============================] - 4s 38ms/step - loss: 0.0433
# Epoch 565/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0406
# Epoch 566/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0412
# Epoch 567/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0421
# Epoch 568/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0414
# Epoch 569/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0427
# Epoch 570/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0436
# Epoch 571/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0414
# Epoch 572/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0394
# Epoch 573/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0557
# Epoch 574/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0430
# Epoch 575/1000
# 100/100 [==============================] - 4s 38ms/step - loss: 0.0426
# Epoch 576/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0432
# Epoch 577/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0416
# Epoch 578/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0384
# Epoch 579/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0418
# Epoch 580/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0404
# Epoch 581/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0485
# Epoch 582/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0382
# Epoch 583/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0417
# Epoch 584/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0438
# Epoch 585/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0481
# Epoch 586/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0445
# Epoch 587/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0430
# Epoch 588/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0414
# Epoch 589/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0392
# Epoch 590/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0477
# Epoch 591/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0448
# Epoch 592/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0415
# Epoch 593/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0444
# Epoch 594/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0438
# Epoch 595/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0425
# Epoch 596/1000
# 100/100 [==============================] - 4s 38ms/step - loss: 0.0446
# Epoch 597/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0513
# Epoch 598/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0444
# Epoch 599/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0443
# Epoch 600/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0447
# Epoch 601/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0423
# Epoch 602/1000
# 100/100 [==============================] - 4s 41ms/step - loss: 0.0447
# Epoch 603/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0482
# Epoch 604/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0397
# Epoch 605/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0401
# Epoch 606/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0458
# Epoch 607/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0445
# Epoch 608/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0455
# Epoch 609/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0428
# Epoch 610/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0410
# Epoch 611/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0432
# Epoch 612/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0410
# Epoch 613/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0400
# Epoch 614/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0455
# Epoch 615/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0424
# Epoch 616/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0422
# Epoch 617/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0385
# Epoch 618/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0469
# Epoch 619/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0541
# Epoch 620/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0471
# Epoch 621/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0423
# Epoch 622/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0468
# Epoch 623/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0421
# Epoch 624/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0440
# Epoch 625/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0414
# Epoch 626/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0407
# Epoch 627/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0408
# Epoch 628/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0507
# Epoch 629/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0407
# Epoch 630/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0425
# Epoch 631/1000
# 100/100 [==============================] - 4s 41ms/step - loss: 0.0391
# Epoch 632/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0469
# Epoch 633/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0405
# Epoch 634/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0396
# Epoch 635/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0412
# Epoch 636/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0388
# Epoch 637/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0516
# Epoch 638/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0424
# Epoch 639/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0400
# Epoch 640/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0470
# Epoch 641/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0427
# Epoch 642/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0410
# Epoch 643/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0442
# Epoch 644/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0411
# Epoch 645/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0460
# Epoch 646/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0434
# Epoch 647/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0458
# Epoch 648/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0395
# Epoch 649/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0407
# Epoch 650/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0418
# Epoch 651/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0441
# Epoch 652/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0393
# Epoch 653/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0407
# Epoch 654/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0395
# Epoch 655/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0391
# Epoch 656/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0478
# Epoch 657/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0444
# Epoch 658/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0439
# Epoch 659/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0433
# Epoch 660/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0411
# Epoch 661/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0406
# Epoch 662/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0481
# Epoch 663/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0390
# Epoch 664/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0413
# Epoch 665/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0397
# Epoch 666/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0484
# Epoch 667/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0421
# Epoch 668/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0399
# Epoch 669/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0407
# Epoch 670/1000
# 100/100 [==============================] - 4s 41ms/step - loss: 0.0465
# Epoch 671/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0384
# Epoch 672/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0445
# Epoch 673/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0419
# Epoch 674/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0428
# Epoch 675/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0399
# Epoch 676/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0408
# Epoch 677/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0441
# Epoch 678/1000
# 100/100 [==============================] - 4s 41ms/step - loss: 0.0413
# Epoch 679/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0414
# Epoch 680/1000
# 100/100 [==============================] - 4s 41ms/step - loss: 0.0394
# Epoch 681/1000
# 100/100 [==============================] - 4s 41ms/step - loss: 0.0419
# Epoch 682/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0408
# Epoch 683/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0402
# Epoch 684/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0410
# Epoch 685/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0446
# Epoch 686/1000
# 100/100 [==============================] - 4s 41ms/step - loss: 0.0546
# Epoch 687/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0397
# Epoch 688/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0417
# Epoch 689/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0508
# Epoch 690/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0405
# Epoch 691/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0398
# Epoch 692/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0433
# Epoch 693/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0422
# Epoch 694/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0526
# Epoch 695/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0409
# Epoch 696/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0454
# Epoch 697/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0461
# Epoch 698/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0391
# Epoch 699/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0483
# Epoch 700/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0449
# Epoch 701/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0393
# Epoch 702/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0403
# Epoch 703/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0440
# Epoch 704/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0432
# Epoch 705/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0393
# Epoch 706/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0406
# Epoch 707/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0400
# Epoch 708/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0449
# Epoch 709/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0411
# Epoch 710/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0404
# Epoch 711/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0399
# Epoch 712/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0474
# Epoch 713/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0426
# Epoch 714/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0477
# Epoch 715/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0417
# Epoch 716/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0405
# Epoch 717/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0396
# Epoch 718/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0463
# Epoch 719/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0461
# Epoch 720/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0414
# Epoch 721/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0407
# Epoch 722/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0416
# Epoch 723/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0393
# Epoch 724/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0458
# Epoch 725/1000
# 100/100 [==============================] - 4s 41ms/step - loss: 0.0461
# Epoch 726/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0403
# Epoch 727/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0566
# Epoch 728/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0445
# Epoch 729/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0431
# Epoch 730/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0457
# Epoch 731/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0409
# Epoch 732/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0414
# Epoch 733/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0429
# Epoch 734/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0423
# Epoch 735/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0402
# Epoch 736/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0413
# Epoch 737/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0435
# Epoch 738/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0395
# Epoch 739/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0456
# Epoch 740/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0471
# Epoch 741/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0407
# Epoch 742/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0429
# Epoch 743/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0439
# Epoch 744/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0484
# Epoch 745/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0469
# Epoch 746/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0411
# Epoch 747/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0509
# Epoch 748/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0407
# Epoch 749/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0527
# Epoch 750/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0388
# Epoch 751/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0446
# Epoch 752/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0462
# Epoch 753/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0527
# Epoch 754/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0443
# Epoch 755/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0432
# Epoch 756/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0390
# Epoch 757/1000
# 100/100 [==============================] - 4s 42ms/step - loss: 0.0398
# Epoch 758/1000
# 100/100 [==============================] - 4s 42ms/step - loss: 0.0390
# Epoch 759/1000
# 100/100 [==============================] - 4s 41ms/step - loss: 0.0433
# Epoch 760/1000
# 100/100 [==============================] - 4s 41ms/step - loss: 0.0475
# Epoch 761/1000
# 100/100 [==============================] - 4s 41ms/step - loss: 0.0453
# Epoch 762/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0413
# Epoch 763/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0426
# Epoch 764/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0457
# Epoch 765/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0451
# Epoch 766/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0405
# Epoch 767/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0427
# Epoch 768/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0387
# Epoch 769/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0450
# Epoch 770/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0465
# Epoch 771/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0409
# Epoch 772/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0439
# Epoch 773/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0390
# Epoch 774/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0553
# Epoch 775/1000
# 100/100 [==============================] - 4s 41ms/step - loss: 0.0418
# Epoch 776/1000
# 100/100 [==============================] - 4s 41ms/step - loss: 0.0409
# Epoch 777/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0400
# Epoch 778/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0423
# Epoch 779/1000
# 100/100 [==============================] - 4s 42ms/step - loss: 0.0484
# Epoch 780/1000
# 100/100 [==============================] - 4s 41ms/step - loss: 0.0412
# Epoch 781/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0406
# Epoch 782/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0386
# Epoch 783/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0392
# Epoch 784/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0452
# Epoch 785/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0421
# Epoch 786/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0407
# Epoch 787/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0403
# Epoch 788/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0425
# Epoch 789/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0399
# Epoch 790/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0412
# Epoch 791/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0393
# Epoch 792/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0408
# Epoch 793/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0401
# Epoch 794/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0395
# Epoch 795/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0395
# Epoch 796/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0399
# Epoch 797/1000
# 100/100 [==============================] - 4s 41ms/step - loss: 0.0383
# Epoch 798/1000
# 100/100 [==============================] - 4s 41ms/step - loss: 0.0393
# Epoch 799/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0393
# Epoch 800/1000
# 100/100 [==============================] - 4s 41ms/step - loss: 0.0462
# Epoch 801/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0453
# Epoch 802/1000
# 100/100 [==============================] - 4s 41ms/step - loss: 0.0514
# Epoch 803/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0524
# Epoch 804/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0389
# Epoch 805/1000
# 100/100 [==============================] - 4s 41ms/step - loss: 0.0396
# Epoch 806/1000
# 100/100 [==============================] - 4s 41ms/step - loss: 0.0433
# Epoch 807/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0385
# Epoch 808/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0386
# Epoch 809/1000
# 100/100 [==============================] - 4s 41ms/step - loss: 0.0379
# Epoch 810/1000
# 100/100 [==============================] - 4s 41ms/step - loss: 0.0389
# Epoch 811/1000
# 100/100 [==============================] - 4s 41ms/step - loss: 0.0391
# Epoch 812/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0415
# Epoch 813/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0396
# Epoch 814/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0412
# Epoch 815/1000
# 100/100 [==============================] - 4s 41ms/step - loss: 0.0437
# Epoch 816/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0446
# Epoch 817/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0406
# Epoch 818/1000
# 100/100 [==============================] - 4s 41ms/step - loss: 0.0413
# Epoch 819/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0412
# Epoch 820/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0388
# Epoch 821/1000
# 100/100 [==============================] - 4s 41ms/step - loss: 0.0454
# Epoch 822/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0389
# Epoch 823/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0422
# Epoch 824/1000
# 100/100 [==============================] - 4s 41ms/step - loss: 0.0430
# Epoch 825/1000
# 100/100 [==============================] - 4s 41ms/step - loss: 0.0409
# Epoch 826/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0413
# Epoch 827/1000
# 100/100 [==============================] - 4s 41ms/step - loss: 0.0414
# Epoch 828/1000
# 100/100 [==============================] - 4s 41ms/step - loss: 0.0392
# Epoch 829/1000
# 100/100 [==============================] - 4s 41ms/step - loss: 0.0468
# Epoch 830/1000
# 100/100 [==============================] - 4s 42ms/step - loss: 0.0433
# Epoch 831/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0434
# Epoch 832/1000
# 100/100 [==============================] - 4s 41ms/step - loss: 0.0396
# Epoch 833/1000
# 100/100 [==============================] - 4s 42ms/step - loss: 0.0404
# Epoch 834/1000
# 100/100 [==============================] - 4s 41ms/step - loss: 0.0458
# Epoch 835/1000
# 100/100 [==============================] - 4s 42ms/step - loss: 0.0388
# Epoch 836/1000
# 100/100 [==============================] - 4s 41ms/step - loss: 0.0431
# Epoch 837/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0447
# Epoch 838/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0393
# Epoch 839/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0422
# Epoch 840/1000
# 100/100 [==============================] - 4s 41ms/step - loss: 0.0437
# Epoch 841/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0388
# Epoch 842/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0449
# Epoch 843/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0396
# Epoch 844/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0397
# Epoch 845/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0436
# Epoch 846/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0414
# Epoch 847/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0429
# Epoch 848/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0449
# Epoch 849/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0391
# Epoch 850/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0405
# Epoch 851/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0381
# Epoch 852/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0387
# Epoch 853/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0426
# Epoch 854/1000
# 100/100 [==============================] - 4s 41ms/step - loss: 0.0493
# Epoch 855/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0397
# Epoch 856/1000
# 100/100 [==============================] - 4s 41ms/step - loss: 0.0436
# Epoch 857/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0388
# Epoch 858/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0422
# Epoch 859/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0425
# Epoch 860/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0446
# Epoch 861/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0394
# Epoch 862/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0421
# Epoch 863/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0428
# Epoch 864/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0486
# Epoch 865/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0473
# Epoch 866/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0394
# Epoch 867/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0411
# Epoch 868/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0402
# Epoch 869/1000
# 100/100 [==============================] - 4s 41ms/step - loss: 0.0388
# Epoch 870/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0377
# Epoch 871/1000
# 100/100 [==============================] - 4s 41ms/step - loss: 0.0395
# Epoch 872/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0417
# Epoch 873/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0393
# Epoch 874/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0376
# Epoch 875/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0403
# Epoch 876/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0501
# Epoch 877/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0489
# Epoch 878/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0398
# Epoch 879/1000
# 100/100 [==============================] - 4s 41ms/step - loss: 0.0416
# Epoch 880/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0452
# Epoch 881/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0388
# Epoch 882/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0431
# Epoch 883/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0397
# Epoch 884/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0384
# Epoch 885/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0406
# Epoch 886/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0452
# Epoch 887/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0436
# Epoch 888/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0374
# Epoch 889/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0451
# Epoch 890/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0451
# Epoch 891/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0409
# Epoch 892/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0438
# Epoch 893/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0378
# Epoch 894/1000
# 100/100 [==============================] - 4s 41ms/step - loss: 0.0400
# Epoch 895/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0468
# Epoch 896/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0400
# Epoch 897/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0403
# Epoch 898/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0400
# Epoch 899/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0394
# Epoch 900/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0450
# Epoch 901/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0390
# Epoch 902/1000
# 100/100 [==============================] - 4s 42ms/step - loss: 0.0458
# Epoch 903/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0426
# Epoch 904/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0462
# Epoch 905/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0380
# Epoch 906/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0400
# Epoch 907/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0420
# Epoch 908/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0406
# Epoch 909/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0387
# Epoch 910/1000
# 100/100 [==============================] - 4s 42ms/step - loss: 0.0399
# Epoch 911/1000
# 100/100 [==============================] - 4s 42ms/step - loss: 0.0387
# Epoch 912/1000
# 100/100 [==============================] - 4s 42ms/step - loss: 0.0396
# Epoch 913/1000
# 100/100 [==============================] - 4s 42ms/step - loss: 0.0385
# Epoch 914/1000
# 100/100 [==============================] - 4s 41ms/step - loss: 0.0387
# Epoch 915/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0383
# Epoch 916/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0394
# Epoch 917/1000
# 100/100 [==============================] - 4s 41ms/step - loss: 0.0382
# Epoch 918/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0374
# Epoch 919/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0431
# Epoch 920/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0377
# Epoch 921/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0427
# Epoch 922/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0415
# Epoch 923/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0394
# Epoch 924/1000
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0392
# Epoch 925/1000
# 100/100 [==============================] - 4s 41ms/step - loss: 0.0424
# Epoch 926/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0389
# Epoch 927/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0426
# Epoch 928/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0396
# Epoch 929/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0429
# Epoch 930/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0402
# Epoch 931/1000
# 100/100 [==============================] - 4s 41ms/step - loss: 0.0413
# Epoch 932/1000
# 100/100 [==============================] - 4s 41ms/step - loss: 0.0389
# Epoch 933/1000
# 100/100 [==============================] - 4s 41ms/step - loss: 0.0377
# Epoch 934/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0417
# Epoch 935/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0465
# Epoch 936/1000
# 100/100 [==============================] - 4s 41ms/step - loss: 0.0387
# Epoch 937/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0403
# Epoch 938/1000
# 100/100 [==============================] - 4s 41ms/step - loss: 0.0394
# Epoch 939/1000
# 100/100 [==============================] - 4s 41ms/step - loss: 0.0385
# Epoch 940/1000
# 100/100 [==============================] - 4s 41ms/step - loss: 0.0389
# Epoch 941/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0383
# Epoch 942/1000
# 100/100 [==============================] - 4s 41ms/step - loss: 0.0425
# Epoch 943/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0380
# Epoch 944/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0375
# Epoch 945/1000
# 100/100 [==============================] - 4s 41ms/step - loss: 0.0424
# Epoch 946/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0460
# Epoch 947/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0439
# Epoch 948/1000
# 100/100 [==============================] - 4s 41ms/step - loss: 0.0406
# Epoch 949/1000
# 100/100 [==============================] - 4s 41ms/step - loss: 0.0417
# Epoch 950/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0377
# Epoch 951/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0391
# Epoch 952/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0443
# Epoch 953/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0406
# Epoch 954/1000
# 100/100 [==============================] - 4s 41ms/step - loss: 0.0383
# Epoch 955/1000
# 100/100 [==============================] - 4s 41ms/step - loss: 0.0398
# Epoch 956/1000
# 100/100 [==============================] - 4s 43ms/step - loss: 0.0398
# Epoch 957/1000
# 100/100 [==============================] - 4s 42ms/step - loss: 0.0404
# Epoch 958/1000
# 100/100 [==============================] - 4s 41ms/step - loss: 0.0395
# Epoch 959/1000
# 100/100 [==============================] - 4s 42ms/step - loss: 0.0408
# Epoch 960/1000
# 100/100 [==============================] - 4s 41ms/step - loss: 0.0379
# Epoch 961/1000
# 100/100 [==============================] - 4s 41ms/step - loss: 0.0373
# Epoch 962/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0383
# Epoch 963/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0400
# Epoch 964/1000
# 100/100 [==============================] - 4s 42ms/step - loss: 0.0384
# Epoch 965/1000
# 100/100 [==============================] - 4s 41ms/step - loss: 0.0393
# Epoch 966/1000
# 100/100 [==============================] - 4s 42ms/step - loss: 0.0439
# Epoch 967/1000
# 100/100 [==============================] - 4s 41ms/step - loss: 0.0414
# Epoch 968/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0424
# Epoch 969/1000
# 100/100 [==============================] - 4s 41ms/step - loss: 0.0442
# Epoch 970/1000
# 100/100 [==============================] - 4s 41ms/step - loss: 0.0391
# Epoch 971/1000
# 100/100 [==============================] - 4s 43ms/step - loss: 0.0422
# Epoch 972/1000
# 100/100 [==============================] - 4s 41ms/step - loss: 0.0410
# Epoch 973/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0431
# Epoch 974/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0482
# Epoch 975/1000
# 100/100 [==============================] - 4s 41ms/step - loss: 0.0388
# Epoch 976/1000
# 100/100 [==============================] - 4s 41ms/step - loss: 0.0426
# Epoch 977/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0412
# Epoch 978/1000
# 100/100 [==============================] - 4s 41ms/step - loss: 0.0379
# Epoch 979/1000
# 100/100 [==============================] - 4s 41ms/step - loss: 0.0396
# Epoch 980/1000
# 100/100 [==============================] - 4s 41ms/step - loss: 0.0425
# Epoch 981/1000
# 100/100 [==============================] - 4s 41ms/step - loss: 0.0453
# Epoch 982/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0421
# Epoch 983/1000
# 100/100 [==============================] - 4s 42ms/step - loss: 0.0457
# Epoch 984/1000
# 100/100 [==============================] - 4s 41ms/step - loss: 0.0404
# Epoch 985/1000
# 100/100 [==============================] - 4s 41ms/step - loss: 0.0402
# Epoch 986/1000
# 100/100 [==============================] - 4s 43ms/step - loss: 0.0397
# Epoch 987/1000
# 100/100 [==============================] - 4s 41ms/step - loss: 0.0407
# Epoch 988/1000
# 100/100 [==============================] - 4s 42ms/step - loss: 0.0430
# Epoch 989/1000
# 100/100 [==============================] - 4s 41ms/step - loss: 0.0417
# Epoch 990/1000
# 100/100 [==============================] - 4s 41ms/step - loss: 0.0421
# Epoch 991/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0469
# Epoch 992/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0388
# Epoch 993/1000
# 100/100 [==============================] - 4s 41ms/step - loss: 0.0388
# Epoch 994/1000
# 100/100 [==============================] - 4s 41ms/step - loss: 0.0438
# Epoch 995/1000
# 100/100 [==============================] - 4s 41ms/step - loss: 0.0383
# Epoch 996/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0393
# Epoch 997/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0391
# Epoch 998/1000
# 100/100 [==============================] - 4s 41ms/step - loss: 0.0422
# Epoch 999/1000
# 100/100 [==============================] - 4s 41ms/step - loss: 0.0406
# Epoch 1000/1000
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0397
# Epoch 1/1000
# 100/100 [==============================] - 7s 66ms/step - loss: 0.2582
# Epoch 2/1000
# 100/100 [==============================] - 7s 65ms/step - loss: 0.2531
# Epoch 3/1000
# 100/100 [==============================] - 7s 66ms/step - loss: 0.2488
# Epoch 4/1000
# 100/100 [==============================] - 7s 65ms/step - loss: 0.2673
# Epoch 5/1000
# 100/100 [==============================] - 7s 66ms/step - loss: 0.2481
# Epoch 6/1000
# 100/100 [==============================] - 7s 65ms/step - loss: 0.2330
# Epoch 7/1000
# 100/100 [==============================] - 7s 65ms/step - loss: 0.2375
# Epoch 8/1000
# 100/100 [==============================] - 7s 66ms/step - loss: 0.2336
# Epoch 9/1000
# 100/100 [==============================] - 7s 66ms/step - loss: 0.2365
# Epoch 10/1000
# 100/100 [==============================] - 7s 68ms/step - loss: 0.2338
# Epoch 11/1000
# 100/100 [==============================] - 7s 67ms/step - loss: 0.2265
# Epoch 12/1000
# 100/100 [==============================] - 7s 66ms/step - loss: 0.2434
# Epoch 13/1000
# 100/100 [==============================] - 7s 66ms/step - loss: 0.2811
# Epoch 14/1000
# 100/100 [==============================] - 7s 67ms/step - loss: 0.2457
# Epoch 15/1000
# 100/100 [==============================] - 7s 68ms/step - loss: 0.2373
# Epoch 16/1000
# 100/100 [==============================] - 7s 66ms/step - loss: 0.2568
# Epoch 17/1000
# 100/100 [==============================] - 7s 66ms/step - loss: 0.2166
# Epoch 18/1000
# 100/100 [==============================] - 7s 66ms/step - loss: 0.2403
# Epoch 19/1000
# 100/100 [==============================] - 7s 67ms/step - loss: 0.2166
# Epoch 20/1000
# 100/100 [==============================] - 7s 66ms/step - loss: 0.2482
# Epoch 21/1000
# 100/100 [==============================] - 7s 66ms/step - loss: 0.2277
# Epoch 22/1000
# 100/100 [==============================] - 7s 65ms/step - loss: 0.1855
# Epoch 23/1000
# 100/100 [==============================] - 7s 66ms/step - loss: 0.1921
# Epoch 24/1000
# 100/100 [==============================] - 7s 66ms/step - loss: 0.2294
# Epoch 25/1000
# 100/100 [==============================] - 7s 66ms/step - loss: 0.2226
# Epoch 26/1000
# 100/100 [==============================] - 7s 65ms/step - loss: 0.2361
# Epoch 27/1000
# 100/100 [==============================] - 7s 66ms/step - loss: 0.2377
# Epoch 28/1000
# 100/100 [==============================] - 7s 65ms/step - loss: 0.2064
# Epoch 29/1000
# 100/100 [==============================] - 7s 66ms/step - loss: 0.2062
# Epoch 30/1000
# 100/100 [==============================] - 7s 66ms/step - loss: 0.2012
# Epoch 31/1000
# 100/100 [==============================] - 7s 65ms/step - loss: 0.1886
# Epoch 32/1000
# 100/100 [==============================] - 7s 65ms/step - loss: 0.2559
# Epoch 33/1000
# 100/100 [==============================] - 7s 66ms/step - loss: 0.2199
# Epoch 34/1000
# 100/100 [==============================] - 7s 66ms/step - loss: 0.2216
# Epoch 35/1000
# 100/100 [==============================] - 7s 66ms/step - loss: 0.2423
# Epoch 36/1000
# 100/100 [==============================] - 7s 67ms/step - loss: 0.1979
# Epoch 37/1000
# 100/100 [==============================] - 7s 67ms/step - loss: 0.2183
# Epoch 38/1000
# 100/100 [==============================] - 7s 67ms/step - loss: 0.1783
# Epoch 39/1000
# 100/100 [==============================] - 7s 68ms/step - loss: 0.2167
# Epoch 40/1000
# 100/100 [==============================] - 7s 67ms/step - loss: 0.1952
# Epoch 41/1000
# 100/100 [==============================] - 7s 66ms/step - loss: 0.1888
# Epoch 42/1000
# 100/100 [==============================] - 7s 66ms/step - loss: 0.1974
# Epoch 43/1000
# 100/100 [==============================] - 7s 66ms/step - loss: 0.2294
# Epoch 44/1000
# 100/100 [==============================] - 7s 65ms/step - loss: 0.1883
# Epoch 45/1000
# 100/100 [==============================] - 7s 66ms/step - loss: 0.2169
# Epoch 46/1000
# 100/100 [==============================] - 7s 66ms/step - loss: 0.1785
# Epoch 47/1000
# 100/100 [==============================] - 7s 66ms/step - loss: 0.1839
# Epoch 48/1000
# 100/100 [==============================] - 7s 67ms/step - loss: 0.2023
# Epoch 49/1000
# 100/100 [==============================] - 7s 66ms/step - loss: 0.2370
# Epoch 50/1000
# 100/100 [==============================] - 7s 66ms/step - loss: 0.1970
# Epoch 51/1000
# 100/100 [==============================] - 7s 67ms/step - loss: 0.2044
# Epoch 52/1000
# 100/100 [==============================] - 7s 66ms/step - loss: 0.2049
# Epoch 53/1000
# 100/100 [==============================] - 7s 66ms/step - loss: 0.2051
# Epoch 54/1000
# 100/100 [==============================] - 7s 65ms/step - loss: 0.2036
# Epoch 55/1000
# 100/100 [==============================] - 7s 66ms/step - loss: 0.1757
# Epoch 56/1000
# 100/100 [==============================] - 7s 66ms/step - loss: 0.1974
# Epoch 57/1000
# 100/100 [==============================] - 7s 68ms/step - loss: 0.2224
# Epoch 58/1000
# 100/100 [==============================] - 7s 67ms/step - loss: 0.2547
# Epoch 59/1000
# ...
# Epoch 820/1000
# 100/100 [==============================] - 12s 121ms/step - loss: 0.1476
# Epoch 821/1000
# 100/100 [==============================] - 12s 120ms/step - loss: 0.1265
# Epoch 822/1000
# 100/100 [==============================] - 12s 122ms/step - loss: 0.1583
# Epoch 823/1000
# 100/100 [==============================] - 12s 121ms/step - loss: 0.1006
# Epoch 824/1000
# 100/100 [==============================] - 12s 120ms/step - loss: 0.1217
# Epoch 825/1000
# 100/100 [==============================] - 12s 120ms/step - loss: 0.1082
# Epoch 826/1000
# 100/100 [==============================] - 12s 120ms/step - loss: 0.1020
# Epoch 827/1000
# 100/100 [==============================] - 12s 122ms/step - loss: 0.1020
# Epoch 828/1000
# 100/100 [==============================] - 12s 121ms/step - loss: 0.1206
# Epoch 829/1000
# 100/100 [==============================] - 12s 121ms/step - loss: 0.1605
# Epoch 830/1000
# 100/100 [==============================] - 12s 122ms/step - loss: 0.1004
# Epoch 831/1000
# 100/100 [==============================] - 12s 121ms/step - loss: 0.1233
# Epoch 832/1000
# 100/100 [==============================] - 12s 121ms/step - loss: 0.1088
# Epoch 833/1000
# 100/100 [==============================] - 12s 122ms/step - loss: 0.1156
# Epoch 834/1000
# 100/100 [==============================] - 12s 121ms/step - loss: 0.1042
# Epoch 835/1000
# 100/100 [==============================] - 12s 121ms/step - loss: 0.1119
# Epoch 836/1000
# 100/100 [==============================] - 12s 121ms/step - loss: 0.1317
# Epoch 837/1000
# 100/100 [==============================] - 12s 123ms/step - loss: 0.1256
# Epoch 838/1000
# 100/100 [==============================] - 12s 121ms/step - loss: 0.1002
# Epoch 839/1000
# 100/100 [==============================] - 12s 123ms/step - loss: 0.1099
# Epoch 840/1000
# 100/100 [==============================] - 12s 124ms/step - loss: 0.1124
# Epoch 841/1000
# 100/100 [==============================] - 12s 121ms/step - loss: 0.1091
# Epoch 842/1000
# 100/100 [==============================] - 12s 124ms/step - loss: 0.1286
# Epoch 843/1000
# 100/100 [==============================] - 12s 121ms/step - loss: 0.1074
# Epoch 844/1000
# 100/100 [==============================] - 12s 120ms/step - loss: 0.1027
# Epoch 845/1000
# 100/100 [==============================] - 12s 121ms/step - loss: 0.1065
# Epoch 846/1000
# 100/100 [==============================] - 12s 122ms/step - loss: 0.1083
# Epoch 847/1000
# 100/100 [==============================] - 12s 122ms/step - loss: 0.1000
# Epoch 848/1000
# 100/100 [==============================] - 12s 120ms/step - loss: 0.1227
# Epoch 849/1000
# 100/100 [==============================] - 12s 121ms/step - loss: 0.1761
# Epoch 850/1000
# 100/100 [==============================] - 12s 122ms/step - loss: 0.1368
# Epoch 851/1000
# 100/100 [==============================] - 12s 120ms/step - loss: 0.2249
# Epoch 852/1000
# 100/100 [==============================] - 12s 122ms/step - loss: 0.0991
# Epoch 853/1000
# 100/100 [==============================] - 12s 123ms/step - loss: 0.1024
# Epoch 854/1000
# 100/100 [==============================] - 12s 121ms/step - loss: 0.1001
# Epoch 855/1000
# 100/100 [==============================] - 12s 123ms/step - loss: 0.1167
# Epoch 856/1000
# 100/100 [==============================] - 12s 121ms/step - loss: 0.1051
# Epoch 857/1000
# 100/100 [==============================] - 12s 121ms/step - loss: 0.1089
# Epoch 858/1000
# 100/100 [==============================] - 12s 121ms/step - loss: 0.1566
# Epoch 859/1000
# 100/100 [==============================] - 12s 122ms/step - loss: 0.1655
# Epoch 860/1000
# 100/100 [==============================] - 12s 121ms/step - loss: 0.1149
# Epoch 861/1000
# 100/100 [==============================] - 12s 121ms/step - loss: 0.1714
# Epoch 862/1000
# 100/100 [==============================] - 12s 123ms/step - loss: 0.1187
# Epoch 863/1000
# 100/100 [==============================] - 12s 122ms/step - loss: 0.1330
# Epoch 864/1000
# 100/100 [==============================] - 12s 123ms/step - loss: 0.0969
# Epoch 865/1000
# 100/100 [==============================] - 12s 123ms/step - loss: 0.1059
# Epoch 866/1000
# 100/100 [==============================] - 12s 121ms/step - loss: 0.0985
# Epoch 867/1000
# 100/100 [==============================] - 12s 121ms/step - loss: 0.0983
# Epoch 868/1000
# 100/100 [==============================] - 12s 122ms/step - loss: 0.1201
# Epoch 869/1000
# 100/100 [==============================] - 12s 120ms/step - loss: 0.1642
# Epoch 870/1000
# 100/100 [==============================] - 12s 122ms/step - loss: 0.1037
# Epoch 871/1000
# 100/100 [==============================] - 12s 122ms/step - loss: 0.1898
# Epoch 872/1000
# 100/100 [==============================] - 12s 124ms/step - loss: 0.1036
# Epoch 873/1000
# 100/100 [==============================] - 12s 123ms/step - loss: 0.1320
# Epoch 874/1000
# 100/100 [==============================] - 13s 126ms/step - loss: 0.1526
# Epoch 875/1000
# 100/100 [==============================] - 12s 123ms/step - loss: 0.0977
# Epoch 876/1000
# 100/100 [==============================] - 12s 123ms/step - loss: 0.1098
# Epoch 877/1000
# 100/100 [==============================] - 12s 123ms/step - loss: 0.0994
# Epoch 878/1000
# 100/100 [==============================] - 12s 121ms/step - loss: 0.1101
# Epoch 879/1000
# 100/100 [==============================] - 12s 121ms/step - loss: 0.1317
# Epoch 880/1000
# 100/100 [==============================] - 12s 124ms/step - loss: 0.1032
# Epoch 881/1000
# 100/100 [==============================] - 12s 121ms/step - loss: 0.1119
# Epoch 882/1000
# 100/100 [==============================] - 12s 123ms/step - loss: 0.1265
# Epoch 883/1000
# 100/100 [==============================] - 12s 122ms/step - loss: 0.1018
# Epoch 884/1000
# 100/100 [==============================] - 12s 122ms/step - loss: 0.0955
# Epoch 885/1000
# 100/100 [==============================] - 12s 121ms/step - loss: 0.1317
# Epoch 886/1000
# 100/100 [==============================] - 12s 123ms/step - loss: 0.1009
# Epoch 887/1000
# 100/100 [==============================] - 12s 122ms/step - loss: 0.1365
# Epoch 888/1000
# 100/100 [==============================] - 12s 122ms/step - loss: 0.1297
# Epoch 889/1000
# 100/100 [==============================] - 12s 123ms/step - loss: 0.1022
# Epoch 890/1000
# 100/100 [==============================] - 12s 124ms/step - loss: 0.1184
# Epoch 891/1000
# 100/100 [==============================] - 12s 121ms/step - loss: 0.1253
# Epoch 892/1000
# 100/100 [==============================] - 12s 122ms/step - loss: 0.1055
# Epoch 893/1000
# 100/100 [==============================] - 12s 122ms/step - loss: 0.1173
# Epoch 894/1000
# 100/100 [==============================] - 12s 123ms/step - loss: 0.0972
# Epoch 895/1000
# 100/100 [==============================] - 12s 122ms/step - loss: 0.1351
# Epoch 896/1000
# 100/100 [==============================] - 12s 122ms/step - loss: 0.1238
# Epoch 897/1000
# 100/100 [==============================] - 12s 121ms/step - loss: 0.1450
# Epoch 898/1000
# 100/100 [==============================] - 12s 123ms/step - loss: 0.1025
# Epoch 899/1000
# 100/100 [==============================] - 12s 122ms/step - loss: 0.1019
# Epoch 900/1000
# 100/100 [==============================] - 12s 122ms/step - loss: 0.1168
# Epoch 901/1000
# 100/100 [==============================] - 12s 122ms/step - loss: 0.1130
# Epoch 902/1000
# 100/100 [==============================] - 12s 123ms/step - loss: 0.1383
# Epoch 903/1000
# 100/100 [==============================] - 12s 122ms/step - loss: 0.1217
# Epoch 904/1000
# 100/100 [==============================] - 12s 122ms/step - loss: 0.1240
# Epoch 905/1000
# 100/100 [==============================] - 12s 121ms/step - loss: 0.1152
# Epoch 906/1000
# 100/100 [==============================] - 12s 123ms/step - loss: 0.1027
# Epoch 907/1000
# 100/100 [==============================] - 12s 122ms/step - loss: 0.0986
# Epoch 908/1000
# 100/100 [==============================] - 12s 122ms/step - loss: 0.1105
# Epoch 909/1000
# 100/100 [==============================] - 12s 121ms/step - loss: 0.1180
# Epoch 910/1000
# 100/100 [==============================] - 12s 123ms/step - loss: 0.1150
# Epoch 911/1000
# 100/100 [==============================] - 12s 122ms/step - loss: 0.1426
# Epoch 912/1000
# 100/100 [==============================] - 12s 121ms/step - loss: 0.1058
# Epoch 913/1000
# 100/100 [==============================] - 12s 121ms/step - loss: 0.1564
# Epoch 914/1000
# 100/100 [==============================] - 12s 123ms/step - loss: 0.1054
# Epoch 915/1000
# 100/100 [==============================] - 12s 123ms/step - loss: 0.1003
# Epoch 916/1000
# 100/100 [==============================] - 12s 122ms/step - loss: 0.1038
# Epoch 917/1000
# 100/100 [==============================] - 12s 121ms/step - loss: 0.0993
# Epoch 918/1000
# 100/100 [==============================] - 12s 123ms/step - loss: 0.1063
# Epoch 919/1000
# 100/100 [==============================] - 12s 124ms/step - loss: 0.1024
# Epoch 920/1000
# 100/100 [==============================] - 21s 205ms/step - loss: 0.1048
# Epoch 921/1000
# 100/100 [==============================] - 12s 121ms/step - loss: 0.1366
# Epoch 922/1000
# 100/100 [==============================] - 12s 122ms/step - loss: 0.1172
# Epoch 923/1000
# 100/100 [==============================] - 12s 122ms/step - loss: 0.1103
# Epoch 924/1000
# 100/100 [==============================] - 12s 121ms/step - loss: 0.1110
# Epoch 925/1000
# 100/100 [==============================] - 12s 123ms/step - loss: 0.1284
# Epoch 926/1000
# 100/100 [==============================] - 12s 122ms/step - loss: 0.1014
# Epoch 927/1000
# 100/100 [==============================] - 12s 121ms/step - loss: 0.1033
# Epoch 928/1000
# 100/100 [==============================] - 12s 122ms/step - loss: 0.1106
# Epoch 929/1000
# 100/100 [==============================] - 12s 123ms/step - loss: 0.0983
# Epoch 930/1000
# 100/100 [==============================] - 12s 122ms/step - loss: 0.1212
# Epoch 931/1000
# 100/100 [==============================] - 12s 121ms/step - loss: 0.1134
# Epoch 932/1000
# 100/100 [==============================] - 12s 121ms/step - loss: 0.1987
# Epoch 933/1000
# 100/100 [==============================] - 12s 122ms/step - loss: 0.1021
# Epoch 934/1000
# 100/100 [==============================] - 12s 121ms/step - loss: 0.1024
# Epoch 935/1000
# 100/100 [==============================] - 12s 123ms/step - loss: 0.1002
# Epoch 936/1000
# 100/100 [==============================] - 12s 120ms/step - loss: 0.1101
# Epoch 937/1000
# 100/100 [==============================] - 12s 121ms/step - loss: 0.1591
# Epoch 938/1000
# 100/100 [==============================] - 12s 122ms/step - loss: 0.1315
# Epoch 939/1000
# 100/100 [==============================] - 12s 122ms/step - loss: 0.1063
# Epoch 940/1000
# 100/100 [==============================] - 13s 125ms/step - loss: 0.1291
# Epoch 941/1000
# 100/100 [==============================] - 12s 121ms/step - loss: 0.1116
# Epoch 942/1000
# 100/100 [==============================] - 12s 120ms/step - loss: 0.1030
# Epoch 943/1000
# 100/100 [==============================] - 12s 121ms/step - loss: 0.0973
# Epoch 944/1000
# 100/100 [==============================] - 12s 121ms/step - loss: 0.1165
# Epoch 945/1000
# 100/100 [==============================] - 12s 122ms/step - loss: 0.1134
# Epoch 946/1000
# 100/100 [==============================] - 12s 122ms/step - loss: 0.1062
# Epoch 947/1000
# 100/100 [==============================] - 12s 121ms/step - loss: 0.1243
# Epoch 948/1000
# 100/100 [==============================] - 12s 122ms/step - loss: 0.1398
# Epoch 949/1000
# 100/100 [==============================] - 12s 121ms/step - loss: 0.1103
# Epoch 950/1000
# 100/100 [==============================] - 12s 121ms/step - loss: 0.1673
# Epoch 951/1000
# 100/100 [==============================] - 12s 123ms/step - loss: 0.1114
# Epoch 952/1000
# 100/100 [==============================] - 12s 121ms/step - loss: 0.1181
# Epoch 953/1000
# 100/100 [==============================] - 12s 122ms/step - loss: 0.1466
# Epoch 954/1000
# 100/100 [==============================] - 12s 121ms/step - loss: 0.1036
# Epoch 955/1000
# 100/100 [==============================] - 12s 122ms/step - loss: 0.1347
# Epoch 956/1000
# 100/100 [==============================] - 12s 121ms/step - loss: 0.1195
# Epoch 957/1000
# 100/100 [==============================] - 12s 122ms/step - loss: 0.1076
# Epoch 958/1000
# 100/100 [==============================] - 12s 121ms/step - loss: 0.1063
# Epoch 959/1000
# 100/100 [==============================] - 12s 121ms/step - loss: 0.1078
# Epoch 960/1000
# 100/100 [==============================] - 12s 121ms/step - loss: 0.1071
# Epoch 961/1000
# 100/100 [==============================] - 12s 121ms/step - loss: 0.1108
# Epoch 962/1000
# 100/100 [==============================] - 12s 122ms/step - loss: 0.1054
# Epoch 963/1000
# 100/100 [==============================] - 12s 123ms/step - loss: 0.1270
# Epoch 964/1000
# 100/100 [==============================] - 12s 121ms/step - loss: 0.1065
# Epoch 965/1000
# 100/100 [==============================] - 12s 123ms/step - loss: 0.1141
# Epoch 966/1000
# 100/100 [==============================] - 12s 121ms/step - loss: 0.1001
# Epoch 967/1000
# 100/100 [==============================] - 12s 121ms/step - loss: 0.1315
# Epoch 968/1000
# 100/100 [==============================] - 12s 122ms/step - loss: 0.1037
# Epoch 969/1000
# 100/100 [==============================] - 12s 122ms/step - loss: 0.1218
# Epoch 970/1000
# 100/100 [==============================] - 12s 121ms/step - loss: 0.1017
# Epoch 971/1000
# 100/100 [==============================] - 12s 121ms/step - loss: 0.1072
# Epoch 972/1000
# 100/100 [==============================] - 12s 121ms/step - loss: 0.1307
# Epoch 973/1000
# 100/100 [==============================] - 12s 121ms/step - loss: 0.0984
# Epoch 974/1000
# 100/100 [==============================] - 12s 121ms/step - loss: 0.1044
# Epoch 975/1000
# 100/100 [==============================] - 12s 123ms/step - loss: 0.1092
# Epoch 976/1000
# 100/100 [==============================] - 12s 123ms/step - loss: 0.1067
# Epoch 977/1000
# 100/100 [==============================] - 12s 122ms/step - loss: 0.1116
# Epoch 978/1000
# 100/100 [==============================] - 12s 121ms/step - loss: 0.1010
# Epoch 979/1000
# 100/100 [==============================] - 12s 122ms/step - loss: 0.1075
# Epoch 980/1000
# 100/100 [==============================] - 12s 122ms/step - loss: 0.1156
# Epoch 981/1000
# 100/100 [==============================] - 12s 122ms/step - loss: 0.0994
# Epoch 982/1000
# 100/100 [==============================] - 24s 245ms/step - loss: 0.1250
# Epoch 983/1000
# 100/100 [==============================] - 38s 376ms/step - loss: 0.1026
# Epoch 984/1000
# 100/100 [==============================] - 13s 123ms/step - loss: 0.1047
# Epoch 985/1000
# 100/100 [==============================] - 12s 120ms/step - loss: 0.1208
# Epoch 986/1000
# 100/100 [==============================] - 12s 122ms/step - loss: 0.1085
# Epoch 987/1000
# 100/100 [==============================] - 12s 123ms/step - loss: 0.1870
# Epoch 988/1000
# 100/100 [==============================] - 12s 122ms/step - loss: 0.1073
# Epoch 989/1000
# 100/100 [==============================] - 12s 122ms/step - loss: 0.1078
# Epoch 990/1000
# 100/100 [==============================] - 12s 122ms/step - loss: 0.1003
# Epoch 991/1000
# 100/100 [==============================] - 12s 121ms/step - loss: 0.1072
# Epoch 992/1000
# 100/100 [==============================] - 12s 121ms/step - loss: 0.1493
# Epoch 993/1000
# 100/100 [==============================] - 12s 121ms/step - loss: 0.1158
# Epoch 994/1000
# 100/100 [==============================] - 12s 121ms/step - loss: 0.1845
# Epoch 995/1000
# 100/100 [==============================] - 12s 121ms/step - loss: 0.1001
# Epoch 996/1000
# 100/100 [==============================] - 12s 122ms/step - loss: 0.1003
# Epoch 997/1000
# 100/100 [==============================] - 12s 121ms/step - loss: 0.1034
# Epoch 998/1000
# 100/100 [==============================] - 12s 122ms/step - loss: 0.1033
# Epoch 999/1000
# 100/100 [==============================] - 12s 121ms/step - loss: 0.0979
# Epoch 1000/1000
# 100/100 [==============================] - 12s 122ms/step - loss: 0.1051

# %% [markdown]
# ## Visualise Loss function

# %%
#print(result.history.keys())

plt.rcParams['figure.figsize'] = [10, 10]

# summarize history for loss
plt.plot(result_1.history['loss'])
plt.plot(result_2.history['loss'])
plt.plot(result_3.history['loss'])
plt.plot(result_4.history['loss'])

plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.rc('font', size=12)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=20)    # legend fontsize
plt.rc('figure', titlesize=20)  # fontsize of the figure title
plt.legend(['$\Delta_v$','$20\Delta_v$','$40\Delta_v$','$100\Delta_v$'], loc='upper left')
plt.yscale("log")
plt.show()

# %% [markdown]
# ## Plot trajectories generated to $t=32$ by Verlet integrator and neural

# %%
# Final time
T_final = 32

# Initial conditions
x = np.zeros(1)
v = np.zeros(1)
x[0] = -0.8
v[0] = -0.3
verlet_rugged.set_state(x,v)

# ==== Verlet integrator ====
t = 0.0
t_verlet_rugged = []
x_verlet_rugged = []
v_verlet_rugged = []
E_verlet_rugged = []



while t<T_final:
    t_verlet_rugged.append(t)
    E_verlet_rugged.append(verlet_rugged.energy())
    x_verlet_rugged.append(verlet_rugged.x[0])
    v_verlet_rugged.append(verlet_rugged.v[0])
    verlet_rugged.integrate(1)
    t += dt_verlet
        

# ==== Neural network integrator ====



# Initialise with Verlet integrator
x_initial_1 = np.zeros((hnn_integrator_1.nsteps,hnn_integrator_1.dynamical_system.dim))
v_initial_1 = np.zeros((hnn_integrator_1.nsteps,hnn_integrator_1.dynamical_system.dim))
x_initial_2 = np.zeros((hnn_integrator_2.nsteps,hnn_integrator_2.dynamical_system.dim))
v_initial_2 = np.zeros((hnn_integrator_2.nsteps,hnn_integrator_2.dynamical_system.dim))
x_initial_3 = np.zeros((hnn_integrator_3.nsteps,hnn_integrator_3.dynamical_system.dim))
v_initial_3 = np.zeros((hnn_integrator_3.nsteps,hnn_integrator_3.dynamical_system.dim))
x_initial_4 = np.zeros((hnn_integrator_4.nsteps,hnn_integrator_4.dynamical_system.dim))
v_initial_4 = np.zeros((hnn_integrator_4.nsteps,hnn_integrator_4.dynamical_system.dim))



verlet_rugged.set_state(x,v)
for k in range(hnn_integrator_1.nsteps):    
    x_initial_1[k,:] = verlet_rugged.x[:]
    v_initial_1[k,:] = verlet_rugged.v[:]
    verlet_rugged.integrate(int(dt_1/dt_verlet))
verlet_rugged.set_state(x,v)
for k in range(hnn_integrator_2.nsteps):    
    x_initial_2[k,:] = verlet_rugged.x[:]
    v_initial_2[k,:] = verlet_rugged.v[:]
    verlet_rugged.integrate(int(dt_2/dt_verlet))
verlet_rugged.set_state(x,v)
for k in range(hnn_integrator_3.nsteps):    
    x_initial_3[k,:] = verlet_rugged.x[:]
    v_initial_3[k,:] = verlet_rugged.v[:]
    verlet_rugged.integrate(int(dt_3/dt_verlet))
verlet_rugged.set_state(x,v)
for k in range(hnn_integrator_4.nsteps):    
    x_initial_4[k,:] = verlet_rugged.x[:]
    v_initial_4[k,:] = verlet_rugged.v[:]
    verlet_rugged.integrate(int(dt_4/dt_verlet))


hnn_integrator_1.set_state(x_initial_1,v_initial_1)
t_1 = (hnn_integrator_1.nsteps-1)*hnn_integrator_1.dt
hnn_integrator_2.set_state(x_initial_2,v_initial_2)
t_2 = (hnn_integrator_2.nsteps-1)*hnn_integrator_2.dt
hnn_integrator_3.set_state(x_initial_3,v_initial_3)
t_3 = (hnn_integrator_3.nsteps-1)*hnn_integrator_3.dt
hnn_integrator_4.set_state(x_initial_4,v_initial_4)
t_4 = (hnn_integrator_4.nsteps-1)*hnn_integrator_4.dt



# Timestepping loop
t_hnn_1 = []
x_hnn_1 = []
v_hnn_1 = []
E_hnn_1 = []
t_hnn_2 = []
x_hnn_2 = []
v_hnn_2 = []
E_hnn_2 = []
t_hnn_3 = []
x_hnn_3 = []
v_hnn_3 = []
E_hnn_3 = []
t_hnn_4 = []
x_hnn_4 = []
v_hnn_4 = []
E_hnn_4 = []


while t_1<T_final:
    t_hnn_1.append(t_1)
    x_hnn_1.append(hnn_integrator_1.x[0])
    v_hnn_1.append(hnn_integrator_1.v[0])
    E_hnn_1.append(hnn_integrator_1.energy())
    hnn_integrator_1.integrate(1)
    t_1 += dt_1
while t_2<T_final:
    t_hnn_2.append(t_2)
    x_hnn_2.append(hnn_integrator_2.x[0])
    v_hnn_2.append(hnn_integrator_2.v[0])
    E_hnn_2.append(hnn_integrator_2.energy())
    hnn_integrator_2.integrate(1)
    t_2 += dt_2
while t_3<T_final:
    t_hnn_3.append(t_3)
    x_hnn_3.append(hnn_integrator_3.x[0])
    v_hnn_3.append(hnn_integrator_3.v[0])
    E_hnn_3.append(hnn_integrator_3.energy())
    hnn_integrator_3.integrate(1)
    t_3 += dt_3
while t_4<T_final:
    t_hnn_4.append(t_4)
    x_hnn_4.append(hnn_integrator_4.x[0])
    v_hnn_4.append(hnn_integrator_4.v[0])
    E_hnn_4.append(hnn_integrator_4.energy())
    hnn_integrator_4.integrate(1)
    t_4 += dt_4
 



x_hnn_1 = np.array(x_hnn_1)
x_hnn_2 = np.array(x_hnn_2)
x_hnn_3 = np.array(x_hnn_3)
x_hnn_4 = np.array(x_hnn_4)
x_verlet_rugged = np.array(x_verlet_rugged)
v_hnn_1 = np.array(v_hnn_1)
v_hnn_2 = np.array(v_hnn_2)
v_hnn_3 = np.array(v_hnn_3)
v_hnn_4 = np.array(v_hnn_4)
v_verlet_rugged = np.array(v_verlet_rugged)

# %%
nsteps = 1

# Plot position error as a function of time
plt.clf()
plt.rcParams['figure.figsize'] = [10, 10]

plt.plot(t_hnn_1,x_hnn_1-x_verlet_rugged[int((nsteps-1)*dt_1/dt_verlet)::int(dt_1/dt_verlet)],label='$\Delta_v$',color='blue')
plt.plot(t_hnn_2,x_hnn_2-x_verlet_rugged[int((nsteps-1)*dt_2/dt_verlet):int(np.size(x_verlet_rugged)-dt_2/dt_verlet):int(dt_2/dt_verlet)],label='$20\Delta_v$',color='orange')
plt.plot(t_hnn_3,x_hnn_3-x_verlet_rugged[int((nsteps-1)*dt_3/dt_verlet)::int(dt_3/dt_verlet)],label='$40\Delta_v$',color='green')
plt.plot(t_hnn_4,x_hnn_4-x_verlet_rugged[int((nsteps-1)*dt_4/dt_verlet):int(np.size(x_verlet_rugged)-dt_4/dt_verlet):int(dt_4/dt_verlet)],label='$100\Delta_v$',color='red')
plt.legend(loc='upper left')
ax = plt.gca()
ax.set_xlabel('time $t$')
ax.set_ylabel('position Error $x_{NN}(t)-x_V(t)$')
ax.set_title('Position Error')
plt.rc('font', size=12)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=20)    # legend fontsize
plt.rc('figure', titlesize=20)  # fontsize of the figure title
#plt.grid()
plt.show()

# Plot velocity error as a function of time

plt.plot(t_hnn_1,v_hnn_1-v_verlet_rugged[int((nsteps-1)*dt_1/dt_verlet)::int(dt_1/dt_verlet)],label='$\Delta_v$',color='blue')
plt.plot(t_hnn_2,v_hnn_2-v_verlet_rugged[int((nsteps-1)*dt_2/dt_verlet):int(np.size(v_verlet_rugged)-dt_2/dt_verlet):int(dt_2/dt_verlet)],label='$20\Delta_v$',color='orange')
plt.plot(t_hnn_3,v_hnn_3-v_verlet_rugged[int((nsteps-1)*dt_3/dt_verlet)::int(dt_3/dt_verlet)],label='$40\Delta_v$',color='green')
plt.plot(t_hnn_4,v_hnn_4-v_verlet_rugged[int((nsteps-1)*dt_4/dt_verlet):int(np.size(v_verlet_rugged)-dt_4/dt_verlet):int(dt_4/dt_verlet)],label='$100\Delta_v$',color='red')
plt.legend(loc='upper left')
ax = plt.gca()
ax.set_xlabel('time $t$')
ax.set_ylabel('Velocity Error $v_{NN}(t)-v_V(t)$')
ax.set_title('Velocity Error')
plt.rc('font', size=12)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=20)    # legend fontsize
plt.rc('figure', titlesize=20)  # fontsize of the figure title
#plt.grid()
plt.show()

# Plot L2 error as a function of time

plt.plot(t_hnn_1,((v_hnn_1-v_verlet_rugged[int((nsteps-1)*dt_1/dt_verlet)::int(dt_1/dt_verlet)])**2+(x_hnn_1-x_verlet_rugged[int((nsteps-1)*dt_1/dt_verlet)::int(dt_1/dt_verlet)])**2)**0.5,label='$\Delta_v$',color='blue')
plt.plot(t_hnn_2,((v_hnn_2-v_verlet_rugged[int((nsteps-1)*dt_2/dt_verlet):int(np.size(v_verlet_rugged)-dt_2/dt_verlet):int(dt_2/dt_verlet)])**2+(x_hnn_2-x_verlet_rugged[int((nsteps-1)*dt_2/dt_verlet):int(np.size(x_verlet_rugged)-dt_2/dt_verlet):int(dt_2/dt_verlet)])**2)**0.5,label='$20\Delta_v$',color='orange')
plt.plot(t_hnn_3,((v_hnn_3-v_verlet_rugged[int((nsteps-1)*dt_3/dt_verlet)::int(dt_3/dt_verlet)])**2+(x_hnn_3-x_verlet_rugged[int((nsteps-1)*dt_3/dt_verlet)::int(dt_3/dt_verlet)])**2)**0.5,label='$40\Delta_v$',color='green')
plt.plot(t_hnn_4,((v_hnn_4-v_verlet_rugged[int((nsteps-1)*dt_4/dt_verlet):int(np.size(v_verlet_rugged)-dt_4/dt_verlet):int(dt_4/dt_verlet)])**2+(x_hnn_4-x_verlet_rugged[int((nsteps-1)*dt_4/dt_verlet):int(np.size(x_verlet_rugged)-dt_4/dt_verlet):int(dt_4/dt_verlet)])**2)**0.5,label='$100\Delta_v$',color='red')
plt.legend(loc='upper left')
ax = plt.gca()
ax.set_xlabel('time $t$')
ax.set_ylabel('L2 Error')
ax.set_title('L2 Error')
plt.rc('font', size=12)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=20)    # legend fontsize
plt.rc('figure', titlesize=20)  # fontsize of the figure title
#plt.grid()
plt.show()


plt.clf()
# Plot energy as a function of time
# (subtract energy at time t=0 to show energy drift)

plt.plot(t_verlet_rugged,E_verlet_rugged-E_verlet_rugged[0],label='Verlet',color='black')
plt.plot(t_hnn_1,E_hnn_1-E_hnn_1[0],label='$\Delta_v$',color='blue')
plt.plot(t_hnn_2,E_hnn_2-E_hnn_2[0],label='$20\Delta_v$',color='orange')
plt.plot(t_hnn_3,E_hnn_3-E_hnn_3[0],label='$40\Delta_v$',color='green')
plt.plot(t_hnn_4,E_hnn_4-E_hnn_4[0],label='$100\Delta_v$',color='red')
plt.legend(loc='upper left')
ax = plt.gca()
ax.set_xlabel('time $t$')
ax.set_ylabel('energy shift $E(t)-E(t_0)$')
#ax.grid()
plt.rc('font', size=12)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=20)    # legend fontsize
plt.rc('figure', titlesize=20)  # fontsize of the figure title

plt.show()

#subplots of position versus velocity for all 4

plt.rcParams['figure.figsize'] = [10, 10]

plt.clf()
plt.plot(x_verlet_rugged,v_verlet_rugged,label='Verlet',color='black')
plt.plot(x_hnn_1,v_hnn_1,label='$\Delta_v$',color='blue')
plt.plot(x_hnn_2,v_hnn_2,label='$20\Delta_v$',color='orange')
plt.plot(x_hnn_3,v_hnn_3,label='$40\Delta_v$',color='green')
plt.plot(x_hnn_4,v_hnn_4,label='$100\Delta_v$',color='red')
plt.legend(loc='upper left')
ax = plt.gca()
ax.set_ylabel('Velocity $v(t)$')
ax.set_xlabel('Position $q(t)$')
plt.rc('font', size=12)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=20)    # legend fontsize
plt.rc('figure', titlesize=20)  # fontsize of the figure title
plt.show()

# %% [markdown]
# ## Plot trajectories generated to $t=128$ by Verlet integrator and neural

# %%
# Final time
T_final = 128

# Initial conditions
x = np.zeros(1)
v = np.zeros(1)
x[0] = -0.8
v[0] = -0.3
verlet_rugged.set_state(x,v)

# ==== Verlet integrator ====
t = 0.0
t_verlet_rugged = []
x_verlet_rugged = []
v_verlet_rugged = []
E_verlet_rugged = []



while t<T_final:
    t_verlet_rugged.append(t)
    E_verlet_rugged.append(verlet_rugged.energy())
    x_verlet_rugged.append(verlet_rugged.x[0])
    v_verlet_rugged.append(verlet_rugged.v[0])
    verlet_rugged.integrate(1)
    t += dt_verlet
        

# ==== Neural network integrator ====

# Initialise with Verlet integrator
x_initial_1 = np.zeros((hnn_integrator_1.nsteps,hnn_integrator_1.dynamical_system.dim))
v_initial_1 = np.zeros((hnn_integrator_1.nsteps,hnn_integrator_1.dynamical_system.dim))
x_initial_2 = np.zeros((hnn_integrator_2.nsteps,hnn_integrator_2.dynamical_system.dim))
v_initial_2 = np.zeros((hnn_integrator_2.nsteps,hnn_integrator_2.dynamical_system.dim))
x_initial_3 = np.zeros((hnn_integrator_3.nsteps,hnn_integrator_3.dynamical_system.dim))
v_initial_3 = np.zeros((hnn_integrator_3.nsteps,hnn_integrator_3.dynamical_system.dim))
x_initial_4 = np.zeros((hnn_integrator_4.nsteps,hnn_integrator_4.dynamical_system.dim))
v_initial_4 = np.zeros((hnn_integrator_4.nsteps,hnn_integrator_4.dynamical_system.dim))



verlet_rugged.set_state(x,v)
for k in range(hnn_integrator_1.nsteps):    
    x_initial_1[k,:] = verlet_rugged.x[:]
    v_initial_1[k,:] = verlet_rugged.v[:]
    verlet_rugged.integrate(int(dt_1/dt_verlet))
verlet_rugged.set_state(x,v)
for k in range(hnn_integrator_2.nsteps):    
    x_initial_2[k,:] = verlet_rugged.x[:]
    v_initial_2[k,:] = verlet_rugged.v[:]
    verlet_rugged.integrate(int(dt_2/dt_verlet))
verlet_rugged.set_state(x,v)
for k in range(hnn_integrator_3.nsteps):    
    x_initial_3[k,:] = verlet_rugged.x[:]
    v_initial_3[k,:] = verlet_rugged.v[:]
    verlet_rugged.integrate(int(dt_3/dt_verlet))
verlet_rugged.set_state(x,v)
for k in range(hnn_integrator_4.nsteps):    
    x_initial_4[k,:] = verlet_rugged.x[:]
    v_initial_4[k,:] = verlet_rugged.v[:]
    verlet_rugged.integrate(int(dt_4/dt_verlet))


hnn_integrator_1.set_state(x_initial_1,v_initial_1)
t_1 = (hnn_integrator_1.nsteps-1)*hnn_integrator_1.dt
hnn_integrator_2.set_state(x_initial_2,v_initial_2)
t_2 = (hnn_integrator_2.nsteps-1)*hnn_integrator_2.dt
hnn_integrator_3.set_state(x_initial_3,v_initial_3)
t_3 = (hnn_integrator_3.nsteps-1)*hnn_integrator_3.dt
hnn_integrator_4.set_state(x_initial_4,v_initial_4)
t_4 = (hnn_integrator_4.nsteps-1)*hnn_integrator_4.dt



# Timestepping loop
t_hnn_1 = []
x_hnn_1 = []
v_hnn_1 = []
E_hnn_1 = []
t_hnn_2 = []
x_hnn_2 = []
v_hnn_2 = []
E_hnn_2 = []
t_hnn_3 = []
x_hnn_3 = []
v_hnn_3 = []
E_hnn_3 = []
t_hnn_4 = []
x_hnn_4 = []
v_hnn_4 = []
E_hnn_4 = []


while t_1<T_final:
    t_hnn_1.append(t_1)
    x_hnn_1.append(hnn_integrator_1.x[0])
    v_hnn_1.append(hnn_integrator_1.v[0])
    E_hnn_1.append(hnn_integrator_1.energy())
    hnn_integrator_1.integrate(1)
    t_1 += dt_1
while t_2<T_final:
    t_hnn_2.append(t_2)
    x_hnn_2.append(hnn_integrator_2.x[0])
    v_hnn_2.append(hnn_integrator_2.v[0])
    E_hnn_2.append(hnn_integrator_2.energy())
    hnn_integrator_2.integrate(1)
    t_2 += dt_2
while t_3<T_final:
    t_hnn_3.append(t_3)
    x_hnn_3.append(hnn_integrator_3.x[0])
    v_hnn_3.append(hnn_integrator_3.v[0])
    E_hnn_3.append(hnn_integrator_3.energy())
    hnn_integrator_3.integrate(1)
    t_3 += dt_3
while t_4<T_final:
    t_hnn_4.append(t_4)
    x_hnn_4.append(hnn_integrator_4.x[0])
    v_hnn_4.append(hnn_integrator_4.v[0])
    E_hnn_4.append(hnn_integrator_4.energy())
    hnn_integrator_4.integrate(1)
    t_4 += dt_4
 



x_hnn_1 = np.array(x_hnn_1)
x_hnn_2 = np.array(x_hnn_2)
x_hnn_3 = np.array(x_hnn_3)
x_hnn_4 = np.array(x_hnn_4)
x_verlet_rugged = np.array(x_verlet_rugged)
v_hnn_1 = np.array(v_hnn_1)
v_hnn_2 = np.array(v_hnn_2)
v_hnn_3 = np.array(v_hnn_3)
v_hnn_4 = np.array(v_hnn_4)
v_verlet_rugged = np.array(v_verlet_rugged)


# Plot position error as a function of time

nsteps = 1


plt.clf()
plt.rcParams['figure.figsize'] = [10, 10]

plt.plot(t_hnn_1,x_hnn_1-x_verlet_rugged[int((nsteps-1)*dt_1/dt_verlet)::int(dt_1/dt_verlet)],label='$\Delta_v$',color='blue')
plt.plot(t_hnn_2,x_hnn_2-x_verlet_rugged[int((nsteps-1)*dt_2/dt_verlet)::int(dt_2/dt_verlet)],label='$20\Delta_v$',color='orange')
plt.plot(t_hnn_3,x_hnn_3-x_verlet_rugged[int((nsteps-1)*dt_3/dt_verlet):int(np.size(x_verlet_rugged)-dt_3/dt_verlet):int(dt_3/dt_verlet)],label='$40\Delta_v$',color='green')
plt.plot(t_hnn_4,x_hnn_4-x_verlet_rugged[int((nsteps-1)*dt_4/dt_verlet):int(np.size(x_verlet_rugged)-dt_4/dt_verlet):int(dt_4/dt_verlet)],label='$100\Delta_v$',color='red')
plt.legend(loc='upper left')
ax = plt.gca()
ax.set_xlabel('time $t$')
ax.set_ylabel('position Error $x_{NN}(t)-x_V(t)$')
ax.set_title('Position Error')
plt.rc('font', size=12)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=20)    # legend fontsize
plt.rc('figure', titlesize=20)  # fontsize of the figure title
#plt.grid()
plt.show()

# Plot velocity error as a function of time

plt.plot(t_hnn_1,v_hnn_1-v_verlet_rugged[int((nsteps-1)*dt_1/dt_verlet)::int(dt_1/dt_verlet)],label='$\Delta_v$',color='blue')
plt.plot(t_hnn_2,v_hnn_2-v_verlet_rugged[int((nsteps-1)*dt_2/dt_verlet)::int(dt_2/dt_verlet)],label='$20\Delta_v$',color='orange')
plt.plot(t_hnn_3,v_hnn_3-v_verlet_rugged[int((nsteps-1)*dt_3/dt_verlet):int(np.size(v_verlet_rugged)-dt_3/dt_verlet):int(dt_3/dt_verlet)],label='$40\Delta_v$',color='green')
plt.plot(t_hnn_4,v_hnn_4-v_verlet_rugged[int((nsteps-1)*dt_4/dt_verlet):int(np.size(v_verlet_rugged)-dt_4/dt_verlet):int(dt_4/dt_verlet)],label='$100\Delta_v$',color='red')
plt.legend(loc='upper left')
ax = plt.gca()
ax.set_xlabel('time $t$')
ax.set_ylabel('Velocity Error $v_{NN}(t)-v_V(t)$')
ax.set_title('Velocity Error')
plt.rc('font', size=12)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=20)    # legend fontsize
plt.rc('figure', titlesize=20)  # fontsize of the figure title
#plt.grid()
plt.show()

# Plot L2 error as a function of time

plt.plot(t_hnn_1,((v_hnn_1-v_verlet_rugged[int((nsteps-1)*dt_1/dt_verlet)::int(dt_1/dt_verlet)])**2+(x_hnn_1-x_verlet_rugged[int((nsteps-1)*dt_1/dt_verlet)::int(dt_1/dt_verlet)])**2)**0.5,label='$\Delta_v$',color='blue')
plt.plot(t_hnn_2,((v_hnn_2-v_verlet_rugged[int((nsteps-1)*dt_2/dt_verlet)::int(dt_2/dt_verlet)])**2+(x_hnn_2-x_verlet_rugged[int((nsteps-1)*dt_2/dt_verlet)::int(dt_2/dt_verlet)])**2)**0.5,label='$20\Delta_v$',color='orange')
plt.plot(t_hnn_3,((v_hnn_3-v_verlet_rugged[int((nsteps-1)*dt_3/dt_verlet):int(np.size(v_verlet_rugged)-dt_3/dt_verlet):int(dt_3/dt_verlet)])**2+(x_hnn_3-x_verlet_rugged[int((nsteps-1)*dt_3/dt_verlet):int(np.size(x_verlet_rugged)-dt_3/dt_verlet):int(dt_3/dt_verlet)])**2)**0.5,label='$40\Delta_v$',color='green')
plt.plot(t_hnn_4,((v_hnn_4-v_verlet_rugged[int((nsteps-1)*dt_4/dt_verlet):int(np.size(v_verlet_rugged)-dt_4/dt_verlet):int(dt_4/dt_verlet)])**2+(x_hnn_4-x_verlet_rugged[int((nsteps-1)*dt_4/dt_verlet):int(np.size(x_verlet_rugged)-dt_4/dt_verlet):int(dt_4/dt_verlet)])**2)**0.5,label='$100\Delta_v$',color='red')
plt.legend(loc='upper left')
ax = plt.gca()
ax.set_xlabel('time $t$')
ax.set_ylabel('L2 Error')
ax.set_title('L2 Error')
plt.rc('font', size=12)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=20)    # legend fontsize
plt.rc('figure', titlesize=20)  # fontsize of the figure title
#plt.grid()
plt.show()


plt.clf()
# Plot energy as a function of time
# (subtract energy at time t=0 to show energy drift)

plt.plot(t_verlet_rugged,E_verlet_rugged-E_verlet_rugged[0],label='Verlet',color='black')
plt.plot(t_hnn_1,E_hnn_1-E_hnn_1[0],label='$\Delta_v$',color='blue')
plt.plot(t_hnn_2,E_hnn_2-E_hnn_2[0],label='$20\Delta_v$',color='orange')
plt.plot(t_hnn_3,E_hnn_3-E_hnn_3[0],label='$40\Delta_v$',color='green')
plt.plot(t_hnn_4,E_hnn_4-E_hnn_4[0],label='$100\Delta_v$',color='red')
plt.legend(loc='upper left')
ax = plt.gca()
ax.set_xlabel('time $t$')
ax.set_ylabel('energy shift $E(t)-E(t_0)$')
#ax.grid()
plt.rc('font', size=12)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=20)    # legend fontsize
plt.rc('figure', titlesize=20)  # fontsize of the figure title

plt.show()

#subplots of position versus velocity for all 4

plt.rcParams['figure.figsize'] = [10, 10]

plt.clf()
plt.plot(x_verlet_rugged,v_verlet_rugged,label='Verlet',color='black')
plt.plot(x_hnn_1,v_hnn_1,label='$\Delta_v$',color='blue')
plt.plot(x_hnn_2,v_hnn_2,label='$20\Delta_v$',color='orange')
plt.plot(x_hnn_3,v_hnn_3,label='$40\Delta_v$',color='green')
plt.plot(x_hnn_4,v_hnn_4,label='$100\Delta_v$',color='red')
plt.legend(loc='upper left')
ax = plt.gca()
ax.set_ylabel('Velocity $v(t)$')
ax.set_xlabel('Position $q(t)$')
plt.rc('font', size=12)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=20)    # legend fontsize
plt.rc('figure', titlesize=20)  # fontsize of the figure title
plt.show()

# %% [markdown]
# ## Plot trajectories generated to $t=512$ by Verlet integrator and neural

# %%
# Final time
T_final = 512

# Initial conditions
x = np.zeros(1)
v = np.zeros(1)
x[0] = -0.8
v[0] = -0.3
verlet_rugged.set_state(x,v)

# ==== Verlet integrator ====
t = 0.0
t_verlet_rugged = []
x_verlet_rugged = []
v_verlet_rugged = []
E_verlet_rugged = []



while t<T_final:
    t_verlet_rugged.append(t)
    E_verlet_rugged.append(verlet_rugged.energy())
    x_verlet_rugged.append(verlet_rugged.x[0])
    v_verlet_rugged.append(verlet_rugged.v[0])
    verlet_rugged.integrate(1)
    t += dt_verlet
        

# ==== Neural network integrator ====

# Initialise with Verlet integrator
x_initial_1 = np.zeros((hnn_integrator_1.nsteps,hnn_integrator_1.dynamical_system.dim))
v_initial_1 = np.zeros((hnn_integrator_1.nsteps,hnn_integrator_1.dynamical_system.dim))
x_initial_2 = np.zeros((hnn_integrator_2.nsteps,hnn_integrator_2.dynamical_system.dim))
v_initial_2 = np.zeros((hnn_integrator_2.nsteps,hnn_integrator_2.dynamical_system.dim))
x_initial_3 = np.zeros((hnn_integrator_3.nsteps,hnn_integrator_3.dynamical_system.dim))
v_initial_3 = np.zeros((hnn_integrator_3.nsteps,hnn_integrator_3.dynamical_system.dim))
x_initial_4 = np.zeros((hnn_integrator_4.nsteps,hnn_integrator_4.dynamical_system.dim))
v_initial_4 = np.zeros((hnn_integrator_4.nsteps,hnn_integrator_4.dynamical_system.dim))



verlet_rugged.set_state(x,v)
for k in range(hnn_integrator_1.nsteps):    
    x_initial_1[k,:] = verlet_rugged.x[:]
    v_initial_1[k,:] = verlet_rugged.v[:]
    verlet_rugged.integrate(int(dt_1/dt_verlet))
verlet_rugged.set_state(x,v)
for k in range(hnn_integrator_2.nsteps):    
    x_initial_2[k,:] = verlet_rugged.x[:]
    v_initial_2[k,:] = verlet_rugged.v[:]
    verlet_rugged.integrate(int(dt_2/dt_verlet))
verlet_rugged.set_state(x,v)
for k in range(hnn_integrator_3.nsteps):    
    x_initial_3[k,:] = verlet_rugged.x[:]
    v_initial_3[k,:] = verlet_rugged.v[:]
    verlet_rugged.integrate(int(dt_3/dt_verlet))
verlet_rugged.set_state(x,v)
for k in range(hnn_integrator_4.nsteps):    
    x_initial_4[k,:] = verlet_rugged.x[:]
    v_initial_4[k,:] = verlet_rugged.v[:]
    verlet_rugged.integrate(int(dt_4/dt_verlet))


hnn_integrator_1.set_state(x_initial_1,v_initial_1)
t_1 = (hnn_integrator_1.nsteps-1)*hnn_integrator_1.dt
hnn_integrator_2.set_state(x_initial_2,v_initial_2)
t_2 = (hnn_integrator_2.nsteps-1)*hnn_integrator_2.dt
hnn_integrator_3.set_state(x_initial_3,v_initial_3)
t_3 = (hnn_integrator_3.nsteps-1)*hnn_integrator_3.dt
hnn_integrator_4.set_state(x_initial_4,v_initial_4)
t_4 = (hnn_integrator_4.nsteps-1)*hnn_integrator_4.dt



# Timestepping loop
t_hnn_1 = []
x_hnn_1 = []
v_hnn_1 = []
E_hnn_1 = []
t_hnn_2 = []
x_hnn_2 = []
v_hnn_2 = []
E_hnn_2 = []
t_hnn_3 = []
x_hnn_3 = []
v_hnn_3 = []
E_hnn_3 = []
t_hnn_4 = []
x_hnn_4 = []
v_hnn_4 = []
E_hnn_4 = []


while t_1<T_final:
    t_hnn_1.append(t_1)
    x_hnn_1.append(hnn_integrator_1.x[0])
    v_hnn_1.append(hnn_integrator_1.v[0])
    E_hnn_1.append(hnn_integrator_1.energy())
    hnn_integrator_1.integrate(1)
    t_1 += dt_1
while t_2<T_final:
    t_hnn_2.append(t_2)
    x_hnn_2.append(hnn_integrator_2.x[0])
    v_hnn_2.append(hnn_integrator_2.v[0])
    E_hnn_2.append(hnn_integrator_2.energy())
    hnn_integrator_2.integrate(1)
    t_2 += dt_2
while t_3<T_final:
    t_hnn_3.append(t_3)
    x_hnn_3.append(hnn_integrator_3.x[0])
    v_hnn_3.append(hnn_integrator_3.v[0])
    E_hnn_3.append(hnn_integrator_3.energy())
    hnn_integrator_3.integrate(1)
    t_3 += dt_3
while t_4<T_final:
    t_hnn_4.append(t_4)
    x_hnn_4.append(hnn_integrator_4.x[0])
    v_hnn_4.append(hnn_integrator_4.v[0])
    E_hnn_4.append(hnn_integrator_4.energy())
    hnn_integrator_4.integrate(1)
    t_4 += dt_4
 



x_hnn_1 = np.array(x_hnn_1)
x_hnn_2 = np.array(x_hnn_2)
x_hnn_3 = np.array(x_hnn_3)
x_hnn_4 = np.array(x_hnn_4)
x_verlet_rugged = np.array(x_verlet_rugged)
v_hnn_1 = np.array(v_hnn_1)
v_hnn_2 = np.array(v_hnn_2)
v_hnn_3 = np.array(v_hnn_3)
v_hnn_4 = np.array(v_hnn_4)
v_verlet_rugged = np.array(v_verlet_rugged)


nsteps = 1

# Plot position error as a function of time
plt.clf()
plt.rcParams['figure.figsize'] = [10, 10]

plt.plot(t_hnn_1,x_hnn_1-x_verlet_rugged[int((nsteps-1)*dt_1/dt_verlet)::int(dt_1/dt_verlet)],label='$\Delta_v$',color='blue')
plt.plot(t_hnn_2,x_hnn_2-x_verlet_rugged[int((nsteps-1)*dt_2/dt_verlet):int(np.size(x_verlet_rugged)-dt_2/dt_verlet):int(dt_2/dt_verlet)],label='$20\Delta_v$',color='orange')
plt.plot(t_hnn_3,x_hnn_3-x_verlet_rugged[int((nsteps-1)*dt_3/dt_verlet)::int(dt_3/dt_verlet)],label='$40\Delta_v$',color='green')
plt.plot(t_hnn_4,x_hnn_4-x_verlet_rugged[int((nsteps-1)*dt_4/dt_verlet):int(np.size(x_verlet_rugged)-dt_4/dt_verlet):int(dt_4/dt_verlet)],label='$100\Delta_v$',color='red')
plt.legend(loc='upper left')
ax = plt.gca()
ax.set_xlabel('time $t$')
ax.set_ylabel('position Error $x_{NN}(t)-x_V(t)$')
ax.set_title('Position Error')
plt.rc('font', size=12)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=20)    # legend fontsize
plt.rc('figure', titlesize=20)  # fontsize of the figure title
#plt.grid()
plt.show()

# Plot velocity error as a function of time

plt.plot(t_hnn_1,v_hnn_1-v_verlet_rugged[int((nsteps-1)*dt_1/dt_verlet)::int(dt_1/dt_verlet)],label='$\Delta_v$',color='blue')
plt.plot(t_hnn_2,v_hnn_2-v_verlet_rugged[int((nsteps-1)*dt_2/dt_verlet):int(np.size(v_verlet_rugged)-dt_2/dt_verlet):int(dt_2/dt_verlet)],label='$20\Delta_v$',color='orange')
plt.plot(t_hnn_3,v_hnn_3-v_verlet_rugged[int((nsteps-1)*dt_3/dt_verlet)::int(dt_3/dt_verlet)],label='$40\Delta_v$',color='green')
plt.plot(t_hnn_4,v_hnn_4-v_verlet_rugged[int((nsteps-1)*dt_4/dt_verlet):int(np.size(v_verlet_rugged)-dt_4/dt_verlet):int(dt_4/dt_verlet)],label='$100\Delta_v$',color='red')
plt.legend(loc='upper left')
ax = plt.gca()
ax.set_xlabel('time $t$')
ax.set_ylabel('Velocity Error $v_{NN}(t)-v_V(t)$')
ax.set_title('Velocity Error')
plt.rc('font', size=12)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=20)    # legend fontsize
plt.rc('figure', titlesize=20)  # fontsize of the figure title
#plt.grid()
plt.show()

# Plot L2 error as a function of time

plt.plot(t_hnn_1,((v_hnn_1-v_verlet_rugged[int((nsteps-1)*dt_1/dt_verlet)::int(dt_1/dt_verlet)])**2+(x_hnn_1-x_verlet_rugged[int((nsteps-1)*dt_1/dt_verlet)::int(dt_1/dt_verlet)])**2)**0.5,label='$\Delta_v$',color='blue')
plt.plot(t_hnn_2,((v_hnn_2-v_verlet_rugged[int((nsteps-1)*dt_2/dt_verlet):int(np.size(v_verlet_rugged)-dt_2/dt_verlet):int(dt_2/dt_verlet)])**2+(x_hnn_2-x_verlet_rugged[int((nsteps-1)*dt_2/dt_verlet):int(np.size(x_verlet_rugged)-dt_2/dt_verlet):int(dt_2/dt_verlet)])**2)**0.5,label='$20\Delta_v$',color='orange')
plt.plot(t_hnn_3,((v_hnn_3-v_verlet_rugged[int((nsteps-1)*dt_3/dt_verlet)::int(dt_3/dt_verlet)])**2+(x_hnn_3-x_verlet_rugged[int((nsteps-1)*dt_3/dt_verlet)::int(dt_3/dt_verlet)])**2)**0.5,label='$40\Delta_v$',color='green')
plt.plot(t_hnn_4,((v_hnn_4-v_verlet_rugged[int((nsteps-1)*dt_4/dt_verlet):int(np.size(v_verlet_rugged)-dt_4/dt_verlet):int(dt_4/dt_verlet)])**2+(x_hnn_4-x_verlet_rugged[int((nsteps-1)*dt_4/dt_verlet):int(np.size(x_verlet_rugged)-dt_4/dt_verlet):int(dt_4/dt_verlet)])**2)**0.5,label='$100\Delta_v$',color='red')
plt.legend(loc='upper left')
ax = plt.gca()
ax.set_xlabel('time $t$')
ax.set_ylabel('L2 Error')
ax.set_title('L2 Error')
plt.rc('font', size=12)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=20)    # legend fontsize
plt.rc('figure', titlesize=20)  # fontsize of the figure title
#plt.grid()
plt.show()


plt.clf()
# Plot energy as a function of time
# (subtract energy at time t=0 to show energy drift)

plt.plot(t_verlet_rugged,E_verlet_rugged-E_verlet_rugged[0],label='Verlet',color='black')
plt.plot(t_hnn_1,E_hnn_1-E_hnn_1[0],label='$\Delta_v$',color='blue')
plt.plot(t_hnn_2,E_hnn_2-E_hnn_2[0],label='$20\Delta_v$',color='orange')
plt.plot(t_hnn_3,E_hnn_3-E_hnn_3[0],label='$40\Delta_v$',color='green')
plt.plot(t_hnn_4,E_hnn_4-E_hnn_4[0],label='$100\Delta_v$',color='red')
plt.legend(loc='upper left')
ax = plt.gca()
ax.set_xlabel('time $t$')
ax.set_ylabel('energy shift $E(t)-E(t_0)$')
#ax.grid()
plt.rc('font', size=12)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=20)    # legend fontsize
plt.rc('figure', titlesize=20)  # fontsize of the figure title

plt.show()

#subplots of position versus velocity for all 4

plt.rcParams['figure.figsize'] = [10, 10]

plt.clf()
plt.plot(x_verlet_rugged,v_verlet_rugged,label='Verlet',color='black')
plt.plot(x_hnn_1,v_hnn_1,label='$\Delta_v$',color='blue')
plt.plot(x_hnn_2,v_hnn_2,label='$20\Delta_v$',color='orange')
plt.plot(x_hnn_3,v_hnn_3,label='$40\Delta_v$',color='green')
plt.plot(x_hnn_4,v_hnn_4,label='$100\Delta_v$',color='red')
plt.legend(loc='upper left')
ax = plt.gca()
ax.set_ylabel('Velocity $v(t)$')
ax.set_xlabel('Position $q(t)$')
plt.rc('font', size=12)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=20)    # legend fontsize
plt.rc('figure', titlesize=20)  # fontsize of the figure title
plt.show()
