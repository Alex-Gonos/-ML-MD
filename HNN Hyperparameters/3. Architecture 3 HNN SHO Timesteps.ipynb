# %% [markdown]
# # Hamiltonian neural network based integrator

# %%
import sys
sys.path.append('..')

import numpy as np
from matplotlib import pyplot as plt
from Code.dynamical_system import *
from Code.time_integrator import *
from Code.neuralnet import *

np.random.seed(2512517)

# %% [markdown]
# ## Hamiltonian Neural network integrator
# In this notebook, we test an alternative architecture for our HNN.

# %% [markdown]
# Set system parameters, construct dynamical system and integrator.
#
# The model system we are using here is the harmonic oscillator, defined by the equations of motion
#
# $$
# \frac{dx}{dt} = v,\qquad\qquad
# \frac{dv}{dt} = -\frac{k}{m}x
# $$
#
# The timestep size of the Neural network integrator takes values in $\Delta t_{\text{Verlet}},20\Delta t_{\text{Verlet}},40\Delta t_{\text{Verlet}},100\Delta t_{\text{Verlet}}$ where $\Delta t_{\text{Verlet}}$ is the step size of the Verlet integrator that is used for training.

# %%
# mass of particle
mass = 1.2
# spring constant of harmonic oscillator
k_spring = 0.9
# timestep for Verlet integrator
dt_verlet = 0.005
# timestep for neural network integrator
dt_1 = 0.005
dt_2 = 0.1
dt_3 = 0.2
dt_4 = 0.5

harmonic_oscillator = HarmonicOscillator(mass,k_spring)

verlet_SHO = VerletIntegrator(harmonic_oscillator,dt_verlet)

# Layers for the potential and kinetic parts of the hamiltonian

V_pot_layers = [keras.layers.Dense(64,activation='relu'),
                    keras.layers.Dense(64,activation='relu'),
                    keras.layers.Dense(32,activation='relu')]
T_kin_layers = [keras.layers.Dense(64,activation='relu'),
                    keras.layers.Dense(64,activation='relu'),
                    keras.layers.Dense(32,activation='relu')]

hnn_integrator_1 = HamiltonianNNIntegrator(harmonic_oscillator,dt_1,V_pot_layers,T_kin_layers)
hnn_integrator_2 = HamiltonianNNIntegrator(harmonic_oscillator,dt_2,V_pot_layers,T_kin_layers)
hnn_integrator_3 = HamiltonianNNIntegrator(harmonic_oscillator,dt_3,V_pot_layers,T_kin_layers)
hnn_integrator_4 = HamiltonianNNIntegrator(harmonic_oscillator,dt_4,V_pot_layers,T_kin_layers)

# visualise the neural network model
hnn_integrator_1.model.summary()
keras.utils.plot_model(hnn_integrator_1.model, show_shapes=True)
# Out:
# Model: "verlet_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               multiple                  128
#
#  dense_1 (Dense)             multiple                  4160
#
#  dense_2 (Dense)             multiple                  2080
#
#  dense_3 (Dense)             multiple                  128
#
#  dense_4 (Dense)             multiple                  4160
#
#  dense_5 (Dense)             multiple                  2080
#
#  dense_10 (Dense)            multiple                  32
#
#  dense_11 (Dense)            multiple                  32
#
# =================================================================
# Total params: 12,800
# Trainable params: 12,800
# Non-trainable params: 0
# _________________________________________________________________

# %%
BATCH_SIZE=64

data_generator_1 = DataGenerator(hnn_integrator_1,verlet_SHO)
train_batches_1 = data_generator_1.dataset.batch(BATCH_SIZE)

data_generator_2 = DataGenerator(hnn_integrator_2,verlet_SHO)
train_batches_2 = data_generator_2.dataset.batch(BATCH_SIZE)

data_generator_3 = DataGenerator(hnn_integrator_3,verlet_SHO)
train_batches_3 = data_generator_3.dataset.batch(BATCH_SIZE)

data_generator_4 = DataGenerator(hnn_integrator_4,verlet_SHO)
train_batches_4 = data_generator_4.dataset.batch(BATCH_SIZE)

# %% [markdown]
# ## Train neural network based integrator

# %%
EPOCHS=300
STEPS_PER_EPOCH=100
log_dir = './tb_logs/'
tensorboard_cb = tf.keras.callbacks.TensorBoard(log_dir=log_dir)

result_1 = hnn_integrator_1.model.fit(train_batches_1,epochs=EPOCHS,steps_per_epoch=STEPS_PER_EPOCH,
                                 callbacks=tensorboard_cb)
result_2 = hnn_integrator_2.model.fit(train_batches_2,epochs=EPOCHS,steps_per_epoch=STEPS_PER_EPOCH,
                                 callbacks=tensorboard_cb)
result_3 = hnn_integrator_3.model.fit(train_batches_3,epochs=EPOCHS,steps_per_epoch=STEPS_PER_EPOCH,
                                callbacks=tensorboard_cb)
result_4 = hnn_integrator_4.model.fit(train_batches_4,epochs=EPOCHS,steps_per_epoch=STEPS_PER_EPOCH,
                                 callbacks=tensorboard_cb)
# Out:
# Epoch 1/300
# 100/100 [==============================] - 6s 22ms/step - loss: 7.4796e-05
# Epoch 2/300
# 100/100 [==============================] - 2s 21ms/step - loss: 6.9131e-05
# Epoch 3/300
# 100/100 [==============================] - 2s 21ms/step - loss: 5.8312e-05
# Epoch 4/300
# 100/100 [==============================] - 2s 21ms/step - loss: 4.8050e-05
# Epoch 5/300
# 100/100 [==============================] - 2s 21ms/step - loss: 3.7133e-05
# Epoch 6/300
# 100/100 [==============================] - 2s 21ms/step - loss: 3.3322e-05
# Epoch 7/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.9208e-05
# Epoch 8/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.8091e-05
# Epoch 9/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.8225e-05
# Epoch 10/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.7176e-05
# Epoch 11/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.7904e-05
# Epoch 12/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.7423e-05
# Epoch 13/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.8383e-05
# Epoch 14/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.7219e-05
# Epoch 15/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.6879e-05
# Epoch 16/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.7497e-05
# Epoch 17/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.7343e-05
# Epoch 18/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.7523e-05
# Epoch 19/300
# 100/100 [==============================] - 2s 20ms/step - loss: 2.8365e-05
# Epoch 20/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.6931e-05
# Epoch 21/300
# 100/100 [==============================] - 2s 22ms/step - loss: 2.7756e-05
# Epoch 22/300
# 100/100 [==============================] - 2s 20ms/step - loss: 2.8460e-05
# Epoch 23/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.7620e-05
# Epoch 24/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.8026e-05
# Epoch 25/300
# 100/100 [==============================] - 2s 20ms/step - loss: 2.7429e-05
# Epoch 26/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.8225e-05
# Epoch 27/300
# 100/100 [==============================] - 2s 23ms/step - loss: 2.7505e-05
# Epoch 28/300
# 100/100 [==============================] - 2s 22ms/step - loss: 2.6954e-05
# Epoch 29/300
# 100/100 [==============================] - 2s 23ms/step - loss: 2.7429e-05
# Epoch 30/300
# 100/100 [==============================] - 2s 22ms/step - loss: 2.7453e-05
# Epoch 31/300
# 100/100 [==============================] - 2s 22ms/step - loss: 2.6606e-05
# Epoch 32/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.7974e-05
# Epoch 33/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.7462e-05
# Epoch 34/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.7164e-05
# Epoch 35/300
# 100/100 [==============================] - 2s 22ms/step - loss: 2.7837e-05
# Epoch 36/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.7972e-05
# Epoch 37/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.8080e-05
# Epoch 38/300
# 100/100 [==============================] - 2s 22ms/step - loss: 2.7213e-05
# Epoch 39/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.7717e-05
# Epoch 40/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.7061e-05
# Epoch 41/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.6954e-05
# Epoch 42/300
# 100/100 [==============================] - 2s 22ms/step - loss: 2.7396e-05
# Epoch 43/300
# 100/100 [==============================] - 2s 22ms/step - loss: 2.7385e-05
# Epoch 44/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.7662e-05
# Epoch 45/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.6868e-05
# Epoch 46/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.8168e-05
# Epoch 47/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.6886e-05
# Epoch 48/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.8037e-05
# Epoch 49/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.6873e-05
# Epoch 50/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.8398e-05
# Epoch 51/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.7933e-05
# Epoch 52/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.7707e-05
# Epoch 53/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.7670e-05
# Epoch 54/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.7219e-05
# Epoch 55/300
# 100/100 [==============================] - 2s 20ms/step - loss: 2.6570e-05
# Epoch 56/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.7090e-05
# Epoch 57/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.6982e-05
# Epoch 58/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.7639e-05
# Epoch 59/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.7999e-05
# Epoch 60/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.7893e-05
# Epoch 61/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.7124e-05
# Epoch 62/300
# 100/100 [==============================] - 2s 24ms/step - loss: 2.7541e-05
# Epoch 63/300
# 100/100 [==============================] - 2s 22ms/step - loss: 2.7322e-05
# Epoch 64/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.7734e-05
# Epoch 65/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.7140e-05
# Epoch 66/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.7664e-05
# Epoch 67/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.8688e-05
# Epoch 68/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.8749e-05
# Epoch 69/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.6612e-05
# Epoch 70/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.7458e-05
# Epoch 71/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.6592e-05
# Epoch 72/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.7539e-05
# Epoch 73/300
# 100/100 [==============================] - 2s 22ms/step - loss: 2.7088e-05
# Epoch 74/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.7419e-05
# Epoch 75/300
# 100/100 [==============================] - 2s 22ms/step - loss: 2.8417e-05
# Epoch 76/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.7724e-05
# Epoch 77/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.7628e-05
# Epoch 78/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.8159e-05
# Epoch 79/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.7512e-05
# Epoch 80/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.7053e-05
# Epoch 81/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.7625e-05
# Epoch 82/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.6842e-05
# Epoch 83/300
# 100/100 [==============================] - 2s 22ms/step - loss: 2.7769e-05
# Epoch 84/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.7027e-05
# Epoch 85/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.7691e-05
# Epoch 86/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.8118e-05
# Epoch 87/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.7392e-05
# Epoch 88/300
# 100/100 [==============================] - 2s 24ms/step - loss: 2.7798e-05
# Epoch 89/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.7275e-05
# Epoch 90/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.7958e-05
# Epoch 91/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.8782e-05
# Epoch 92/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.7410e-05
# Epoch 93/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.7589e-05
# Epoch 94/300
# 100/100 [==============================] - 2s 22ms/step - loss: 2.7605e-05
# Epoch 95/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.7179e-05
# Epoch 96/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.7053e-05
# Epoch 97/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.6662e-05
# Epoch 98/300
# 100/100 [==============================] - 2s 20ms/step - loss: 2.7256e-05
# Epoch 99/300
# 100/100 [==============================] - 2s 20ms/step - loss: 2.7565e-05
# Epoch 100/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.6740e-05
# Epoch 101/300
# 100/100 [==============================] - 2s 22ms/step - loss: 2.8144e-05
# Epoch 102/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.7325e-05
# Epoch 103/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.7566e-05
# Epoch 104/300
# 100/100 [==============================] - 2s 22ms/step - loss: 2.8086e-05
# Epoch 105/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.6679e-05
# Epoch 106/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.7207e-05
# Epoch 107/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.7576e-05
# Epoch 108/300
# 100/100 [==============================] - 2s 22ms/step - loss: 2.7256e-05
# Epoch 109/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.8055e-05
# Epoch 110/300
# 100/100 [==============================] - 2s 22ms/step - loss: 2.7981e-05
# Epoch 111/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.7364e-05
# Epoch 112/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.8018e-05
# Epoch 113/300
# 100/100 [==============================] - 2s 22ms/step - loss: 2.6815e-05
# Epoch 114/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.7849e-05
# Epoch 115/300
# 100/100 [==============================] - 2s 22ms/step - loss: 2.6438e-05
# Epoch 116/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.6479e-05
# Epoch 117/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.7386e-05
# Epoch 118/300
# 100/100 [==============================] - 2s 22ms/step - loss: 2.8379e-05
# Epoch 119/300
# 100/100 [==============================] - 2s 22ms/step - loss: 2.7834e-05
# Epoch 120/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.7235e-05
# Epoch 121/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.7519e-05
# Epoch 122/300
# 100/100 [==============================] - 2s 22ms/step - loss: 2.7067e-05
# Epoch 123/300
# 100/100 [==============================] - 2s 22ms/step - loss: 2.7110e-05
# Epoch 124/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.6807e-05
# Epoch 125/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.8046e-05
# Epoch 126/300
# 100/100 [==============================] - 2s 22ms/step - loss: 2.7505e-05
# Epoch 127/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.7977e-05
# Epoch 128/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.7769e-05
# Epoch 129/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.7346e-05
# Epoch 130/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.7518e-05
# Epoch 131/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.7278e-05
# Epoch 132/300
# 100/100 [==============================] - 2s 22ms/step - loss: 2.7491e-05
# Epoch 133/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.7786e-05
# Epoch 134/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.7787e-05
# Epoch 135/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.7166e-05
# Epoch 136/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.7162e-05
# Epoch 137/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.7257e-05
# Epoch 138/300
# 100/100 [==============================] - 2s 23ms/step - loss: 2.7993e-05
# Epoch 139/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.7659e-05
# Epoch 140/300
# 100/100 [==============================] - 2s 22ms/step - loss: 2.7410e-05
# Epoch 141/300
# 100/100 [==============================] - 2s 22ms/step - loss: 2.7097e-05
# Epoch 142/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.7593e-05
# Epoch 143/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.7349e-05
# Epoch 144/300
# 100/100 [==============================] - 2s 22ms/step - loss: 2.7148e-05
# Epoch 145/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.7247e-05
# Epoch 146/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.6894e-05
# Epoch 147/300
# 100/100 [==============================] - 2s 22ms/step - loss: 2.7807e-05
# Epoch 148/300
# 100/100 [==============================] - 2s 22ms/step - loss: 2.8209e-05
# Epoch 149/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.7838e-05
# Epoch 150/300
# 100/100 [==============================] - 2s 22ms/step - loss: 2.7801e-05
# Epoch 151/300
# 100/100 [==============================] - 2s 22ms/step - loss: 2.7825e-05
# Epoch 152/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.7723e-05
# Epoch 153/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.7736e-05
# Epoch 154/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.7295e-05
# Epoch 155/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.7871e-05
# Epoch 156/300
# 100/100 [==============================] - 2s 22ms/step - loss: 2.8107e-05
# Epoch 157/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.7735e-05
# Epoch 158/300
# 100/100 [==============================] - 2s 22ms/step - loss: 2.7624e-05
# Epoch 159/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.7184e-05
# Epoch 160/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.6745e-05
# Epoch 161/300
# 100/100 [==============================] - 2s 22ms/step - loss: 2.8247e-05
# Epoch 162/300
# 100/100 [==============================] - 2s 22ms/step - loss: 2.7552e-05
# Epoch 163/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.7835e-05
# Epoch 164/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.7098e-05
# Epoch 165/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.7840e-05
# Epoch 166/300
# 100/100 [==============================] - 2s 22ms/step - loss: 2.7826e-05
# Epoch 167/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.6716e-05
# Epoch 168/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.7775e-05
# Epoch 169/300
# 100/100 [==============================] - 2s 22ms/step - loss: 2.7660e-05
# Epoch 170/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.7716e-05
# Epoch 171/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.7120e-05
# Epoch 172/300
# 100/100 [==============================] - 2s 22ms/step - loss: 2.7647e-05
# Epoch 173/300
# 100/100 [==============================] - 2s 23ms/step - loss: 2.8174e-05
# Epoch 174/300
# 100/100 [==============================] - 2s 23ms/step - loss: 2.7073e-05
# Epoch 175/300
# 100/100 [==============================] - 2s 24ms/step - loss: 2.7557e-05
# Epoch 176/300
# 100/100 [==============================] - 2s 22ms/step - loss: 2.6976e-05
# Epoch 177/300
# 100/100 [==============================] - 2s 22ms/step - loss: 2.7076e-05
# Epoch 178/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.7429e-05
# Epoch 179/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.7673e-05
# Epoch 180/300
# 100/100 [==============================] - 2s 22ms/step - loss: 2.7017e-05
# Epoch 181/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.8496e-05
# Epoch 182/300
# 100/100 [==============================] - 2s 22ms/step - loss: 2.7646e-05
# Epoch 183/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.7371e-05
# Epoch 184/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.7231e-05
# Epoch 185/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.8086e-05
# Epoch 186/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.7418e-05
# Epoch 187/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.8002e-05
# Epoch 188/300
# 100/100 [==============================] - 2s 22ms/step - loss: 2.8801e-05
# Epoch 189/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.7872e-05
# Epoch 190/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.7941e-05
# Epoch 191/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.7465e-05
# Epoch 192/300
# 100/100 [==============================] - 2s 22ms/step - loss: 2.7245e-05
# Epoch 193/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.7682e-05
# Epoch 194/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.8253e-05
# Epoch 195/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.8028e-05
# Epoch 196/300
# 100/100 [==============================] - 2s 22ms/step - loss: 2.7417e-05
# Epoch 197/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.7857e-05
# Epoch 198/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.7309e-05
# Epoch 199/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.7909e-05
# Epoch 200/300
# 100/100 [==============================] - 2s 22ms/step - loss: 2.6387e-05
# Epoch 201/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.7895e-05
# Epoch 202/300
# 100/100 [==============================] - 2s 22ms/step - loss: 2.7569e-05
# Epoch 203/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.6799e-05
# Epoch 204/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.7081e-05
# Epoch 205/300
# 100/100 [==============================] - 2s 22ms/step - loss: 2.8700e-05
# Epoch 206/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.6913e-05
# Epoch 207/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.7011e-05
# Epoch 208/300
# 100/100 [==============================] - 2s 22ms/step - loss: 2.7817e-05
# Epoch 209/300
# 100/100 [==============================] - 2s 22ms/step - loss: 2.7376e-05
# Epoch 210/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.6917e-05
# Epoch 211/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.7477e-05
# Epoch 212/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.7914e-05
# Epoch 213/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.7603e-05
# Epoch 214/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.8354e-05
# Epoch 215/300
# 100/100 [==============================] - 2s 22ms/step - loss: 2.7062e-05
# Epoch 216/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.7630e-05
# Epoch 217/300
# 100/100 [==============================] - 2s 23ms/step - loss: 2.6644e-05
# Epoch 218/300
# 100/100 [==============================] - 2s 22ms/step - loss: 2.8602e-05
# Epoch 219/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.8177e-05
# Epoch 220/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.7895e-05
# Epoch 221/300
# 100/100 [==============================] - 2s 22ms/step - loss: 2.7366e-05
# Epoch 222/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.6908e-05
# Epoch 223/300
# 100/100 [==============================] - 2s 22ms/step - loss: 2.6659e-05
# Epoch 224/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.7404e-05
# Epoch 225/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.7940e-05
# Epoch 226/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.7977e-05
# Epoch 227/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.7435e-05
# Epoch 228/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.7911e-05
# Epoch 229/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.7463e-05
# Epoch 230/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.8276e-05
# Epoch 231/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.6657e-05
# Epoch 232/300
# 100/100 [==============================] - 2s 22ms/step - loss: 2.6893e-05
# Epoch 233/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.7153e-05
# Epoch 234/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.8022e-05
# Epoch 235/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.7167e-05
# Epoch 236/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.6530e-05
# Epoch 237/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.7530e-05
# Epoch 238/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.6434e-05
# Epoch 239/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.7220e-05
# Epoch 240/300
# 100/100 [==============================] - 2s 20ms/step - loss: 2.7971e-05
# Epoch 241/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.7749e-05
# Epoch 242/300
# 100/100 [==============================] - 2s 22ms/step - loss: 2.7546e-05
# Epoch 243/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.7073e-05
# Epoch 244/300
# 100/100 [==============================] - 2s 22ms/step - loss: 2.8387e-05
# Epoch 245/300
# 100/100 [==============================] - 2s 22ms/step - loss: 2.7258e-05
# Epoch 246/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.7524e-05
# Epoch 247/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.7968e-05
# Epoch 248/300
# 100/100 [==============================] - 2s 22ms/step - loss: 2.6972e-05
# Epoch 249/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.7437e-05
# Epoch 250/300
# 100/100 [==============================] - 2s 23ms/step - loss: 2.7871e-05
# Epoch 251/300
# 100/100 [==============================] - 2s 22ms/step - loss: 2.7134e-05
# Epoch 252/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.8637e-05
# Epoch 253/300
# 100/100 [==============================] - 2s 22ms/step - loss: 2.6925e-05
# Epoch 254/300
# 100/100 [==============================] - 2s 22ms/step - loss: 2.7689e-05
# Epoch 255/300
# 100/100 [==============================] - 2s 22ms/step - loss: 2.7411e-05
# Epoch 256/300
# 100/100 [==============================] - 2s 22ms/step - loss: 2.6848e-05
# Epoch 257/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.7115e-05
# Epoch 258/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.7605e-05
# Epoch 259/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.7757e-05
# Epoch 260/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.7565e-05
# Epoch 261/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.8007e-05
# Epoch 262/300
# 100/100 [==============================] - 2s 22ms/step - loss: 2.7908e-05
# Epoch 263/300
# 100/100 [==============================] - 2s 20ms/step - loss: 2.7102e-05
# Epoch 264/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.6552e-05
# Epoch 265/300
# 100/100 [==============================] - 2s 22ms/step - loss: 2.8113e-05
# Epoch 266/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.7233e-05
# Epoch 267/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.7155e-05
# Epoch 268/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.7562e-05
# Epoch 269/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.7897e-05
# Epoch 270/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.7701e-05
# Epoch 271/300
# 100/100 [==============================] - 2s 22ms/step - loss: 2.7242e-05
# Epoch 272/300
# 100/100 [==============================] - 2s 22ms/step - loss: 2.7240e-05
# Epoch 273/300
# 100/100 [==============================] - 2s 22ms/step - loss: 2.7682e-05
# Epoch 274/300
# 100/100 [==============================] - 2s 23ms/step - loss: 2.7415e-05
# Epoch 275/300
# 100/100 [==============================] - 2s 22ms/step - loss: 2.5849e-05
# Epoch 276/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.7206e-05
# Epoch 277/300
# 100/100 [==============================] - 2s 22ms/step - loss: 2.8594e-05
# Epoch 278/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.6412e-05
# Epoch 279/300
# 100/100 [==============================] - 2s 22ms/step - loss: 2.7360e-05
# Epoch 280/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.7646e-05
# Epoch 281/300
# 100/100 [==============================] - 2s 22ms/step - loss: 2.7079e-05
# Epoch 282/300
# 100/100 [==============================] - 2s 22ms/step - loss: 2.7911e-05
# Epoch 283/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.8022e-05
# Epoch 284/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.7605e-05
# Epoch 285/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.7749e-05
# Epoch 286/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.5926e-05
# Epoch 287/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.7698e-05
# Epoch 288/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.7402e-05
# Epoch 289/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.8466e-05
# Epoch 290/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.7061e-05
# Epoch 291/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.6679e-05
# Epoch 292/300
# 100/100 [==============================] - 2s 20ms/step - loss: 2.7296e-05
# Epoch 293/300
# 100/100 [==============================] - 2s 20ms/step - loss: 2.8377e-05
# Epoch 294/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.7513e-05
# Epoch 295/300
# 100/100 [==============================] - 2s 22ms/step - loss: 2.7331e-05
# Epoch 296/300
# 100/100 [==============================] - 2s 22ms/step - loss: 2.6853e-05
# Epoch 297/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.6519e-05
# Epoch 298/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.7672e-05
# Epoch 299/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.7196e-05
# Epoch 300/300
# 100/100 [==============================] - 2s 21ms/step - loss: 2.8255e-05
# Epoch 1/300
# 100/100 [==============================] - 5s 37ms/step - loss: 0.0366
# Epoch 2/300
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0295
# Epoch 3/300
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0236
# Epoch 4/300
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0195
# Epoch 5/300
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0151
# Epoch 6/300
# 100/100 [==============================] - 4s 35ms/step - loss: 0.0128
# Epoch 7/300
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0111
# Epoch 8/300
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0111
# Epoch 9/300
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0110
# Epoch 10/300
# 100/100 [==============================] - 4s 35ms/step - loss: 0.0112
# Epoch 11/300
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0105
# Epoch 12/300
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0108
# Epoch 13/300
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0105
# Epoch 14/300
# 100/100 [==============================] - 3s 35ms/step - loss: 0.0107
# Epoch 15/300
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0107
# Epoch 16/300
# 100/100 [==============================] - 4s 35ms/step - loss: 0.0108
# Epoch 17/300
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0106
# Epoch 18/300
# 100/100 [==============================] - 4s 35ms/step - loss: 0.0110
# Epoch 19/300
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0108
# Epoch 20/300
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0109
# Epoch 21/300
# 100/100 [==============================] - 4s 35ms/step - loss: 0.0107
# Epoch 22/300
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0110
# Epoch 23/300
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0113
# Epoch 24/300
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0110
# Epoch 25/300
# 100/100 [==============================] - 4s 35ms/step - loss: 0.0112
# Epoch 26/300
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0107
# Epoch 27/300
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0109
# Epoch 28/300
# 100/100 [==============================] - 4s 38ms/step - loss: 0.0108
# Epoch 29/300
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0111
# Epoch 30/300
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0107
# Epoch 31/300
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0108
# Epoch 32/300
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0108
# Epoch 33/300
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0112
# Epoch 34/300
# 100/100 [==============================] - 4s 35ms/step - loss: 0.0109
# Epoch 35/300
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0105
# Epoch 36/300
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0110
# Epoch 37/300
# 100/100 [==============================] - 4s 35ms/step - loss: 0.0109
# Epoch 38/300
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0107
# Epoch 39/300
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0104
# Epoch 40/300
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0110
# Epoch 41/300
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0109
# Epoch 42/300
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0111
# Epoch 43/300
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0109
# Epoch 44/300
# 100/100 [==============================] - 4s 38ms/step - loss: 0.0109
# Epoch 45/300
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0108
# Epoch 46/300
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0109
# Epoch 47/300
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0109
# Epoch 48/300
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0106
# Epoch 49/300
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0104
# Epoch 50/300
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0111
# Epoch 51/300
# 100/100 [==============================] - 4s 35ms/step - loss: 0.0109
# Epoch 52/300
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0106
# Epoch 53/300
# 100/100 [==============================] - 4s 35ms/step - loss: 0.0107
# Epoch 54/300
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0108
# Epoch 55/300
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0111
# Epoch 56/300
# 100/100 [==============================] - 4s 35ms/step - loss: 0.0107
# Epoch 57/300
# 100/100 [==============================] - 4s 35ms/step - loss: 0.0108
# Epoch 58/300
# 100/100 [==============================] - 4s 35ms/step - loss: 0.0109
# Epoch 59/300
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0110
# Epoch 60/300
# 100/100 [==============================] - 4s 35ms/step - loss: 0.0110
# Epoch 61/300
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0109
# Epoch 62/300
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0106
# Epoch 63/300
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0109
# Epoch 64/300
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0105
# Epoch 65/300
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0103
# Epoch 66/300
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0105
# Epoch 67/300
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0109
# Epoch 68/300
# 100/100 [==============================] - 4s 35ms/step - loss: 0.0109
# Epoch 69/300
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0108
# Epoch 70/300
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0107
# Epoch 71/300
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0111
# Epoch 72/300
# 100/100 [==============================] - 4s 35ms/step - loss: 0.0108
# Epoch 73/300
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0106
# Epoch 74/300
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0107
# Epoch 75/300
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0108
# Epoch 76/300
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0110
# Epoch 77/300
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0107
# Epoch 78/300
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0106
# Epoch 79/300
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0109
# Epoch 80/300
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0108
# Epoch 81/300
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0110
# Epoch 82/300
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0110
# Epoch 83/300
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0108
# Epoch 84/300
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0110
# Epoch 85/300
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0107
# Epoch 86/300
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0110
# Epoch 87/300
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0110
# Epoch 88/300
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0107
# Epoch 89/300
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0108
# Epoch 90/300
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0108
# Epoch 91/300
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0104
# Epoch 92/300
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0110
# Epoch 93/300
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0107
# Epoch 94/300
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0107
# Epoch 95/300
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0106
# Epoch 96/300
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0110
# Epoch 97/300
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0105
# Epoch 98/300
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0110
# Epoch 99/300
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0108
# Epoch 100/300
# 100/100 [==============================] - 4s 38ms/step - loss: 0.0111
# Epoch 101/300
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0108
# Epoch 102/300
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0109
# Epoch 103/300
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0108
# Epoch 104/300
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0105
# Epoch 105/300
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0111
# Epoch 106/300
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0108
# Epoch 107/300
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0111
# Epoch 108/300
# 100/100 [==============================] - 4s 38ms/step - loss: 0.0109
# Epoch 109/300
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0110
# Epoch 110/300
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0106
# Epoch 111/300
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0109
# Epoch 112/300
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0111
# Epoch 113/300
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0110
# Epoch 114/300
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0108
# Epoch 115/300
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0109
# Epoch 116/300
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0107
# Epoch 117/300
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0106
# Epoch 118/300
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0109
# Epoch 119/300
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0108
# Epoch 120/300
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0106
# Epoch 121/300
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0110
# Epoch 122/300
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0111
# Epoch 123/300
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0108
# Epoch 124/300
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0108
# Epoch 125/300
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0110
# Epoch 126/300
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0106
# Epoch 127/300
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0109
# Epoch 128/300
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0107
# Epoch 129/300
# 100/100 [==============================] - 4s 38ms/step - loss: 0.0108
# Epoch 130/300
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0111
# Epoch 131/300
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0110
# Epoch 132/300
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0106
# Epoch 133/300
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0109
# Epoch 134/300
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0106
# Epoch 135/300
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0104
# Epoch 136/300
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0107
# Epoch 137/300
# 100/100 [==============================] - 4s 38ms/step - loss: 0.0110
# Epoch 138/300
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0110
# Epoch 139/300
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0110
# Epoch 140/300
# 100/100 [==============================] - 4s 38ms/step - loss: 0.0109
# Epoch 141/300
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0107
# Epoch 142/300
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0107
# Epoch 143/300
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0108
# Epoch 144/300
# 100/100 [==============================] - 4s 38ms/step - loss: 0.0113
# Epoch 145/300
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0111
# Epoch 146/300
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0111
# Epoch 147/300
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0109
# Epoch 148/300
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0106
# Epoch 149/300
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0110
# Epoch 150/300
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0107
# Epoch 151/300
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0110
# Epoch 152/300
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0110
# Epoch 153/300
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0107
# Epoch 154/300
# 100/100 [==============================] - 4s 38ms/step - loss: 0.0110
# Epoch 155/300
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0109
# Epoch 156/300
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0109
# Epoch 157/300
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0108
# Epoch 158/300
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0108
# Epoch 159/300
# 100/100 [==============================] - 4s 38ms/step - loss: 0.0112
# Epoch 160/300
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0107
# Epoch 161/300
# 100/100 [==============================] - 4s 38ms/step - loss: 0.0106
# Epoch 162/300
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0106
# Epoch 163/300
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0105
# Epoch 164/300
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0109
# Epoch 165/300
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0107
# Epoch 166/300
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0108
# Epoch 167/300
# 100/100 [==============================] - 4s 38ms/step - loss: 0.0110
# Epoch 168/300
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0106
# Epoch 169/300
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0107
# Epoch 170/300
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0107
# Epoch 171/300
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0106
# Epoch 172/300
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0111
# Epoch 173/300
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0110
# Epoch 174/300
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0108
# Epoch 175/300
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0111
# Epoch 176/300
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0109
# Epoch 177/300
# 100/100 [==============================] - 4s 38ms/step - loss: 0.0109
# Epoch 178/300
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0111
# Epoch 179/300
# 100/100 [==============================] - 4s 38ms/step - loss: 0.0106
# Epoch 180/300
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0108
# Epoch 181/300
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0109
# Epoch 182/300
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0107
# Epoch 183/300
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0109
# Epoch 184/300
# 100/100 [==============================] - 4s 38ms/step - loss: 0.0107
# Epoch 185/300
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0108
# Epoch 186/300
# 100/100 [==============================] - 4s 38ms/step - loss: 0.0106
# Epoch 187/300
# 100/100 [==============================] - 4s 38ms/step - loss: 0.0105
# Epoch 188/300
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0107
# Epoch 189/300
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0107
# Epoch 190/300
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0113
# Epoch 191/300
# 100/100 [==============================] - 4s 38ms/step - loss: 0.0110
# Epoch 192/300
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0111
# Epoch 193/300
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0110
# Epoch 194/300
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0105
# Epoch 195/300
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0106
# Epoch 196/300
# 100/100 [==============================] - 4s 38ms/step - loss: 0.0105
# Epoch 197/300
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0107
# Epoch 198/300
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0107
# Epoch 199/300
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0109
# Epoch 200/300
# 100/100 [==============================] - 4s 38ms/step - loss: 0.0109
# Epoch 201/300
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0108
# Epoch 202/300
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0111
# Epoch 203/300
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0106
# Epoch 204/300
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0109
# Epoch 205/300
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0106
# Epoch 206/300
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0110
# Epoch 207/300
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0107
# Epoch 208/300
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0109
# Epoch 209/300
# 100/100 [==============================] - 4s 38ms/step - loss: 0.0109
# Epoch 210/300
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0110
# Epoch 211/300
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0112
# Epoch 212/300
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0111
# Epoch 213/300
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0108
# Epoch 214/300
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0110
# Epoch 215/300
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0109
# Epoch 216/300
# 100/100 [==============================] - 4s 38ms/step - loss: 0.0111
# Epoch 217/300
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0107
# Epoch 218/300
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0107
# Epoch 219/300
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0109
# Epoch 220/300
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0110
# Epoch 221/300
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0111
# Epoch 222/300
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0108
# Epoch 223/300
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0108
# Epoch 224/300
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0107
# Epoch 225/300
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0106
# Epoch 226/300
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0110
# Epoch 227/300
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0106
# Epoch 228/300
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0109
# Epoch 229/300
# 100/100 [==============================] - 4s 38ms/step - loss: 0.0109
# Epoch 230/300
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0110
# Epoch 231/300
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0110
# Epoch 232/300
# 100/100 [==============================] - 4s 38ms/step - loss: 0.0104
# Epoch 233/300
# 100/100 [==============================] - 4s 38ms/step - loss: 0.0108
# Epoch 234/300
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0109
# Epoch 235/300
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0108
# Epoch 236/300
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0109
# Epoch 237/300
# 100/100 [==============================] - 4s 38ms/step - loss: 0.0109
# Epoch 238/300
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0108
# Epoch 239/300
# 100/100 [==============================] - 4s 38ms/step - loss: 0.0109
# Epoch 240/300
# 100/100 [==============================] - 4s 38ms/step - loss: 0.0111
# Epoch 241/300
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0107
# Epoch 242/300
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0110
# Epoch 243/300
# 100/100 [==============================] - 4s 38ms/step - loss: 0.0108
# Epoch 244/300
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0106
# Epoch 245/300
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0109
# Epoch 246/300
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0108
# Epoch 247/300
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0109
# Epoch 248/300
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0109
# Epoch 249/300
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0110
# Epoch 250/300
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0106
# Epoch 251/300
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0110
# Epoch 252/300
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0110
# Epoch 253/300
# 100/100 [==============================] - 4s 38ms/step - loss: 0.0110
# ...
# 100/100 [==============================] - 11s 106ms/step - loss: 0.2490
# Epoch 118/300
# 100/100 [==============================] - 11s 106ms/step - loss: 0.2520
# Epoch 119/300
# 100/100 [==============================] - 11s 109ms/step - loss: 0.2559
# Epoch 120/300
# 100/100 [==============================] - 11s 106ms/step - loss: 0.2569
# Epoch 121/300
# 100/100 [==============================] - 11s 106ms/step - loss: 0.2590
# Epoch 122/300
# 100/100 [==============================] - 11s 108ms/step - loss: 0.2599
# Epoch 123/300
# 100/100 [==============================] - 11s 108ms/step - loss: 0.2531
# Epoch 124/300
# 100/100 [==============================] - 11s 107ms/step - loss: 0.2506
# Epoch 125/300
# 100/100 [==============================] - 11s 107ms/step - loss: 0.2552
# Epoch 126/300
# 100/100 [==============================] - 11s 107ms/step - loss: 0.2662
# Epoch 127/300
# 100/100 [==============================] - 11s 107ms/step - loss: 0.2498
# Epoch 128/300
# 100/100 [==============================] - 11s 107ms/step - loss: 0.2574
# Epoch 129/300
# 100/100 [==============================] - 11s 107ms/step - loss: 0.2559
# Epoch 130/300
# 100/100 [==============================] - 11s 107ms/step - loss: 0.2521
# Epoch 131/300
# 100/100 [==============================] - 11s 107ms/step - loss: 0.2624
# Epoch 132/300
# 100/100 [==============================] - 11s 107ms/step - loss: 0.2527
# Epoch 133/300
# 100/100 [==============================] - 11s 108ms/step - loss: 0.2605
# Epoch 134/300
# 100/100 [==============================] - 11s 111ms/step - loss: 0.2501
# Epoch 135/300
# 100/100 [==============================] - 11s 108ms/step - loss: 0.2632
# Epoch 136/300
# 100/100 [==============================] - 11s 107ms/step - loss: 0.2470
# Epoch 137/300
# 100/100 [==============================] - 11s 107ms/step - loss: 0.2593
# Epoch 138/300
# 100/100 [==============================] - 11s 108ms/step - loss: 0.2603
# Epoch 139/300
# 100/100 [==============================] - 11s 106ms/step - loss: 0.2567
# Epoch 140/300
# 100/100 [==============================] - 11s 107ms/step - loss: 0.2594
# Epoch 141/300
# 100/100 [==============================] - 11s 108ms/step - loss: 0.2571
# Epoch 142/300
# 100/100 [==============================] - 11s 107ms/step - loss: 0.2597
# Epoch 143/300
# 100/100 [==============================] - 11s 108ms/step - loss: 0.2525
# Epoch 144/300
# 100/100 [==============================] - 11s 108ms/step - loss: 0.2488
# Epoch 145/300
# 100/100 [==============================] - 11s 108ms/step - loss: 0.2572
# Epoch 146/300
# 100/100 [==============================] - 11s 107ms/step - loss: 0.2548
# Epoch 147/300
# 100/100 [==============================] - 11s 108ms/step - loss: 0.2519
# Epoch 148/300
# 100/100 [==============================] - 11s 106ms/step - loss: 0.2507
# Epoch 149/300
# 100/100 [==============================] - 11s 108ms/step - loss: 0.2552
# Epoch 150/300
# 100/100 [==============================] - 11s 107ms/step - loss: 0.2599
# Epoch 151/300
# 100/100 [==============================] - 11s 108ms/step - loss: 0.2543
# Epoch 152/300
# 100/100 [==============================] - 11s 107ms/step - loss: 0.2571
# Epoch 153/300
# 100/100 [==============================] - 11s 108ms/step - loss: 0.2499
# Epoch 154/300
# 100/100 [==============================] - 11s 108ms/step - loss: 0.2548
# Epoch 155/300
# 100/100 [==============================] - 11s 108ms/step - loss: 0.2566
# Epoch 156/300
# 100/100 [==============================] - 11s 108ms/step - loss: 0.2504
# Epoch 157/300
# 100/100 [==============================] - 11s 107ms/step - loss: 0.2606
# Epoch 158/300
# 100/100 [==============================] - 11s 108ms/step - loss: 0.2551
# Epoch 159/300
# 100/100 [==============================] - 11s 107ms/step - loss: 0.2436
# Epoch 160/300
# 100/100 [==============================] - 11s 107ms/step - loss: 0.2566
# Epoch 161/300
# 100/100 [==============================] - 11s 106ms/step - loss: 0.2575
# Epoch 162/300
# 100/100 [==============================] - 11s 108ms/step - loss: 0.2537
# Epoch 163/300
# 100/100 [==============================] - 11s 111ms/step - loss: 0.2535
# Epoch 164/300
# 100/100 [==============================] - 11s 108ms/step - loss: 0.2561
# Epoch 165/300
# 100/100 [==============================] - 11s 108ms/step - loss: 0.2531
# Epoch 166/300
# 100/100 [==============================] - 11s 107ms/step - loss: 0.2540
# Epoch 167/300
# 100/100 [==============================] - 11s 107ms/step - loss: 0.2536
# Epoch 168/300
# 100/100 [==============================] - 11s 107ms/step - loss: 0.2602
# Epoch 169/300
# 100/100 [==============================] - 11s 108ms/step - loss: 0.2526
# Epoch 170/300
# 100/100 [==============================] - 11s 107ms/step - loss: 0.2552
# Epoch 171/300
# 100/100 [==============================] - 11s 107ms/step - loss: 0.2547
# Epoch 172/300
# 100/100 [==============================] - 11s 107ms/step - loss: 0.2552
# Epoch 173/300
# 100/100 [==============================] - 11s 107ms/step - loss: 0.2519
# Epoch 174/300
# 100/100 [==============================] - 11s 107ms/step - loss: 0.2522
# Epoch 175/300
# 100/100 [==============================] - 11s 108ms/step - loss: 0.2475
# Epoch 176/300
# 100/100 [==============================] - 11s 108ms/step - loss: 0.2482
# Epoch 177/300
# 100/100 [==============================] - 11s 108ms/step - loss: 0.2432
# Epoch 178/300
# 100/100 [==============================] - 11s 107ms/step - loss: 0.2535
# Epoch 179/300
# 100/100 [==============================] - 11s 107ms/step - loss: 0.2604
# Epoch 180/300
# 100/100 [==============================] - 11s 107ms/step - loss: 0.2605
# Epoch 181/300
# 100/100 [==============================] - 11s 108ms/step - loss: 0.2593
# Epoch 182/300
# 100/100 [==============================] - 11s 107ms/step - loss: 0.2571
# Epoch 183/300
# 100/100 [==============================] - 11s 107ms/step - loss: 0.2566
# Epoch 184/300
# 100/100 [==============================] - 11s 108ms/step - loss: 0.2549
# Epoch 185/300
# 100/100 [==============================] - 11s 107ms/step - loss: 0.2504
# Epoch 186/300
# 100/100 [==============================] - 11s 108ms/step - loss: 0.2567
# Epoch 187/300
# 100/100 [==============================] - 11s 107ms/step - loss: 0.2617
# Epoch 188/300
# 100/100 [==============================] - 11s 106ms/step - loss: 0.2555
# Epoch 189/300
# 100/100 [==============================] - 11s 107ms/step - loss: 0.2529
# Epoch 190/300
# 100/100 [==============================] - 11s 108ms/step - loss: 0.2598
# Epoch 191/300
# 100/100 [==============================] - 11s 109ms/step - loss: 0.2637
# Epoch 192/300
# 100/100 [==============================] - 11s 109ms/step - loss: 0.2559
# Epoch 193/300
# 100/100 [==============================] - 11s 107ms/step - loss: 0.2607
# Epoch 194/300
# 100/100 [==============================] - 11s 108ms/step - loss: 0.2547
# Epoch 195/300
# 100/100 [==============================] - 11s 108ms/step - loss: 0.2589
# Epoch 196/300
# 100/100 [==============================] - 11s 108ms/step - loss: 0.2545
# Epoch 197/300
# 100/100 [==============================] - 11s 105ms/step - loss: 0.2570
# Epoch 198/300
# 100/100 [==============================] - 11s 107ms/step - loss: 0.2535
# Epoch 199/300
# 100/100 [==============================] - 11s 106ms/step - loss: 0.2623
# Epoch 200/300
# 100/100 [==============================] - 11s 108ms/step - loss: 0.2631
# Epoch 201/300
# 100/100 [==============================] - 11s 107ms/step - loss: 0.2505
# Epoch 202/300
# 100/100 [==============================] - 11s 107ms/step - loss: 0.2534
# Epoch 203/300
# 100/100 [==============================] - 11s 108ms/step - loss: 0.2600
# Epoch 204/300
# 100/100 [==============================] - 11s 107ms/step - loss: 0.2568
# Epoch 205/300
# 100/100 [==============================] - 11s 107ms/step - loss: 0.2559
# Epoch 206/300
# 100/100 [==============================] - 11s 107ms/step - loss: 0.2598
# Epoch 207/300
# 100/100 [==============================] - 11s 109ms/step - loss: 0.2525
# Epoch 208/300
# 100/100 [==============================] - 11s 107ms/step - loss: 0.2612
# Epoch 209/300
# 100/100 [==============================] - 11s 108ms/step - loss: 0.2599
# Epoch 210/300
# 100/100 [==============================] - 11s 107ms/step - loss: 0.2516
# Epoch 211/300
# 100/100 [==============================] - 11s 107ms/step - loss: 0.2638
# Epoch 212/300
# 100/100 [==============================] - 11s 106ms/step - loss: 0.2584
# Epoch 213/300
# 100/100 [==============================] - 11s 108ms/step - loss: 0.2607
# Epoch 214/300
# 100/100 [==============================] - 11s 107ms/step - loss: 0.2518
# Epoch 215/300
# 100/100 [==============================] - 11s 108ms/step - loss: 0.2483
# Epoch 216/300
# 100/100 [==============================] - 11s 109ms/step - loss: 0.2619
# Epoch 217/300
# 100/100 [==============================] - 11s 108ms/step - loss: 0.2622
# Epoch 218/300
# 100/100 [==============================] - 11s 107ms/step - loss: 0.2598
# Epoch 219/300
# 100/100 [==============================] - 11s 107ms/step - loss: 0.2531
# Epoch 220/300
# 100/100 [==============================] - 11s 108ms/step - loss: 0.2519
# Epoch 221/300
# 100/100 [==============================] - 11s 108ms/step - loss: 0.2545
# Epoch 222/300
# 100/100 [==============================] - 11s 107ms/step - loss: 0.2573
# Epoch 223/300
# 100/100 [==============================] - 11s 108ms/step - loss: 0.2548
# Epoch 224/300
# 100/100 [==============================] - 11s 106ms/step - loss: 0.2608
# Epoch 225/300
# 100/100 [==============================] - 11s 108ms/step - loss: 0.2596
# Epoch 226/300
# 100/100 [==============================] - 11s 108ms/step - loss: 0.2467
# Epoch 227/300
# 100/100 [==============================] - 11s 107ms/step - loss: 0.2548
# Epoch 228/300
# 100/100 [==============================] - 11s 108ms/step - loss: 0.2528
# Epoch 229/300
# 100/100 [==============================] - 11s 108ms/step - loss: 0.2623
# Epoch 230/300
# 100/100 [==============================] - 11s 108ms/step - loss: 0.2513
# Epoch 231/300
# 100/100 [==============================] - 11s 107ms/step - loss: 0.2572
# Epoch 232/300
# 100/100 [==============================] - 11s 108ms/step - loss: 0.2503
# Epoch 233/300
# 100/100 [==============================] - 11s 107ms/step - loss: 0.2656
# Epoch 234/300
# 100/100 [==============================] - 11s 108ms/step - loss: 0.2560
# Epoch 235/300
# 100/100 [==============================] - 11s 108ms/step - loss: 0.2506
# Epoch 236/300
# 100/100 [==============================] - 11s 107ms/step - loss: 0.2513
# Epoch 237/300
# 100/100 [==============================] - 11s 107ms/step - loss: 0.2515
# Epoch 238/300
# 100/100 [==============================] - 11s 108ms/step - loss: 0.2674
# Epoch 239/300
# 100/100 [==============================] - 11s 107ms/step - loss: 0.2445
# Epoch 240/300
# 100/100 [==============================] - 11s 108ms/step - loss: 0.2584
# Epoch 241/300
# 100/100 [==============================] - 11s 107ms/step - loss: 0.2550
# Epoch 242/300
# 100/100 [==============================] - 11s 109ms/step - loss: 0.2464
# Epoch 243/300
# 100/100 [==============================] - 11s 108ms/step - loss: 0.2566
# Epoch 244/300
# 100/100 [==============================] - 11s 110ms/step - loss: 0.2558
# Epoch 245/300
# 100/100 [==============================] - 11s 108ms/step - loss: 0.2536
# Epoch 246/300
# 100/100 [==============================] - 11s 107ms/step - loss: 0.2566
# Epoch 247/300
# 100/100 [==============================] - 11s 108ms/step - loss: 0.2566
# Epoch 248/300
# 100/100 [==============================] - 11s 107ms/step - loss: 0.2498
# Epoch 249/300
# 100/100 [==============================] - 11s 110ms/step - loss: 0.2522
# Epoch 250/300
# 100/100 [==============================] - 11s 109ms/step - loss: 0.2498
# Epoch 251/300
# 100/100 [==============================] - 11s 106ms/step - loss: 0.2443
# Epoch 252/300
# 100/100 [==============================] - 11s 107ms/step - loss: 0.2538
# Epoch 253/300
# 100/100 [==============================] - 11s 108ms/step - loss: 0.2689
# Epoch 254/300
# 100/100 [==============================] - 11s 107ms/step - loss: 0.2563
# Epoch 255/300
# 100/100 [==============================] - 11s 108ms/step - loss: 0.2534
# Epoch 256/300
# 100/100 [==============================] - 11s 108ms/step - loss: 0.2519
# Epoch 257/300
# 100/100 [==============================] - 11s 108ms/step - loss: 0.2546
# Epoch 258/300
# 100/100 [==============================] - 11s 107ms/step - loss: 0.2519
# Epoch 259/300
# 100/100 [==============================] - 11s 107ms/step - loss: 0.2534
# Epoch 260/300
# 100/100 [==============================] - 11s 109ms/step - loss: 0.2584
# Epoch 261/300
# 100/100 [==============================] - 11s 108ms/step - loss: 0.2540
# Epoch 262/300
# 100/100 [==============================] - 11s 107ms/step - loss: 0.2462
# Epoch 263/300
# 100/100 [==============================] - 11s 107ms/step - loss: 0.2493
# Epoch 264/300
# 100/100 [==============================] - 11s 108ms/step - loss: 0.2630
# Epoch 265/300
# 100/100 [==============================] - 11s 108ms/step - loss: 0.2433
# Epoch 266/300
# 100/100 [==============================] - 11s 108ms/step - loss: 0.2606
# Epoch 267/300
# 100/100 [==============================] - 11s 109ms/step - loss: 0.2606
# Epoch 268/300
# 100/100 [==============================] - 11s 108ms/step - loss: 0.2601
# Epoch 269/300
# 100/100 [==============================] - 11s 108ms/step - loss: 0.2514
# Epoch 270/300
# 100/100 [==============================] - 11s 106ms/step - loss: 0.2571
# Epoch 271/300
# 100/100 [==============================] - 11s 109ms/step - loss: 0.2559
# Epoch 272/300
# 100/100 [==============================] - 11s 108ms/step - loss: 0.2482
# Epoch 273/300
# 100/100 [==============================] - 11s 108ms/step - loss: 0.2528
# Epoch 274/300
# 100/100 [==============================] - 11s 109ms/step - loss: 0.2537
# Epoch 275/300
# 100/100 [==============================] - 11s 110ms/step - loss: 0.2595
# Epoch 276/300
# 100/100 [==============================] - 11s 107ms/step - loss: 0.2602
# Epoch 277/300
# 100/100 [==============================] - 11s 108ms/step - loss: 0.2473
# Epoch 278/300
# 100/100 [==============================] - 11s 110ms/step - loss: 0.2553
# Epoch 279/300
# 100/100 [==============================] - 11s 111ms/step - loss: 0.2552
# Epoch 280/300
# 100/100 [==============================] - 11s 109ms/step - loss: 0.2535
# Epoch 281/300
# 100/100 [==============================] - 11s 110ms/step - loss: 0.2545
# Epoch 282/300
# 100/100 [==============================] - 11s 109ms/step - loss: 0.2537
# Epoch 283/300
# 100/100 [==============================] - 11s 109ms/step - loss: 0.2535
# Epoch 284/300
# 100/100 [==============================] - 11s 108ms/step - loss: 0.2574
# Epoch 285/300
# 100/100 [==============================] - 11s 108ms/step - loss: 0.2507
# Epoch 286/300
# 100/100 [==============================] - 11s 108ms/step - loss: 0.2583
# Epoch 287/300
# 100/100 [==============================] - 11s 108ms/step - loss: 0.2587
# Epoch 288/300
# 100/100 [==============================] - 11s 109ms/step - loss: 0.2571
# Epoch 289/300
# 100/100 [==============================] - 11s 109ms/step - loss: 0.2572
# Epoch 290/300
# 100/100 [==============================] - 11s 110ms/step - loss: 0.2652
# Epoch 291/300
# 100/100 [==============================] - 11s 108ms/step - loss: 0.2776
# Epoch 292/300
# 100/100 [==============================] - 11s 108ms/step - loss: 0.2579
# Epoch 293/300
# 100/100 [==============================] - 11s 110ms/step - loss: 0.2548
# Epoch 294/300
# 100/100 [==============================] - 11s 109ms/step - loss: 0.2524
# Epoch 295/300
# 100/100 [==============================] - 11s 108ms/step - loss: 0.2513
# Epoch 296/300
# 100/100 [==============================] - 11s 109ms/step - loss: 0.2550
# Epoch 297/300
# 100/100 [==============================] - 11s 108ms/step - loss: 0.2603
# Epoch 298/300
# 100/100 [==============================] - 11s 110ms/step - loss: 0.2507
# Epoch 299/300
# 100/100 [==============================] - 11s 109ms/step - loss: 0.2673
# Epoch 300/300
# 100/100 [==============================] - 11s 109ms/step - loss: 0.2597

# %% [markdown]
# ## Visualise Loss function

# %%
#print(result.history.keys())

plt.rcParams['figure.figsize'] = [10, 10]

# summarize history for loss
plt.plot(result_1.history['loss'])
plt.plot(result_2.history['loss'])
plt.plot(result_3.history['loss'])
plt.plot(result_4.history['loss'])

plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.rc('font', size=12)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=20)    # legend fontsize
plt.rc('figure', titlesize=20)  # fontsize of the figure title
plt.legend(['$\Delta_v$','$20\Delta_v$','$40\Delta_v$','$100\Delta_v$'], loc='upper left')
plt.yscale("log")
plt.show()

# %% [markdown]
# ## Plot trajectories generated to $t=32$ by Verlet integrator and neural

# %%
# Final time
T_final = 32

# Initial conditions
x = np.zeros(1)
v = np.zeros(1)
x[0] = 2.70
v[0] = -0.6
verlet_SHO.set_state(x,v)

# ==== Verlet integrator ====
t = 0.0
t_verlet_SHO = []
x_verlet_SHO = []
v_verlet_SHO = []
E_verlet_SHO = []



while t<T_final:
    t_verlet_SHO.append(t)
    E_verlet_SHO.append(verlet_SHO.energy())
    x_verlet_SHO.append(verlet_SHO.x[0])
    v_verlet_SHO.append(verlet_SHO.v[0])
    verlet_SHO.integrate(1)
    t += dt_verlet
        

# ==== Neural network integrator ====



# Initialise with Verlet integrator
x_initial_1 = np.zeros((hnn_integrator_1.nsteps,hnn_integrator_1.dynamical_system.dim))
v_initial_1 = np.zeros((hnn_integrator_1.nsteps,hnn_integrator_1.dynamical_system.dim))
x_initial_2 = np.zeros((hnn_integrator_2.nsteps,hnn_integrator_2.dynamical_system.dim))
v_initial_2 = np.zeros((hnn_integrator_2.nsteps,hnn_integrator_2.dynamical_system.dim))
x_initial_3 = np.zeros((hnn_integrator_3.nsteps,hnn_integrator_3.dynamical_system.dim))
v_initial_3 = np.zeros((hnn_integrator_3.nsteps,hnn_integrator_3.dynamical_system.dim))
x_initial_4 = np.zeros((hnn_integrator_4.nsteps,hnn_integrator_4.dynamical_system.dim))
v_initial_4 = np.zeros((hnn_integrator_4.nsteps,hnn_integrator_4.dynamical_system.dim))



verlet_SHO.set_state(x,v)
for k in range(hnn_integrator_1.nsteps):    
    x_initial_1[k,:] = verlet_SHO.x[:]
    v_initial_1[k,:] = verlet_SHO.v[:]
    verlet_SHO.integrate(int(dt_1/dt_verlet))
verlet_SHO.set_state(x,v)
for k in range(hnn_integrator_2.nsteps):    
    x_initial_2[k,:] = verlet_SHO.x[:]
    v_initial_2[k,:] = verlet_SHO.v[:]
    verlet_SHO.integrate(int(dt_2/dt_verlet))
verlet_SHO.set_state(x,v)
for k in range(hnn_integrator_3.nsteps):    
    x_initial_3[k,:] = verlet_SHO.x[:]
    v_initial_3[k,:] = verlet_SHO.v[:]
    verlet_SHO.integrate(int(dt_3/dt_verlet))
verlet_SHO.set_state(x,v)
for k in range(hnn_integrator_4.nsteps):    
    x_initial_4[k,:] = verlet_SHO.x[:]
    v_initial_4[k,:] = verlet_SHO.v[:]
    verlet_SHO.integrate(int(dt_4/dt_verlet))


hnn_integrator_1.set_state(x_initial_1,v_initial_1)
t_1 = (hnn_integrator_1.nsteps-1)*hnn_integrator_1.dt
hnn_integrator_2.set_state(x_initial_2,v_initial_2)
t_2 = (hnn_integrator_2.nsteps-1)*hnn_integrator_2.dt
hnn_integrator_3.set_state(x_initial_3,v_initial_3)
t_3 = (hnn_integrator_3.nsteps-1)*hnn_integrator_3.dt
hnn_integrator_4.set_state(x_initial_4,v_initial_4)
t_4 = (hnn_integrator_4.nsteps-1)*hnn_integrator_4.dt



# Timestepping loop
t_hnn_1 = []
x_hnn_1 = []
v_hnn_1 = []
E_hnn_1 = []
t_hnn_2 = []
x_hnn_2 = []
v_hnn_2 = []
E_hnn_2 = []
t_hnn_3 = []
x_hnn_3 = []
v_hnn_3 = []
E_hnn_3 = []
t_hnn_4 = []
x_hnn_4 = []
v_hnn_4 = []
E_hnn_4 = []


while t_1<T_final:
    t_hnn_1.append(t_1)
    x_hnn_1.append(hnn_integrator_1.x[0])
    v_hnn_1.append(hnn_integrator_1.v[0])
    E_hnn_1.append(hnn_integrator_1.energy())
    hnn_integrator_1.integrate(1)
    t_1 += dt_1
while t_2<T_final:
    t_hnn_2.append(t_2)
    x_hnn_2.append(hnn_integrator_2.x[0])
    v_hnn_2.append(hnn_integrator_2.v[0])
    E_hnn_2.append(hnn_integrator_2.energy())
    hnn_integrator_2.integrate(1)
    t_2 += dt_2
while t_3<T_final:
    t_hnn_3.append(t_3)
    x_hnn_3.append(hnn_integrator_3.x[0])
    v_hnn_3.append(hnn_integrator_3.v[0])
    E_hnn_3.append(hnn_integrator_3.energy())
    hnn_integrator_3.integrate(1)
    t_3 += dt_3
while t_4<T_final:
    t_hnn_4.append(t_4)
    x_hnn_4.append(hnn_integrator_4.x[0])
    v_hnn_4.append(hnn_integrator_4.v[0])
    E_hnn_4.append(hnn_integrator_4.energy())
    hnn_integrator_4.integrate(1)
    t_4 += dt_4

# %%
nsteps = 1


x_hnn_1 = np.array(x_hnn_1)
x_hnn_2 = np.array(x_hnn_2)
x_hnn_3 = np.array(x_hnn_3)
x_hnn_4 = np.array(x_hnn_4)
x_verlet_SHO = np.array(x_verlet_SHO)
v_hnn_1 = np.array(v_hnn_1)
v_hnn_2 = np.array(v_hnn_2)
v_hnn_3 = np.array(v_hnn_3)
v_hnn_4 = np.array(v_hnn_4)
v_verlet_SHO = np.array(v_verlet_SHO)


# Plot position error as a function of time
plt.clf()
plt.rcParams['figure.figsize'] = [10, 10]

plt.plot(t_hnn_1,x_hnn_1-x_verlet_SHO[int((nsteps-1)*dt_1/dt_verlet)::int(dt_1/dt_verlet)],label='$\Delta_v$',color='blue')
plt.plot(t_hnn_2,x_hnn_2-x_verlet_SHO[int((nsteps-1)*dt_2/dt_verlet):int(np.size(x_verlet_SHO)-dt_2/dt_verlet):int(dt_2/dt_verlet)],label='$20\Delta_v$',color='orange')
plt.plot(t_hnn_3,x_hnn_3-x_verlet_SHO[int((nsteps-1)*dt_3/dt_verlet)::int(dt_3/dt_verlet)],label='$40\Delta_v$',color='green')
plt.plot(t_hnn_4,x_hnn_4-x_verlet_SHO[int((nsteps-1)*dt_4/dt_verlet):int(np.size(x_verlet_SHO)-dt_4/dt_verlet):int(dt_4/dt_verlet)],label='$100\Delta_v$',color='red')
plt.legend(loc='upper left')
ax = plt.gca()
ax.set_xlabel('time $t$')
ax.set_ylabel('position Error $x_{NN}(t)-x_V(t)$')
ax.set_title('Position Error')
plt.rc('font', size=12)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=20)    # legend fontsize
plt.rc('figure', titlesize=20)  # fontsize of the figure title
#plt.grid()
plt.show()

# Plot velocity error as a function of time

plt.plot(t_hnn_1,v_hnn_1-v_verlet_SHO[int((nsteps-1)*dt_1/dt_verlet)::int(dt_1/dt_verlet)],label='$\Delta_v$',color='blue')
plt.plot(t_hnn_2,v_hnn_2-v_verlet_SHO[int((nsteps-1)*dt_2/dt_verlet):int(np.size(v_verlet_SHO)-dt_2/dt_verlet):int(dt_2/dt_verlet)],label='$20\Delta_v$',color='orange')
plt.plot(t_hnn_3,v_hnn_3-v_verlet_SHO[int((nsteps-1)*dt_3/dt_verlet)::int(dt_3/dt_verlet)],label='$40\Delta_v$',color='green')
plt.plot(t_hnn_4,v_hnn_4-v_verlet_SHO[int((nsteps-1)*dt_4/dt_verlet):int(np.size(v_verlet_SHO)-dt_4/dt_verlet):int(dt_4/dt_verlet)],label='$100\Delta_v$',color='red')
plt.legend(loc='upper left')
ax = plt.gca()
ax.set_xlabel('time $t$')
ax.set_ylabel('Velocity Error $v_{NN}(t)-v_V(t)$')
ax.set_title('Velocity Error')
plt.rc('font', size=12)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=20)    # legend fontsize
plt.rc('figure', titlesize=20)  # fontsize of the figure title
#plt.grid()
plt.show()

# Plot L2 error as a function of time

plt.plot(t_hnn_1,((v_hnn_1-v_verlet_SHO[int((nsteps-1)*dt_1/dt_verlet)::int(dt_1/dt_verlet)])**2+(x_hnn_1-x_verlet_SHO[int((nsteps-1)*dt_1/dt_verlet)::int(dt_1/dt_verlet)])**2)**0.5,label='$\Delta_v$',color='blue')
plt.plot(t_hnn_2,((v_hnn_2-v_verlet_SHO[int((nsteps-1)*dt_2/dt_verlet):int(np.size(v_verlet_SHO)-dt_2/dt_verlet):int(dt_2/dt_verlet)])**2+(x_hnn_2-x_verlet_SHO[int((nsteps-1)*dt_2/dt_verlet):int(np.size(x_verlet_SHO)-dt_2/dt_verlet):int(dt_2/dt_verlet)])**2)**0.5,label='$20\Delta_v$',color='orange')
plt.plot(t_hnn_3,((v_hnn_3-v_verlet_SHO[int((nsteps-1)*dt_3/dt_verlet)::int(dt_3/dt_verlet)])**2+(x_hnn_3-x_verlet_SHO[int((nsteps-1)*dt_3/dt_verlet)::int(dt_3/dt_verlet)])**2)**0.5,label='$40\Delta_v$',color='green')
plt.plot(t_hnn_4,((v_hnn_4-v_verlet_SHO[int((nsteps-1)*dt_4/dt_verlet):int(np.size(v_verlet_SHO)-dt_4/dt_verlet):int(dt_4/dt_verlet)])**2+(x_hnn_4-x_verlet_SHO[int((nsteps-1)*dt_4/dt_verlet):int(np.size(x_verlet_SHO)-dt_4/dt_verlet):int(dt_4/dt_verlet)])**2)**0.5,label='$100\Delta_v$',color='red')
plt.legend(loc='upper left')
ax = plt.gca()
ax.set_xlabel('time $t$')
ax.set_ylabel('L2 Error')
ax.set_title('L2 Error')
plt.rc('font', size=12)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=20)    # legend fontsize
plt.rc('figure', titlesize=20)  # fontsize of the figure title
#plt.grid()
plt.show()


plt.clf()
# Plot energy as a function of time
# (subtract energy at time t=0 to show energy drift)

plt.plot(t_verlet_SHO,E_verlet_SHO-E_verlet_SHO[0],label='Verlet',color='black')
plt.plot(t_hnn_1,E_hnn_1-E_hnn_1[0],label='$\Delta_v$',color='blue')
plt.plot(t_hnn_2,E_hnn_2-E_hnn_2[0],label='$20\Delta_v$',color='orange')
plt.plot(t_hnn_3,E_hnn_3-E_hnn_3[0],label='$40\Delta_v$',color='green')
plt.plot(t_hnn_4,E_hnn_4-E_hnn_4[0],label='$100\Delta_v$',color='red')
plt.legend(loc='upper left')
ax = plt.gca()
ax.set_xlabel('time $t$')
ax.set_ylabel('energy shift $E(t)-E(t_0)$')
#ax.grid()
plt.rc('font', size=12)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=20)    # legend fontsize
plt.rc('figure', titlesize=20)  # fontsize of the figure title

plt.show()

#subplots of position versus velocity for all 4

plt.rcParams['figure.figsize'] = [10, 10]

plt.clf()
plt.plot(x_verlet_SHO,v_verlet_SHO,label='Verlet',color='black')
plt.plot(x_hnn_1,v_hnn_1,label='$\Delta_v$',color='blue')
plt.plot(x_hnn_2,v_hnn_2,label='$20\Delta_v$',color='orange')
plt.plot(x_hnn_3,v_hnn_3,label='$40\Delta_v$',color='green')
plt.plot(x_hnn_4,v_hnn_4,label='$100\Delta_v$',color='red')
plt.legend(loc='upper left')
ax = plt.gca()
ax.set_ylabel('Velocity $v(t)$')
ax.set_xlabel('Position $q(t)$')
plt.rc('font', size=12)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=20)    # legend fontsize
plt.rc('figure', titlesize=20)  # fontsize of the figure title
plt.show()

# %% [markdown]
# ## Plot trajectories generated to $t=128$ by Verlet integrator and neural

# %%
# Final time
T_final = 128

# Initial conditions
x = np.zeros(1)
v = np.zeros(1)
x[0] = 2.70
v[0] = -0.6
verlet_SHO.set_state(x,v)

# ==== Verlet integrator ====
t = 0.0
t_verlet_SHO = []
x_verlet_SHO = []
v_verlet_SHO = []
E_verlet_SHO = []



while t<T_final:
    t_verlet_SHO.append(t)
    E_verlet_SHO.append(verlet_SHO.energy())
    x_verlet_SHO.append(verlet_SHO.x[0])
    v_verlet_SHO.append(verlet_SHO.v[0])
    verlet_SHO.integrate(1)
    t += dt_verlet
        

# ==== Neural network integrator ====

# Initialise with Verlet integrator
x_initial_1 = np.zeros((hnn_integrator_1.nsteps,hnn_integrator_1.dynamical_system.dim))
v_initial_1 = np.zeros((hnn_integrator_1.nsteps,hnn_integrator_1.dynamical_system.dim))
x_initial_2 = np.zeros((hnn_integrator_2.nsteps,hnn_integrator_2.dynamical_system.dim))
v_initial_2 = np.zeros((hnn_integrator_2.nsteps,hnn_integrator_2.dynamical_system.dim))
x_initial_3 = np.zeros((hnn_integrator_3.nsteps,hnn_integrator_3.dynamical_system.dim))
v_initial_3 = np.zeros((hnn_integrator_3.nsteps,hnn_integrator_3.dynamical_system.dim))
x_initial_4 = np.zeros((hnn_integrator_4.nsteps,hnn_integrator_4.dynamical_system.dim))
v_initial_4 = np.zeros((hnn_integrator_4.nsteps,hnn_integrator_4.dynamical_system.dim))



verlet_SHO.set_state(x,v)
for k in range(hnn_integrator_1.nsteps):    
    x_initial_1[k,:] = verlet_SHO.x[:]
    v_initial_1[k,:] = verlet_SHO.v[:]
    verlet_SHO.integrate(int(dt_1/dt_verlet))
verlet_SHO.set_state(x,v)
for k in range(hnn_integrator_2.nsteps):    
    x_initial_2[k,:] = verlet_SHO.x[:]
    v_initial_2[k,:] = verlet_SHO.v[:]
    verlet_SHO.integrate(int(dt_2/dt_verlet))
verlet_SHO.set_state(x,v)
for k in range(hnn_integrator_3.nsteps):    
    x_initial_3[k,:] = verlet_SHO.x[:]
    v_initial_3[k,:] = verlet_SHO.v[:]
    verlet_SHO.integrate(int(dt_3/dt_verlet))
verlet_SHO.set_state(x,v)
for k in range(hnn_integrator_4.nsteps):    
    x_initial_4[k,:] = verlet_SHO.x[:]
    v_initial_4[k,:] = verlet_SHO.v[:]
    verlet_SHO.integrate(int(dt_4/dt_verlet))


hnn_integrator_1.set_state(x_initial_1,v_initial_1)
t_1 = (hnn_integrator_1.nsteps-1)*hnn_integrator_1.dt
hnn_integrator_2.set_state(x_initial_2,v_initial_2)
t_2 = (hnn_integrator_2.nsteps-1)*hnn_integrator_2.dt
hnn_integrator_3.set_state(x_initial_3,v_initial_3)
t_3 = (hnn_integrator_3.nsteps-1)*hnn_integrator_3.dt
hnn_integrator_4.set_state(x_initial_4,v_initial_4)
t_4 = (hnn_integrator_4.nsteps-1)*hnn_integrator_4.dt



# Timestepping loop
t_hnn_1 = []
x_hnn_1 = []
v_hnn_1 = []
E_hnn_1 = []
t_hnn_2 = []
x_hnn_2 = []
v_hnn_2 = []
E_hnn_2 = []
t_hnn_3 = []
x_hnn_3 = []
v_hnn_3 = []
E_hnn_3 = []
t_hnn_4 = []
x_hnn_4 = []
v_hnn_4 = []
E_hnn_4 = []


while t_1<T_final:
    t_hnn_1.append(t_1)
    x_hnn_1.append(hnn_integrator_1.x[0])
    v_hnn_1.append(hnn_integrator_1.v[0])
    E_hnn_1.append(hnn_integrator_1.energy())
    hnn_integrator_1.integrate(1)
    t_1 += dt_1
while t_2<T_final:
    t_hnn_2.append(t_2)
    x_hnn_2.append(hnn_integrator_2.x[0])
    v_hnn_2.append(hnn_integrator_2.v[0])
    E_hnn_2.append(hnn_integrator_2.energy())
    hnn_integrator_2.integrate(1)
    t_2 += dt_2
while t_3<T_final:
    t_hnn_3.append(t_3)
    x_hnn_3.append(hnn_integrator_3.x[0])
    v_hnn_3.append(hnn_integrator_3.v[0])
    E_hnn_3.append(hnn_integrator_3.energy())
    hnn_integrator_3.integrate(1)
    t_3 += dt_3
while t_4<T_final:
    t_hnn_4.append(t_4)
    x_hnn_4.append(hnn_integrator_4.x[0])
    v_hnn_4.append(hnn_integrator_4.v[0])
    E_hnn_4.append(hnn_integrator_4.energy())
    hnn_integrator_4.integrate(1)
    t_4 += dt_4
 



x_hnn_1 = np.array(x_hnn_1)
x_hnn_2 = np.array(x_hnn_2)
x_hnn_3 = np.array(x_hnn_3)
x_hnn_4 = np.array(x_hnn_4)
x_verlet_SHO = np.array(x_verlet_SHO)
v_hnn_1 = np.array(v_hnn_1)
v_hnn_2 = np.array(v_hnn_2)
v_hnn_3 = np.array(v_hnn_3)
v_hnn_4 = np.array(v_hnn_4)
v_verlet_SHO = np.array(v_verlet_SHO)


# Plot position error as a function of time

nsteps = 1


plt.clf()
plt.rcParams['figure.figsize'] = [10, 10]

plt.plot(t_hnn_1,x_hnn_1-x_verlet_SHO[int((nsteps-1)*dt_1/dt_verlet)::int(dt_1/dt_verlet)],label='$\Delta_v$',color='blue')
plt.plot(t_hnn_2,x_hnn_2-x_verlet_SHO[int((nsteps-1)*dt_2/dt_verlet)::int(dt_2/dt_verlet)],label='$20\Delta_v$',color='orange')
plt.plot(t_hnn_3,x_hnn_3-x_verlet_SHO[int((nsteps-1)*dt_3/dt_verlet):int(np.size(x_verlet_SHO)-dt_3/dt_verlet):int(dt_3/dt_verlet)],label='$40\Delta_v$',color='green')
plt.plot(t_hnn_4,x_hnn_4-x_verlet_SHO[int((nsteps-1)*dt_4/dt_verlet):int(np.size(x_verlet_SHO)-dt_4/dt_verlet):int(dt_4/dt_verlet)],label='$100\Delta_v$',color='red')
plt.legend(loc='upper left')
ax = plt.gca()
ax.set_xlabel('time $t$')
ax.set_ylabel('position Error $x_{NN}(t)-x_V(t)$')
ax.set_title('Position Error')
plt.rc('font', size=12)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=20)    # legend fontsize
plt.rc('figure', titlesize=20)  # fontsize of the figure title
#plt.grid()
plt.show()

# Plot velocity error as a function of time

plt.plot(t_hnn_1,v_hnn_1-v_verlet_SHO[int((nsteps-1)*dt_1/dt_verlet)::int(dt_1/dt_verlet)],label='$\Delta_v$',color='blue')
plt.plot(t_hnn_2,v_hnn_2-v_verlet_SHO[int((nsteps-1)*dt_2/dt_verlet)::int(dt_2/dt_verlet)],label='$20\Delta_v$',color='orange')
plt.plot(t_hnn_3,v_hnn_3-v_verlet_SHO[int((nsteps-1)*dt_3/dt_verlet):int(np.size(v_verlet_SHO)-dt_3/dt_verlet):int(dt_3/dt_verlet)],label='$40\Delta_v$',color='green')
plt.plot(t_hnn_4,v_hnn_4-v_verlet_SHO[int((nsteps-1)*dt_4/dt_verlet):int(np.size(v_verlet_SHO)-dt_4/dt_verlet):int(dt_4/dt_verlet)],label='$100\Delta_v$',color='red')
plt.legend(loc='upper left')
ax = plt.gca()
ax.set_xlabel('time $t$')
ax.set_ylabel('Velocity Error $v_{NN}(t)-v_V(t)$')
ax.set_title('Velocity Error')
plt.rc('font', size=12)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=20)    # legend fontsize
plt.rc('figure', titlesize=20)  # fontsize of the figure title
#plt.grid()
plt.show()

# Plot L2 error as a function of time

plt.plot(t_hnn_1,((v_hnn_1-v_verlet_SHO[int((nsteps-1)*dt_1/dt_verlet)::int(dt_1/dt_verlet)])**2+(x_hnn_1-x_verlet_SHO[int((nsteps-1)*dt_1/dt_verlet)::int(dt_1/dt_verlet)])**2)**0.5,label='$\Delta_v$',color='blue')
plt.plot(t_hnn_2,((v_hnn_2-v_verlet_SHO[int((nsteps-1)*dt_2/dt_verlet)::int(dt_2/dt_verlet)])**2+(x_hnn_2-x_verlet_SHO[int((nsteps-1)*dt_2/dt_verlet)::int(dt_2/dt_verlet)])**2)**0.5,label='$20\Delta_v$',color='orange')
plt.plot(t_hnn_3,((v_hnn_3-v_verlet_SHO[int((nsteps-1)*dt_3/dt_verlet):int(np.size(v_verlet_SHO)-dt_3/dt_verlet):int(dt_3/dt_verlet)])**2+(x_hnn_3-x_verlet_SHO[int((nsteps-1)*dt_3/dt_verlet):int(np.size(x_verlet_SHO)-dt_3/dt_verlet):int(dt_3/dt_verlet)])**2)**0.5,label='$40\Delta_v$',color='green')
plt.plot(t_hnn_4,((v_hnn_4-v_verlet_SHO[int((nsteps-1)*dt_4/dt_verlet):int(np.size(v_verlet_SHO)-dt_4/dt_verlet):int(dt_4/dt_verlet)])**2+(x_hnn_4-x_verlet_SHO[int((nsteps-1)*dt_4/dt_verlet):int(np.size(x_verlet_SHO)-dt_4/dt_verlet):int(dt_4/dt_verlet)])**2)**0.5,label='$100\Delta_v$',color='red')
plt.legend(loc='upper left')
ax = plt.gca()
ax.set_xlabel('time $t$')
ax.set_ylabel('L2 Error')
ax.set_title('L2 Error')
plt.rc('font', size=12)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=20)    # legend fontsize
plt.rc('figure', titlesize=20)  # fontsize of the figure title
#plt.grid()
plt.show()


plt.clf()
# Plot energy as a function of time
# (subtract energy at time t=0 to show energy drift)

plt.plot(t_verlet_SHO,E_verlet_SHO-E_verlet_SHO[0],label='Verlet',color='black')
plt.plot(t_hnn_1,E_hnn_1-E_hnn_1[0],label='$\Delta_v$',color='blue')
plt.plot(t_hnn_2,E_hnn_2-E_hnn_2[0],label='$20\Delta_v$',color='orange')
plt.plot(t_hnn_3,E_hnn_3-E_hnn_3[0],label='$40\Delta_v$',color='green')
plt.plot(t_hnn_4,E_hnn_4-E_hnn_4[0],label='$100\Delta_v$',color='red')
plt.legend(loc='upper left')
ax = plt.gca()
ax.set_xlabel('time $t$')
ax.set_ylabel('energy shift $E(t)-E(t_0)$')
#ax.grid()
plt.rc('font', size=12)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=20)    # legend fontsize
plt.rc('figure', titlesize=20)  # fontsize of the figure title

plt.show()

#subplots of position versus velocity for all 4

plt.rcParams['figure.figsize'] = [10, 10]

plt.clf()
plt.plot(x_verlet_SHO,v_verlet_SHO,label='Verlet',color='black')
plt.plot(x_hnn_1,v_hnn_1,label='$\Delta_v$',color='blue')
plt.plot(x_hnn_2,v_hnn_2,label='$20\Delta_v$',color='orange')
plt.plot(x_hnn_3,v_hnn_3,label='$40\Delta_v$',color='green')
plt.plot(x_hnn_4,v_hnn_4,label='$100\Delta_v$',color='red')
plt.legend(loc='upper left')
ax = plt.gca()
ax.set_ylabel('Velocity $v(t)$')
ax.set_xlabel('Position $q(t)$')
plt.rc('font', size=12)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=20)    # legend fontsize
plt.rc('figure', titlesize=20)  # fontsize of the figure title
plt.show()

# %% [markdown]
# ## Plot trajectories generated to $t=512$ by Verlet integrator and neural

# %%
# Final time
T_final = 512

# Initial conditions
x = np.zeros(1)
v = np.zeros(1)
x[0] = 2.70
v[0] = -0.6
verlet_SHO.set_state(x,v)

# ==== Verlet integrator ====
t = 0.0
t_verlet_SHO = []
x_verlet_SHO = []
v_verlet_SHO = []
E_verlet_SHO = []



while t<T_final:
    t_verlet_SHO.append(t)
    E_verlet_SHO.append(verlet_SHO.energy())
    x_verlet_SHO.append(verlet_SHO.x[0])
    v_verlet_SHO.append(verlet_SHO.v[0])
    verlet_SHO.integrate(1)
    t += dt_verlet
        

# ==== Neural network integrator ====

# Initialise with Verlet integrator
x_initial_1 = np.zeros((hnn_integrator_1.nsteps,hnn_integrator_1.dynamical_system.dim))
v_initial_1 = np.zeros((hnn_integrator_1.nsteps,hnn_integrator_1.dynamical_system.dim))
x_initial_2 = np.zeros((hnn_integrator_2.nsteps,hnn_integrator_2.dynamical_system.dim))
v_initial_2 = np.zeros((hnn_integrator_2.nsteps,hnn_integrator_2.dynamical_system.dim))
x_initial_3 = np.zeros((hnn_integrator_3.nsteps,hnn_integrator_3.dynamical_system.dim))
v_initial_3 = np.zeros((hnn_integrator_3.nsteps,hnn_integrator_3.dynamical_system.dim))
x_initial_4 = np.zeros((hnn_integrator_4.nsteps,hnn_integrator_4.dynamical_system.dim))
v_initial_4 = np.zeros((hnn_integrator_4.nsteps,hnn_integrator_4.dynamical_system.dim))



verlet_SHO.set_state(x,v)
for k in range(hnn_integrator_1.nsteps):    
    x_initial_1[k,:] = verlet_SHO.x[:]
    v_initial_1[k,:] = verlet_SHO.v[:]
    verlet_SHO.integrate(int(dt_1/dt_verlet))
verlet_SHO.set_state(x,v)
for k in range(hnn_integrator_2.nsteps):    
    x_initial_2[k,:] = verlet_SHO.x[:]
    v_initial_2[k,:] = verlet_SHO.v[:]
    verlet_SHO.integrate(int(dt_2/dt_verlet))
verlet_SHO.set_state(x,v)
for k in range(hnn_integrator_3.nsteps):    
    x_initial_3[k,:] = verlet_SHO.x[:]
    v_initial_3[k,:] = verlet_SHO.v[:]
    verlet_SHO.integrate(int(dt_3/dt_verlet))
verlet_SHO.set_state(x,v)
for k in range(hnn_integrator_4.nsteps):    
    x_initial_4[k,:] = verlet_SHO.x[:]
    v_initial_4[k,:] = verlet_SHO.v[:]
    verlet_SHO.integrate(int(dt_4/dt_verlet))


hnn_integrator_1.set_state(x_initial_1,v_initial_1)
t_1 = (hnn_integrator_1.nsteps-1)*hnn_integrator_1.dt
hnn_integrator_2.set_state(x_initial_2,v_initial_2)
t_2 = (hnn_integrator_2.nsteps-1)*hnn_integrator_2.dt
hnn_integrator_3.set_state(x_initial_3,v_initial_3)
t_3 = (hnn_integrator_3.nsteps-1)*hnn_integrator_3.dt
hnn_integrator_4.set_state(x_initial_4,v_initial_4)
t_4 = (hnn_integrator_4.nsteps-1)*hnn_integrator_4.dt



# Timestepping loop
t_hnn_1 = []
x_hnn_1 = []
v_hnn_1 = []
E_hnn_1 = []
t_hnn_2 = []
x_hnn_2 = []
v_hnn_2 = []
E_hnn_2 = []
t_hnn_3 = []
x_hnn_3 = []
v_hnn_3 = []
E_hnn_3 = []
t_hnn_4 = []
x_hnn_4 = []
v_hnn_4 = []
E_hnn_4 = []


while t_1<T_final:
    t_hnn_1.append(t_1)
    x_hnn_1.append(hnn_integrator_1.x[0])
    v_hnn_1.append(hnn_integrator_1.v[0])
    E_hnn_1.append(hnn_integrator_1.energy())
    hnn_integrator_1.integrate(1)
    t_1 += dt_1
while t_2<T_final:
    t_hnn_2.append(t_2)
    x_hnn_2.append(hnn_integrator_2.x[0])
    v_hnn_2.append(hnn_integrator_2.v[0])
    E_hnn_2.append(hnn_integrator_2.energy())
    hnn_integrator_2.integrate(1)
    t_2 += dt_2
while t_3<T_final:
    t_hnn_3.append(t_3)
    x_hnn_3.append(hnn_integrator_3.x[0])
    v_hnn_3.append(hnn_integrator_3.v[0])
    E_hnn_3.append(hnn_integrator_3.energy())
    hnn_integrator_3.integrate(1)
    t_3 += dt_3
while t_4<T_final:
    t_hnn_4.append(t_4)
    x_hnn_4.append(hnn_integrator_4.x[0])
    v_hnn_4.append(hnn_integrator_4.v[0])
    E_hnn_4.append(hnn_integrator_4.energy())
    hnn_integrator_4.integrate(1)
    t_4 += dt_4
 



x_hnn_1 = np.array(x_hnn_1)
x_hnn_2 = np.array(x_hnn_2)
x_hnn_3 = np.array(x_hnn_3)
x_hnn_4 = np.array(x_hnn_4)
x_verlet_SHO = np.array(x_verlet_SHO)
v_hnn_1 = np.array(v_hnn_1)
v_hnn_2 = np.array(v_hnn_2)
v_hnn_3 = np.array(v_hnn_3)
v_hnn_4 = np.array(v_hnn_4)
v_verlet_SHO = np.array(v_verlet_SHO)


nsteps = 1

# Plot position error as a function of time
plt.clf()
plt.rcParams['figure.figsize'] = [10, 10]

plt.plot(t_hnn_1,x_hnn_1-x_verlet_SHO[int((nsteps-1)*dt_1/dt_verlet)::int(dt_1/dt_verlet)],label='$\Delta_v$',color='blue')
plt.plot(t_hnn_2,x_hnn_2-x_verlet_SHO[int((nsteps-1)*dt_2/dt_verlet):int(np.size(x_verlet_SHO)-dt_2/dt_verlet):int(dt_2/dt_verlet)],label='$20\Delta_v$',color='orange')
plt.plot(t_hnn_3,x_hnn_3-x_verlet_SHO[int((nsteps-1)*dt_3/dt_verlet)::int(dt_3/dt_verlet)],label='$40\Delta_v$',color='green')
plt.plot(t_hnn_4,x_hnn_4-x_verlet_SHO[int((nsteps-1)*dt_4/dt_verlet):int(np.size(x_verlet_SHO)-dt_4/dt_verlet):int(dt_4/dt_verlet)],label='$100\Delta_v$',color='red')
plt.legend(loc='upper left')
ax = plt.gca()
ax.set_xlabel('time $t$')
ax.set_ylabel('position Error $x_{NN}(t)-x_V(t)$')
ax.set_title('Position Error')
plt.rc('font', size=12)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=20)    # legend fontsize
plt.rc('figure', titlesize=20)  # fontsize of the figure title
#plt.grid()
plt.show()

# Plot velocity error as a function of time

plt.plot(t_hnn_1,v_hnn_1-v_verlet_SHO[int((nsteps-1)*dt_1/dt_verlet)::int(dt_1/dt_verlet)],label='$\Delta_v$',color='blue')
plt.plot(t_hnn_2,v_hnn_2-v_verlet_SHO[int((nsteps-1)*dt_2/dt_verlet):int(np.size(v_verlet_SHO)-dt_2/dt_verlet):int(dt_2/dt_verlet)],label='$20\Delta_v$',color='orange')
plt.plot(t_hnn_3,v_hnn_3-v_verlet_SHO[int((nsteps-1)*dt_3/dt_verlet)::int(dt_3/dt_verlet)],label='$40\Delta_v$',color='green')
plt.plot(t_hnn_4,v_hnn_4-v_verlet_SHO[int((nsteps-1)*dt_4/dt_verlet):int(np.size(v_verlet_SHO)-dt_4/dt_verlet):int(dt_4/dt_verlet)],label='$100\Delta_v$',color='red')
plt.legend(loc='upper left')
ax = plt.gca()
ax.set_xlabel('time $t$')
ax.set_ylabel('Velocity Error $v_{NN}(t)-v_V(t)$')
ax.set_title('Velocity Error')
plt.rc('font', size=12)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=20)    # legend fontsize
plt.rc('figure', titlesize=20)  # fontsize of the figure title
#plt.grid()
plt.show()

# Plot L2 error as a function of time

plt.plot(t_hnn_1,((v_hnn_1-v_verlet_SHO[int((nsteps-1)*dt_1/dt_verlet)::int(dt_1/dt_verlet)])**2+(x_hnn_1-x_verlet_SHO[int((nsteps-1)*dt_1/dt_verlet)::int(dt_1/dt_verlet)])**2)**0.5,label='$\Delta_v$',color='blue')
plt.plot(t_hnn_2,((v_hnn_2-v_verlet_SHO[int((nsteps-1)*dt_2/dt_verlet):int(np.size(v_verlet_SHO)-dt_2/dt_verlet):int(dt_2/dt_verlet)])**2+(x_hnn_2-x_verlet_SHO[int((nsteps-1)*dt_2/dt_verlet):int(np.size(x_verlet_SHO)-dt_2/dt_verlet):int(dt_2/dt_verlet)])**2)**0.5,label='$20\Delta_v$',color='orange')
plt.plot(t_hnn_3,((v_hnn_3-v_verlet_SHO[int((nsteps-1)*dt_3/dt_verlet)::int(dt_3/dt_verlet)])**2+(x_hnn_3-x_verlet_SHO[int((nsteps-1)*dt_3/dt_verlet)::int(dt_3/dt_verlet)])**2)**0.5,label='$40\Delta_v$',color='green')
plt.plot(t_hnn_4,((v_hnn_4-v_verlet_SHO[int((nsteps-1)*dt_4/dt_verlet):int(np.size(v_verlet_SHO)-dt_4/dt_verlet):int(dt_4/dt_verlet)])**2+(x_hnn_4-x_verlet_SHO[int((nsteps-1)*dt_4/dt_verlet):int(np.size(x_verlet_SHO)-dt_4/dt_verlet):int(dt_4/dt_verlet)])**2)**0.5,label='$100\Delta_v$',color='red')
plt.legend(loc='upper left')
ax = plt.gca()
ax.set_xlabel('time $t$')
ax.set_ylabel('L2 Error')
ax.set_title('L2 Error')
plt.rc('font', size=12)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=20)    # legend fontsize
plt.rc('figure', titlesize=20)  # fontsize of the figure title
#plt.grid()
plt.show()


plt.clf()
# Plot energy as a function of time
# (subtract energy at time t=0 to show energy drift)

plt.plot(t_verlet_SHO,E_verlet_SHO-E_verlet_SHO[0],label='Verlet',color='black')
plt.plot(t_hnn_1,E_hnn_1-E_hnn_1[0],label='$\Delta_v$',color='blue')
plt.plot(t_hnn_2,E_hnn_2-E_hnn_2[0],label='$20\Delta_v$',color='orange')
plt.plot(t_hnn_3,E_hnn_3-E_hnn_3[0],label='$40\Delta_v$',color='green')
plt.plot(t_hnn_4,E_hnn_4-E_hnn_4[0],label='$100\Delta_v$',color='red')
plt.legend(loc='upper left')
ax = plt.gca()
ax.set_xlabel('time $t$')
ax.set_ylabel('energy shift $E(t)-E(t_0)$')
#ax.grid()
plt.rc('font', size=12)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=20)    # legend fontsize
plt.rc('figure', titlesize=20)  # fontsize of the figure title

plt.show()

#subplots of position versus velocity for all 4

plt.rcParams['figure.figsize'] = [10, 10]

plt.clf()
plt.plot(x_verlet_SHO,v_verlet_SHO,label='Verlet',color='black')
plt.plot(x_hnn_1,v_hnn_1,label='$\Delta_v$',color='blue')
plt.plot(x_hnn_2,v_hnn_2,label='$20\Delta_v$',color='orange')
plt.plot(x_hnn_3,v_hnn_3,label='$40\Delta_v$',color='green')
plt.plot(x_hnn_4,v_hnn_4,label='$100\Delta_v$',color='red')
plt.legend(loc='upper left')
ax = plt.gca()
ax.set_ylabel('Velocity $v(t)$')
ax.set_xlabel('Position $q(t)$')
plt.rc('font', size=12)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=20)    # legend fontsize
plt.rc('figure', titlesize=20)  # fontsize of the figure title
plt.show()
