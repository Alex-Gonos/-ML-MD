# %% [markdown]
# #Neural network based integrator simulating rugged system

# %%
import sys
sys.path.append('..')

import numpy as np
from matplotlib import pyplot as plt
from Code.dynamical_system import *
from Code.time_integrator import *
from Code.neuralnet import *

np.random.seed(2512517)

# %% [markdown]
# ## Neural network integrator

# %% [markdown]
# Set system parameters, construct dynamical system and integrator.
#
# The model system we are using here is the rugged oscillator.
#
# The timestep size of the Neural network integrator takes values in $\Delta t_{\text{Verlet}},20\Delta t_{\text{Verlet}},40\Delta t_{\text{Verlet}},100\Delta t_{\text{Verlet}}$ where $\Delta t_{\text{Verlet}}$ is the step size of the Verlet integrator that is used for training.

# %%
# mass of particle
mass = 1.2
# timestep for Verlet integrator
dt_verlet = 0.005
# timestep for neural network integrator
dt_1 = dt_verlet
dt_2 = 20*dt_verlet
dt_3 = 40*dt_verlet
dt_4 = 100*dt_verlet
# number of steps for neural network integrator
nsteps = 4

rugged = Rugged(mass)

verlet_rugged = VerletIntegrator(rugged,dt_verlet)

nn_integrator_1 = NN5LR3Integrator(rugged,nsteps,dt_1)
nn_integrator_2 = NN5LR3Integrator(rugged,nsteps,dt_2)
nn_integrator_3 = NN5LR3Integrator(rugged,nsteps,dt_3)
nn_integrator_4 = NN5LR3Integrator(rugged,nsteps,dt_4)

# visualise the neural network model
nn_integrator_1.model.summary()
keras.utils.plot_model(nn_integrator_1.model, show_shapes=True)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 4, 2)]       0           []
#
#  flatten (Flatten)              (None, 8)            0           ['input_1[0][0]']
#
#  dense (Dense)                  (None, 64)           576         ['flatten[0][0]']
#
#  dense_1 (Dense)                (None, 64)           4160        ['dense[0][0]']
#
#  dense_2 (Dense)                (None, 32)           2080        ['dense_1[0][0]']
#
#  dense_3 (Dense)                (None, 2)            66          ['dense_2[0][0]']
#
#  tf.unstack (TFOpLambda)        [(None, 2),          0           ['input_1[0][0]']
#                                  (None, 2),
#                                  (None, 2),
#                                  (None, 2)]
#
#  rescaling (Rescaling)          (None, 2)            0           ['dense_3[0][0]']
#
#  add (Add)                      (None, 2)            0           ['tf.unstack[0][3]',
#                                                                   'rescaling[0][0]']
#
# ==================================================================================================
# Total params: 6,882
# Trainable params: 6,882
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
BATCH_SIZE=64

data_generator_1 = DataGenerator(nn_integrator_1,verlet_rugged)
train_batches_1 = data_generator_1.dataset.batch(BATCH_SIZE)

data_generator_2 = DataGenerator(nn_integrator_2,verlet_rugged)
train_batches_2 = data_generator_2.dataset.batch(BATCH_SIZE)

data_generator_3 = DataGenerator(nn_integrator_3,verlet_rugged)
train_batches_3 = data_generator_3.dataset.batch(BATCH_SIZE)

data_generator_4 = DataGenerator(nn_integrator_4,verlet_rugged)
train_batches_4 = data_generator_4.dataset.batch(BATCH_SIZE)

# %% [markdown]
# ## Train neural network based integrator

# %%
EPOCHS=300
STEPS_PER_EPOCH=100
log_dir = './tb_logs/'
tensorboard_cb = tf.keras.callbacks.TensorBoard(log_dir=log_dir)

result_1 = nn_integrator_1.model.fit(train_batches_1,epochs=EPOCHS,steps_per_epoch=STEPS_PER_EPOCH,
                                 callbacks=tensorboard_cb)
result_2 = nn_integrator_2.model.fit(train_batches_2,epochs=EPOCHS,steps_per_epoch=STEPS_PER_EPOCH,
                                 callbacks=tensorboard_cb)
result_3 = nn_integrator_3.model.fit(train_batches_3,epochs=EPOCHS,steps_per_epoch=STEPS_PER_EPOCH,
                                callbacks=tensorboard_cb)
result_4 = nn_integrator_4.model.fit(train_batches_4,epochs=EPOCHS,steps_per_epoch=STEPS_PER_EPOCH,
                                 callbacks=tensorboard_cb)
300
# 100/100 [==============================] - 9s 89ms/step - loss: 0.0141
# Epoch 70/300
# 100/100 [==============================] - 9s 90ms/step - loss: 0.0146
# Epoch 71/300
# 100/100 [==============================] - 9s 90ms/step - loss: 0.0134
# Epoch 72/300
# 100/100 [==============================] - 9s 90ms/step - loss: 0.0134
# Epoch 73/300
# 100/100 [==============================] - 9s 90ms/step - loss: 0.0134
# Epoch 74/300
# 100/100 [==============================] - 9s 90ms/step - loss: 0.0130
# Epoch 75/300
# 100/100 [==============================] - 9s 91ms/step - loss: 0.0124
# Epoch 76/300
# 100/100 [==============================] - 9s 91ms/step - loss: 0.0124
# Epoch 77/300
# 100/100 [==============================] - 9s 90ms/step - loss: 0.0123
# Epoch 78/300
# 100/100 [==============================] - 9s 89ms/step - loss: 0.0120
# Epoch 79/300
# 100/100 [==============================] - 9s 91ms/step - loss: 0.0112
# Epoch 80/300
# 100/100 [==============================] - 9s 90ms/step - loss: 0.0114
# Epoch 81/300
# 100/100 [==============================] - 9s 91ms/step - loss: 0.0112
# Epoch 82/300
# 100/100 [==============================] - 9s 92ms/step - loss: 0.0107
# Epoch 83/300
# 100/100 [==============================] - 9s 93ms/step - loss: 0.0105
# Epoch 84/300
# 100/100 [==============================] - 9s 91ms/step - loss: 0.0105
# Epoch 85/300
# 100/100 [==============================] - 9s 91ms/step - loss: 0.0098
# Epoch 86/300
# 100/100 [==============================] - 9s 89ms/step - loss: 0.0099
# Epoch 87/300
# 100/100 [==============================] - 9s 89ms/step - loss: 0.0096
# Epoch 88/300
# 100/100 [==============================] - 9s 89ms/step - loss: 0.0092
# Epoch 89/300
# 100/100 [==============================] - 9s 91ms/step - loss: 0.0089
# Epoch 90/300
# 100/100 [==============================] - 9s 91ms/step - loss: 0.0089
# Epoch 91/300
# 100/100 [==============================] - 9s 90ms/step - loss: 0.0089
# Epoch 92/300
# 100/100 [==============================] - 9s 90ms/step - loss: 0.0085
# Epoch 93/300
# 100/100 [==============================] - 9s 90ms/step - loss: 0.0083
# Epoch 94/300
# 100/100 [==============================] - 9s 90ms/step - loss: 0.0082
# Epoch 95/300
# 100/100 [==============================] - 9s 89ms/step - loss: 0.0077
# Epoch 96/300
# 100/100 [==============================] - 9s 89ms/step - loss: 0.0076
# Epoch 97/300
# 100/100 [==============================] - 9s 90ms/step - loss: 0.0076
# Epoch 98/300
# 100/100 [==============================] - 9s 89ms/step - loss: 0.0071
# Epoch 99/300
# 100/100 [==============================] - 9s 90ms/step - loss: 0.0071
# Epoch 100/300
# 100/100 [==============================] - 9s 90ms/step - loss: 0.0071
# Epoch 101/300
# 100/100 [==============================] - 9s 90ms/step - loss: 0.0068
# Epoch 102/300
# 100/100 [==============================] - 9s 91ms/step - loss: 0.0067
# Epoch 103/300
# 100/100 [==============================] - 9s 90ms/step - loss: 0.0066
# Epoch 104/300
# 100/100 [==============================] - 9s 91ms/step - loss: 0.0066
# Epoch 105/300
# 100/100 [==============================] - 9s 89ms/step - loss: 0.0066
# Epoch 106/300
# 100/100 [==============================] - 9s 90ms/step - loss: 0.0063
# Epoch 107/300
# 100/100 [==============================] - 9s 89ms/step - loss: 0.0060
# Epoch 108/300
# 100/100 [==============================] - 9s 89ms/step - loss: 0.0061
# Epoch 109/300
# 100/100 [==============================] - 9s 92ms/step - loss: 0.0058
# Epoch 110/300
# 100/100 [==============================] - 9s 93ms/step - loss: 0.0060
# Epoch 111/300
# 100/100 [==============================] - 9s 92ms/step - loss: 0.0056
# Epoch 112/300
# 100/100 [==============================] - 9s 90ms/step - loss: 0.0058
# Epoch 113/300
# 100/100 [==============================] - 9s 89ms/step - loss: 0.0059
# Epoch 114/300
# 100/100 [==============================] - 9s 89ms/step - loss: 0.0056
# Epoch 115/300
# 100/100 [==============================] - 9s 90ms/step - loss: 0.0055
# Epoch 116/300
# 100/100 [==============================] - 9s 92ms/step - loss: 0.0056
# Epoch 117/300
# 100/100 [==============================] - 9s 92ms/step - loss: 0.0051
# Epoch 118/300
# 100/100 [==============================] - 9s 92ms/step - loss: 0.0054
# Epoch 119/300
# 100/100 [==============================] - 9s 90ms/step - loss: 0.0054
# Epoch 120/300
# 100/100 [==============================] - 9s 90ms/step - loss: 0.0052
# Epoch 121/300
# 100/100 [==============================] - 9s 91ms/step - loss: 0.0050
# Epoch 122/300
# 100/100 [==============================] - 9s 89ms/step - loss: 0.0051
# Epoch 123/300
# 100/100 [==============================] - 9s 90ms/step - loss: 0.0050
# Epoch 124/300
# 100/100 [==============================] - 9s 93ms/step - loss: 0.0050
# Epoch 125/300
# 100/100 [==============================] - 9s 91ms/step - loss: 0.0048
# Epoch 126/300
# 100/100 [==============================] - 9s 92ms/step - loss: 0.0048
# Epoch 127/300
# 100/100 [==============================] - 9s 91ms/step - loss: 0.0049
# Epoch 128/300
# 100/100 [==============================] - 9s 91ms/step - loss: 0.0048
# Epoch 129/300
# 100/100 [==============================] - 9s 92ms/step - loss: 0.0046
# Epoch 130/300
# 100/100 [==============================] - 9s 92ms/step - loss: 0.0046
# Epoch 131/300
# 100/100 [==============================] - 9s 91ms/step - loss: 0.0045
# Epoch 132/300
# 100/100 [==============================] - 9s 92ms/step - loss: 0.0047
# Epoch 133/300
# 100/100 [==============================] - 9s 93ms/step - loss: 0.0045
# Epoch 134/300
# 100/100 [==============================] - 9s 91ms/step - loss: 0.0045
# Epoch 135/300
# 100/100 [==============================] - 9s 92ms/step - loss: 0.0043
# Epoch 136/300
# 100/100 [==============================] - 9s 91ms/step - loss: 0.0046
# Epoch 137/300
# 100/100 [==============================] - 9s 92ms/step - loss: 0.0046
# Epoch 138/300
# 100/100 [==============================] - 9s 91ms/step - loss: 0.0046
# Epoch 139/300
# 100/100 [==============================] - 9s 93ms/step - loss: 0.0046
# Epoch 140/300
# 100/100 [==============================] - 9s 90ms/step - loss: 0.0043
# Epoch 141/300
# 100/100 [==============================] - 9s 91ms/step - loss: 0.0041
# Epoch 142/300
# 100/100 [==============================] - 9s 92ms/step - loss: 0.0043
# Epoch 143/300
# 100/100 [==============================] - 9s 90ms/step - loss: 0.0043
# Epoch 144/300
# 100/100 [==============================] - 9s 91ms/step - loss: 0.0043
# Epoch 145/300
# 100/100 [==============================] - 9s 93ms/step - loss: 0.0042
# Epoch 146/300
# 100/100 [==============================] - 9s 91ms/step - loss: 0.0041
# Epoch 147/300
# 100/100 [==============================] - 9s 92ms/step - loss: 0.0041
# Epoch 148/300
# 100/100 [==============================] - 9s 92ms/step - loss: 0.0041
# Epoch 149/300
# 100/100 [==============================] - 9s 90ms/step - loss: 0.0041
# Epoch 150/300
# 100/100 [==============================] - 9s 91ms/step - loss: 0.0040
# Epoch 151/300
# 100/100 [==============================] - 9s 94ms/step - loss: 0.0042
# Epoch 152/300
# 100/100 [==============================] - 9s 93ms/step - loss: 0.0038
# Epoch 153/300
# 100/100 [==============================] - 9s 93ms/step - loss: 0.0038
# Epoch 154/300
# 100/100 [==============================] - 9s 95ms/step - loss: 0.0039
# Epoch 155/300
# 100/100 [==============================] - 11s 109ms/step - loss: 0.0039
# Epoch 156/300
# 100/100 [==============================] - 9s 92ms/step - loss: 0.0038
# Epoch 157/300
# 100/100 [==============================] - 9s 90ms/step - loss: 0.0038
# Epoch 158/300
# 100/100 [==============================] - 9s 91ms/step - loss: 0.0039
# Epoch 159/300
# 100/100 [==============================] - 9s 92ms/step - loss: 0.0038
# Epoch 160/300
# 100/100 [==============================] - 9s 91ms/step - loss: 0.0035
# Epoch 161/300
# 100/100 [==============================] - 9s 91ms/step - loss: 0.0038
# Epoch 162/300
# 100/100 [==============================] - 9s 93ms/step - loss: 0.0036
# Epoch 163/300
# 100/100 [==============================] - 9s 90ms/step - loss: 0.0037
# Epoch 164/300
# 100/100 [==============================] - 9s 93ms/step - loss: 0.0038
# Epoch 165/300
# 100/100 [==============================] - 9s 92ms/step - loss: 0.0035
# Epoch 166/300
# 100/100 [==============================] - 9s 90ms/step - loss: 0.0038
# Epoch 167/300
# 100/100 [==============================] - 9s 90ms/step - loss: 0.0035
# Epoch 168/300
# 100/100 [==============================] - 9s 92ms/step - loss: 0.0036
# Epoch 169/300
# 100/100 [==============================] - 9s 92ms/step - loss: 0.0036
# Epoch 170/300
# 100/100 [==============================] - 9s 91ms/step - loss: 0.0034
# Epoch 171/300
# 100/100 [==============================] - 9s 93ms/step - loss: 0.0037
# Epoch 172/300
# 100/100 [==============================] - 9s 92ms/step - loss: 0.0034
# Epoch 173/300
# 100/100 [==============================] - 9s 93ms/step - loss: 0.0035
# Epoch 174/300
# 100/100 [==============================] - 9s 93ms/step - loss: 0.0034
# Epoch 175/300
# 100/100 [==============================] - 9s 90ms/step - loss: 0.0036
# Epoch 176/300
# 100/100 [==============================] - 9s 91ms/step - loss: 0.0033
# Epoch 177/300
# 100/100 [==============================] - 9s 92ms/step - loss: 0.0037
# Epoch 178/300
# 100/100 [==============================] - 9s 92ms/step - loss: 0.0034
# Epoch 179/300
# 100/100 [==============================] - 9s 93ms/step - loss: 0.0033
# Epoch 180/300
# 100/100 [==============================] - 9s 92ms/step - loss: 0.0033
# Epoch 181/300
# 100/100 [==============================] - 9s 91ms/step - loss: 0.0033
# Epoch 182/300
# 100/100 [==============================] - 9s 93ms/step - loss: 0.0034
# Epoch 183/300
# 100/100 [==============================] - 9s 91ms/step - loss: 0.0035
# Epoch 184/300
# 100/100 [==============================] - 9s 92ms/step - loss: 0.0034
# Epoch 185/300
# 100/100 [==============================] - 9s 94ms/step - loss: 0.0032
# Epoch 186/300
# 100/100 [==============================] - 9s 93ms/step - loss: 0.0032
# Epoch 187/300
# 100/100 [==============================] - 9s 93ms/step - loss: 0.0033
# Epoch 188/300
# 100/100 [==============================] - 9s 92ms/step - loss: 0.0032
# Epoch 189/300
# 100/100 [==============================] - 9s 91ms/step - loss: 0.0032
# Epoch 190/300
# 100/100 [==============================] - 9s 91ms/step - loss: 0.0032
# Epoch 191/300
# 100/100 [==============================] - 9s 91ms/step - loss: 0.0032
# Epoch 192/300
# 100/100 [==============================] - 9s 91ms/step - loss: 0.0031
# Epoch 193/300
# 100/100 [==============================] - 9s 91ms/step - loss: 0.0033
# Epoch 194/300
# 100/100 [==============================] - 9s 92ms/step - loss: 0.0031
# Epoch 195/300
# 100/100 [==============================] - 9s 93ms/step - loss: 0.0031
# Epoch 196/300
# 100/100 [==============================] - 9s 92ms/step - loss: 0.0030
# Epoch 197/300
# 100/100 [==============================] - 9s 90ms/step - loss: 0.0032
# Epoch 198/300
# 100/100 [==============================] - 9s 92ms/step - loss: 0.0032
# Epoch 199/300
# 100/100 [==============================] - 9s 93ms/step - loss: 0.0032
# Epoch 200/300
# 100/100 [==============================] - 9s 93ms/step - loss: 0.0032
# Epoch 201/300
# 100/100 [==============================] - 9s 91ms/step - loss: 0.0032
# Epoch 202/300
# 100/100 [==============================] - 9s 92ms/step - loss: 0.0031
# Epoch 203/300
# 100/100 [==============================] - 9s 92ms/step - loss: 0.0031
# Epoch 204/300
# 100/100 [==============================] - 9s 92ms/step - loss: 0.0031
# Epoch 205/300
# 100/100 [==============================] - 9s 92ms/step - loss: 0.0031
# Epoch 206/300
# 100/100 [==============================] - 9s 93ms/step - loss: 0.0029
# Epoch 207/300
# 100/100 [==============================] - 9s 93ms/step - loss: 0.0030
# Epoch 208/300
# 100/100 [==============================] - 9s 92ms/step - loss: 0.0030
# Epoch 209/300
# 100/100 [==============================] - 9s 92ms/step - loss: 0.0030
# Epoch 210/300
# 100/100 [==============================] - 9s 91ms/step - loss: 0.0029
# Epoch 211/300
# 100/100 [==============================] - 9s 92ms/step - loss: 0.0030
# Epoch 212/300
# 100/100 [==============================] - 9s 91ms/step - loss: 0.0030
# Epoch 213/300
# 100/100 [==============================] - 9s 93ms/step - loss: 0.0029
# Epoch 214/300
# 100/100 [==============================] - 9s 92ms/step - loss: 0.0028
# Epoch 215/300
# 100/100 [==============================] - 9s 92ms/step - loss: 0.0029
# Epoch 216/300
# 100/100 [==============================] - 9s 92ms/step - loss: 0.0029
# Epoch 217/300
# 100/100 [==============================] - 9s 91ms/step - loss: 0.0028
# Epoch 218/300
# 100/100 [==============================] - 9s 93ms/step - loss: 0.0030
# Epoch 219/300
# 100/100 [==============================] - 9s 92ms/step - loss: 0.0028
# Epoch 220/300
# 100/100 [==============================] - 9s 93ms/step - loss: 0.0028
# Epoch 221/300
# 100/100 [==============================] - 9s 94ms/step - loss: 0.0029
# Epoch 222/300
# 100/100 [==============================] - 9s 92ms/step - loss: 0.0029
# Epoch 223/300
# 100/100 [==============================] - 9s 93ms/step - loss: 0.0029
# Epoch 224/300
# 100/100 [==============================] - 9s 94ms/step - loss: 0.0028
# Epoch 225/300
# 100/100 [==============================] - 9s 92ms/step - loss: 0.0027
# Epoch 226/300
# 100/100 [==============================] - 9s 93ms/step - loss: 0.0028
# Epoch 227/300
# 100/100 [==============================] - 9s 92ms/step - loss: 0.0027
# Epoch 228/300
# 100/100 [==============================] - 9s 92ms/step - loss: 0.0028
# Epoch 229/300
# 100/100 [==============================] - 9s 92ms/step - loss: 0.0028
# Epoch 230/300
# 100/100 [==============================] - 9s 93ms/step - loss: 0.0028
# Epoch 231/300
# 100/100 [==============================] - 9s 91ms/step - loss: 0.0027
# Epoch 232/300
# 100/100 [==============================] - 9s 91ms/step - loss: 0.0025
# Epoch 233/300
# 100/100 [==============================] - 9s 93ms/step - loss: 0.0026
# Epoch 234/300
# 100/100 [==============================] - 9s 93ms/step - loss: 0.0028
# Epoch 235/300
# 100/100 [==============================] - 9s 92ms/step - loss: 0.0028
# Epoch 236/300
# 100/100 [==============================] - 9s 91ms/step - loss: 0.0026
# Epoch 237/300
# 100/100 [==============================] - 9s 92ms/step - loss: 0.0028
# Epoch 238/300
# 100/100 [==============================] - 9s 92ms/step - loss: 0.0026
# Epoch 239/300
# 100/100 [==============================] - 9s 91ms/step - loss: 0.0028
# Epoch 240/300
# 100/100 [==============================] - 9s 92ms/step - loss: 0.0026
# Epoch 241/300
# 100/100 [==============================] - 9s 94ms/step - loss: 0.0027
# Epoch 242/300
# 100/100 [==============================] - 9s 93ms/step - loss: 0.0027
# Epoch 243/300
# 100/100 [==============================] - 9s 93ms/step - loss: 0.0026
# Epoch 244/300
# 100/100 [==============================] - 9s 93ms/step - loss: 0.0027
# Epoch 245/300
# 100/100 [==============================] - 10s 96ms/step - loss: 0.0025
# Epoch 246/300
# 100/100 [==============================] - 9s 93ms/step - loss: 0.0025
# Epoch 247/300
# 100/100 [==============================] - 9s 94ms/step - loss: 0.0027
# Epoch 248/300
# 100/100 [==============================] - 9s 93ms/step - loss: 0.0028
# Epoch 249/300
# 100/100 [==============================] - 9s 92ms/step - loss: 0.0026
# Epoch 250/300
# 100/100 [==============================] - 9s 93ms/step - loss: 0.0026
# Epoch 251/300
# 100/100 [==============================] - 9s 92ms/step - loss: 0.0027
# Epoch 252/300
# 100/100 [==============================] - 9s 93ms/step - loss: 0.0024
# Epoch 253/300
# 100/100 [==============================] - 9s 93ms/step - loss: 0.0026
# ...
# 100/100 [==============================] - 35s 353ms/step - loss: 0.0378
# Epoch 118/300
# 100/100 [==============================] - 35s 355ms/step - loss: 0.0363
# Epoch 119/300
# 100/100 [==============================] - 35s 355ms/step - loss: 0.0357
# Epoch 120/300
# 100/100 [==============================] - 36s 357ms/step - loss: 0.0357
# Epoch 121/300
# 100/100 [==============================] - 36s 356ms/step - loss: 0.0363
# Epoch 122/300
# 100/100 [==============================] - 35s 355ms/step - loss: 0.0356
# Epoch 123/300
# 100/100 [==============================] - 36s 356ms/step - loss: 0.0352
# Epoch 124/300
# 100/100 [==============================] - 35s 353ms/step - loss: 0.0358
# Epoch 125/300
# 100/100 [==============================] - 36s 360ms/step - loss: 0.0345
# Epoch 126/300
# 100/100 [==============================] - 36s 355ms/step - loss: 0.0355
# Epoch 127/300
# 100/100 [==============================] - 36s 356ms/step - loss: 0.0359
# Epoch 128/300
# 100/100 [==============================] - 36s 357ms/step - loss: 0.0393
# Epoch 129/300
# 100/100 [==============================] - 35s 354ms/step - loss: 0.0364
# Epoch 130/300
# 100/100 [==============================] - 36s 357ms/step - loss: 0.0354
# Epoch 131/300
# 100/100 [==============================] - 36s 358ms/step - loss: 0.0342
# Epoch 132/300
# 100/100 [==============================] - 36s 358ms/step - loss: 0.0353
# Epoch 133/300
# 100/100 [==============================] - 35s 352ms/step - loss: 0.0350
# Epoch 134/300
# 100/100 [==============================] - 36s 359ms/step - loss: 0.0347
# Epoch 135/300
# 100/100 [==============================] - 36s 356ms/step - loss: 0.0352
# Epoch 136/300
# 100/100 [==============================] - 35s 354ms/step - loss: 0.0347
# Epoch 137/300
# 100/100 [==============================] - 36s 355ms/step - loss: 0.0346
# Epoch 138/300
# 100/100 [==============================] - 36s 355ms/step - loss: 0.0345
# Epoch 139/300
# 100/100 [==============================] - 36s 361ms/step - loss: 0.
# 100/100 [==============================] - 36s 364ms/step - loss: 0.0292
# Epoch 250/300
# 100/100 [==============================] - 36s 362ms/step - loss: 0.0281
# Epoch 251/300
# 100/100 [==============================] - 36s 361ms/step - loss: 0.0290
# Epoch 252/300
# 100/100 [==============================] - 36s 360ms/step - loss: 0.0298
# Epoch 253/300
# 100/100 [==============================] - 36s 357ms/step - loss: 0.0277
# Epoch 254/300
# 100/100 [==============================] - 37s 366ms/step - loss: 0.0285
# Epoch 255/300
# 100/100 [==============================] - 36s 358ms/step - loss: 0.0284
# Epoch 256/300
# 100/100 [==============================] - 36s 364ms/step - loss: 0.0286
# Epoch 257/300
# 100/100 [==============================] - 36s 358ms/step - loss: 0.0282
# Epoch 258/300
# 100/100 [==============================] - 36s 359ms/step - loss: 0.0276
# Epoch 259/300
# 100/100 [==============================] - 36s 364ms/step - loss: 0.0273
# Epoch 260/300
# 100/100 [==============================] - 36s 358ms/step - loss: 0.0277
# Epoch 261/300
# 100/100 [==============================] - 36s 360ms/step - loss: 0.0276
# Epoch 262/300
# 100/100 [==============================] - 36s 357ms/step - loss: 0.0289
# Epoch 263/300
# 100/100 [==============================] - 36s 361ms/step - loss: 0.0269
# Epoch 264/300
# 100/100 [==============================] - 36s 355ms/step - loss: 0.0272
# Epoch 265/300
# 100/100 [==============================] - 36s 363ms/step - loss: 0.0269
# Epoch 266/300
# 100/100 [==============================] - 36s 362ms/step - loss: 0.0268
# Epoch 267/300
# 100/100 [==============================] - 36s 359ms/step - loss: 0.0278
# Epoch 268/300
# 100/100 [==============================] - 36s 364ms/step - loss: 0.0284
# Epoch 269/300
# 100/100 [==============================] - 36s 362ms/step - loss: 0.0277
# Epoch 270/300
# 100/100 [==============================] - 36s 362ms/step - loss: 0.0269
# Epoch 271/300
# 100/100 [==============================] - 36s 360ms/step - loss: 0.0271
# Epoch 272/300
# 100/100 [==============================] - 36s 362ms/step - loss: 0.0280
# Epoch 273/300
# 100/100 [==============================] - 36s 359ms/step - loss: 0.0280
# Epoch 274/300
# 100/100 [==============================] - 36s 360ms/step - loss: 0.0290
# Epoch 275/300
# 100/100 [==============================] - 36s 362ms/step - loss: 0.0299
# Epoch 276/300
# 100/100 [==============================] - 36s 360ms/step - loss: 0.0294
# Epoch 277/300
# 100/100 [==============================] - 36s 363ms/step - loss: 0.0274
# Epoch 278/300
# 100/100 [==============================] - 36s 361ms/step - loss: 0.0273
# Epoch 279/300
# 100/100 [==============================] - 36s 361ms/step - loss: 0.0274
# Epoch 280/300
# 100/100 [==============================] - 36s 360ms/step - loss: 0.0277
# Epoch 281/300
# 100/100 [==============================] - 36s 356ms/step - loss: 0.0275
# Epoch 282/300
# 100/100 [==============================] - 36s 360ms/step - loss: 0.0283
# Epoch 283/300
# 100/100 [==============================] - 36s 361ms/step - loss: 0.0286
# Epoch 284/300
# 100/100 [==============================] - 36s 363ms/step - loss: 0.0280
# Epoch 285/300
# 100/100 [==============================] - 36s 363ms/step - loss: 0.0268
# Epoch 286/300
# 100/100 [==============================] - 36s 363ms/step - loss: 0.0270
# Epoch 287/300
# 100/100 [==============================] - 36s 360ms/step - loss: 0.0274
# Epoch 288/300
# 100/100 [==============================] - 36s 362ms/step - loss: 0.0276
# Epoch 289/300
# 100/100 [==============================] - 36s 359ms/step - loss: 0.0278
# Epoch 290/300
# 100/100 [==============================] - 36s 362ms/step - loss: 0.0275
# Epoch 291/300
# 100/100 [==============================] - 36s 359ms/step - loss: 0.0274
# Epoch 292/300
# 100/100 [==============================] - 36s 365ms/step - loss: 0.0277
# Epoch 293/300
# 100/100 [==============================] - 36s 361ms/step - loss: 0.0273
# Epoch 294/300
# 100/100 [==============================] - 36s 365ms/step - loss: 0.0262
# Epoch 295/300
# 100/100 [==============================] - 36s 361ms/step - loss: 0.0257
# Epoch 296/300
# 100/100 [==============================] - 36s 361ms/step - loss: 0.0260
# Epoch 297/300
# 100/100 [==============================] - 36s 361ms/step - loss: 0.0256
# Epoch 298/300
# 100/100 [==============================] - 36s 360ms/step - loss: 0.0276
# Epoch 299/300
# 100/100 [==============================] - 36s 363ms/step - loss: 0.0273
# Epoch 300/300
# 100/100 [==============================] - 36s 357ms/step - loss: 0.0262

# %% [markdown]
# ## Visualise Loss function

# %%
#print(result.history.keys())

plt.rcParams['figure.figsize'] = [10, 10]

# summarize history for loss
plt.plot(result_1.history['loss'])
plt.plot(result_2.history['loss'])
plt.plot(result_3.history['loss'])
plt.plot(result_4.history['loss'])

plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.rc('font', size=12)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=20)    # legend fontsize
plt.rc('figure', titlesize=20)  # fontsize of the figure title
plt.legend(['$\Delta_v$','$20\Delta_v$','$40\Delta_v$','$100\Delta_v$'], loc='upper left')
plt.yscale("log")
plt.show()

# %% [markdown]
# ## Plot trajectories to $t=32$ generated by Verlet integrator and neural network based integrator

# %%
# Final time
T_final = 32

# Initial conditions
x = np.zeros(1)
v = np.zeros(1)
x[0] = -0.8
v[0] = -0.3
verlet_rugged.set_state(x,v)

# ==== Verlet integrator ====
t = 0.0
t_verlet_rugged = []
x_verlet_rugged = []
v_verlet_rugged = []
E_verlet_rugged = []



while t<T_final:
    t_verlet_rugged.append(t)
    E_verlet_rugged.append(verlet_rugged.energy())
    x_verlet_rugged.append(verlet_rugged.x[0])
    v_verlet_rugged.append(verlet_rugged.v[0])
    verlet_rugged.integrate(1)
    t += dt_verlet
        

# ==== Neural network integrator ====

# Initialise with Verlet integrator
x_initial_1 = np.zeros((nn_integrator_1.nsteps,nn_integrator_1.dynamical_system.dim))
v_initial_1 = np.zeros((nn_integrator_1.nsteps,nn_integrator_1.dynamical_system.dim))
x_initial_2 = np.zeros((nn_integrator_2.nsteps,nn_integrator_2.dynamical_system.dim))
v_initial_2 = np.zeros((nn_integrator_2.nsteps,nn_integrator_2.dynamical_system.dim))
x_initial_3 = np.zeros((nn_integrator_3.nsteps,nn_integrator_3.dynamical_system.dim))
v_initial_3 = np.zeros((nn_integrator_3.nsteps,nn_integrator_3.dynamical_system.dim))
x_initial_4 = np.zeros((nn_integrator_4.nsteps,nn_integrator_4.dynamical_system.dim))
v_initial_4 = np.zeros((nn_integrator_4.nsteps,nn_integrator_4.dynamical_system.dim))



verlet_rugged.set_state(x,v)
for k in range(nn_integrator_1.nsteps):    
    x_initial_1[k,:] = verlet_rugged.x[:]
    v_initial_1[k,:] = verlet_rugged.v[:]
    verlet_rugged.integrate(int(dt_1/dt_verlet))
verlet_rugged.set_state(x,v)
for k in range(nn_integrator_2.nsteps):    
    x_initial_2[k,:] = verlet_rugged.x[:]
    v_initial_2[k,:] = verlet_rugged.v[:]
    verlet_rugged.integrate(int(dt_2/dt_verlet))
verlet_rugged.set_state(x,v)
for k in range(nn_integrator_3.nsteps):    
    x_initial_3[k,:] = verlet_rugged.x[:]
    v_initial_3[k,:] = verlet_rugged.v[:]
    verlet_rugged.integrate(int(dt_3/dt_verlet))
verlet_rugged.set_state(x,v)
for k in range(nn_integrator_4.nsteps):    
    x_initial_4[k,:] = verlet_rugged.x[:]
    v_initial_4[k,:] = verlet_rugged.v[:]
    verlet_rugged.integrate(int(dt_4/dt_verlet))


nn_integrator_1.set_state(x_initial_1,v_initial_1)
t_1 = (nn_integrator_1.nsteps-1)*nn_integrator_1.dt
nn_integrator_2.set_state(x_initial_2,v_initial_2)
t_2 = (nn_integrator_2.nsteps-1)*nn_integrator_2.dt
nn_integrator_3.set_state(x_initial_3,v_initial_3)
t_3 = (nn_integrator_3.nsteps-1)*nn_integrator_3.dt
nn_integrator_4.set_state(x_initial_4,v_initial_4)
t_4 = (nn_integrator_4.nsteps-1)*nn_integrator_4.dt



# Timestepping loop
t_nn_1 = []
x_nn_1 = []
v_nn_1 = []
E_nn_1 = []
t_nn_2 = []
x_nn_2 = []
v_nn_2 = []
E_nn_2 = []
t_nn_3 = []
x_nn_3 = []
v_nn_3 = []
E_nn_3 = []
t_nn_4 = []
x_nn_4 = []
v_nn_4 = []
E_nn_4 = []


while t_1<T_final:
    t_nn_1.append(t_1)
    x_nn_1.append(nn_integrator_1.x[0])
    v_nn_1.append(nn_integrator_1.v[0])
    E_nn_1.append(nn_integrator_1.energy())
    nn_integrator_1.integrate(1)
    t_1 += dt_1
while t_2<T_final:
    t_nn_2.append(t_2)
    x_nn_2.append(nn_integrator_2.x[0])
    v_nn_2.append(nn_integrator_2.v[0])
    E_nn_2.append(nn_integrator_2.energy())
    nn_integrator_2.integrate(1)
    t_2 += dt_2
while t_3<T_final:
    t_nn_3.append(t_3)
    x_nn_3.append(nn_integrator_3.x[0])
    v_nn_3.append(nn_integrator_3.v[0])
    E_nn_3.append(nn_integrator_3.energy())
    nn_integrator_3.integrate(1)
    t_3 += dt_3
while t_4<T_final:
    t_nn_4.append(t_4)
    x_nn_4.append(nn_integrator_4.x[0])
    v_nn_4.append(nn_integrator_4.v[0])
    E_nn_4.append(nn_integrator_4.energy())
    nn_integrator_4.integrate(1)
    t_4 += dt_4
 



x_nn_1 = np.array(x_nn_1)
x_nn_2 = np.array(x_nn_2)
x_nn_3 = np.array(x_nn_3)
x_nn_4 = np.array(x_nn_4)
x_verlet_rugged = np.array(x_verlet_rugged)
v_nn_1 = np.array(v_nn_1)
v_nn_2 = np.array(v_nn_2)
v_nn_3 = np.array(v_nn_3)
v_nn_4 = np.array(v_nn_4)
v_verlet_rugged = np.array(v_verlet_rugged)


# Plot position error as a function of time

plt.rcParams['figure.figsize'] = [10, 10]

plt.plot(t_nn_1,x_nn_1-x_verlet_rugged[int((nsteps-1)*dt_1/dt_verlet)::int(dt_1/dt_verlet)],label='$\Delta_v$',color='blue')
plt.plot(t_nn_2,x_nn_2-x_verlet_rugged[int((nsteps-1)*dt_2/dt_verlet):int(np.size(x_verlet_rugged)-dt_2/dt_verlet):int(dt_2/dt_verlet)],label='$20\Delta_v$',color='orange')
plt.plot(t_nn_3,x_nn_3-x_verlet_rugged[int((nsteps-1)*dt_3/dt_verlet)::int(dt_3/dt_verlet)],label='$40\Delta_v$',color='green')
plt.plot(t_nn_4,x_nn_4-x_verlet_rugged[int((nsteps-1)*dt_4/dt_verlet):int(np.size(x_verlet_rugged)-dt_4/dt_verlet):int(dt_4/dt_verlet)],label='$100\Delta_v$',color='red')
plt.legend(loc='upper left')
ax = plt.gca()
ax.set_xlabel('time $t$')
ax.set_ylabel('position Error $x_{NN}(t)-x_V(t)$')
ax.set_title('Position Error')
plt.rc('font', size=12)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=20)    # legend fontsize
plt.rc('figure', titlesize=20)  # fontsize of the figure title
#plt.grid()
plt.show()

# Plot velocity error as a function of time

plt.plot(t_nn_1,v_nn_1-v_verlet_rugged[int((nsteps-1)*dt_1/dt_verlet)::int(dt_1/dt_verlet)],label='$\Delta_v$',color='blue')
plt.plot(t_nn_2,v_nn_2-v_verlet_rugged[int((nsteps-1)*dt_2/dt_verlet):int(np.size(v_verlet_rugged)-dt_2/dt_verlet):int(dt_2/dt_verlet)],label='$20\Delta_v$',color='orange')
plt.plot(t_nn_3,v_nn_3-v_verlet_rugged[int((nsteps-1)*dt_3/dt_verlet)::int(dt_3/dt_verlet)],label='$40\Delta_v$',color='green')
plt.plot(t_nn_4,v_nn_4-v_verlet_rugged[int((nsteps-1)*dt_4/dt_verlet):int(np.size(v_verlet_rugged)-dt_4/dt_verlet):int(dt_4/dt_verlet)],label='$100\Delta_v$',color='red')
plt.legend(loc='upper left')
ax = plt.gca()
ax.set_xlabel('time $t$')
ax.set_ylabel('Velocity Error $v_{NN}(t)-v_V(t)$')
ax.set_title('Velocity Error')
plt.rc('font', size=12)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=20)    # legend fontsize
plt.rc('figure', titlesize=20)  # fontsize of the figure title
#plt.grid()
plt.show()

# Plot L2 error as a function of time

plt.plot(t_nn_1,((v_nn_1-v_verlet_rugged[int((nsteps-1)*dt_1/dt_verlet)::int(dt_1/dt_verlet)])**2+(x_nn_1-x_verlet_rugged[int((nsteps-1)*dt_1/dt_verlet)::int(dt_1/dt_verlet)])**2)**0.5,label='$\Delta_v$',color='blue')
plt.plot(t_nn_2,((v_nn_2-v_verlet_rugged[int((nsteps-1)*dt_2/dt_verlet):int(np.size(v_verlet_rugged)-dt_2/dt_verlet):int(dt_2/dt_verlet)])**2+(x_nn_2-x_verlet_rugged[int((nsteps-1)*dt_2/dt_verlet):int(np.size(x_verlet_rugged)-dt_2/dt_verlet):int(dt_2/dt_verlet)])**2)**0.5,label='$20\Delta_v$',color='orange')
plt.plot(t_nn_3,((v_nn_3-v_verlet_rugged[int((nsteps-1)*dt_3/dt_verlet)::int(dt_3/dt_verlet)])**2+(x_nn_3-x_verlet_rugged[int((nsteps-1)*dt_3/dt_verlet)::int(dt_3/dt_verlet)])**2)**0.5,label='$40\Delta_v$',color='green')
plt.plot(t_nn_4,((v_nn_4-v_verlet_rugged[int((nsteps-1)*dt_4/dt_verlet):int(np.size(v_verlet_rugged)-dt_4/dt_verlet):int(dt_4/dt_verlet)])**2+(x_nn_4-x_verlet_rugged[int((nsteps-1)*dt_4/dt_verlet):int(np.size(x_verlet_rugged)-dt_4/dt_verlet):int(dt_4/dt_verlet)])**2)**0.5,label='$100\Delta_v$',color='red')
plt.legend(loc='upper left')
ax = plt.gca()
ax.set_xlabel('time $t$')
ax.set_ylabel('L2 Error')
ax.set_title('L2 Error')
plt.rc('font', size=12)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=20)    # legend fontsize
plt.rc('figure', titlesize=20)  # fontsize of the figure title
#plt.grid()
plt.show()


plt.clf()
# Plot energy as a function of time
# (subtract energy at time t=0 to show energy drift)

plt.plot(t_verlet_rugged,E_verlet_rugged-E_verlet_rugged[0],label='rugged',color='black')
plt.plot(t_nn_1,E_nn_1-E_nn_1[0],label='$\Delta_v$',color='blue')
plt.plot(t_nn_2,E_nn_2-E_nn_2[0],label='$20\Delta_v$',color='orange')
plt.plot(t_nn_3,E_nn_3-E_nn_3[0],label='$40\Delta_v$',color='green')
plt.plot(t_nn_4,E_nn_4-E_nn_4[0],label='$100\Delta_v$',color='red')
plt.legend(loc='upper left')
ax = plt.gca()
ax.set_xlabel('time $t$')
ax.set_ylabel('energy shift $E(t)-E(t_0)$')
#ax.grid()
plt.rc('font', size=12)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=20)    # legend fontsize
plt.rc('figure', titlesize=20)  # fontsize of the figure title

plt.show()

#subplots of position versus velocity for all 4

plt.rcParams['figure.figsize'] = [10, 10]

plt.clf()
plt.plot(x_verlet_rugged,v_verlet_rugged,label='Verlet',color='black')
plt.plot(x_nn_1,v_nn_1,label='$\Delta_v$',color='blue')
plt.plot(x_nn_2,v_nn_2,label='$20\Delta_v$',color='orange')
plt.plot(x_nn_3,v_nn_3,label='$40\Delta_v$',color='green')
plt.plot(x_nn_4,v_nn_4,label='$100\Delta_v$',color='red')
plt.legend(loc='upper left')
ax = plt.gca()
ax.set_ylabel('Velocity $v(t)$')
ax.set_xlabel('Position $q(t)$')
plt.rc('font', size=12)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=20)    # legend fontsize
plt.rc('figure', titlesize=20)  # fontsize of the figure title
plt.show()

# %% [markdown]
# ## Plot trajectories to $t=128$ generated by Verlet integrator and neural network based integrator

# %%
# Final time
T_final = 128

# Initial conditions
x = np.zeros(1)
v = np.zeros(1)
x[0] = -0.8
v[0] = -0.3
verlet_rugged.set_state(x,v)

# ==== Verlet integrator ====
t = 0.0
t_verlet_rugged = []
x_verlet_rugged = []
v_verlet_rugged = []
E_verlet_rugged = []



while t<T_final:
    t_verlet_rugged.append(t)
    E_verlet_rugged.append(verlet_rugged.energy())
    x_verlet_rugged.append(verlet_rugged.x[0])
    v_verlet_rugged.append(verlet_rugged.v[0])
    verlet_rugged.integrate(1)
    t += dt_verlet
        

# ==== Neural network integrator ====

# Initialise with Verlet integrator
x_initial_1 = np.zeros((nn_integrator_1.nsteps,nn_integrator_1.dynamical_system.dim))
v_initial_1 = np.zeros((nn_integrator_1.nsteps,nn_integrator_1.dynamical_system.dim))
x_initial_2 = np.zeros((nn_integrator_2.nsteps,nn_integrator_2.dynamical_system.dim))
v_initial_2 = np.zeros((nn_integrator_2.nsteps,nn_integrator_2.dynamical_system.dim))
x_initial_3 = np.zeros((nn_integrator_3.nsteps,nn_integrator_3.dynamical_system.dim))
v_initial_3 = np.zeros((nn_integrator_3.nsteps,nn_integrator_3.dynamical_system.dim))
x_initial_4 = np.zeros((nn_integrator_4.nsteps,nn_integrator_4.dynamical_system.dim))
v_initial_4 = np.zeros((nn_integrator_4.nsteps,nn_integrator_4.dynamical_system.dim))



verlet_rugged.set_state(x,v)
for k in range(nn_integrator_1.nsteps):    
    x_initial_1[k,:] = verlet_rugged.x[:]
    v_initial_1[k,:] = verlet_rugged.v[:]
    verlet_rugged.integrate(int(dt_1/dt_verlet))
verlet_rugged.set_state(x,v)
for k in range(nn_integrator_2.nsteps):    
    x_initial_2[k,:] = verlet_rugged.x[:]
    v_initial_2[k,:] = verlet_rugged.v[:]
    verlet_rugged.integrate(int(dt_2/dt_verlet))
verlet_rugged.set_state(x,v)
for k in range(nn_integrator_3.nsteps):    
    x_initial_3[k,:] = verlet_rugged.x[:]
    v_initial_3[k,:] = verlet_rugged.v[:]
    verlet_rugged.integrate(int(dt_3/dt_verlet))
verlet_rugged.set_state(x,v)
for k in range(nn_integrator_4.nsteps):    
    x_initial_4[k,:] = verlet_rugged.x[:]
    v_initial_4[k,:] = verlet_rugged.v[:]
    verlet_rugged.integrate(int(dt_4/dt_verlet))


nn_integrator_1.set_state(x_initial_1,v_initial_1)
t_1 = (nn_integrator_1.nsteps-1)*nn_integrator_1.dt
nn_integrator_2.set_state(x_initial_2,v_initial_2)
t_2 = (nn_integrator_2.nsteps-1)*nn_integrator_2.dt
nn_integrator_3.set_state(x_initial_3,v_initial_3)
t_3 = (nn_integrator_3.nsteps-1)*nn_integrator_3.dt
nn_integrator_4.set_state(x_initial_4,v_initial_4)
t_4 = (nn_integrator_4.nsteps-1)*nn_integrator_4.dt



# Timestepping loop
t_nn_1 = []
x_nn_1 = []
v_nn_1 = []
E_nn_1 = []
t_nn_2 = []
x_nn_2 = []
v_nn_2 = []
E_nn_2 = []
t_nn_3 = []
x_nn_3 = []
v_nn_3 = []
E_nn_3 = []
t_nn_4 = []
x_nn_4 = []
v_nn_4 = []
E_nn_4 = []


while t_1<T_final:
    t_nn_1.append(t_1)
    x_nn_1.append(nn_integrator_1.x[0])
    v_nn_1.append(nn_integrator_1.v[0])
    E_nn_1.append(nn_integrator_1.energy())
    nn_integrator_1.integrate(1)
    t_1 += dt_1
while t_2<T_final:
    t_nn_2.append(t_2)
    x_nn_2.append(nn_integrator_2.x[0])
    v_nn_2.append(nn_integrator_2.v[0])
    E_nn_2.append(nn_integrator_2.energy())
    nn_integrator_2.integrate(1)
    t_2 += dt_2
while t_3<T_final:
    t_nn_3.append(t_3)
    x_nn_3.append(nn_integrator_3.x[0])
    v_nn_3.append(nn_integrator_3.v[0])
    E_nn_3.append(nn_integrator_3.energy())
    nn_integrator_3.integrate(1)
    t_3 += dt_3
while t_4<T_final:
    t_nn_4.append(t_4)
    x_nn_4.append(nn_integrator_4.x[0])
    v_nn_4.append(nn_integrator_4.v[0])
    E_nn_4.append(nn_integrator_4.energy())
    nn_integrator_4.integrate(1)
    t_4 += dt_4
 



x_nn_1 = np.array(x_nn_1)
x_nn_2 = np.array(x_nn_2)
x_nn_3 = np.array(x_nn_3)
x_nn_4 = np.array(x_nn_4)
x_verlet_rugged = np.array(x_verlet_rugged)
v_nn_1 = np.array(v_nn_1)
v_nn_2 = np.array(v_nn_2)
v_nn_3 = np.array(v_nn_3)
v_nn_4 = np.array(v_nn_4)
v_verlet_rugged = np.array(v_verlet_rugged)

# %%
# Plot position error as a function of time

plt.rcParams['figure.figsize'] = [10, 10]

plt.plot(t_nn_1,x_nn_1-x_verlet_rugged[int((nsteps-1)*dt_1/dt_verlet)::int(dt_1/dt_verlet)],label='$\Delta_v$',color='blue')
plt.legend(loc='upper left')
ax = plt.gca()
ax.set_xlabel('time $t$')
ax.set_ylabel('position Error $x_{NN}(t)-x_V(t)$')
ax.set_title('Position Error')
plt.rc('font', size=12)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=20)    # legend fontsize
plt.rc('figure', titlesize=20)  # fontsize of the figure title
#plt.grid()
plt.show()

# Plot velocity error as a function of time

plt.plot(t_nn_1,v_nn_1-v_verlet_rugged[int((nsteps-1)*dt_1/dt_verlet)::int(dt_1/dt_verlet)],label='$\Delta_v$',color='blue')
plt.legend(loc='upper left')
ax = plt.gca()
ax.set_xlabel('time $t$')
ax.set_ylabel('Velocity Error $v_{NN}(t)-v_V(t)$')
ax.set_title('Velocity Error')
plt.rc('font', size=12)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=20)    # legend fontsize
plt.rc('figure', titlesize=20)  # fontsize of the figure title
#plt.grid()
plt.show()

# Plot L2 error as a function of time

plt.plot(t_nn_1,((v_nn_1-v_verlet_rugged[int((nsteps-1)*dt_1/dt_verlet)::int(dt_1/dt_verlet)])**2+(x_nn_1-x_verlet_rugged[int((nsteps-1)*dt_1/dt_verlet)::int(dt_1/dt_verlet)])**2)**0.5,label='$\Delta_v$',color='blue')
plt.legend(loc='upper left')
ax = plt.gca()
ax.set_xlabel('time $t$')
ax.set_ylabel('L2 Error')
ax.set_title('L2 Error')
plt.rc('font', size=12)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=20)    # legend fontsize
plt.rc('figure', titlesize=20)  # fontsize of the figure title
#plt.grid()
plt.show()


plt.clf()
# Plot energy as a function of time
# (subtract energy at time t=0 to show energy drift)

plt.plot(t_verlet_rugged,E_verlet_rugged-E_verlet_rugged[0],label='rugged',color='black')
plt.plot(t_nn_1,E_nn_1-E_nn_1[0],label='$\Delta_v$',color='blue')
plt.legend(loc='upper left')
ax = plt.gca()
ax.set_xlabel('time $t$')
ax.set_ylabel('energy shift $E(t)-E(t_0)$')
#ax.grid()
plt.rc('font', size=12)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=20)    # legend fontsize
plt.rc('figure', titlesize=20)  # fontsize of the figure title

plt.show()

#subplots of position versus velocity for all 4

plt.rcParams['figure.figsize'] = [10, 10]

plt.clf()
plt.plot(x_verlet_rugged,v_verlet_rugged,label='Verlet',color='black')
plt.plot(x_nn_1,v_nn_1,label='$\Delta_v$',color='blue')
plt.legend(loc='upper left')
ax = plt.gca()
ax.set_ylabel('Velocity $v(t)$')
ax.set_xlabel('Position $q(t)$')
plt.rc('font', size=12)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=20)    # legend fontsize
plt.rc('figure', titlesize=20)  # fontsize of the figure title
plt.show()

# %%
# Plot position error as a function of time

plt.rcParams['figure.figsize'] = [10, 10]

plt.plot(t_nn_2,x_nn_2-x_verlet_rugged[int((nsteps-1)*dt_2/dt_verlet)::int(dt_2/dt_verlet)],label='$20\Delta_v$',color='orange')
plt.plot(t_nn_3,x_nn_3-x_verlet_rugged[int((nsteps-1)*dt_3/dt_verlet):int(np.size(x_verlet_rugged)-dt_3/dt_verlet):int(dt_3/dt_verlet)],label='$40\Delta_v$',color='green')
plt.plot(t_nn_4,x_nn_4-x_verlet_rugged[int((nsteps-1)*dt_4/dt_verlet):int(np.size(x_verlet_rugged)-dt_4/dt_verlet):int(dt_4/dt_verlet)],label='$100\Delta_v$',color='red')
plt.legend(loc='upper left')
ax = plt.gca()
ax.set_xlabel('time $t$')
ax.set_ylabel('position Error $x_{NN}(t)-x_V(t)$')
ax.set_title('Position Error')
plt.rc('font', size=12)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=20)    # legend fontsize
plt.rc('figure', titlesize=20)  # fontsize of the figure title
#plt.grid()
plt.show()

# Plot velocity error as a function of time

plt.plot(t_nn_2,v_nn_2-v_verlet_rugged[int((nsteps-1)*dt_2/dt_verlet)::int(dt_2/dt_verlet)],label='$20\Delta_v$',color='orange')
plt.plot(t_nn_3,v_nn_3-v_verlet_rugged[int((nsteps-1)*dt_3/dt_verlet):int(np.size(v_verlet_rugged)-dt_3/dt_verlet):int(dt_3/dt_verlet)],label='$40\Delta_v$',color='green')
plt.plot(t_nn_4,v_nn_4-v_verlet_rugged[int((nsteps-1)*dt_4/dt_verlet):int(np.size(v_verlet_rugged)-dt_4/dt_verlet):int(dt_4/dt_verlet)],label='$100\Delta_v$',color='red')
plt.legend(loc='upper left')
ax = plt.gca()
ax.set_xlabel('time $t$')
ax.set_ylabel('Velocity Error $v_{NN}(t)-v_V(t)$')
ax.set_title('Velocity Error')
plt.rc('font', size=12)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=20)    # legend fontsize
plt.rc('figure', titlesize=20)  # fontsize of the figure title
#plt.grid()
plt.show()

# Plot L2 error as a function of time

plt.plot(t_nn_2,((v_nn_2-v_verlet_rugged[int((nsteps-1)*dt_2/dt_verlet)::int(dt_2/dt_verlet)])**2+(x_nn_2-x_verlet_rugged[int((nsteps-1)*dt_2/dt_verlet)::int(dt_2/dt_verlet)])**2)**0.5,label='$20\Delta_v$',color='orange')
plt.plot(t_nn_3,((v_nn_3-v_verlet_rugged[int((nsteps-1)*dt_3/dt_verlet):int(np.size(v_verlet_rugged)-dt_3/dt_verlet):int(dt_3/dt_verlet)])**2+(x_nn_3-x_verlet_rugged[int((nsteps-1)*dt_3/dt_verlet):int(np.size(x_verlet_rugged)-dt_3/dt_verlet):int(dt_3/dt_verlet)])**2)**0.5,label='$40\Delta_v$',color='green')
plt.plot(t_nn_4,((v_nn_4-v_verlet_rugged[int((nsteps-1)*dt_4/dt_verlet):int(np.size(v_verlet_rugged)-dt_4/dt_verlet):int(dt_4/dt_verlet)])**2+(x_nn_4-x_verlet_rugged[int((nsteps-1)*dt_4/dt_verlet):int(np.size(x_verlet_rugged)-dt_4/dt_verlet):int(dt_4/dt_verlet)])**2)**0.5,label='$100\Delta_v$',color='red')
plt.legend(loc='upper left')
ax = plt.gca()
ax.set_xlabel('time $t$')
ax.set_ylabel('L2 Error')
ax.set_title('L2 Error')
plt.rc('font', size=12)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=20)    # legend fontsize
plt.rc('figure', titlesize=20)  # fontsize of the figure title
#plt.grid()
plt.show()


plt.clf()
# Plot energy as a function of time
# (subtract energy at time t=0 to show energy drift)

plt.plot(t_verlet_rugged,E_verlet_rugged-E_verlet_rugged[0],label='rugged',color='black')
plt.plot(t_nn_2,E_nn_2-E_nn_2[0],label='$20\Delta_v$',color='orange')
plt.plot(t_nn_3,E_nn_3-E_nn_3[0],label='$40\Delta_v$',color='green')
plt.plot(t_nn_4,E_nn_4-E_nn_4[0],label='$100\Delta_v$',color='red')
plt.legend(loc='upper left')
ax = plt.gca()
ax.set_xlabel('time $t$')
ax.set_ylabel('energy shift $E(t)-E(t_0)$')
#ax.grid()
plt.rc('font', size=12)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=20)    # legend fontsize
plt.rc('figure', titlesize=20)  # fontsize of the figure title

plt.show()

#subplots of position versus velocity for all 4

plt.rcParams['figure.figsize'] = [10, 10]

plt.clf()
plt.plot(x_verlet_rugged,v_verlet_rugged,label='Verlet',color='black')
plt.plot(x_nn_1,v_nn_1,label='$\Delta_v$',color='blue')
plt.plot(x_nn_2,v_nn_2,label='$20\Delta_v$',color='orange')
plt.plot(x_nn_3,v_nn_3,label='$40\Delta_v$',color='green')
plt.plot(x_nn_4,v_nn_4,label='$100\Delta_v$',color='red')
plt.legend(loc='upper left')
ax = plt.gca()
ax.set_ylabel('Velocity $v(t)$')
ax.set_xlabel('Position $q(t)$')
plt.rc('font', size=12)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=20)    # legend fontsize
plt.rc('figure', titlesize=20)  # fontsize of the figure title
plt.show()

# %% [markdown]
# ## Plot trajectories to $t=512$ generated by Verlet integrator and neural network based integrator

# %%
# Final time
T_final = 512

# Initial conditions
x = np.zeros(1)
v = np.zeros(1)
x[0] = -0.8
v[0] = -0.3
verlet_rugged.set_state(x,v)

# ==== Verlet integrator ====
t = 0.0
t_verlet_rugged = []
x_verlet_rugged = []
v_verlet_rugged = []
E_verlet_rugged = []



while t<T_final:
    t_verlet_rugged.append(t)
    E_verlet_rugged.append(verlet_rugged.energy())
    x_verlet_rugged.append(verlet_rugged.x[0])
    v_verlet_rugged.append(verlet_rugged.v[0])
    verlet_rugged.integrate(1)
    t += dt_verlet
        

# ==== Neural network integrator ====

# Initialise with Verlet integrator
x_initial_1 = np.zeros((nn_integrator_1.nsteps,nn_integrator_1.dynamical_system.dim))
v_initial_1 = np.zeros((nn_integrator_1.nsteps,nn_integrator_1.dynamical_system.dim))
x_initial_2 = np.zeros((nn_integrator_2.nsteps,nn_integrator_2.dynamical_system.dim))
v_initial_2 = np.zeros((nn_integrator_2.nsteps,nn_integrator_2.dynamical_system.dim))
x_initial_3 = np.zeros((nn_integrator_3.nsteps,nn_integrator_3.dynamical_system.dim))
v_initial_3 = np.zeros((nn_integrator_3.nsteps,nn_integrator_3.dynamical_system.dim))
x_initial_4 = np.zeros((nn_integrator_4.nsteps,nn_integrator_4.dynamical_system.dim))
v_initial_4 = np.zeros((nn_integrator_4.nsteps,nn_integrator_4.dynamical_system.dim))



verlet_rugged.set_state(x,v)
for k in range(nn_integrator_1.nsteps):    
    x_initial_1[k,:] = verlet_rugged.x[:]
    v_initial_1[k,:] = verlet_rugged.v[:]
    verlet_rugged.integrate(int(dt_1/dt_verlet))
verlet_rugged.set_state(x,v)
for k in range(nn_integrator_2.nsteps):    
    x_initial_2[k,:] = verlet_rugged.x[:]
    v_initial_2[k,:] = verlet_rugged.v[:]
    verlet_rugged.integrate(int(dt_2/dt_verlet))
verlet_rugged.set_state(x,v)
for k in range(nn_integrator_3.nsteps):    
    x_initial_3[k,:] = verlet_rugged.x[:]
    v_initial_3[k,:] = verlet_rugged.v[:]
    verlet_rugged.integrate(int(dt_3/dt_verlet))
verlet_rugged.set_state(x,v)
for k in range(nn_integrator_4.nsteps):    
    x_initial_4[k,:] = verlet_rugged.x[:]
    v_initial_4[k,:] = verlet_rugged.v[:]
    verlet_rugged.integrate(int(dt_4/dt_verlet))


nn_integrator_1.set_state(x_initial_1,v_initial_1)
t_1 = (nn_integrator_1.nsteps-1)*nn_integrator_1.dt
nn_integrator_2.set_state(x_initial_2,v_initial_2)
t_2 = (nn_integrator_2.nsteps-1)*nn_integrator_2.dt
nn_integrator_3.set_state(x_initial_3,v_initial_3)
t_3 = (nn_integrator_3.nsteps-1)*nn_integrator_3.dt
nn_integrator_4.set_state(x_initial_4,v_initial_4)
t_4 = (nn_integrator_4.nsteps-1)*nn_integrator_4.dt



# Timestepping loop
t_nn_1 = []
x_nn_1 = []
v_nn_1 = []
E_nn_1 = []
t_nn_2 = []
x_nn_2 = []
v_nn_2 = []
E_nn_2 = []
t_nn_3 = []
x_nn_3 = []
v_nn_3 = []
E_nn_3 = []
t_nn_4 = []
x_nn_4 = []
v_nn_4 = []
E_nn_4 = []


while t_1<T_final:
    t_nn_1.append(t_1)
    x_nn_1.append(nn_integrator_1.x[0])
    v_nn_1.append(nn_integrator_1.v[0])
    E_nn_1.append(nn_integrator_1.energy())
    nn_integrator_1.integrate(1)
    t_1 += dt_1
while t_2<T_final:
    t_nn_2.append(t_2)
    x_nn_2.append(nn_integrator_2.x[0])
    v_nn_2.append(nn_integrator_2.v[0])
    E_nn_2.append(nn_integrator_2.energy())
    nn_integrator_2.integrate(1)
    t_2 += dt_2
while t_3<T_final:
    t_nn_3.append(t_3)
    x_nn_3.append(nn_integrator_3.x[0])
    v_nn_3.append(nn_integrator_3.v[0])
    E_nn_3.append(nn_integrator_3.energy())
    nn_integrator_3.integrate(1)
    t_3 += dt_3
while t_4<T_final:
    t_nn_4.append(t_4)
    x_nn_4.append(nn_integrator_4.x[0])
    v_nn_4.append(nn_integrator_4.v[0])
    E_nn_4.append(nn_integrator_4.energy())
    nn_integrator_4.integrate(1)
    t_4 += dt_4 


x_nn_1 = np.array(x_nn_1)
x_nn_2 = np.array(x_nn_2)
x_nn_3 = np.array(x_nn_3)
x_nn_4 = np.array(x_nn_4)
x_verlet_rugged = np.array(x_verlet_rugged)
v_nn_1 = np.array(v_nn_1)
v_nn_2 = np.array(v_nn_2)
v_nn_3 = np.array(v_nn_3)
v_nn_4 = np.array(v_nn_4)
v_verlet_rugged = np.array(v_verlet_rugged)


# Plot position error as a function of time

plt.rcParams['figure.figsize'] = [10, 10]

plt.plot(t_nn_1,x_nn_1-x_verlet_rugged[int((nsteps-1)*dt_1/dt_verlet)::int(dt_1/dt_verlet)],label='$\Delta_v$',color='blue')
plt.legend(loc='upper left')
ax = plt.gca()
ax.set_xlabel('time $t$')
ax.set_ylabel('position Error $x_{NN}(t)-x_V(t)$')
ax.set_title('Position Error')
plt.rc('font', size=12)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=20)    # legend fontsize
plt.rc('figure', titlesize=20)  # fontsize of the figure title
#plt.grid()
plt.show()

# Plot velocity error as a function of time

plt.plot(t_nn_1,v_nn_1-v_verlet_rugged[int((nsteps-1)*dt_1/dt_verlet)::int(dt_1/dt_verlet)],label='$\Delta_v$',color='blue')
plt.legend(loc='upper left')
ax = plt.gca()
ax.set_xlabel('time $t$')
ax.set_ylabel('Velocity Error $v_{NN}(t)-v_V(t)$')
ax.set_title('Velocity Error')
plt.rc('font', size=12)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=20)    # legend fontsize
plt.rc('figure', titlesize=20)  # fontsize of the figure title
#plt.grid()
plt.show()

# Plot L2 error as a function of time

plt.plot(t_nn_1,((v_nn_1-v_verlet_rugged[int((nsteps-1)*dt_1/dt_verlet)::int(dt_1/dt_verlet)])**2+(x_nn_1-x_verlet_rugged[int((nsteps-1)*dt_1/dt_verlet)::int(dt_1/dt_verlet)])**2)**0.5,label='$\Delta_v$',color='blue')
plt.legend(loc='upper left')
ax = plt.gca()
ax.set_xlabel('time $t$')
ax.set_ylabel('L2 Error')
ax.set_title('L2 Error')
plt.rc('font', size=12)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=20)    # legend fontsize
plt.rc('figure', titlesize=20)  # fontsize of the figure title
#plt.grid()
plt.show()


plt.clf()
# Plot energy as a function of time
# (subtract energy at time t=0 to show energy drift)

plt.plot(t_verlet_rugged,E_verlet_rugged-E_verlet_rugged[0],label='rugged',color='black')
plt.plot(t_nn_1,E_nn_1-E_nn_1[0],label='$\Delta_v$',color='blue')
plt.legend(loc='upper left')
ax = plt.gca()
ax.set_xlabel('time $t$')
ax.set_ylabel('energy shift $E(t)-E(t_0)$')
#ax.grid()
plt.rc('font', size=12)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=20)    # legend fontsize
plt.rc('figure', titlesize=20)  # fontsize of the figure title

plt.show()

#subplots of position versus velocity for all 4

plt.rcParams['figure.figsize'] = [10, 10]

plt.clf()
plt.plot(x_verlet_rugged,v_verlet_rugged,label='Verlet',color='black')
plt.plot(x_nn_1,v_nn_1,label='$\Delta_v$',color='blue')
plt.legend(loc='upper left')
ax = plt.gca()
ax.set_ylabel('Velocity $v(t)$')
ax.set_xlabel('Position $q(t)$')
plt.rc('font', size=12)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=20)    # legend fontsize
plt.rc('figure', titlesize=20)  # fontsize of the figure title
plt.show()


# Plot position error as a function of time

plt.rcParams['figure.figsize'] = [10, 10]

plt.plot(t_nn_2,x_nn_2-x_verlet_rugged[int((nsteps-1)*dt_2/dt_verlet):int(np.size(x_verlet_rugged)-dt_2/dt_verlet):int(dt_2/dt_verlet)],label='$20\Delta_v$',color='orange')
plt.plot(t_nn_3,x_nn_3-x_verlet_rugged[int((nsteps-1)*dt_3/dt_verlet)::int(dt_3/dt_verlet)],label='$40\Delta_v$',color='green')
plt.plot(t_nn_4,x_nn_4-x_verlet_rugged[int((nsteps-1)*dt_4/dt_verlet):int(np.size(x_verlet_rugged)-dt_4/dt_verlet):int(dt_4/dt_verlet)],label='$100\Delta_v$',color='red')
plt.legend(loc='upper left')
ax = plt.gca()
ax.set_xlabel('time $t$')
ax.set_ylabel('position Error $x_{NN}(t)-x_V(t)$')
ax.set_title('Position Error')
plt.rc('font', size=12)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=20)    # legend fontsize
plt.rc('figure', titlesize=20)  # fontsize of the figure title
#plt.grid()
plt.show()

# Plot velocity error as a function of time

plt.plot(t_nn_2,v_nn_2-v_verlet_rugged[int((nsteps-1)*dt_2/dt_verlet):int(np.size(v_verlet_rugged)-dt_2/dt_verlet):int(dt_2/dt_verlet)],label='$20\Delta_v$',color='orange')
plt.plot(t_nn_3,v_nn_3-v_verlet_rugged[int((nsteps-1)*dt_3/dt_verlet)::int(dt_3/dt_verlet)],label='$40\Delta_v$',color='green')
plt.plot(t_nn_4,v_nn_4-v_verlet_rugged[int((nsteps-1)*dt_4/dt_verlet):int(np.size(v_verlet_rugged)-dt_4/dt_verlet):int(dt_4/dt_verlet)],label='$100\Delta_v$',color='red')
plt.legend(loc='upper left')
ax = plt.gca()
ax.set_xlabel('time $t$')
ax.set_ylabel('Velocity Error $v_{NN}(t)-v_V(t)$')
ax.set_title('Velocity Error')
plt.rc('font', size=12)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=20)    # legend fontsize
plt.rc('figure', titlesize=20)  # fontsize of the figure title
#plt.grid()
plt.show()

# Plot L2 error as a function of time

plt.plot(t_nn_2,((v_nn_2-v_verlet_rugged[int((nsteps-1)*dt_2/dt_verlet):int(np.size(v_verlet_rugged)-dt_2/dt_verlet):int(dt_2/dt_verlet)])**2+(x_nn_2-x_verlet_rugged[int((nsteps-1)*dt_2/dt_verlet):int(np.size(x_verlet_rugged)-dt_2/dt_verlet):int(dt_2/dt_verlet)])**2)**0.5,label='$20\Delta_v$',color='orange')
plt.plot(t_nn_3,((v_nn_3-v_verlet_rugged[int((nsteps-1)*dt_3/dt_verlet)::int(dt_3/dt_verlet)])**2+(x_nn_3-x_verlet_rugged[int((nsteps-1)*dt_3/dt_verlet)::int(dt_3/dt_verlet)])**2)**0.5,label='$40\Delta_v$',color='green')
plt.plot(t_nn_4,((v_nn_4-v_verlet_rugged[int((nsteps-1)*dt_4/dt_verlet):int(np.size(v_verlet_rugged)-dt_4/dt_verlet):int(dt_4/dt_verlet)])**2+(x_nn_4-x_verlet_rugged[int((nsteps-1)*dt_4/dt_verlet):int(np.size(x_verlet_rugged)-dt_4/dt_verlet):int(dt_4/dt_verlet)])**2)**0.5,label='$100\Delta_v$',color='red')
plt.legend(loc='upper left')
ax = plt.gca()
ax.set_xlabel('time $t$')
ax.set_ylabel('L2 Error')
ax.set_title('L2 Error')
plt.rc('font', size=12)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=20)    # legend fontsize
plt.rc('figure', titlesize=20)  # fontsize of the figure title
#plt.grid()
plt.show()


plt.clf()
# Plot energy as a function of time
# (subtract energy at time t=0 to show energy drift)

plt.plot(t_verlet_rugged,E_verlet_rugged-E_verlet_rugged[0],label='rugged',color='black')
plt.plot(t_nn_2,E_nn_2-E_nn_2[0],label='$20\Delta_v$',color='orange')
plt.plot(t_nn_3,E_nn_3-E_nn_3[0],label='$40\Delta_v$',color='green')
plt.plot(t_nn_4,E_nn_4-E_nn_4[0],label='$100\Delta_v$',color='red')
plt.legend(loc='upper left')
ax = plt.gca()
ax.set_xlabel('time $t$')
ax.set_ylabel('energy shift $E(t)-E(t_0)$')
#ax.grid()
plt.rc('font', size=12)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=20)    # legend fontsize
plt.rc('figure', titlesize=20)  # fontsize of the figure title

plt.show()

#subplots of position versus velocity for all 4

plt.rcParams['figure.figsize'] = [10, 10]

plt.clf()
plt.plot(x_verlet_rugged,v_verlet_rugged,label='Verlet',color='black')
plt.plot(x_nn_2,v_nn_2,label='$20\Delta_v$',color='orange')
plt.plot(x_nn_3,v_nn_3,label='$40\Delta_v$',color='green')
plt.plot(x_nn_4,v_nn_4,label='$100\Delta_v$',color='red')
plt.legend(loc='upper left')
ax = plt.gca()
ax.set_ylabel('Velocity $v(t)$')
ax.set_xlabel('Position $q(t)$')
plt.rc('font', size=12)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=20)    # legend fontsize
plt.rc('figure', titlesize=20)  # fontsize of the figure title
plt.show()
